# %% [markdown]
# ## Library

# %%
# # !pip install --upgrade
# !pip install numpy scikit-learn pandas yfinance tensorflow matplotlib
# !pip install tensorflow==2.12.0

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('KBANK.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  157.268051  188.5  191.0  188.5  189.5  6817000
# 2019-07-02 00:00:00+00:00  157.268051  188.5  189.5  188.0  188.5  3797000
# 2019-07-03 00:00:00+00:00  157.685181  189.0  189.5  188.0  188.5  3524300
# 2019-07-04 00:00:00+00:00  156.016556  187.0  190.0  187.0  189.0  7623900
# 2019-07-05 00:00:00+00:00  156.433731  187.5  188.0  187.0  187.0  2385300

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('KBank Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 31,feat_name=df.columns)
# แก้ไขจากการ drop คอลัมน์ตั้งแต่ t ถึง t-6 เป็น t ถึง t-29
reframed.drop(['High(t+1)', 'High(t+2)', 'High(t+3)', 'High(t+4)', 'High(t+5)', 'High(t+6)', 'High(t+7)', \
               'High(t+8)', 'High(t+9)', 'High(t+10)', 'High(t+11)', 'High(t+12)', 'High(t+13)', 'High(t+14)', \
               'High(t+15)', 'High(t+16)', 'High(t+17)', 'High(t+18)', 'High(t+19)', 'High(t+20)', 'High(t+21)', \
               'High(t+22)', 'High(t+23)', 'High(t+24)', 'High(t+25)', 'High(t+26)', 'High(t+27)', 'High(t+28)', 'High(t+29)','High(t+30)',\
               'Low(t+1)', 'Low(t+2)', 'Low(t+3)', 'Low(t+4)', 'Low(t+5)', 'Low(t+6)', 'Low(t+7)', \
               'Low(t+8)', 'Low(t+9)', 'Low(t+10)', 'Low(t+11)', 'Low(t+12)', 'Low(t+13)', 'Low(t+14)', \
               'Low(t+15)', 'Low(t+16)', 'Low(t+17)', 'Low(t+18)', 'Low(t+19)', 'Low(t+20)', 'Low(t+21)', \
               'Low(t+22)', 'Low(t+23)', 'Low(t+24)', 'Low(t+25)', 'Low(t+26)', 'Low(t+27)', 'Low(t+28)', 'Low(t+29)','Low(t+30)',\
               'Open(t+1)', 'Open(t+2)', 'Open(t+3)', 'Open(t+4)', 'Open(t+5)', 'Open(t+6)', 'Open(t+7)', 
               'Open(t+8)', 'Open(t+9)', 'Open(t+10)', 'Open(t+11)', 'Open(t+12)', 'Open(t+13)', 'Open(t+14)', \
               'Open(t+15)', 'Open(t+16)', 'Open(t+17)', 'Open(t+18)', 'Open(t+19)', 'Open(t+20)', 'Open(t+21)', \
               'Open(t+22)', 'Open(t+23)', 'Open(t+24)', 'Open(t+25)', 'Open(t+26)', 'Open(t+27)', 'Open(t+28)', 'Open(t+29)','Open(t+30)',\
               'Volume(t+1)', 'Volume(t+2)', 'Volume(t+3)', 'Volume(t+4)', 'Volume(t+5)', 'Volume(t+6)', 'Volume(t+7)', \
               'Volume(t+8)', 'Volume(t+9)', 'Volume(t+10)', 'Volume(t+11)', 'Volume(t+12)', 'Volume(t+13)', 'Volume(t+14)', \
               'Volume(t+15)', 'Volume(t+16)', 'Volume(t+17)', 'Volume(t+18)', 'Volume(t+19)', 'Volume(t+20)', 'Volume(t+21)', \
               'Volume(t+22)', 'Volume(t+23)', 'Volume(t+24)', 'Volume(t+25)', 'Volume(t+26)', 'Volume(t+27)', 'Volume(t+28)', 'Volume(t+29)','Volume(t+30)'], axis=1, inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.995641    1.000000   1.000000    1.000000      0.039494
# 16         0.995641    0.987288   0.995781    0.991507      0.021998
# 17         1.000000    0.987288   0.995781    0.991507      0.020418
# 18         0.982562    0.991525   0.987342    0.995754      0.044169
# 19         0.986922    0.974576   0.987342    0.978769      0.013819
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.995641    0.987288   0.995781    0.991507      0.021998  ...
# 16         1.000000    0.987288   0.995781    0.991507      0.020418  ...
# 17         0.982562    0.991525   0.987342    0.995754      0.044169  ...
# 18         0.986922    0.974576   0.987342    0.978769      0.013819  ...
# 19         0.982562    0.974576   0.978903    0.978769      0.025213  ...
#
#     Adj Close(t+21)  Adj Close(t+22)  Adj Close(t+23)  Adj Close(t+24)  \
# 15         0.742789         0.720991         0.694834         0.707913
# 16         0.720991         0.694834         0.707913         0.729710
# 17         0.694834         0.707913         0.729710         0.747148
# 18         0.707913         0.729710         0.747148         0.747148
# 19         0.729710         0.747148         0.747148         0.716632
#
#     Adj Close(t+25)  Adj Close(t+26)  Adj Close(t+27)  Adj Close(t+28)  \
# 15         0.729710         0.747148         0.747148         0.716632
# 16         0.747148         0.747148         0.716632         0.712272
# 17         0.747148         0.716632         0.712272         0.738429
# 18         0.716632         0.712272         0.738429         0.734070
# 19         0.712272         0.738429         0.734070         0.751508
#
#     Adj Close(t+29)  Adj Close(t+30)
# 15         0.712272         0.738429
# 16         0.738429         0.734070
# 17         0.734070         0.751508
# 18         0.751508         0.795103
# 19         0.795103         0.830085
#
# [5 rows x 110 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-30], train[:, -30:]
val_X, val_y = val[:, :-30], val[:, -30:]
test_X, test_y = test[:, :-30], test[:, -30:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (816, 1, 80)
# (816, 30)
# (175, 1, 80)
# (175, 30)
# (175, 1, 80)
# (175, 30)

# %% [markdown]
# ## Create Model & Evaluate (ยังไม่ Hyperparameter tuning)

# %%
model = Sequential()

# LSTM 2 layer with ReLU activation
model.add(LSTM(units=70,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)))
model.add(Dropout(0.1))
model.add(LSTM(units=70,activation='relu'))
model.add(Dropout(0.1))

# Output layer for 1 targets
model.add(Dense(1))

# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 1, 70)             42280
#
#  dropout (Dropout)           (None, 1, 70)             0
#
#  lstm_1 (LSTM)               (None, 70)                39480
#
#  dropout_1 (Dropout)         (None, 70)                0
#
#  dense (Dense)               (None, 1)                 71
#
# =================================================================
# Total params: 81,831
# Trainable params: 81,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 3s 38ms/step - loss: 0.3486 - root_mean_squared_error: 0.4839 - val_loss: 0.2086 - val_root_mean_squared_error: 0.3249
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1545 - root_mean_squared_error: 0.2431 - val_loss: 0.0956 - val_root_mean_squared_error: 0.0994
# Epoch 3/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1169 - root_mean_squared_error: 0.1961 - val_loss: 0.0974 - val_root_mean_squared_error: 0.1634
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0972 - root_mean_squared_error: 0.1781 - val_loss: 0.0679 - val_root_mean_squared_error: 0.0912
# Epoch 5/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0864 - root_mean_squared_error: 0.1765 - val_loss: 0.0616 - val_root_mean_squared_error: 0.1056
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0758 - root_mean_squared_error: 0.1693 - val_loss: 0.0545 - val_root_mean_squared_error: 0.1052
# Epoch 7/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0682 - root_mean_squared_error: 0.1654 - val_loss: 0.0439 - val_root_mean_squared_error: 0.0770
# Epoch 8/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0628 - root_mean_squared_error: 0.1641 - val_loss: 0.0399 - val_root_mean_squared_error: 0.0796
# Epoch 9/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0578 - root_mean_squared_error: 0.1612 - val_loss: 0.0372 - val_root_mean_squared_error: 0.0854
# Epoch 10/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0534 - root_mean_squared_error: 0.1577 - val_loss: 0.0337 - val_root_mean_squared_error: 0.0818
# Epoch 11/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0512 - root_mean_squared_error: 0.1595 - val_loss: 0.0303 - val_root_mean_squared_error: 0.0766
# Epoch 12/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0482 - root_mean_squared_error: 0.1573 - val_loss: 0.0275 - val_root_mean_squared_error: 0.0717
# Epoch 13/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0457 - root_mean_squared_error: 0.1557 - val_loss: 0.0257 - val_root_mean_squared_error: 0.0719
# Epoch 14/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0435 - root_mean_squared_error: 0.1538 - val_loss: 0.0234 - val_root_mean_squared_error: 0.0663
# Epoch 15/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0423 - root_mean_squared_error: 0.1547 - val_loss: 0.0237 - val_root_mean_squared_error: 0.0777
# Epoch 16/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0397 - root_mean_squared_error: 0.1504 - val_loss: 0.0218 - val_root_mean_squared_error: 0.0731
# Epoch 17/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0388 - root_mean_squared_error: 0.1513 - val_loss: 0.0196 - val_root_mean_squared_error: 0.0656
# Epoch 18/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0372 - root_mean_squared_error: 0.1494 - val_loss: 0.0190 - val_root_mean_squared_error: 0.0680
# Epoch 19/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0360 - root_mean_squared_error: 0.1484 - val_loss: 0.0188 - val_root_mean_squared_error: 0.0731
# Epoch 20/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0360 - root_mean_squared_error: 0.1513 - val_loss: 0.0212 - val_root_mean_squared_error: 0.0929
# Epoch 21/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0343 - root_mean_squared_error: 0.1484 - val_loss: 0.0159 - val_root_mean_squared_error: 0.0630
# Epoch 22/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0336 - root_mean_squared_error: 0.1485 - val_loss: 0.0152 - val_root_mean_squared_error: 0.0630
# Epoch 23/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0333 - root_mean_squared_error: 0.1495 - val_loss: 0.0155 - val_root_mean_squared_error: 0.0702
# Epoch 24/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0325 - root_mean_squared_error: 0.1490 - val_loss: 0.0145 - val_root_mean_squared_error: 0.0668
# Epoch 25/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0305 - root_mean_squared_error: 0.1438 - val_loss: 0.0133 - val_root_mean_squared_error: 0.0616
# Epoch 26/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0294 - root_mean_squared_error: 0.1420 - val_loss: 0.0136 - val_root_mean_squared_error: 0.0673
# Epoch 27/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0295 - root_mean_squared_error: 0.1440 - val_loss: 0.0125 - val_root_mean_squared_error: 0.0625
# Epoch 28/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0293 - root_mean_squared_error: 0.1448 - val_loss: 0.0138 - val_root_mean_squared_error: 0.0759
# Epoch 29/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0286 - root_mean_squared_error: 0.1438 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0599
# Epoch 30/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0282 - root_mean_squared_error: 0.1435 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0644
# Epoch 31/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0275 - root_mean_squared_error: 0.1422 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0676
# Epoch 32/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0278 - root_mean_squared_error: 0.1446 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0590
# Epoch 33/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0272 - root_mean_squared_error: 0.1435 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0656
# Epoch 34/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0256 - root_mean_squared_error: 0.1388 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0600
# Epoch 35/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0257 - root_mean_squared_error: 0.1399 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0616
# Epoch 36/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0252 - root_mean_squared_error: 0.1391 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0609
# Epoch 37/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0249 - root_mean_squared_error: 0.1388 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0676
# Epoch 38/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0243 - root_mean_squared_error: 0.1375 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0595
# Epoch 39/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0247 - root_mean_squared_error: 0.1398 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0593
# Epoch 40/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0247 - root_mean_squared_error: 0.1407 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0645
# Epoch 41/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0235 - root_mean_squared_error: 0.1368 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0621
# Epoch 42/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0236 - root_mean_squared_error: 0.1378 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0680
# Epoch 43/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0230 - root_mean_squared_error: 0.1361 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0579
# Epoch 44/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0233 - root_mean_squared_error: 0.1380 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0575
# Epoch 45/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0221 - root_mean_squared_error: 0.1339 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0580
# Epoch 46/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0226 - root_mean_squared_error: 0.1364 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0625
# Epoch 47/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0216 - root_mean_squared_error: 0.1329 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0866
# Epoch 48/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0220 - root_mean_squared_error: 0.1351 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0648
# Epoch 49/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0233 - root_mean_squared_error: 0.1402 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0577
# Epoch 50/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0228 - root_mean_squared_error: 0.1387 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0931
# Epoch 51/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0226 - root_mean_squared_error: 0.1383 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0564
# Epoch 52/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0209 - root_mean_squared_error: 0.1326 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0827
# Epoch 53/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0212 - root_mean_squared_error: 0.1340 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0561
# Epoch 54/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0216 - root_mean_squared_error: 0.1356 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0735
# Epoch 55/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0207 - root_mean_squared_error: 0.1327 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0781
# Epoch 56/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0204 - root_mean_squared_error: 0.1316 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0585
# Epoch 57/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0205 - root_mean_squared_error: 0.1325 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0922
# Epoch 58/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0214 - root_mean_squared_error: 0.1361 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0699

# %%
# คำนวณ predicted values
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# # Reshape residuals for GRU input (samples, timesteps, features)
# resid_train = resid_train.reshape((resid_train.shape[0], 1, resid_train.shape[1]))
# resid_val = resid_val.reshape((resid_val.shape[0], 1, resid_val.shape[1]))
# resid_test = resid_test.reshape((resid_test.shape[0], 1, resid_test.shape[1]))

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (816, 1, 80)
# (816, 1)
# (175, 1, 80)
# (175, 1)
# (175, 1, 80)
# (175, 1)

# %%
# GRU model for predicting residuals
res_model = Sequential()
res_model.add(GRU(units=50, activation='relu', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)))
res_model.add(Dropout(0.1))
res_model.add(GRU(units=50, activation='relu'))
res_model.add(Dropout(0.1))
res_model.add(Dense(1))

# Compile the GRU model
optimizer = Adam(learning_rate=0.001)
res_model.compile(optimizer=optimizer, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
# Train the GRU model
history_gru = res_model.fit(train_X_resid, train_y_resid, epochs=100, batch_size=64, validation_data=(val_X_resid, val_y_resid), 
                            callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 3s 35ms/step - loss: 0.1095 - root_mean_squared_error: 0.1285 - val_loss: 0.0863 - val_root_mean_squared_error: 0.0654
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0894 - root_mean_squared_error: 0.1249 - val_loss: 0.0694 - val_root_mean_squared_error: 0.0694
# Epoch 3/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0737 - root_mean_squared_error: 0.1254 - val_loss: 0.0541 - val_root_mean_squared_error: 0.0604
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0606 - root_mean_squared_error: 0.1241 - val_loss: 0.0441 - val_root_mean_squared_error: 0.0701
# Epoch 5/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0503 - root_mean_squared_error: 0.1237 - val_loss: 0.0353 - val_root_mean_squared_error: 0.0704
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0422 - root_mean_squared_error: 0.1232 - val_loss: 0.0274 - val_root_mean_squared_error: 0.0631
# Epoch 7/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0363 - root_mean_squared_error: 0.1240 - val_loss: 0.0218 - val_root_mean_squared_error: 0.0608
# Epoch 8/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0315 - root_mean_squared_error: 0.1238 - val_loss: 0.0183 - val_root_mean_squared_error: 0.0661
# Epoch 9/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0275 - root_mean_squared_error: 0.1225 - val_loss: 0.0148 - val_root_mean_squared_error: 0.0633
# Epoch 10/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0248 - root_mean_squared_error: 0.1231 - val_loss: 0.0130 - val_root_mean_squared_error: 0.0679
# Epoch 11/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0225 - root_mean_squared_error: 0.1225 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0683
# Epoch 12/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0209 - root_mean_squared_error: 0.1225 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0765
# Epoch 13/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0200 - root_mean_squared_error: 0.1242 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0665
# Epoch 14/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0187 - root_mean_squared_error: 0.1225 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0652
# Epoch 15/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0178 - root_mean_squared_error: 0.1218 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0665
# Epoch 16/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0172 - root_mean_squared_error: 0.1217 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0679
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0168 - root_mean_squared_error: 0.1215 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0633
# Epoch 18/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0163 - root_mean_squared_error: 0.1209 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0716
# Epoch 19/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0160 - root_mean_squared_error: 0.1208 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0697
# Epoch 20/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0160 - root_mean_squared_error: 0.1214 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0608
# Epoch 21/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0157 - root_mean_squared_error: 0.1207 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0779
# Epoch 22/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0156 - root_mean_squared_error: 0.1209 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0672
# Epoch 23/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0153 - root_mean_squared_error: 0.1200 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0708
# Epoch 24/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0153 - root_mean_squared_error: 0.1205 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0687
# Epoch 25/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0152 - root_mean_squared_error: 0.1201 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0755

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_gru.history['loss'], label='train_loss')
plt.plot(history_gru.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0094 - root_mean_squared_error: 0.0788
# Test Loss: 0.009411069564521313
# Test RMSE: 0.0788295716047287

# %%
# คำนวณ predicted residuals
yhat_train_resid = res_model.predict(train_X_resid)
yhat_val_resid = res_model.predict(val_X_resid)
yhat_test_resid = res_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('KBANK_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 4.5355%
# RMSE: 7.0453

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_lstm_model(lstm_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_3896100/252092345.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-19 16:58:06.435280: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.443842: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.642609: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.687762: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.702794: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.718441: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.719315: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.764499: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.770359: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.775543: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.839813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.875361: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.875442: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.945360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:06.988203: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.001097: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.001555: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.026679: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.029901: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.035996: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.064062: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.065603: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.134785: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.144483: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.153210: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.167144: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.194818: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.258199: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.272931: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.296561: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.352237: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:58:07.391638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:15:41.492073: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:15:41.512917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:15:41.525155: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 17:15:42.528674: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:15:42.531372: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:15:42.533562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 17:15:44.167213: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:15:44.169530: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:15:44.171312: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 17:15:47.672960: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:15:47.675339: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:15:47.677230: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 1831.790428161621 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 70, 'beta_1': 0.8, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.11532853448370149

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
lstm_model = create_lstm_model(lstm_units_1=70,beta_1=0.8, LR=0.003, L2=0.001)
lstm_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 70)                42280
#
#  dropout_5 (Dropout)         (None, 70)                0
#
#  dense_5 (Dense)             (None, 30)                2130
#
# =================================================================
# Total params: 44,410
# Trainable params: 44,410
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-19 17:18:38.297712: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:18:38.299599: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:18:38.300883: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = lstm_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-19 17:18:46.568576: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:18:46.581487: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:18:46.596362: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 17:18:47.608179: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:18:47.610615: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:18:47.612574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 11/13 [========================>.....] - ETA: 0s - loss: 0.2708 - root_mean_squared_error: 0.4057
# 2024-12-19 17:18:49.538873: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:18:49.540979: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:18:49.542433: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 4s 68ms/step - loss: 0.2494 - root_mean_squared_error: 0.3823 - val_loss: 0.0886 - val_root_mean_squared_error: 0.0906
# Epoch 2/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0904 - root_mean_squared_error: 0.1614 - val_loss: 0.0525 - val_root_mean_squared_error: 0.0670
# Epoch 3/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0614 - root_mean_squared_error: 0.1496 - val_loss: 0.0351 - val_root_mean_squared_error: 0.0706
# Epoch 4/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0451 - root_mean_squared_error: 0.1410 - val_loss: 0.0244 - val_root_mean_squared_error: 0.0628
# Epoch 5/150
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0362 - root_mean_squared_error: 0.1367 - val_loss: 0.0210 - val_root_mean_squared_error: 0.0808
# Epoch 6/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0309 - root_mean_squared_error: 0.1347 - val_loss: 0.0180 - val_root_mean_squared_error: 0.0846
# Epoch 7/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0269 - root_mean_squared_error: 0.1307 - val_loss: 0.0121 - val_root_mean_squared_error: 0.0577
# Epoch 8/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0243 - root_mean_squared_error: 0.1285 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0655
# Epoch 9/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0218 - root_mean_squared_error: 0.1242 - val_loss: 0.0134 - val_root_mean_squared_error: 0.0879
# Epoch 10/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0209 - root_mean_squared_error: 0.1249 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0588
# Epoch 11/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0198 - root_mean_squared_error: 0.1232 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0664
# Epoch 12/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0190 - root_mean_squared_error: 0.1222 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0551
# Epoch 13/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0177 - root_mean_squared_error: 0.1190 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0676
# Epoch 14/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0172 - root_mean_squared_error: 0.1182 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0604
# Epoch 15/150
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0175 - root_mean_squared_error: 0.1202 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0678
# Epoch 16/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0161 - root_mean_squared_error: 0.1159 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0834
# Epoch 17/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0164 - root_mean_squared_error: 0.1178 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0566
# Epoch 18/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0166 - root_mean_squared_error: 0.1195 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0825
# Epoch 19/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0174 - root_mean_squared_error: 0.1233 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0589
# Epoch 20/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0157 - root_mean_squared_error: 0.1165 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0540
# Epoch 21/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0157 - root_mean_squared_error: 0.1166 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0657
# Epoch 22/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0165 - root_mean_squared_error: 0.1207 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0563
# Epoch 23/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0151 - root_mean_squared_error: 0.1149 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0540
# Epoch 24/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0153 - root_mean_squared_error: 0.1158 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0690
# Epoch 25/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0152 - root_mean_squared_error: 0.1155 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0658
# Epoch 26/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0158 - root_mean_squared_error: 0.1184 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0609
# Epoch 27/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0147 - root_mean_squared_error: 0.1133 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0795
# Epoch 28/150
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0157 - root_mean_squared_error: 0.1178 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0537
# Epoch 29/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0141 - root_mean_squared_error: 0.1113 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0539
# Epoch 30/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0142 - root_mean_squared_error: 0.1115 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0554
# Epoch 31/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0142 - root_mean_squared_error: 0.1119 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0784
# Epoch 32/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0146 - root_mean_squared_error: 0.1140 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0540
# Epoch 33/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0144 - root_mean_squared_error: 0.1131 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0751
# Epoch 34/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0138 - root_mean_squared_error: 0.1102 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0548
# Epoch 35/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0155 - root_mean_squared_error: 0.1176 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0804
# Epoch 36/150
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0142 - root_mean_squared_error: 0.1124 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0532
# Epoch 37/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0135 - root_mean_squared_error: 0.1092 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0695
# Epoch 38/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0140 - root_mean_squared_error: 0.1116 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0563
# Epoch 39/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0139 - root_mean_squared_error: 0.1110 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0773
# Epoch 40/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0138 - root_mean_squared_error: 0.1109 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0610
# Epoch 41/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0142 - root_mean_squared_error: 0.1126 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0874

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = lstm_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0055 - root_mean_squared_error: 0.0626
# Test Loss: 0.005498852115124464
# Test RMSE: 0.06261724978685379

# %%
# คำนวณ predicted values
yhat_train = lstm_model.predict(train_X)
yhat_val = lstm_model.predict(val_X)
yhat_test = lstm_model.predict(test_X)
# Out:
# 2024-12-19 17:19:06.780800: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:19:06.782766: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:19:06.784310: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 2ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (816, 1, 80)
# (816, 30)
# (175, 1, 80)
# (175, 30)
# (175, 1, 80)
# (175, 30)

# %%
def create_gru_model(gru_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_3896100/1859486926.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-19 17:20:42.335983: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:20:42.338051: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:20:42.339338: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 17:20:42.775481: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:20:42.778097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:20:42.780214: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 17:20:43.783049: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:20:43.785510: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:20:43.787176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 17:20:45.447549: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:20:45.450254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:20:45.452101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 76.29770565032959 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 1, 'beta_1': 0.7, 'LR': 0.082, 'L2': 0.001}
# Best RMSE Score: 0.09673526077719019

# %%
gru_model = create_gru_model(gru_units_1=1 ,beta_1=0.7 , LR=0.082, L2=0.001)
gru_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 1)                 249
#
#  dropout_7 (Dropout)         (None, 1)                 0
#
#  dense_7 (Dense)             (None, 30)                60
#
# =================================================================
# Total params: 309
# Trainable params: 309
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-19 17:21:29.722773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:21:29.724520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:21:29.725713: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = gru_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-19 17:21:34.022277: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:21:34.024497: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:21:34.026101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 17:21:34.993715: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:21:34.995867: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:21:34.997473: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 29s - loss: 0.0172 - root_mean_squared_error: 0.1057
# 2024-12-19 17:21:36.619868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:21:36.622221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:21:36.623959: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 52ms/step - loss: 0.0136 - root_mean_squared_error: 0.1081 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0556
# Epoch 2/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0129 - root_mean_squared_error: 0.1089 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0540
# Epoch 3/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0110 - root_mean_squared_error: 0.1048 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0541
# Epoch 4/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0535
# Epoch 5/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0541
# Epoch 6/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0546
# Epoch 7/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0109 - root_mean_squared_error: 0.1043 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0581
# Epoch 8/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0110 - root_mean_squared_error: 0.1046 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0571
# Epoch 9/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0112 - root_mean_squared_error: 0.1056 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0538

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0040 - root_mean_squared_error: 0.0633
# Test Loss: 0.004013068042695522
# Test RMSE: 0.06333697587251663

# %%
# คำนวณ predicted residuals
yhat_train_resid = gru_model.predict(train_X_resid)
yhat_val_resid = gru_model.predict(val_X_resid)
yhat_test_resid = gru_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-19 17:22:16.182076: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:22:16.184039: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:22:16.185470: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('KBANK_Adj_close_prediction By cascaded')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.6579%
# RMSE: 6.0606
