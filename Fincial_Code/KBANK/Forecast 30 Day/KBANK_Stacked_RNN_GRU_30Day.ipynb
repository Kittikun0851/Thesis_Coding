# %% [markdown]
# ## Library

# %%
# !pip install tensorflow==2.12.0

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# Out:
# 2024-12-18 16:49:42.606961: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-18 16:49:42.618770: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-18 16:49:42.676190: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-18 16:49:42.677273: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 16:50:31.648179: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('KBANK.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  157.268021  188.5  191.0  188.5  189.5  6817000
# 2019-07-02 00:00:00+00:00  157.268021  188.5  189.5  188.0  188.5  3797000
# 2019-07-03 00:00:00+00:00  157.685196  189.0  189.5  188.0  188.5  3524300
# 2019-07-04 00:00:00+00:00  156.016556  187.0  190.0  187.0  189.0  7623900
# 2019-07-05 00:00:00+00:00  156.433716  187.5  188.0  187.0  187.0  2385300

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('KBANK Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 31,feat_name=df.columns)
# แก้ไขจากการ drop คอลัมน์ตั้งแต่ t ถึง t-6 เป็น t ถึง t-29
reframed.drop(['High(t+1)', 'High(t+2)', 'High(t+3)', 'High(t+4)', 'High(t+5)', 'High(t+6)', 'High(t+7)', \
               'High(t+8)', 'High(t+9)', 'High(t+10)', 'High(t+11)', 'High(t+12)', 'High(t+13)', 'High(t+14)', \
               'High(t+15)', 'High(t+16)', 'High(t+17)', 'High(t+18)', 'High(t+19)', 'High(t+20)', 'High(t+21)', \
               'High(t+22)', 'High(t+23)', 'High(t+24)', 'High(t+25)', 'High(t+26)', 'High(t+27)', 'High(t+28)', 'High(t+29)','High(t+30)',\
               'Low(t+1)', 'Low(t+2)', 'Low(t+3)', 'Low(t+4)', 'Low(t+5)', 'Low(t+6)', 'Low(t+7)', \
               'Low(t+8)', 'Low(t+9)', 'Low(t+10)', 'Low(t+11)', 'Low(t+12)', 'Low(t+13)', 'Low(t+14)', \
               'Low(t+15)', 'Low(t+16)', 'Low(t+17)', 'Low(t+18)', 'Low(t+19)', 'Low(t+20)', 'Low(t+21)', \
               'Low(t+22)', 'Low(t+23)', 'Low(t+24)', 'Low(t+25)', 'Low(t+26)', 'Low(t+27)', 'Low(t+28)', 'Low(t+29)','Low(t+30)',\
               'Open(t+1)', 'Open(t+2)', 'Open(t+3)', 'Open(t+4)', 'Open(t+5)', 'Open(t+6)', 'Open(t+7)', 
               'Open(t+8)', 'Open(t+9)', 'Open(t+10)', 'Open(t+11)', 'Open(t+12)', 'Open(t+13)', 'Open(t+14)', \
               'Open(t+15)', 'Open(t+16)', 'Open(t+17)', 'Open(t+18)', 'Open(t+19)', 'Open(t+20)', 'Open(t+21)', \
               'Open(t+22)', 'Open(t+23)', 'Open(t+24)', 'Open(t+25)', 'Open(t+26)', 'Open(t+27)', 'Open(t+28)', 'Open(t+29)','Open(t+30)',\
               'Volume(t+1)', 'Volume(t+2)', 'Volume(t+3)', 'Volume(t+4)', 'Volume(t+5)', 'Volume(t+6)', 'Volume(t+7)', \
               'Volume(t+8)', 'Volume(t+9)', 'Volume(t+10)', 'Volume(t+11)', 'Volume(t+12)', 'Volume(t+13)', 'Volume(t+14)', \
               'Volume(t+15)', 'Volume(t+16)', 'Volume(t+17)', 'Volume(t+18)', 'Volume(t+19)', 'Volume(t+20)', 'Volume(t+21)', \
               'Volume(t+22)', 'Volume(t+23)', 'Volume(t+24)', 'Volume(t+25)', 'Volume(t+26)', 'Volume(t+27)', 'Volume(t+28)', 'Volume(t+29)','Volume(t+30)'], axis=1, inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.995640    1.000000   1.000000    1.000000      0.039494
# 16         0.995640    0.987288   0.995781    0.991507      0.021998
# 17         1.000000    0.987288   0.995781    0.991507      0.020418
# 18         0.982562    0.991525   0.987342    0.995754      0.044169
# 19         0.986921    0.974576   0.987342    0.978769      0.013819
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.995640    0.987288   0.995781    0.991507      0.021998  ...
# 16         1.000000    0.987288   0.995781    0.991507      0.020418  ...
# 17         0.982562    0.991525   0.987342    0.995754      0.044169  ...
# 18         0.986921    0.974576   0.987342    0.978769      0.013819  ...
# 19         0.982562    0.974576   0.978903    0.978769      0.025213  ...
#
#     Adj Close(t+21)  Adj Close(t+22)  Adj Close(t+23)  Adj Close(t+24)  \
# 15         0.742789         0.720991         0.694834         0.707913
# 16         0.720991         0.694834         0.707913         0.729710
# 17         0.694834         0.707913         0.729710         0.747148
# 18         0.707913         0.729710         0.747148         0.747148
# 19         0.729710         0.747148         0.747148         0.716632
#
#     Adj Close(t+25)  Adj Close(t+26)  Adj Close(t+27)  Adj Close(t+28)  \
# 15         0.729710         0.747148         0.747148         0.716632
# 16         0.747148         0.747148         0.716632         0.712272
# 17         0.747148         0.716632         0.712272         0.738429
# 18         0.716632         0.712272         0.738429         0.734070
# 19         0.712272         0.738429         0.734070         0.751508
#
#     Adj Close(t+29)  Adj Close(t+30)
# 15         0.712272         0.738429
# 16         0.738429         0.734070
# 17         0.734070         0.751508
# 18         0.751508         0.795103
# 19         0.795103         0.830085
#
# [5 rows x 110 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-30], train[:, -30:]
val_X, val_y = val[:, :-30], val[:, -30:]
test_X, test_y = test[:, :-30], test[:, -30:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (816, 1, 80)
# (816, 30)
# (175, 1, 80)
# (175, 30)
# (175, 1, 80)
# (175, 30)

# %% [markdown]
# ## Create Model & Evaluate (ยังไม่ Hyperparameter tuning)

# %%
model = Sequential()

# SimpleRNN layer with ReLU activation
model.add(SimpleRNN(units=94,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.005)))
model.add(Dropout(0.1))
# GRU layer with ReLU activation
model.add(GRU(units=73,activation='relu'))
model.add(Dropout(0.1))
# Output layer for 1 targets
model.add(Dense(1,activation='sigmoid'))
# model.add(Dense(1))
# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Compile the model
# model.compile(optimizer='adam', loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 1, 94)             16450
#
#  dropout_6 (Dropout)         (None, 1, 94)             0
#
#  gru_3 (GRU)                 (None, 73)                37011
#
#  dropout_7 (Dropout)         (None, 73)                0
#
#  dense_3 (Dense)             (None, 1)                 74
#
# =================================================================
# Total params: 53,535
# Trainable params: 53,535
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 4s 58ms/step - loss: 0.4438 - root_mean_squared_error: 0.1981 - val_loss: 0.4875 - val_root_mean_squared_error: 0.3572
# Epoch 2/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.3601 - root_mean_squared_error: 0.1833 - val_loss: 0.3835 - val_root_mean_squared_error: 0.3083
# Epoch 3/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.2895 - root_mean_squared_error: 0.1692 - val_loss: 0.3142 - val_root_mean_squared_error: 0.2905
# Epoch 4/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.2295 - root_mean_squared_error: 0.1484 - val_loss: 0.2446 - val_root_mean_squared_error: 0.2497
# Epoch 5/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1792 - root_mean_squared_error: 0.1218 - val_loss: 0.1827 - val_root_mean_squared_error: 0.1959
# Epoch 6/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1380 - root_mean_squared_error: 0.0895 - val_loss: 0.1325 - val_root_mean_squared_error: 0.1364
# Epoch 7/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.1073 - root_mean_squared_error: 0.0702 - val_loss: 0.1008 - val_root_mean_squared_error: 0.1066
# Epoch 8/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0846 - root_mean_squared_error: 0.0658 - val_loss: 0.0827 - val_root_mean_squared_error: 0.1128
# Epoch 9/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0667 - root_mean_squared_error: 0.0635 - val_loss: 0.0712 - val_root_mean_squared_error: 0.1293
# Epoch 10/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0527 - root_mean_squared_error: 0.0633 - val_loss: 0.0575 - val_root_mean_squared_error: 0.1235
# Epoch 11/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0416 - root_mean_squared_error: 0.0623 - val_loss: 0.0483 - val_root_mean_squared_error: 0.1250
# Epoch 12/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0330 - root_mean_squared_error: 0.0619 - val_loss: 0.0404 - val_root_mean_squared_error: 0.1235
# Epoch 13/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0262 - root_mean_squared_error: 0.0617 - val_loss: 0.0348 - val_root_mean_squared_error: 0.1246
# Epoch 14/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0210 - root_mean_squared_error: 0.0620 - val_loss: 0.0308 - val_root_mean_squared_error: 0.1267
# Epoch 15/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0170 - root_mean_squared_error: 0.0621 - val_loss: 0.0262 - val_root_mean_squared_error: 0.1219
# Epoch 16/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0139 - root_mean_squared_error: 0.0619 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1268
# Epoch 17/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0114 - root_mean_squared_error: 0.0609 - val_loss: 0.0234 - val_root_mean_squared_error: 0.1294
# Epoch 18/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0097 - root_mean_squared_error: 0.0614 - val_loss: 0.0223 - val_root_mean_squared_error: 0.1310
# Epoch 19/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0086 - root_mean_squared_error: 0.0630 - val_loss: 0.0220 - val_root_mean_squared_error: 0.1341
# Epoch 20/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0074 - root_mean_squared_error: 0.0617 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1252
# Epoch 21/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0066 - root_mean_squared_error: 0.0618 - val_loss: 0.0203 - val_root_mean_squared_error: 0.1337
# Epoch 22/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0060 - root_mean_squared_error: 0.0611 - val_loss: 0.0179 - val_root_mean_squared_error: 0.1262
# Epoch 23/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0055 - root_mean_squared_error: 0.0609 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1269
# Epoch 24/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0053 - root_mean_squared_error: 0.0617 - val_loss: 0.0180 - val_root_mean_squared_error: 0.1289
# Epoch 25/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0049 - root_mean_squared_error: 0.0600 - val_loss: 0.0175 - val_root_mean_squared_error: 0.1278
# Epoch 26/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0050 - root_mean_squared_error: 0.0626 - val_loss: 0.0167 - val_root_mean_squared_error: 0.1251
# Epoch 27/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0048 - root_mean_squared_error: 0.0623 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1241
# Epoch 28/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0046 - root_mean_squared_error: 0.0611 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1227
# Epoch 29/100
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0045 - root_mean_squared_error: 0.0607 - val_loss: 0.0174 - val_root_mean_squared_error: 0.1290
# Epoch 30/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0047 - root_mean_squared_error: 0.0632 - val_loss: 0.0188 - val_root_mean_squared_error: 0.1345
# Epoch 31/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0045 - root_mean_squared_error: 0.0613 - val_loss: 0.0152 - val_root_mean_squared_error: 0.1204
# Epoch 32/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0056 - root_mean_squared_error: 0.0699 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1237
# Epoch 33/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0051 - root_mean_squared_error: 0.0665 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1285
# Epoch 34/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0045 - root_mean_squared_error: 0.0616 - val_loss: 0.0155 - val_root_mean_squared_error: 0.1217
# Epoch 35/100
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0043 - root_mean_squared_error: 0.0600 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1233
# Epoch 36/100
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0044 - root_mean_squared_error: 0.0609 - val_loss: 0.0170 - val_root_mean_squared_error: 0.1277

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0871 - root_mean_squared_error: 0.2940
# Test Loss: 0.08712978661060333
# Test RMSE: 0.2939835786819458

# %%
# # ทำ prediction
# yhat = model.predict(test_X)
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# # rescale ข้อมูลกลับ

# # Standardized -> actual
# # inv_yhat = (yhat * std_dict['Adj Close']) + mean_dict['Adj Close']
# # inv_y = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# # # Min-Max Normalized -> actual
# inv_yhat = yhat*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']
# inv_y = test_y*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']

# %%
# ทำ prediction
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='KBANK_predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='KBANK_predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='KBANK_predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('KBANK_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')

# %% [markdown]
# ## Hyperparameter Tuning

# %%
def create_model(rnn_units,gru_units,LR,L2,beta_1):
    model = Sequential()
    model.add(SimpleRNN(gru_units,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(GRU(rnn_units,activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune
param_dist = {
    'gru_units': list(range(1, 101)),
    'rnn_units': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)

import time

start_time = time.time()


# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
random_search_result = random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_340480/1331494904.py:22: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-18 17:21:31.013375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.112491: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.145229: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.194890: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.301658: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.338438: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.375942: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.393905: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.434606: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.463893: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.487529: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.683417: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.753496: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.778536: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.802462: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:31.810413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.019937: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.060996: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.134562: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.234470: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.249805: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.369520: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.402976: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.442577: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.470028: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.518947: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.546257: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.554602: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.619608: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.619971: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.627878: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 17:21:32.690078: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /nfs/workbench/home/g6680025026/venvs/myenv1/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# 2024-12-18 17:47:07.988414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 17:47:07.990450: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 17:47:07.991633: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 17:47:08.896846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 17:47:08.899219: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 17:47:08.901045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 17:47:09.930193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 17:47:09.932544: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 17:47:09.934317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 17:47:11.894463: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 17:47:11.897033: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 17:47:11.898827: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 2943.371424674988 seconds

# %%
# Get the best parameters and the best score
best_params = random_search_result.best_params_
best_score = -random_search_result.best_score_

# %%
print("Best Parameters:", best_params)
print("Best RMSE Score:", best_score)
# Out:
# Best Parameters: {'rnn_units': 55, 'gru_units': 47, 'beta_1': 0.9, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.11342565156282393

# %% [markdown]
# ## After hyperparameter Tuning

# %%
rnn_gru_model = create_model(rnn_units=55, gru_units=47, beta_1=0.9,LR=0.003,L2=0.001)
rnn_gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 1, 47)             6016
#
#  dropout_2 (Dropout)         (None, 1, 47)             0
#
#  gru_1 (GRU)                 (None, 55)                17160
#
#  dropout_3 (Dropout)         (None, 55)                0
#
#  dense_1 (Dense)             (None, 30)                1680
#
# =================================================================
# Total params: 24,856
# Trainable params: 24,856
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-18 18:02:06.849362: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 18:02:06.850984: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 18:02:06.852111: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
rnn_gru_history = rnn_gru_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-18 18:02:07.851737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 18:02:07.853636: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 18:02:07.855206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 18:02:09.242977: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 18:02:09.244886: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 18:02:09.246412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 44s - loss: 0.4533 - root_mean_squared_error: 0.6288
# 2024-12-18 18:02:11.683680: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 18:02:11.685911: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 18:02:11.687516: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 5s 78ms/step - loss: 0.1924 - root_mean_squared_error: 0.3700 - val_loss: 0.0632 - val_root_mean_squared_error: 0.1074
# Epoch 2/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0906 - root_mean_squared_error: 0.2076 - val_loss: 0.0490 - val_root_mean_squared_error: 0.0811
# Epoch 3/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0674 - root_mean_squared_error: 0.1695 - val_loss: 0.0385 - val_root_mean_squared_error: 0.0633
# Epoch 4/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0547 - root_mean_squared_error: 0.1526 - val_loss: 0.0311 - val_root_mean_squared_error: 0.0550
# Epoch 5/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0455 - root_mean_squared_error: 0.1407 - val_loss: 0.0259 - val_root_mean_squared_error: 0.0540
# Epoch 6/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0401 - root_mean_squared_error: 0.1381 - val_loss: 0.0232 - val_root_mean_squared_error: 0.0653
# Epoch 7/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0352 - root_mean_squared_error: 0.1326 - val_loss: 0.0202 - val_root_mean_squared_error: 0.0637
# Epoch 8/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0333 - root_mean_squared_error: 0.1347 - val_loss: 0.0167 - val_root_mean_squared_error: 0.0521
# Epoch 9/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0297 - root_mean_squared_error: 0.1281 - val_loss: 0.0158 - val_root_mean_squared_error: 0.0580
# Epoch 10/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0274 - root_mean_squared_error: 0.1248 - val_loss: 0.0150 - val_root_mean_squared_error: 0.0627
# Epoch 11/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0257 - root_mean_squared_error: 0.1231 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0534
# Epoch 12/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0241 - root_mean_squared_error: 0.1212 - val_loss: 0.0149 - val_root_mean_squared_error: 0.0773
# Epoch 13/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0235 - root_mean_squared_error: 0.1223 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0554
# Epoch 14/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0243 - root_mean_squared_error: 0.1288 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0597
# Epoch 15/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0213 - root_mean_squared_error: 0.1194 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0514
# Epoch 16/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0204 - root_mean_squared_error: 0.1177 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0513
# Epoch 17/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0200 - root_mean_squared_error: 0.1182 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0523
# Epoch 18/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0190 - root_mean_squared_error: 0.1159 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0576
# Epoch 19/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0200 - root_mean_squared_error: 0.1220 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0597
# Epoch 20/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0190 - root_mean_squared_error: 0.1191 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0507
# Epoch 21/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0196 - root_mean_squared_error: 0.1230 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0856
# Epoch 22/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0191 - root_mean_squared_error: 0.1221 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0506
# Epoch 23/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0173 - root_mean_squared_error: 0.1154 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0619
# Epoch 24/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0166 - root_mean_squared_error: 0.1136 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0547
# Epoch 25/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0166 - root_mean_squared_error: 0.1143 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0545
# Epoch 26/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0157 - root_mean_squared_error: 0.1113 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0547
# Epoch 27/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0157 - root_mean_squared_error: 0.1121 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0533
# Epoch 28/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0156 - root_mean_squared_error: 0.1129 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0730
# Epoch 29/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0169 - root_mean_squared_error: 0.1188 - val_loss: 0.0146 - val_root_mean_squared_error: 0.1091
# Epoch 30/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0176 - root_mean_squared_error: 0.1223 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0528
# Epoch 31/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0160 - root_mean_squared_error: 0.1164 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0651
# Epoch 32/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0153 - root_mean_squared_error: 0.1136 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0505
# Epoch 33/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0144 - root_mean_squared_error: 0.1101 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0556
# Epoch 34/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0143 - root_mean_squared_error: 0.1098 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0514
# Epoch 35/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0145 - root_mean_squared_error: 0.1113 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0510
# Epoch 36/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0152 - root_mean_squared_error: 0.1151 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0801
# Epoch 37/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0149 - root_mean_squared_error: 0.1140 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0577
# Epoch 38/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0144 - root_mean_squared_error: 0.1121 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0848
# Epoch 39/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0173 - root_mean_squared_error: 0.1246 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0675
# Epoch 40/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0156 - root_mean_squared_error: 0.1176 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0592

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(rnn_gru_history.history['loss'], label='train_loss')
plt.plot(rnn_gru_history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_gru_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0051 - root_mean_squared_error: 0.0559
# Test Loss: 0.005147309973835945
# Test RMSE: 0.05590987205505371

# %%
# ทำ prediction
yhat_train = rnn_gru_model.predict(train_X)
yhat_val = rnn_gru_model.predict(val_X)
yhat_test = rnn_gru_model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
# Out:
# 2024-12-18 18:03:11.495466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 18:03:11.497435: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 18:03:11.498839: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 2s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('KBANK_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.1839%
# RMSE: 5.3500
