# %% [markdown]
# ## Library

# %%
# # !pip install --upgrade
# !pip install numpy scikit-learn pandas yfinance tensorflow matplotlib
# !pip install tensorflow==2.12.0

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('KBANK.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                       Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  157.268036  188.5  191.0  188.5  189.5  6817000
# 2019-07-02 00:00:00+00:00  157.268036  188.5  189.5  188.0  188.5  3797000
# 2019-07-03 00:00:00+00:00  157.685181  189.0  189.5  188.0  188.5  3524300
# 2019-07-04 00:00:00+00:00  156.016571  187.0  190.0  187.0  189.0  7623900
# 2019-07-05 00:00:00+00:00  156.433701  187.5  188.0  187.0  187.0  2385300

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('KBank Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.995641    1.000000   1.000000    1.000000      0.039494
# 16         0.995641    0.987288   0.995781    0.991507      0.021998
# 17         1.000000    0.987288   0.995781    0.991507      0.020418
# 18         0.982562    0.991525   0.987342    0.995754      0.044169
# 19         0.986921    0.974576   0.987342    0.978769      0.013819
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.995641    0.987288   0.995781    0.991507      0.021998  ...
# 16         1.000000    0.987288   0.995781    0.991507      0.020418  ...
# 17         0.982562    0.991525   0.987342    0.995754      0.044169  ...
# 18         0.986921    0.974576   0.987342    0.978769      0.013819  ...
# 19         0.982562    0.974576   0.978903    0.978769      0.025213  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.902954  0.906582   0.071548        0.908450        0.895372
# 16  0.907173  0.902335   0.026399        0.895372        0.873574
# 17  0.902954  0.906582   0.026877        0.873574        0.851777
# 18  0.877637  0.893843   0.065149        0.851777        0.856136
# 19  0.860759  0.876858   0.042190        0.856136        0.860496
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.873574        0.851777        0.856136        0.860496
# 16        0.851777        0.856136        0.860496        0.886653
# 17        0.856136        0.860496        0.886653        0.856136
# 18        0.860496        0.886653        0.856136        0.864855
# 19        0.886653        0.856136        0.864855        0.812541
#
#     Adj Close(t+7)
# 15        0.886653
# 16        0.856136
# 17        0.864855
# 18        0.812541
# 19        0.795103
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Create Model & Evaluate (ยังไม่ Hyperparameter tuning)

# %%
model = Sequential()

# LSTM 2 layer with ReLU activation
model.add(LSTM(units=70,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)))
model.add(Dropout(0.1))
model.add(LSTM(units=70,activation='relu'))
model.add(Dropout(0.1))

# Output layer for 1 targets
model.add(Dense(1))

# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 1, 70)             42280
#
#  dropout_40 (Dropout)        (None, 1, 70)             0
#
#  lstm_17 (LSTM)              (None, 70)                39480
#
#  dropout_41 (Dropout)        (None, 70)                0
#
#  dense_20 (Dense)            (None, 1)                 71
#
# =================================================================
# Total params: 81,831
# Trainable params: 81,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 3s 32ms/step - loss: 0.3866 - root_mean_squared_error: 0.5230 - val_loss: 0.2858 - val_root_mean_squared_error: 0.4304
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1530 - root_mean_squared_error: 0.2465 - val_loss: 0.0901 - val_root_mean_squared_error: 0.0856
# Epoch 3/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1001 - root_mean_squared_error: 0.1584 - val_loss: 0.0964 - val_root_mean_squared_error: 0.1714
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0809 - root_mean_squared_error: 0.1385 - val_loss: 0.0660 - val_root_mean_squared_error: 0.1013
# Epoch 5/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0672 - root_mean_squared_error: 0.1257 - val_loss: 0.0558 - val_root_mean_squared_error: 0.0949
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0578 - root_mean_squared_error: 0.1195 - val_loss: 0.0524 - val_root_mean_squared_error: 0.1116
# Epoch 7/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0505 - root_mean_squared_error: 0.1148 - val_loss: 0.0397 - val_root_mean_squared_error: 0.0716
# Epoch 8/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0453 - root_mean_squared_error: 0.1132 - val_loss: 0.0352 - val_root_mean_squared_error: 0.0692
# Epoch 9/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0410 - root_mean_squared_error: 0.1108 - val_loss: 0.0337 - val_root_mean_squared_error: 0.0823
# Epoch 10/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0380 - root_mean_squared_error: 0.1112 - val_loss: 0.0300 - val_root_mean_squared_error: 0.0755
# Epoch 11/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0357 - root_mean_squared_error: 0.1117 - val_loss: 0.0269 - val_root_mean_squared_error: 0.0696
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0330 - root_mean_squared_error: 0.1088 - val_loss: 0.0239 - val_root_mean_squared_error: 0.0605
# Epoch 13/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0308 - root_mean_squared_error: 0.1066 - val_loss: 0.0235 - val_root_mean_squared_error: 0.0692
# Epoch 14/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0289 - root_mean_squared_error: 0.1040 - val_loss: 0.0261 - val_root_mean_squared_error: 0.0939
# Epoch 15/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0286 - root_mean_squared_error: 0.1088 - val_loss: 0.0251 - val_root_mean_squared_error: 0.0948
# Epoch 16/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0272 - root_mean_squared_error: 0.1075 - val_loss: 0.0241 - val_root_mean_squared_error: 0.0950
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0260 - root_mean_squared_error: 0.1062 - val_loss: 0.0196 - val_root_mean_squared_error: 0.0740
# Epoch 18/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0239 - root_mean_squared_error: 0.1006 - val_loss: 0.0175 - val_root_mean_squared_error: 0.0643
# Epoch 19/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0229 - root_mean_squared_error: 0.0996 - val_loss: 0.0168 - val_root_mean_squared_error: 0.0655
# Epoch 20/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0219 - root_mean_squared_error: 0.0986 - val_loss: 0.0145 - val_root_mean_squared_error: 0.0519
# Epoch 21/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0207 - root_mean_squared_error: 0.0960 - val_loss: 0.0141 - val_root_mean_squared_error: 0.0552
# Epoch 22/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0200 - root_mean_squared_error: 0.0960 - val_loss: 0.0164 - val_root_mean_squared_error: 0.0768
# Epoch 23/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.0951 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0549
# Epoch 24/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0189 - root_mean_squared_error: 0.0962 - val_loss: 0.0128 - val_root_mean_squared_error: 0.0584
# Epoch 25/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.0940 - val_loss: 0.0143 - val_root_mean_squared_error: 0.0742
# Epoch 26/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0173 - root_mean_squared_error: 0.0932 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0580
# Epoch 27/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0160 - root_mean_squared_error: 0.0888 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0593
# Epoch 28/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.0937 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0486
# Epoch 29/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0161 - root_mean_squared_error: 0.0938 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0691
# Epoch 30/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0155 - root_mean_squared_error: 0.0926 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0510
# Epoch 31/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0154 - root_mean_squared_error: 0.0936 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0597
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0144 - root_mean_squared_error: 0.0901 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0479
# Epoch 33/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - root_mean_squared_error: 0.0882 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0524
# Epoch 34/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0134 - root_mean_squared_error: 0.0878 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0530
# Epoch 35/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0135 - root_mean_squared_error: 0.0904 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0480
# Epoch 36/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.0968 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0678
# Epoch 37/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.0889 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0496
# Epoch 38/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0129 - root_mean_squared_error: 0.0910 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0624
# Epoch 39/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0128 - root_mean_squared_error: 0.0916 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0454
# Epoch 40/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0114 - root_mean_squared_error: 0.0847 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0493
# Epoch 41/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0123 - root_mean_squared_error: 0.0904 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0493
# Epoch 42/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0116 - root_mean_squared_error: 0.0877 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0530
# Epoch 43/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0113 - root_mean_squared_error: 0.0868 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0472
# Epoch 44/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0112 - root_mean_squared_error: 0.0873 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0491
# Epoch 45/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.0871 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0452
# Epoch 46/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.0876 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0481
# Epoch 47/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0113 - root_mean_squared_error: 0.0900 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0551
# Epoch 48/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0102 - root_mean_squared_error: 0.0845 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0473
# Epoch 49/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0105 - root_mean_squared_error: 0.0869 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0580
# Epoch 50/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.0884 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0485
# Epoch 51/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.0909 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0517
# Epoch 52/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0098 - root_mean_squared_error: 0.0846 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0511
# Epoch 53/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0098 - root_mean_squared_error: 0.0851 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0461
# Epoch 54/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0094 - root_mean_squared_error: 0.0829 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0562
# Epoch 55/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0101 - root_mean_squared_error: 0.0880 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0436
# Epoch 56/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0095 - root_mean_squared_error: 0.0846 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0488
# Epoch 57/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - root_mean_squared_error: 0.0830 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0433
# Epoch 58/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0098 - root_mean_squared_error: 0.0870 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0439
# Epoch 59/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0092 - root_mean_squared_error: 0.0839 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0462
# Epoch 60/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - root_mean_squared_error: 0.0825 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0435
# Epoch 61/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0087 - root_mean_squared_error: 0.0821 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0522
# Epoch 62/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - root_mean_squared_error: 0.0847 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0496
# Epoch 63/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0086 - root_mean_squared_error: 0.0822 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0440
# Epoch 64/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0818 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0441
# Epoch 65/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - root_mean_squared_error: 0.0856 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0561
# Epoch 66/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0823 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0437
# Epoch 67/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - root_mean_squared_error: 0.0849 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0446
# Epoch 68/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0829 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0429
# Epoch 69/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0826 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0452
# Epoch 70/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0083 - root_mean_squared_error: 0.0820 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0422
# Epoch 71/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - root_mean_squared_error: 0.0799 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0439
# Epoch 72/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0833 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0458
# Epoch 73/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - root_mean_squared_error: 0.0809 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0490
# Epoch 74/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0837 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0433
# Epoch 75/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0818 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0433
# Epoch 76/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0803 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0443
# Epoch 77/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0086 - root_mean_squared_error: 0.0855 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0433
# Epoch 78/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0082 - root_mean_squared_error: 0.0834 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0423
# Epoch 79/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - root_mean_squared_error: 0.0812 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0443
# Epoch 80/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - root_mean_squared_error: 0.0822 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0417
# Epoch 81/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0827 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0596
# Epoch 82/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0855 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0462
# Epoch 83/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0814 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0464
# Epoch 84/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0852 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0421
# Epoch 85/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - root_mean_squared_error: 0.0804 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0469
# Epoch 86/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - root_mean_squared_error: 0.0775 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0449
# Epoch 87/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - root_mean_squared_error: 0.0826 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0468
# Epoch 88/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - root_mean_squared_error: 0.0825 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0519
# Epoch 89/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0082 - root_mean_squared_error: 0.0842 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0439

# %%
# คำนวณ predicted values
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# # Reshape residuals for GRU input (samples, timesteps, features)
# resid_train = resid_train.reshape((resid_train.shape[0], 1, resid_train.shape[1]))
# resid_val = resid_val.reshape((resid_val.shape[0], 1, resid_val.shape[1]))
# resid_test = resid_test.reshape((resid_test.shape[0], 1, resid_test.shape[1]))

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 1)
# (178, 1, 80)
# (178, 1)
# (179, 1, 80)
# (179, 1)

# %%
# GRU model for predicting residuals
res_model = Sequential()
res_model.add(GRU(units=50, activation='relu', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)))
res_model.add(Dropout(0.1))
res_model.add(GRU(units=50, activation='relu'))
res_model.add(Dropout(0.1))
res_model.add(Dense(1))

# Compile the GRU model
optimizer = Adam(learning_rate=0.001)
res_model.compile(optimizer=optimizer, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
# Train the GRU model
history_gru = res_model.fit(train_X_resid, train_y_resid, epochs=100, batch_size=64, validation_data=(val_X_resid, val_y_resid), 
                            callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 2s 33ms/step - loss: 0.0998 - root_mean_squared_error: 0.0713 - val_loss: 0.0853 - val_root_mean_squared_error: 0.0434
# Epoch 2/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0794 - root_mean_squared_error: 0.0689 - val_loss: 0.0671 - val_root_mean_squared_error: 0.0441
# Epoch 3/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0627 - root_mean_squared_error: 0.0687 - val_loss: 0.0522 - val_root_mean_squared_error: 0.0442
# Epoch 4/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0493 - root_mean_squared_error: 0.0687 - val_loss: 0.0405 - val_root_mean_squared_error: 0.0450
# Epoch 5/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0387 - root_mean_squared_error: 0.0681 - val_loss: 0.0312 - val_root_mean_squared_error: 0.0440
# Epoch 6/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0305 - root_mean_squared_error: 0.0682 - val_loss: 0.0242 - val_root_mean_squared_error: 0.0455
# Epoch 7/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0241 - root_mean_squared_error: 0.0684 - val_loss: 0.0185 - val_root_mean_squared_error: 0.0433
# Epoch 8/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.0680 - val_loss: 0.0143 - val_root_mean_squared_error: 0.0437
# Epoch 9/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0155 - root_mean_squared_error: 0.0680 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0436
# Epoch 10/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0127 - root_mean_squared_error: 0.0683 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0455
# Epoch 11/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.0682 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0447
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0090 - root_mean_squared_error: 0.0680 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0424
# Epoch 13/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0679 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0442
# Epoch 14/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0070 - root_mean_squared_error: 0.0683 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0444
# Epoch 15/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - root_mean_squared_error: 0.0682 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0444
# Epoch 16/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0059 - root_mean_squared_error: 0.0681 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0432
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0055 - root_mean_squared_error: 0.0677 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0440
# Epoch 18/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0053 - root_mean_squared_error: 0.0677 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0431
# Epoch 19/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0051 - root_mean_squared_error: 0.0679 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0422
# Epoch 20/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0051 - root_mean_squared_error: 0.0681 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0459
# Epoch 21/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0049 - root_mean_squared_error: 0.0678 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0443
# Epoch 22/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0676 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0421
# Epoch 23/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0678 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0445
# Epoch 24/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0676 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0430
# Epoch 25/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0674 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0444
# Epoch 26/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0676 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0426
# Epoch 27/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0678 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0449
# Epoch 28/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0681 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0424
# Epoch 29/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0682 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0441
# Epoch 30/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0681 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0443
# Epoch 31/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0677 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0435
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0675 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0432
# Epoch 33/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0046 - root_mean_squared_error: 0.0674 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0429

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_gru.history['loss'], label='train_loss')
plt.plot(history_gru.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0030 - root_mean_squared_error: 0.0431
# Test Loss: 0.003018162213265896
# Test RMSE: 0.043124038726091385

# %%
# คำนวณ predicted residuals
yhat_train_resid = res_model.predict(train_X_resid)
yhat_val_resid = res_model.predict(val_X_resid)
yhat_test_resid = res_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('KBANK_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 2.3950%
# RMSE: 3.9270

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_gru_model(gru_units_1, beta_1 ,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_3895882/2081204696.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-19 16:42:14.654943: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.655007: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.655004: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.661314: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.661513: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.661589: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.661638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.661685: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.663711: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.664033: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.666086: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.666332: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.667489: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.668998: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.669136: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.669254: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.673669: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.674772: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.674952: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.681548: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.681622: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.683873: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.683915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.686721: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.688965: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.692011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.694961: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.695326: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.699255: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.701399: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.701580: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:42:14.701667: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 16:51:26.739582: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 16:51:26.741595: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 16:51:26.742936: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 16:51:27.237906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 16:51:27.240330: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 16:51:27.242135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 16:51:28.110165: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 16:51:28.112524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 16:51:28.114232: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 16:51:29.548297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 16:51:29.550594: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 16:51:29.552344: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 854.0833468437195 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 12, 'beta_1': 0.9, 'LR': 0.018000000000000002, 'L2': 0.001}
# Best RMSE Score: 0.06568789605163604

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
gru_model = create_gru_model(gru_units_1=12 ,beta_1=0.9, LR=0.018, L2=0.001)
gru_model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 12)                3384
#
#  dropout_6 (Dropout)         (None, 12)                0
#
#  dense_6 (Dense)             (None, 7)                 91
#
# =================================================================
# Total params: 3,475
# Trainable params: 3,475
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-19 17:02:32.936968: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:02:32.938667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:02:32.939830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = gru_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-19 17:02:37.511130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:02:37.513329: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:02:37.514829: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 17:02:38.344654: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:02:38.346700: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:02:38.348193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 53ms/step - loss: 0.1438 - root_mean_squared_error: 0.3254 - val_loss: 0.0587 - val_root_mean_squared_error: 0.1607
# Epoch 2/150
#  1/13 [=>............................] - ETA: 0s - loss: 0.0865 - root_mean_squared_error: 0.2315
# 2024-12-19 17:02:39.713726: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:02:39.715931: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:02:39.717522: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0700 - root_mean_squared_error: 0.1962 - val_loss: 0.0344 - val_root_mean_squared_error: 0.0791
# Epoch 3/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0517 - root_mean_squared_error: 0.1647 - val_loss: 0.0247 - val_root_mean_squared_error: 0.0638
# Epoch 4/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0365 - root_mean_squared_error: 0.1361 - val_loss: 0.0205 - val_root_mean_squared_error: 0.0717
# Epoch 5/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0289 - root_mean_squared_error: 0.1238 - val_loss: 0.0136 - val_root_mean_squared_error: 0.0424
# Epoch 6/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0232 - root_mean_squared_error: 0.1129 - val_loss: 0.0132 - val_root_mean_squared_error: 0.0646
# Epoch 7/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0200 - root_mean_squared_error: 0.1093 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0521
# Epoch 8/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0176 - root_mean_squared_error: 0.1062 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0490
# Epoch 9/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.0965 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0440
# Epoch 10/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0123 - root_mean_squared_error: 0.0902 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0560
# Epoch 11/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0132 - root_mean_squared_error: 0.0981 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0775
# Epoch 12/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0130 - root_mean_squared_error: 0.0988 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0604
# Epoch 13/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0105 - root_mean_squared_error: 0.0876 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0579
# Epoch 14/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0092 - root_mean_squared_error: 0.0817 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0419
# Epoch 15/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0085 - root_mean_squared_error: 0.0793 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0411
# Epoch 16/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0079 - root_mean_squared_error: 0.0771 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0881
# Epoch 17/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0088 - root_mean_squared_error: 0.0836 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0671
# Epoch 18/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0088 - root_mean_squared_error: 0.0841 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0515
# Epoch 19/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0072 - root_mean_squared_error: 0.0748 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0393
# Epoch 20/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0074 - root_mean_squared_error: 0.0768 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0440
# Epoch 21/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0078 - root_mean_squared_error: 0.0800 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0688
# Epoch 22/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0100 - root_mean_squared_error: 0.0929 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0421
# Epoch 23/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0081 - root_mean_squared_error: 0.0821 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0637
# Epoch 24/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0078 - root_mean_squared_error: 0.0800 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0426

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0033 - root_mean_squared_error: 0.0422
# Test Loss: 0.003331546438857913
# Test RMSE: 0.04222932085394859

# %%
# คำนวณ predicted values
yhat_train = gru_model.predict(train_X)
yhat_val = gru_model.predict(val_X)
yhat_test = gru_model.predict(test_X)
# Out:
#  1/26 [>.............................] - ETA: 12s
# 2024-12-19 17:02:51.937087: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:02:51.939019: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:02:51.940456: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 2024-12-19 17:02:52.526173: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 17:02:52.528126: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 17:02:52.529502: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_rnn_model(rnn_units_1,beta_1,LR,L2):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_3895882/849910436.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-19 17:18:20.804685: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.805578: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.809293: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.816000: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.823964: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.827497: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.828322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.856022: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.865768: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.865823: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.866752: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.868223: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.872166: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.872669: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.879887: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.885315: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.885792: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.895232: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.914839: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.917477: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.932614: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.936884: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.937962: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.942162: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.953277: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.960260: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.960302: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.965406: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.969880: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.971997: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:20.973873: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 17:18:21.005308: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 1489.754605770111 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 48, 'beta_1': 0.7, 'LR': 0.010000000000000002, 'L2': 0.001}
# Best RMSE Score: 0.052689805535290714

# %%
rnn_model = create_rnn_model(rnn_units_1=48, beta_1=0.7 , LR=0.01, L2=0.001)
rnn_model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_4 (SimpleRNN)    (None, 48)                6192
#
#  dropout_8 (Dropout)         (None, 48)                0
#
#  dense_8 (Dense)             (None, 7)                 343
#
# =================================================================
# Total params: 6,535
# Trainable params: 6,535
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_resid = rnn_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 1s 23ms/step - loss: 0.2534 - root_mean_squared_error: 0.4413 - val_loss: 0.0659 - val_root_mean_squared_error: 0.0940
# Epoch 2/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0924 - root_mean_squared_error: 0.1928 - val_loss: 0.0575 - val_root_mean_squared_error: 0.0667
# Epoch 3/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1023 - root_mean_squared_error: 0.2260 - val_loss: 0.0554 - val_root_mean_squared_error: 0.0775
# Epoch 4/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0614 - root_mean_squared_error: 0.1158 - val_loss: 0.0504 - val_root_mean_squared_error: 0.0634
# Epoch 5/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0507 - root_mean_squared_error: 0.0755 - val_loss: 0.0461 - val_root_mean_squared_error: 0.0519
# Epoch 6/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0469 - root_mean_squared_error: 0.0698 - val_loss: 0.0431 - val_root_mean_squared_error: 0.0505
# Epoch 7/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0489 - root_mean_squared_error: 0.0981 - val_loss: 0.0636 - val_root_mean_squared_error: 0.1604
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0455 - root_mean_squared_error: 0.0934 - val_loss: 0.0384 - val_root_mean_squared_error: 0.0547
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0395 - root_mean_squared_error: 0.0721 - val_loss: 0.0356 - val_root_mean_squared_error: 0.0499
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0369 - root_mean_squared_error: 0.0693 - val_loss: 0.0326 - val_root_mean_squared_error: 0.0409
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0355 - root_mean_squared_error: 0.0746 - val_loss: 0.0349 - val_root_mean_squared_error: 0.0776
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0344 - root_mean_squared_error: 0.0801 - val_loss: 0.0319 - val_root_mean_squared_error: 0.0701
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0338 - root_mean_squared_error: 0.0876 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1016
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0314 - root_mean_squared_error: 0.0837 - val_loss: 0.0311 - val_root_mean_squared_error: 0.0872
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0290 - root_mean_squared_error: 0.0796 - val_loss: 0.0255 - val_root_mean_squared_error: 0.0598
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0255 - root_mean_squared_error: 0.0655 - val_loss: 0.0243 - val_root_mean_squared_error: 0.0628
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0253 - root_mean_squared_error: 0.0747 - val_loss: 0.0214 - val_root_mean_squared_error: 0.0487
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0228 - root_mean_squared_error: 0.0665 - val_loss: 0.0211 - val_root_mean_squared_error: 0.0583
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0223 - root_mean_squared_error: 0.0722 - val_loss: 0.0185 - val_root_mean_squared_error: 0.0453
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0210 - root_mean_squared_error: 0.0717 - val_loss: 0.0254 - val_root_mean_squared_error: 0.1005
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0216 - root_mean_squared_error: 0.0829 - val_loss: 0.0175 - val_root_mean_squared_error: 0.0578
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0174 - root_mean_squared_error: 0.0605 - val_loss: 0.0148 - val_root_mean_squared_error: 0.0402
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0169 - root_mean_squared_error: 0.0643 - val_loss: 0.0155 - val_root_mean_squared_error: 0.0577
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0162 - root_mean_squared_error: 0.0665 - val_loss: 0.0138 - val_root_mean_squared_error: 0.0502
# Epoch 25/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0174 - root_mean_squared_error: 0.0806 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0552
# Epoch 26/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0142 - root_mean_squared_error: 0.0635 - val_loss: 0.0157 - val_root_mean_squared_error: 0.0772
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0146 - root_mean_squared_error: 0.0722 - val_loss: 0.0150 - val_root_mean_squared_error: 0.0776
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0135 - root_mean_squared_error: 0.0694 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0664
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0121 - root_mean_squared_error: 0.0639 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0421
# Epoch 30/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0117 - root_mean_squared_error: 0.0654 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0411
# Epoch 31/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0106 - root_mean_squared_error: 0.0618 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0381
# Epoch 32/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0094 - root_mean_squared_error: 0.0554 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0494
# Epoch 33/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0092 - root_mean_squared_error: 0.0588 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0453
# Epoch 34/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0087 - root_mean_squared_error: 0.0581 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0403
# Epoch 35/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0087 - root_mean_squared_error: 0.0615 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0571
# Epoch 36/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0107 - root_mean_squared_error: 0.0788 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0464
# Epoch 37/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0086 - root_mean_squared_error: 0.0667 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0442
# Epoch 38/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0072 - root_mean_squared_error: 0.0585 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0448
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0069 - root_mean_squared_error: 0.0584 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0472
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0092 - root_mean_squared_error: 0.0770 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0493
# Epoch 41/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0063 - root_mean_squared_error: 0.0577 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0463
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0065 - root_mean_squared_error: 0.0614 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0402
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0056 - root_mean_squared_error: 0.0556 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0468
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0055 - root_mean_squared_error: 0.0565 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0385
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0058 - root_mean_squared_error: 0.0608 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0372
# Epoch 46/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0059 - root_mean_squared_error: 0.0630 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0427
# Epoch 47/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0583 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0384
# Epoch 48/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0550 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0384
# Epoch 49/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0566 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0425
# Epoch 50/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0576 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0388
# Epoch 51/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0045 - root_mean_squared_error: 0.0570 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0426
# Epoch 52/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0045 - root_mean_squared_error: 0.0577 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0455
# Epoch 53/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0045 - root_mean_squared_error: 0.0591 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0438
# Epoch 54/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0602 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0498
# Epoch 55/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0043 - root_mean_squared_error: 0.0584 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0602

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3337 - root_mean_squared_error: 0.5763
# Test Loss: 0.3336600065231323
# Test RMSE: 0.5762913823127747

# %%
# คำนวณ predicted residuals
yhat_train_resid = rnn_model.predict(train_X_resid)
yhat_val_resid = rnn_model.predict(val_X_resid)
yhat_test_resid = rnn_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('KBANK_Adj_close_prediction By cascaded')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 2.2994%
# RMSE: 3.5882
