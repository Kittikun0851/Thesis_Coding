# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-19 21:49:33.487158: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-19 21:49:33.495942: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-19 21:49:33.550722: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-19 21:49:33.552636: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-19 21:50:06.471281: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('MTC.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  54.243725  57.50  57.50  56.50  56.75  5741400
# 2019-07-02 00:00:00+00:00  54.007889  57.25  58.00  56.50  57.50  6927300
# 2019-07-03 00:00:00+00:00  53.772041  57.00  57.75  56.75  57.00  3766300
# 2019-07-04 00:00:00+00:00  53.772041  57.00  58.00  56.50  57.25  4936900
# 2019-07-05 00:00:00+00:00  54.007889  57.25  57.50  56.50  56.50  2941100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('MTC Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.650953    0.610778   0.654545    0.625000      0.102442
# 16         0.645089    0.622754   0.654545    0.642857      0.123602
# 17         0.639224    0.616766   0.660606    0.630952      0.067201
# 18         0.639224    0.622754   0.654545    0.636905      0.088088
# 19         0.645089    0.610778   0.654545    0.619048      0.052477
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.645089    0.622754   0.654545    0.642857      0.123602  ...
# 16         0.639224    0.616766   0.660606    0.630952      0.067201  ...
# 17         0.639224    0.622754   0.654545    0.636905      0.088088  ...
# 18         0.645089    0.610778   0.654545    0.619048      0.052477  ...
# 19         0.627495    0.604790   0.636364    0.630952      0.072568  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.678788  0.654762   0.092292        0.668546        0.692004
# 16  0.678788  0.660714   0.046650        0.692004        0.692004
# 17  0.684848  0.666667   0.126459        0.692004        0.692004
# 18  0.703030  0.678571   0.098638        0.692004        0.721326
# 19  0.709091  0.684524   0.046207        0.721326        0.721326
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.692004        0.692004        0.721326        0.721326
# 16        0.692004        0.721326        0.721326        0.727191
# 17        0.721326        0.721326        0.727191        0.686140
# 18        0.721326        0.727191        0.686140        0.721326
# 19        0.727191        0.686140        0.721326        0.803429
#
#     Adj Close(t+7)
# 15        0.727191
# 16        0.686140
# 17        0.721326
# 18        0.803429
# 19        0.680275
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
model = Sequential()

# LSTM 2 layer with ReLU activation
model.add(LSTM(units=70,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)))
model.add(Dropout(0.1))
model.add(LSTM(units=70,activation='relu'))
model.add(Dropout(0.1))

# Output layer for 1 targets
model.add(Dense(1))

# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_16 (LSTM)              (None, 1, 70)             42280
#
#  dropout_40 (Dropout)        (None, 1, 70)             0
#
#  lstm_17 (LSTM)              (None, 70)                39480
#
#  dropout_41 (Dropout)        (None, 70)                0
#
#  dense_20 (Dense)            (None, 1)                 71
#
# =================================================================
# Total params: 81,831
# Trainable params: 81,831
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 3s 32ms/step - loss: 0.3866 - root_mean_squared_error: 0.5230 - val_loss: 0.2858 - val_root_mean_squared_error: 0.4304
# Epoch 2/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1530 - root_mean_squared_error: 0.2465 - val_loss: 0.0901 - val_root_mean_squared_error: 0.0856
# Epoch 3/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1001 - root_mean_squared_error: 0.1584 - val_loss: 0.0964 - val_root_mean_squared_error: 0.1714
# Epoch 4/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0809 - root_mean_squared_error: 0.1385 - val_loss: 0.0660 - val_root_mean_squared_error: 0.1013
# Epoch 5/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0672 - root_mean_squared_error: 0.1257 - val_loss: 0.0558 - val_root_mean_squared_error: 0.0949
# Epoch 6/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0578 - root_mean_squared_error: 0.1195 - val_loss: 0.0524 - val_root_mean_squared_error: 0.1116
# Epoch 7/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0505 - root_mean_squared_error: 0.1148 - val_loss: 0.0397 - val_root_mean_squared_error: 0.0716
# Epoch 8/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0453 - root_mean_squared_error: 0.1132 - val_loss: 0.0352 - val_root_mean_squared_error: 0.0692
# Epoch 9/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0410 - root_mean_squared_error: 0.1108 - val_loss: 0.0337 - val_root_mean_squared_error: 0.0823
# Epoch 10/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0380 - root_mean_squared_error: 0.1112 - val_loss: 0.0300 - val_root_mean_squared_error: 0.0755
# Epoch 11/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0357 - root_mean_squared_error: 0.1117 - val_loss: 0.0269 - val_root_mean_squared_error: 0.0696
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0330 - root_mean_squared_error: 0.1088 - val_loss: 0.0239 - val_root_mean_squared_error: 0.0605
# Epoch 13/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0308 - root_mean_squared_error: 0.1066 - val_loss: 0.0235 - val_root_mean_squared_error: 0.0692
# Epoch 14/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0289 - root_mean_squared_error: 0.1040 - val_loss: 0.0261 - val_root_mean_squared_error: 0.0939
# Epoch 15/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0286 - root_mean_squared_error: 0.1088 - val_loss: 0.0251 - val_root_mean_squared_error: 0.0948
# Epoch 16/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0272 - root_mean_squared_error: 0.1075 - val_loss: 0.0241 - val_root_mean_squared_error: 0.0950
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0260 - root_mean_squared_error: 0.1062 - val_loss: 0.0196 - val_root_mean_squared_error: 0.0740
# Epoch 18/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0239 - root_mean_squared_error: 0.1006 - val_loss: 0.0175 - val_root_mean_squared_error: 0.0643
# Epoch 19/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0229 - root_mean_squared_error: 0.0996 - val_loss: 0.0168 - val_root_mean_squared_error: 0.0655
# Epoch 20/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0219 - root_mean_squared_error: 0.0986 - val_loss: 0.0145 - val_root_mean_squared_error: 0.0519
# Epoch 21/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0207 - root_mean_squared_error: 0.0960 - val_loss: 0.0141 - val_root_mean_squared_error: 0.0552
# Epoch 22/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0200 - root_mean_squared_error: 0.0960 - val_loss: 0.0164 - val_root_mean_squared_error: 0.0768
# Epoch 23/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.0951 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0549
# Epoch 24/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0189 - root_mean_squared_error: 0.0962 - val_loss: 0.0128 - val_root_mean_squared_error: 0.0584
# Epoch 25/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0179 - root_mean_squared_error: 0.0940 - val_loss: 0.0143 - val_root_mean_squared_error: 0.0742
# Epoch 26/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0173 - root_mean_squared_error: 0.0932 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0580
# Epoch 27/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0160 - root_mean_squared_error: 0.0888 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0593
# Epoch 28/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0165 - root_mean_squared_error: 0.0937 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0486
# Epoch 29/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0161 - root_mean_squared_error: 0.0938 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0691
# Epoch 30/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0155 - root_mean_squared_error: 0.0926 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0510
# Epoch 31/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0154 - root_mean_squared_error: 0.0936 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0597
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0144 - root_mean_squared_error: 0.0901 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0479
# Epoch 33/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - root_mean_squared_error: 0.0882 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0524
# Epoch 34/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0134 - root_mean_squared_error: 0.0878 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0530
# Epoch 35/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0135 - root_mean_squared_error: 0.0904 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0480
# Epoch 36/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0145 - root_mean_squared_error: 0.0968 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0678
# Epoch 37/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.0889 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0496
# Epoch 38/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0129 - root_mean_squared_error: 0.0910 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0624
# Epoch 39/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0128 - root_mean_squared_error: 0.0916 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0454
# Epoch 40/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0114 - root_mean_squared_error: 0.0847 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0493
# Epoch 41/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0123 - root_mean_squared_error: 0.0904 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0493
# Epoch 42/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0116 - root_mean_squared_error: 0.0877 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0530
# Epoch 43/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0113 - root_mean_squared_error: 0.0868 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0472
# Epoch 44/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0112 - root_mean_squared_error: 0.0873 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0491
# Epoch 45/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.0871 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0452
# Epoch 46/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.0876 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0481
# Epoch 47/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0113 - root_mean_squared_error: 0.0900 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0551
# Epoch 48/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0102 - root_mean_squared_error: 0.0845 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0473
# Epoch 49/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0105 - root_mean_squared_error: 0.0869 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0580
# Epoch 50/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.0884 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0485
# Epoch 51/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.0909 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0517
# Epoch 52/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0098 - root_mean_squared_error: 0.0846 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0511
# Epoch 53/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0098 - root_mean_squared_error: 0.0851 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0461
# Epoch 54/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0094 - root_mean_squared_error: 0.0829 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0562
# Epoch 55/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0101 - root_mean_squared_error: 0.0880 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0436
# Epoch 56/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0095 - root_mean_squared_error: 0.0846 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0488
# Epoch 57/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - root_mean_squared_error: 0.0830 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0433
# Epoch 58/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0098 - root_mean_squared_error: 0.0870 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0439
# Epoch 59/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0092 - root_mean_squared_error: 0.0839 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0462
# Epoch 60/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - root_mean_squared_error: 0.0825 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0435
# Epoch 61/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0087 - root_mean_squared_error: 0.0821 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0522
# Epoch 62/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - root_mean_squared_error: 0.0847 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0496
# Epoch 63/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0086 - root_mean_squared_error: 0.0822 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0440
# Epoch 64/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0818 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0441
# Epoch 65/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - root_mean_squared_error: 0.0856 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0561
# Epoch 66/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0823 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0437
# Epoch 67/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - root_mean_squared_error: 0.0849 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0446
# Epoch 68/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0829 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0429
# Epoch 69/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0826 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0452
# Epoch 70/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0083 - root_mean_squared_error: 0.0820 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0422
# Epoch 71/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - root_mean_squared_error: 0.0799 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0439
# Epoch 72/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0833 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0458
# Epoch 73/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - root_mean_squared_error: 0.0809 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0490
# Epoch 74/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0837 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0433
# Epoch 75/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0818 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0433
# Epoch 76/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0803 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0443
# Epoch 77/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0086 - root_mean_squared_error: 0.0855 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0433
# Epoch 78/100
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0082 - root_mean_squared_error: 0.0834 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0423
# Epoch 79/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - root_mean_squared_error: 0.0812 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0443
# Epoch 80/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - root_mean_squared_error: 0.0822 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0417
# Epoch 81/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0827 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0596
# Epoch 82/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0855 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0462
# Epoch 83/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0814 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0464
# Epoch 84/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0852 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0421
# Epoch 85/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - root_mean_squared_error: 0.0804 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0469
# Epoch 86/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - root_mean_squared_error: 0.0775 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0449
# Epoch 87/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - root_mean_squared_error: 0.0826 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0468
# Epoch 88/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - root_mean_squared_error: 0.0825 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0519
# Epoch 89/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0082 - root_mean_squared_error: 0.0842 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0439

# %%
# คำนวณ predicted values
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# # Reshape residuals for GRU input (samples, timesteps, features)
# resid_train = resid_train.reshape((resid_train.shape[0], 1, resid_train.shape[1]))
# resid_val = resid_val.reshape((resid_val.shape[0], 1, resid_val.shape[1]))
# resid_test = resid_test.reshape((resid_test.shape[0], 1, resid_test.shape[1]))

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 1)
# (178, 1, 80)
# (178, 1)
# (179, 1, 80)
# (179, 1)

# %%
# GRU model for predicting residuals
res_model = Sequential()
res_model.add(GRU(units=50, activation='relu', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=True, kernel_regularizer=l2(0.001)))
res_model.add(Dropout(0.1))
res_model.add(GRU(units=50, activation='relu'))
res_model.add(Dropout(0.1))
res_model.add(Dense(1))

# Compile the GRU model
optimizer = Adam(learning_rate=0.001)
res_model.compile(optimizer=optimizer, loss='mse', metrics=[tf.keras.metrics.RootMeanSquaredError()])

# %%
# Train the GRU model
history_gru = res_model.fit(train_X_resid, train_y_resid, epochs=100, batch_size=64, validation_data=(val_X_resid, val_y_resid), 
                            callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 13/13 [==============================] - 2s 33ms/step - loss: 0.0998 - root_mean_squared_error: 0.0713 - val_loss: 0.0853 - val_root_mean_squared_error: 0.0434
# Epoch 2/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0794 - root_mean_squared_error: 0.0689 - val_loss: 0.0671 - val_root_mean_squared_error: 0.0441
# Epoch 3/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0627 - root_mean_squared_error: 0.0687 - val_loss: 0.0522 - val_root_mean_squared_error: 0.0442
# Epoch 4/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0493 - root_mean_squared_error: 0.0687 - val_loss: 0.0405 - val_root_mean_squared_error: 0.0450
# Epoch 5/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0387 - root_mean_squared_error: 0.0681 - val_loss: 0.0312 - val_root_mean_squared_error: 0.0440
# Epoch 6/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0305 - root_mean_squared_error: 0.0682 - val_loss: 0.0242 - val_root_mean_squared_error: 0.0455
# Epoch 7/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0241 - root_mean_squared_error: 0.0684 - val_loss: 0.0185 - val_root_mean_squared_error: 0.0433
# Epoch 8/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.0680 - val_loss: 0.0143 - val_root_mean_squared_error: 0.0437
# Epoch 9/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0155 - root_mean_squared_error: 0.0680 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0436
# Epoch 10/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0127 - root_mean_squared_error: 0.0683 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0455
# Epoch 11/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.0682 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0447
# Epoch 12/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0090 - root_mean_squared_error: 0.0680 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0424
# Epoch 13/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0679 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0442
# Epoch 14/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0070 - root_mean_squared_error: 0.0683 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0444
# Epoch 15/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - root_mean_squared_error: 0.0682 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0444
# Epoch 16/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0059 - root_mean_squared_error: 0.0681 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0432
# Epoch 17/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0055 - root_mean_squared_error: 0.0677 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0440
# Epoch 18/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0053 - root_mean_squared_error: 0.0677 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0431
# Epoch 19/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0051 - root_mean_squared_error: 0.0679 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0422
# Epoch 20/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0051 - root_mean_squared_error: 0.0681 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0459
# Epoch 21/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0049 - root_mean_squared_error: 0.0678 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0443
# Epoch 22/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0676 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0421
# Epoch 23/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0678 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0445
# Epoch 24/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0676 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0430
# Epoch 25/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0674 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0444
# Epoch 26/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0676 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0426
# Epoch 27/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0678 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0449
# Epoch 28/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0681 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0424
# Epoch 29/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0682 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0441
# Epoch 30/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0681 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0443
# Epoch 31/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0677 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0435
# Epoch 32/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0675 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0432
# Epoch 33/100
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0046 - root_mean_squared_error: 0.0674 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0429

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_gru.history['loss'], label='train_loss')
plt.plot(history_gru.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0030 - root_mean_squared_error: 0.0431
# Test Loss: 0.003018162213265896
# Test RMSE: 0.043124038726091385

# %%
# คำนวณ predicted residuals
yhat_train_resid = res_model.predict(train_X_resid)
yhat_val_resid = res_model.predict(val_X_resid)
yhat_test_resid = res_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('MTC_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 2.3950%
# RMSE: 3.9270

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_lstm_model(lstm_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2331906/3770233378.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-20 00:46:59.115782: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.116556: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.116738: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.117992: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.122726: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.123544: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.123546: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.133956: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.134203: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.136492: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.143480: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.148025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.153904: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.155020: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.165525: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.176707: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.177134: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.192947: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.193625: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.193648: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.194103: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.205038: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.226354: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.234828: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.235526: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.237422: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.237510: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.242024: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.255709: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.255907: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.260650: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:46:59.261383: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:06:42.413626: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:06:42.419364: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:06:42.423853: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 01:06:44.844523: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:06:44.847560: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:06:44.849532: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 01:06:47.059384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:06:47.063992: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:06:47.069617: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 01:06:50.944596: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:06:50.956468: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:06:50.973288: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 2100.4680240154266 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 91, 'beta_1': 0.9, 'LR': 0.013000000000000001, 'L2': 0.001}
# Best RMSE Score: 0.08202656836901882

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
lstm_model = create_lstm_model(lstm_units_1=91 ,beta_1=0.9, LR=0.013, L2=0.001)
lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 91)                62608
#
#  dropout_1 (Dropout)         (None, 91)                0
#
#  dense_1 (Dense)             (None, 7)                 644
#
# =================================================================
# Total params: 63,252
# Trainable params: 63,252
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-20 01:12:54.152257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:12:54.153935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:12:54.155073: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = lstm_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-20 01:12:57.035524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:12:57.037485: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:12:57.038994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 01:12:57.738555: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:12:57.740663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:12:57.742135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 21s - loss: 0.5420 - root_mean_squared_error: 0.6411
# 2024-12-20 01:12:58.978385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:12:58.980705: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:12:58.982089: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 50ms/step - loss: 0.1637 - root_mean_squared_error: 0.2635 - val_loss: 0.0802 - val_root_mean_squared_error: 0.0874
# Epoch 2/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0748 - root_mean_squared_error: 0.1439 - val_loss: 0.0434 - val_root_mean_squared_error: 0.0814
# Epoch 3/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0430 - root_mean_squared_error: 0.1245 - val_loss: 0.0222 - val_root_mean_squared_error: 0.0575
# Epoch 4/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0267 - root_mean_squared_error: 0.1086 - val_loss: 0.0141 - val_root_mean_squared_error: 0.0524
# Epoch 5/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0201 - root_mean_squared_error: 0.1044 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0537
# Epoch 6/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0144 - root_mean_squared_error: 0.0921 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0499
# Epoch 7/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0113 - root_mean_squared_error: 0.0850 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0485
# Epoch 8/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0098 - root_mean_squared_error: 0.0835 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0516
# Epoch 9/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0095 - root_mean_squared_error: 0.0850 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0486
# Epoch 10/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0093 - root_mean_squared_error: 0.0864 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0568
# Epoch 11/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0122 - root_mean_squared_error: 0.1022 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0500
# Epoch 12/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0090 - root_mean_squared_error: 0.0851 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0492
# Epoch 13/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0106 - root_mean_squared_error: 0.0947 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0507
# Epoch 14/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0096 - root_mean_squared_error: 0.0896 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0534
# Epoch 15/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0086 - root_mean_squared_error: 0.0844 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0567
# Epoch 16/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0106 - root_mean_squared_error: 0.0954 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0472
# Epoch 17/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0126 - root_mean_squared_error: 0.1050 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0531
# Epoch 18/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0100 - root_mean_squared_error: 0.0913 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0476
# Epoch 19/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0094 - root_mean_squared_error: 0.0885 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0472
# Epoch 20/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0094 - root_mean_squared_error: 0.0881 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0476
# Epoch 21/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0079 - root_mean_squared_error: 0.0793 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0549

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = lstm_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0044 - root_mean_squared_error: 0.0544
# Test Loss: 0.004448305815458298
# Test RMSE: 0.05442303791642189

# %%
# คำนวณ predicted values
yhat_train = lstm_model.predict(train_X)
yhat_val = lstm_model.predict(val_X)
yhat_test = lstm_model.predict(test_X)
# Out:
# 26/26 [==============================] - 1s 1ms/step
# 2024-12-20 01:13:10.779007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:13:10.780994: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:13:10.782488: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 2024-12-20 01:13:11.401971: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:13:11.404442: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:13:11.405768: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_gru_model(gru_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}
# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2331906/974964917.py:18: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-20 01:22:17.691352: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.712541: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.712854: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.738679: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.743215: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.743265: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.746503: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.749243: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.756720: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.761186: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.766868: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.770315: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.779092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.790530: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.793626: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.797462: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.797514: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.812154: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.812393: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.812439: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.812502: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.815288: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.822529: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.822944: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.823929: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.831547: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.834673: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.844591: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.844881: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.848770: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.850861: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:22:17.855008: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 01:31:54.598999: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:31:54.600935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:31:54.602193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 01:31:54.933753: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:31:54.936320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:31:54.938255: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 01:31:55.570720: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:31:55.573257: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:31:55.574935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 01:31:56.593485: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:31:56.595967: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:31:56.597776: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 1118.0307822227478 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 12, 'beta_1': 0.9, 'LR': 0.018000000000000002, 'L2': 0.001}
# Best RMSE Score: 0.07247293878694842

# %%
gru_model = create_gru_model(gru_units_1=12 ,beta_1=0.9 , LR=0.018, L2=0.001)
gru_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 12)                3384
#
#  dropout_3 (Dropout)         (None, 12)                0
#
#  dense_3 (Dense)             (None, 7)                 91
#
# =================================================================
# Total params: 3,475
# Trainable params: 3,475
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-20 01:48:54.279494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:48:54.281229: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:48:54.282363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = gru_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-20 01:48:57.435664: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:48:57.437744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:48:57.439280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 01:48:58.029803: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:48:58.031830: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:48:58.033307: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 41ms/step - loss: 0.0764 - root_mean_squared_error: 0.1897 - val_loss: 0.0433 - val_root_mean_squared_error: 0.0832
# Epoch 2/150
#  1/13 [=>............................] - ETA: 0s - loss: 0.0432 - root_mean_squared_error: 0.0823
# 2024-12-20 01:48:59.030188: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:48:59.032589: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:48:59.034445: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0405 - root_mean_squared_error: 0.0828 - val_loss: 0.0360 - val_root_mean_squared_error: 0.0842
# Epoch 3/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0310 - root_mean_squared_error: 0.0803 - val_loss: 0.0257 - val_root_mean_squared_error: 0.0762
# Epoch 4/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0230 - root_mean_squared_error: 0.0792 - val_loss: 0.0182 - val_root_mean_squared_error: 0.0681
# Epoch 5/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.0785 - val_loss: 0.0146 - val_root_mean_squared_error: 0.0722
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0141 - root_mean_squared_error: 0.0780 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0593
# Epoch 7/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0116 - root_mean_squared_error: 0.0766 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0568
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0099 - root_mean_squared_error: 0.0760 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0589
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0087 - root_mean_squared_error: 0.0749 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0543
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0082 - root_mean_squared_error: 0.0760 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0516
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0073 - root_mean_squared_error: 0.0738 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0473
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0072 - root_mean_squared_error: 0.0758 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0497
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0070 - root_mean_squared_error: 0.0762 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0552
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0064 - root_mean_squared_error: 0.0731 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0484
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0058 - root_mean_squared_error: 0.0708 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0487
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0059 - root_mean_squared_error: 0.0725 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0472
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0055 - root_mean_squared_error: 0.0706 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0478
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0705 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0479
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0698 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0500
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0057 - root_mean_squared_error: 0.0734 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0487
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0712 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0490
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0055 - root_mean_squared_error: 0.0719 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0510
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0055 - root_mean_squared_error: 0.0720 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0485
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0053 - root_mean_squared_error: 0.0707 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0483
# Epoch 25/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0715 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0475
# Epoch 26/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0688 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0487
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0053 - root_mean_squared_error: 0.0710 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0486
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0705 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0500
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0700 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0482
# Epoch 30/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0702 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0480

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0018 - root_mean_squared_error: 0.0389
# Test Loss: 0.0017975842347368598
# Test RMSE: 0.03892673924565315

# %%
# คำนวณ predicted residuals
yhat_train_resid = gru_model.predict(train_X_resid)
yhat_val_resid = gru_model.predict(val_X_resid)
yhat_test_resid = gru_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-20 01:49:08.446108: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:49:08.448225: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:49:08.449583: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 2024-12-20 01:49:08.871152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 01:49:08.873215: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 01:49:08.874562: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('MTC_Adj_close_prediction By cascaded')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 2.8446%
# RMSE: 1.5655
