# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-19 21:44:56.505364: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-19 21:44:56.513961: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-19 21:44:56.570156: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-19 21:44:56.571339: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-19 21:45:26.196050: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('MTC.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  54.243729  57.50  57.50  56.50  56.75  5741400
# 2019-07-02 00:00:00+00:00  54.007889  57.25  58.00  56.50  57.50  6927300
# 2019-07-03 00:00:00+00:00  53.772045  57.00  57.75  56.75  57.00  3766300
# 2019-07-04 00:00:00+00:00  53.772045  57.00  58.00  56.50  57.25  4936900
# 2019-07-05 00:00:00+00:00  54.007889  57.25  57.50  56.50  56.50  2941100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('MTC Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.650953    0.610778   0.654545    0.625000      0.102442
# 16         0.645089    0.622754   0.654545    0.642857      0.123602
# 17         0.639224    0.616766   0.660606    0.630952      0.067201
# 18         0.639224    0.622754   0.654545    0.636905      0.088088
# 19         0.645089    0.610778   0.654545    0.619048      0.052477
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.645089    0.622754   0.654545    0.642857      0.123602  ...
# 16         0.639224    0.616766   0.660606    0.630952      0.067201  ...
# 17         0.639224    0.622754   0.654545    0.636905      0.088088  ...
# 18         0.645089    0.610778   0.654545    0.619048      0.052477  ...
# 19         0.627495    0.604790   0.636364    0.630952      0.072568  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.678788  0.654762   0.092292        0.668546        0.692004
# 16  0.678788  0.660714   0.046650        0.692004        0.692004
# 17  0.684848  0.666667   0.126459        0.692004        0.692004
# 18  0.703030  0.678571   0.098638        0.692004        0.721327
# 19  0.709091  0.684524   0.046207        0.721327        0.721327
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.692004        0.692004        0.721327        0.721327
# 16        0.692004        0.721327        0.721327        0.727191
# 17        0.721327        0.721327        0.727191        0.686140
# 18        0.721327        0.727191        0.686140        0.721327
# 19        0.727191        0.686140        0.721327        0.803429
#
#     Adj Close(t+7)
# 15        0.727191
# 16        0.686140
# 17        0.721327
# 18        0.803429
# 19        0.680275
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_lstm_model(lstm_units_1, beta_1 ,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_2331899/3692575797.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-19 22:22:25.712413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:25.954640: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:25.963990: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:25.965416: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.116197: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.116727: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.219042: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.276221: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.296675: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.297172: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.306531: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.361071: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.363157: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.443241: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.474338: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.711185: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.719891: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.722647: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.762178: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.774117: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.808701: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:26.873402: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:27.032581: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:27.086165: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:27.120032: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:27.120898: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:27.231860: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:27.396463: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:27.537448: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:27.539119: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:27.554449: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:22:28.009645: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:58:58.876414: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 22:58:58.887236: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 22:58:58.888606: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 22:59:04.439537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 22:59:04.442374: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 22:59:04.464767: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 22:59:09.213773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 22:59:09.240628: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 22:59:09.242489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 22:59:19.570743: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 22:59:19.597160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 22:59:19.616621: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 4069.1618475914 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 95, 'beta_1': 0.9, 'LR': 0.038, 'L2': 0.001}
# Best RMSE Score: 0.08177578452247301

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
lstm_model = create_lstm_model(lstm_units_1=95 ,beta_1=0.9, LR=0.038, L2=0.001)
lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 95)                66880
#
#  dropout_1 (Dropout)         (None, 95)                0
#
#  dense_1 (Dense)             (None, 7)                 672
#
# =================================================================
# Total params: 67,552
# Trainable params: 67,552
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-19 23:04:49.469896: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:04:49.472044: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:04:49.473456: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = lstm_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-19 23:04:53.575316: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:04:53.577297: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:04:53.578844: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 23:04:54.348871: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:04:54.350876: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:04:54.352521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 23s - loss: 0.5186 - root_mean_squared_error: 0.6219
# 2024-12-19 23:04:55.705298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:04:55.707474: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:04:55.709044: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 54ms/step - loss: 0.4106 - root_mean_squared_error: 0.4783 - val_loss: 0.2361 - val_root_mean_squared_error: 0.1545
# Epoch 2/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1933 - root_mean_squared_error: 0.1787 - val_loss: 0.1086 - val_root_mean_squared_error: 0.0855
# Epoch 3/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0879 - root_mean_squared_error: 0.1462 - val_loss: 0.0444 - val_root_mean_squared_error: 0.0894
# Epoch 4/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0448 - root_mean_squared_error: 0.1428 - val_loss: 0.0195 - val_root_mean_squared_error: 0.0584
# Epoch 5/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0384 - root_mean_squared_error: 0.1648 - val_loss: 0.0606 - val_root_mean_squared_error: 0.2151
# Epoch 6/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0447 - root_mean_squared_error: 0.1437 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0796
# Epoch 7/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0270 - root_mean_squared_error: 0.1165 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0577
# Epoch 8/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0303 - root_mean_squared_error: 0.1443 - val_loss: 0.0160 - val_root_mean_squared_error: 0.0688
# Epoch 9/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0210 - root_mean_squared_error: 0.1138 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0588
# Epoch 10/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0144 - root_mean_squared_error: 0.1008 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0577
# Epoch 11/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0118 - root_mean_squared_error: 0.0954 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0498
# Epoch 12/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0174 - root_mean_squared_error: 0.1216 - val_loss: 0.0202 - val_root_mean_squared_error: 0.1222
# Epoch 13/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0167 - root_mean_squared_error: 0.1086 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0584
# Epoch 14/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0111 - root_mean_squared_error: 0.0911 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0565
# Epoch 15/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0098 - root_mean_squared_error: 0.0863 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0504
# Epoch 16/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0084 - root_mean_squared_error: 0.0799 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0668
# Epoch 17/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0157 - root_mean_squared_error: 0.1147 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0770
# Epoch 18/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0132 - root_mean_squared_error: 0.1015 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0523
# Epoch 19/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0139 - root_mean_squared_error: 0.1068 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0508
# Epoch 20/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0119 - root_mean_squared_error: 0.0959 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0585

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = lstm_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0056 - root_mean_squared_error: 0.0601
# Test Loss: 0.0056469333358109
# Test RMSE: 0.060142721980810165

# %%
# คำนวณ predicted values
yhat_train = lstm_model.predict(train_X)
yhat_val = lstm_model.predict(val_X)
yhat_test = lstm_model.predict(test_X)
# Out:
# 26/26 [==============================] - 1s 1ms/step
# 2024-12-19 23:05:07.725640: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:05:07.727866: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:05:07.729401: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 2024-12-19 23:05:08.403786: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:05:08.405854: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:05:08.407262: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_rnn_model(rnn_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2331899/1532983884.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-19 23:32:12.062669: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.064162: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.073436: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.073638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.083822: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.099776: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.099803: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.116294: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.118503: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.130011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.139759: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.150482: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.150943: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.151083: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.185546: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.202413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.205723: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.206110: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.224417: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.224858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.225048: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.255805: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.291180: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.291450: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.300715: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.300917: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.302450: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.322038: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.322115: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.322437: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.322565: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:32:12.353397: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 3558.2305738925934 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 36, 'beta_1': 0.9, 'LR': 0.002, 'L2': 0.005}
# Best RMSE Score: 0.0680140909658795

# %%
rnn_model = create_rnn_model(rnn_units_1=36 ,beta_1=0.9 , LR=0.002, L2=0.005)
rnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 36)                4212
#
#  dropout_3 (Dropout)         (None, 36)                0
#
#  dense_3 (Dense)             (None, 7)                 259
#
# =================================================================
# Total params: 4,471
# Trainable params: 4,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_resid = rnn_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 1s 21ms/step - loss: 0.3517 - root_mean_squared_error: 0.3331 - val_loss: 0.2524 - val_root_mean_squared_error: 0.1388
# Epoch 2/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2785 - root_mean_squared_error: 0.2294 - val_loss: 0.2254 - val_root_mean_squared_error: 0.0894
# Epoch 3/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2403 - root_mean_squared_error: 0.1740 - val_loss: 0.2088 - val_root_mean_squared_error: 0.0855
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2102 - root_mean_squared_error: 0.1262 - val_loss: 0.1924 - val_root_mean_squared_error: 0.0802
# Epoch 5/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1894 - root_mean_squared_error: 0.1023 - val_loss: 0.1764 - val_root_mean_squared_error: 0.0741
# Epoch 6/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1727 - root_mean_squared_error: 0.0922 - val_loss: 0.1615 - val_root_mean_squared_error: 0.0703
# Epoch 7/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1575 - root_mean_squared_error: 0.0853 - val_loss: 0.1474 - val_root_mean_squared_error: 0.0664
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1438 - root_mean_squared_error: 0.0825 - val_loss: 0.1341 - val_root_mean_squared_error: 0.0626
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1309 - root_mean_squared_error: 0.0793 - val_loss: 0.1220 - val_root_mean_squared_error: 0.0606
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1194 - root_mean_squared_error: 0.0787 - val_loss: 0.1108 - val_root_mean_squared_error: 0.0582
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1085 - root_mean_squared_error: 0.0766 - val_loss: 0.1005 - val_root_mean_squared_error: 0.0569
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0986 - root_mean_squared_error: 0.0755 - val_loss: 0.0911 - val_root_mean_squared_error: 0.0555
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0896 - root_mean_squared_error: 0.0745 - val_loss: 0.0825 - val_root_mean_squared_error: 0.0545
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0813 - root_mean_squared_error: 0.0731 - val_loss: 0.0747 - val_root_mean_squared_error: 0.0536
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0738 - root_mean_squared_error: 0.0724 - val_loss: 0.0676 - val_root_mean_squared_error: 0.0531
# Epoch 16/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0672 - root_mean_squared_error: 0.0731 - val_loss: 0.0611 - val_root_mean_squared_error: 0.0515
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0610 - root_mean_squared_error: 0.0731 - val_loss: 0.0553 - val_root_mean_squared_error: 0.0513
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0552 - root_mean_squared_error: 0.0708 - val_loss: 0.0501 - val_root_mean_squared_error: 0.0516
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0502 - root_mean_squared_error: 0.0706 - val_loss: 0.0452 - val_root_mean_squared_error: 0.0506
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0458 - root_mean_squared_error: 0.0715 - val_loss: 0.0410 - val_root_mean_squared_error: 0.0507
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0416 - root_mean_squared_error: 0.0710 - val_loss: 0.0370 - val_root_mean_squared_error: 0.0498
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0379 - root_mean_squared_error: 0.0707 - val_loss: 0.0336 - val_root_mean_squared_error: 0.0505
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0345 - root_mean_squared_error: 0.0705 - val_loss: 0.0303 - val_root_mean_squared_error: 0.0497
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0314 - root_mean_squared_error: 0.0695 - val_loss: 0.0274 - val_root_mean_squared_error: 0.0493
# Epoch 25/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0286 - root_mean_squared_error: 0.0695 - val_loss: 0.0248 - val_root_mean_squared_error: 0.0488
# Epoch 26/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0263 - root_mean_squared_error: 0.0701 - val_loss: 0.0226 - val_root_mean_squared_error: 0.0497
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0239 - root_mean_squared_error: 0.0689 - val_loss: 0.0205 - val_root_mean_squared_error: 0.0489
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0219 - root_mean_squared_error: 0.0688 - val_loss: 0.0186 - val_root_mean_squared_error: 0.0488
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0201 - root_mean_squared_error: 0.0687 - val_loss: 0.0169 - val_root_mean_squared_error: 0.0490
# Epoch 30/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0185 - root_mean_squared_error: 0.0685 - val_loss: 0.0156 - val_root_mean_squared_error: 0.0503
# Epoch 31/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0172 - root_mean_squared_error: 0.0692 - val_loss: 0.0140 - val_root_mean_squared_error: 0.0482
# Epoch 32/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0161 - root_mean_squared_error: 0.0705 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0514
# Epoch 33/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0148 - root_mean_squared_error: 0.0699 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0482
# Epoch 34/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0136 - root_mean_squared_error: 0.0685 - val_loss: 0.0106 - val_root_mean_squared_error: 0.0475
# Epoch 35/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0127 - root_mean_squared_error: 0.0683 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0481
# Epoch 36/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0118 - root_mean_squared_error: 0.0683 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0494
# Epoch 37/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0111 - root_mean_squared_error: 0.0685 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0493
# Epoch 38/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0105 - root_mean_squared_error: 0.0693 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0478
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0099 - root_mean_squared_error: 0.0688 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0504
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0096 - root_mean_squared_error: 0.0706 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0479
# Epoch 41/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0090 - root_mean_squared_error: 0.0696 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0491
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0083 - root_mean_squared_error: 0.0679 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0500
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0079 - root_mean_squared_error: 0.0679 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0485
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0079 - root_mean_squared_error: 0.0703 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0478
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0081 - root_mean_squared_error: 0.0737 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0483
# Epoch 46/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0072 - root_mean_squared_error: 0.0692 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0486
# Epoch 47/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0068 - root_mean_squared_error: 0.0678 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0485
# Epoch 48/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0065 - root_mean_squared_error: 0.0672 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0480
# Epoch 49/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0063 - root_mean_squared_error: 0.0677 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0481
# Epoch 50/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0061 - root_mean_squared_error: 0.0670 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0494
# Epoch 51/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0060 - root_mean_squared_error: 0.0680 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0478
# Epoch 52/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0058 - root_mean_squared_error: 0.0674 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0473
# Epoch 53/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0056 - root_mean_squared_error: 0.0667 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0478
# Epoch 54/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0058 - root_mean_squared_error: 0.0686 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0479
# Epoch 55/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0056 - root_mean_squared_error: 0.0678 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0477
# Epoch 56/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0055 - root_mean_squared_error: 0.0681 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0478
# Epoch 57/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0676 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0486
# Epoch 58/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0683 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0481
# Epoch 59/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0676 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0488
# Epoch 60/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0676 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0470
# Epoch 61/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0682 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0495
# Epoch 62/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0051 - root_mean_squared_error: 0.0673 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0464
# Epoch 63/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0051 - root_mean_squared_error: 0.0679 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0470
# Epoch 64/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0690 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0480
# Epoch 65/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0703 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0478
# Epoch 66/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0693 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0465
# Epoch 67/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0053 - root_mean_squared_error: 0.0698 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0478
# Epoch 68/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0705 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0467
# Epoch 69/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0051 - root_mean_squared_error: 0.0685 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0467
# Epoch 70/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0683 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0481
# Epoch 71/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0676 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0475
# Epoch 72/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0673 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0482
# Epoch 73/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0682 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0481
# Epoch 74/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0682 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0493

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0026 - root_mean_squared_error: 0.0468
# Test Loss: 0.0025547672994434834
# Test RMSE: 0.046803612262010574

# %%
# คำนวณ predicted residuals
yhat_train_resid = rnn_model.predict(train_X_resid)
yhat_val_resid = rnn_model.predict(val_X_resid)
yhat_test_resid = rnn_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('MTC_Adj_close_prediction By cascaded')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.6259%
# RMSE: 1.8822
