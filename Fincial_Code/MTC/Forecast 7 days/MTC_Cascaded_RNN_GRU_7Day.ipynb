# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-19 21:47:18.604182: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-19 21:47:18.611703: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-19 21:47:18.669503: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-19 21:47:18.671425: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-19 21:47:48.019523: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('MTC.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  54.243729  57.50  57.50  56.50  56.75  5741400
# 2019-07-02 00:00:00+00:00  54.007889  57.25  58.00  56.50  57.50  6927300
# 2019-07-03 00:00:00+00:00  53.772045  57.00  57.75  56.75  57.00  3766300
# 2019-07-04 00:00:00+00:00  53.772045  57.00  58.00  56.50  57.25  4936900
# 2019-07-05 00:00:00+00:00  54.007889  57.25  57.50  56.50  56.50  2941100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('MTC Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df =df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.650953    0.610778   0.654545    0.625000      0.102442
# 16         0.645089    0.622754   0.654545    0.642857      0.123602
# 17         0.639224    0.616766   0.660606    0.630952      0.067201
# 18         0.639224    0.622754   0.654545    0.636905      0.088088
# 19         0.645089    0.610778   0.654545    0.619048      0.052477
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.645089    0.622754   0.654545    0.642857      0.123602  ...
# 16         0.639224    0.616766   0.660606    0.630952      0.067201  ...
# 17         0.639224    0.622754   0.654545    0.636905      0.088088  ...
# 18         0.645089    0.610778   0.654545    0.619048      0.052477  ...
# 19         0.627495    0.604790   0.636364    0.630952      0.072568  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.678788  0.654762   0.092292        0.668546        0.692004
# 16  0.678788  0.660714   0.046650        0.692004        0.692004
# 17  0.684848  0.666667   0.126459        0.692004        0.692004
# 18  0.703030  0.678571   0.098638        0.692004        0.721326
# 19  0.709091  0.684524   0.046207        0.721326        0.721326
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.692004        0.692004        0.721326        0.721326
# 16        0.692004        0.721326        0.721326        0.727191
# 17        0.721326        0.721326        0.727191        0.686140
# 18        0.721326        0.727191        0.686140        0.721326
# 19        0.727191        0.686140        0.721326        0.803429
#
#     Adj Close(t+7)
# 15        0.727191
# 16        0.686140
# 17        0.721326
# 18        0.803429
# 19        0.680275
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_rnn_model(rnn_units_1, beta_1 ,LR,L2):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_2331902/610512278.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-19 22:23:13.463539: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:13.602201: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:13.602202: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:13.740576: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:13.770413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:13.796858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:13.797116: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:13.897759: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:13.962485: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.071837: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.164242: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.242381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.276766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.413444: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.417567: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.453168: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.453261: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.499162: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.532296: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.597544: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.600407: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.759811: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.963274: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:14.963360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:15.050579: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:15.112485: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:15.249116: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:15.295456: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:15.298953: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:15.415389: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:15.617613: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:23:15.748926: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 4154.9567975997925 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 17, 'beta_1': 0.8, 'LR': 0.004, 'L2': 0.001}
# Best RMSE Score: 0.06844603487338523

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
rnn_model = create_rnn_model(rnn_units_1=17 ,beta_1=0.8, LR=0.004, L2=0.001)
rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 17)                1666
#
#  dropout_1 (Dropout)         (None, 17)                0
#
#  dense_1 (Dense)             (None, 7)                 126
#
# =================================================================
# Total params: 1,792
# Trainable params: 1,792
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 2s 37ms/step - loss: 0.5104 - root_mean_squared_error: 0.6954 - val_loss: 0.0649 - val_root_mean_squared_error: 0.1954
# Epoch 2/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0971 - root_mean_squared_error: 0.2657 - val_loss: 0.0587 - val_root_mean_squared_error: 0.1804
# Epoch 3/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0797 - root_mean_squared_error: 0.2321 - val_loss: 0.0458 - val_root_mean_squared_error: 0.1428
# Epoch 4/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0699 - root_mean_squared_error: 0.2116 - val_loss: 0.0402 - val_root_mean_squared_error: 0.1243
# Epoch 5/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0625 - root_mean_squared_error: 0.1951 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1110
# Epoch 6/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0578 - root_mean_squared_error: 0.1846 - val_loss: 0.0335 - val_root_mean_squared_error: 0.1007
# Epoch 7/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0546 - root_mean_squared_error: 0.1776 - val_loss: 0.0311 - val_root_mean_squared_error: 0.0917
# Epoch 8/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0488 - root_mean_squared_error: 0.1625 - val_loss: 0.0293 - val_root_mean_squared_error: 0.0850
# Epoch 9/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0457 - root_mean_squared_error: 0.1549 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0789
# Epoch 10/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0441 - root_mean_squared_error: 0.1518 - val_loss: 0.0264 - val_root_mean_squared_error: 0.0747
# Epoch 11/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0411 - root_mean_squared_error: 0.1434 - val_loss: 0.0252 - val_root_mean_squared_error: 0.0712
# Epoch 12/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0387 - root_mean_squared_error: 0.1371 - val_loss: 0.0241 - val_root_mean_squared_error: 0.0674
# Epoch 13/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0369 - root_mean_squared_error: 0.1328 - val_loss: 0.0233 - val_root_mean_squared_error: 0.0655
# Epoch 14/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0365 - root_mean_squared_error: 0.1334 - val_loss: 0.0226 - val_root_mean_squared_error: 0.0644
# Epoch 15/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0343 - root_mean_squared_error: 0.1268 - val_loss: 0.0218 - val_root_mean_squared_error: 0.0628
# Epoch 16/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0339 - root_mean_squared_error: 0.1273 - val_loss: 0.0211 - val_root_mean_squared_error: 0.0610
# Epoch 17/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0317 - root_mean_squared_error: 0.1207 - val_loss: 0.0203 - val_root_mean_squared_error: 0.0586
# Epoch 18/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0306 - root_mean_squared_error: 0.1180 - val_loss: 0.0197 - val_root_mean_squared_error: 0.0577
# Epoch 19/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0303 - root_mean_squared_error: 0.1187 - val_loss: 0.0193 - val_root_mean_squared_error: 0.0586
# Epoch 20/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0289 - root_mean_squared_error: 0.1149 - val_loss: 0.0187 - val_root_mean_squared_error: 0.0575
# Epoch 21/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0280 - root_mean_squared_error: 0.1129 - val_loss: 0.0180 - val_root_mean_squared_error: 0.0549
# Epoch 22/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0273 - root_mean_squared_error: 0.1117 - val_loss: 0.0176 - val_root_mean_squared_error: 0.0554
# Epoch 23/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0261 - root_mean_squared_error: 0.1085 - val_loss: 0.0170 - val_root_mean_squared_error: 0.0535
# Epoch 24/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0263 - root_mean_squared_error: 0.1110 - val_loss: 0.0166 - val_root_mean_squared_error: 0.0534
# Epoch 25/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0251 - root_mean_squared_error: 0.1075 - val_loss: 0.0161 - val_root_mean_squared_error: 0.0526
# Epoch 26/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0239 - root_mean_squared_error: 0.1037 - val_loss: 0.0157 - val_root_mean_squared_error: 0.0525
# Epoch 27/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0232 - root_mean_squared_error: 0.1023 - val_loss: 0.0155 - val_root_mean_squared_error: 0.0541
# Epoch 28/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0231 - root_mean_squared_error: 0.1035 - val_loss: 0.0149 - val_root_mean_squared_error: 0.0522
# Epoch 29/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0224 - root_mean_squared_error: 0.1019 - val_loss: 0.0145 - val_root_mean_squared_error: 0.0513
# Epoch 30/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0216 - root_mean_squared_error: 0.0994 - val_loss: 0.0143 - val_root_mean_squared_error: 0.0525
# Epoch 31/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0222 - root_mean_squared_error: 0.1042 - val_loss: 0.0138 - val_root_mean_squared_error: 0.0510
# Epoch 32/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0215 - root_mean_squared_error: 0.1021 - val_loss: 0.0133 - val_root_mean_squared_error: 0.0499
# Epoch 33/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0213 - root_mean_squared_error: 0.1029 - val_loss: 0.0132 - val_root_mean_squared_error: 0.0517
# Epoch 34/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0200 - root_mean_squared_error: 0.0981 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0495
# Epoch 35/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0190 - root_mean_squared_error: 0.0940 - val_loss: 0.0125 - val_root_mean_squared_error: 0.0504
# Epoch 36/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0194 - root_mean_squared_error: 0.0977 - val_loss: 0.0123 - val_root_mean_squared_error: 0.0515
# Epoch 37/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0184 - root_mean_squared_error: 0.0940 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0501
# Epoch 38/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0181 - root_mean_squared_error: 0.0938 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0504
# Epoch 39/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0175 - root_mean_squared_error: 0.0919 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0519
# Epoch 40/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0170 - root_mean_squared_error: 0.0907 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0488
# Epoch 41/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0166 - root_mean_squared_error: 0.0900 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0508
# Epoch 42/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0168 - root_mean_squared_error: 0.0921 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0489
# Epoch 43/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0176 - root_mean_squared_error: 0.0976 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0487
# Epoch 44/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0163 - root_mean_squared_error: 0.0919 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0497
# Epoch 45/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0174 - root_mean_squared_error: 0.0990 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0505
# Epoch 46/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0163 - root_mean_squared_error: 0.0943 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0484
# Epoch 47/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0153 - root_mean_squared_error: 0.0897 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0476
# Epoch 48/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.0933 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0545
# Epoch 49/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0166 - root_mean_squared_error: 0.0987 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0513
# Epoch 50/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0144 - root_mean_squared_error: 0.0881 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0477
# Epoch 51/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0143 - root_mean_squared_error: 0.0884 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0482
# Epoch 52/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0137 - root_mean_squared_error: 0.0860 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0479
# Epoch 53/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0134 - root_mean_squared_error: 0.0854 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0488
# Epoch 54/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0136 - root_mean_squared_error: 0.0876 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0489
# Epoch 55/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.0849 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0506
# Epoch 56/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0133 - root_mean_squared_error: 0.0876 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0474
# Epoch 57/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0136 - root_mean_squared_error: 0.0903 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0522
# Epoch 58/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0142 - root_mean_squared_error: 0.0943 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0507
# Epoch 59/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.0910 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0511
# Epoch 60/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0119 - root_mean_squared_error: 0.0823 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0466
# Epoch 61/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0121 - root_mean_squared_error: 0.0843 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0475
# Epoch 62/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0115 - root_mean_squared_error: 0.0815 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0490
# Epoch 63/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0116 - root_mean_squared_error: 0.0832 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0474
# Epoch 64/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0117 - root_mean_squared_error: 0.0844 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0538
# Epoch 65/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.0927 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0595
# Epoch 66/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0122 - root_mean_squared_error: 0.0888 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0471
# Epoch 67/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0115 - root_mean_squared_error: 0.0851 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0488
# Epoch 68/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0106 - root_mean_squared_error: 0.0802 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0468
# Epoch 69/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0111 - root_mean_squared_error: 0.0843 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0475
# Epoch 70/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0107 - root_mean_squared_error: 0.0825 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0464
# Epoch 71/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0102 - root_mean_squared_error: 0.0797 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0471
# Epoch 72/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0102 - root_mean_squared_error: 0.0804 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0475
# Epoch 73/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0105 - root_mean_squared_error: 0.0831 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0467
# Epoch 74/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0098 - root_mean_squared_error: 0.0790 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0510
# Epoch 75/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0101 - root_mean_squared_error: 0.0813 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0527
# Epoch 76/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0110 - root_mean_squared_error: 0.0874 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0469
# Epoch 77/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0096 - root_mean_squared_error: 0.0797 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0512
# Epoch 78/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0135 - root_mean_squared_error: 0.1013 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0475
# Epoch 79/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0123 - root_mean_squared_error: 0.0959 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0464
# Epoch 80/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0099 - root_mean_squared_error: 0.0829 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0514
# Epoch 81/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0107 - root_mean_squared_error: 0.0878 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0489
# Epoch 82/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0093 - root_mean_squared_error: 0.0795 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0483
# Epoch 83/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0092 - root_mean_squared_error: 0.0793 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0462
# Epoch 84/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0095 - root_mean_squared_error: 0.0817 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0536
# Epoch 85/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0095 - root_mean_squared_error: 0.0824 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0461
# Epoch 86/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0100 - root_mean_squared_error: 0.0858 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0484
# Epoch 87/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0090 - root_mean_squared_error: 0.0796 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0459
# Epoch 88/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0085 - root_mean_squared_error: 0.0769 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0466
# Epoch 89/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0085 - root_mean_squared_error: 0.0776 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0462
# Epoch 90/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0088 - root_mean_squared_error: 0.0797 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0458
# Epoch 91/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0088 - root_mean_squared_error: 0.0799 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0456
# Epoch 92/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0093 - root_mean_squared_error: 0.0831 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0463
# Epoch 93/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0077 - root_mean_squared_error: 0.0732 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0463
# Epoch 94/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0083 - root_mean_squared_error: 0.0776 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0461
# Epoch 95/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0088 - root_mean_squared_error: 0.0811 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0457
# Epoch 96/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0082 - root_mean_squared_error: 0.0780 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0497
# Epoch 97/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0102 - root_mean_squared_error: 0.0902 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0494
# Epoch 98/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0087 - root_mean_squared_error: 0.0814 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0526
# Epoch 99/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0083 - root_mean_squared_error: 0.0795 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0458
# Epoch 100/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0078 - root_mean_squared_error: 0.0766 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0461
# Epoch 101/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0097 - root_mean_squared_error: 0.0879 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0463
# Epoch 102/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0082 - root_mean_squared_error: 0.0795 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0463
# Epoch 103/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0082 - root_mean_squared_error: 0.0799 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0467
# Epoch 104/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0084 - root_mean_squared_error: 0.0810 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0487
# Epoch 105/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0071 - root_mean_squared_error: 0.0730 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0476
# Epoch 106/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0078 - root_mean_squared_error: 0.0781 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0478
# Epoch 107/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0090 - root_mean_squared_error: 0.0854 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0509
# Epoch 108/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0080 - root_mean_squared_error: 0.0796 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0482
# Epoch 109/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0088 - root_mean_squared_error: 0.0845 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0461
# Epoch 110/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0075 - root_mean_squared_error: 0.0769 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0490
# Epoch 111/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0073 - root_mean_squared_error: 0.0757 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0462
# Epoch 112/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0081 - root_mean_squared_error: 0.0810 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0462
# Epoch 113/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0078 - root_mean_squared_error: 0.0790 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0472
# Epoch 114/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0073 - root_mean_squared_error: 0.0761 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0454
# Epoch 115/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0072 - root_mean_squared_error: 0.0757 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0459
# Epoch 116/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0075 - root_mean_squared_error: 0.0780 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0462
# Epoch 117/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0070 - root_mean_squared_error: 0.0746 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0491
# Epoch 118/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0071 - root_mean_squared_error: 0.0753 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0465
# Epoch 119/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0068 - root_mean_squared_error: 0.0739 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0458
# Epoch 120/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0078 - root_mean_squared_error: 0.0803 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0496
# Epoch 121/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0077 - root_mean_squared_error: 0.0796 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0457
# Epoch 122/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0074 - root_mean_squared_error: 0.0782 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0467
# Epoch 123/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0072 - root_mean_squared_error: 0.0772 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0459
# Epoch 124/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0068 - root_mean_squared_error: 0.0744 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0463
# Epoch 125/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0067 - root_mean_squared_error: 0.0742 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0455
# Epoch 126/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0063 - root_mean_squared_error: 0.0710 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0467
# Epoch 127/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0066 - root_mean_squared_error: 0.0738 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0460
# Epoch 128/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0077 - root_mean_squared_error: 0.0811 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0505
# Epoch 129/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0083 - root_mean_squared_error: 0.0847 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0458
# Epoch 130/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0064 - root_mean_squared_error: 0.0723 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0475
# Epoch 131/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0065 - root_mean_squared_error: 0.0737 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0477
# Epoch 132/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0068 - root_mean_squared_error: 0.0756 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0455
# Epoch 133/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0070 - root_mean_squared_error: 0.0770 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0457
# Epoch 134/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0064 - root_mean_squared_error: 0.0733 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0500
# Epoch 135/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0813 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0459
# Epoch 136/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0067 - root_mean_squared_error: 0.0754 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0455
# Epoch 137/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0058 - root_mean_squared_error: 0.0693 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0455
# Epoch 138/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0060 - root_mean_squared_error: 0.0705 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0465
# Epoch 139/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0064 - root_mean_squared_error: 0.0737 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0470
# Epoch 140/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0059 - root_mean_squared_error: 0.0702 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0461
# Epoch 141/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0060 - root_mean_squared_error: 0.0712 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0469
# Epoch 142/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0062 - root_mean_squared_error: 0.0728 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0456
# Epoch 143/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0061 - root_mean_squared_error: 0.0716 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0470
# Epoch 144/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0069 - root_mean_squared_error: 0.0775 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0468
# Epoch 145/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0073 - root_mean_squared_error: 0.0802 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0457
# Epoch 146/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0078 - root_mean_squared_error: 0.0829 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0451
# Epoch 147/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0067 - root_mean_squared_error: 0.0763 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0468
# Epoch 148/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0060 - root_mean_squared_error: 0.0715 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0454
# Epoch 149/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0062 - root_mean_squared_error: 0.0732 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0461
# Epoch 150/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0058 - root_mean_squared_error: 0.0707 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0471

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0047 - root_mean_squared_error: 0.0620
# Test Loss: 0.004672325681895018
# Test RMSE: 0.06195675581693649

# %%
# คำนวณ predicted values
yhat_train = rnn_model.predict(train_X)
yhat_val = rnn_model.predict(val_X)
yhat_test = rnn_model.predict(test_X)
# Out:
# 26/26 [==============================] - 1s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_gru_model(gru_units_1,beta_1,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2331902/1327760477.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-19 23:37:50.860226: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.882044: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.890748: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.903995: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.943306: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.944055: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.944328: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.945385: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.946091: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.946922: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.958753: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.959261: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:50.968019: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.003562: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.004489: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.024558: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.025158: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.039473: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.039678: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.059433: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.060047: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.080126: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.080269: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.080514: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.080669: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.119998: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.134580: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.153031: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.153885: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.153895: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.154068: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:37:51.179293: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 00:09:26.261574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:09:26.265068: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:09:26.268832: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 00:09:27.881242: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:09:27.888609: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:09:27.901709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 00:09:30.799447: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:09:30.804377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:09:30.806221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 00:09:35.684952: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:09:35.701454: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:09:35.737846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 3712.2758028507233 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 23, 'beta_1': 0.8, 'LR': 0.018000000000000002, 'L2': 0.005}
# Best RMSE Score: 0.06317158407081559

# %%
gru_model = create_gru_model(gru_units_1=23 ,beta_1=0.8, LR=0.018, L2=0.005)
gru_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 23)                7245
#
#  dropout_3 (Dropout)         (None, 23)                0
#
#  dense_3 (Dense)             (None, 7)                 168
#
# =================================================================
# Total params: 7,413
# Trainable params: 7,413
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-20 00:28:03.824610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:28:03.826623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:28:03.827912: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = gru_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-20 00:28:06.740157: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:28:06.742572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:28:06.744295: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 00:28:07.344212: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:28:07.346550: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:28:07.348240: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 41ms/step - loss: 0.2298 - root_mean_squared_error: 0.1830 - val_loss: 0.0877 - val_root_mean_squared_error: 0.0634
# Epoch 2/150
#  1/13 [=>............................] - ETA: 0s - loss: 0.0879 - root_mean_squared_error: 0.0652
# 2024-12-20 00:28:08.429193: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:28:08.431548: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:28:08.433278: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0512 - root_mean_squared_error: 0.0708 - val_loss: 0.0204 - val_root_mean_squared_error: 0.0469
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0149 - root_mean_squared_error: 0.0692 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0467
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - root_mean_squared_error: 0.0775 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0473
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0053 - root_mean_squared_error: 0.0660 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0475
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0052 - root_mean_squared_error: 0.0699 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0458
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0673 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0472
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0045 - root_mean_squared_error: 0.0661 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0477
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0048 - root_mean_squared_error: 0.0681 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0451
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0045 - root_mean_squared_error: 0.0662 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0467
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0464
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0043 - root_mean_squared_error: 0.0650 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0467
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0654 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0461
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0678 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0484

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0024 - root_mean_squared_error: 0.0476
# Test Loss: 0.0023556773085147142
# Test RMSE: 0.04756877198815346

# %%
# คำนวณ predicted residuals
yhat_train_resid = gru_model.predict(train_X_resid)
yhat_val_resid = gru_model.predict(val_X_resid)
yhat_test_resid = gru_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-20 00:28:22.105600: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:28:22.107783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:28:22.109337: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 2024-12-20 00:28:22.539886: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:28:22.541969: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:28:22.543371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('MTC_Adj_close_prediction By cascaded')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.6460%
# RMSE: 1.9130
