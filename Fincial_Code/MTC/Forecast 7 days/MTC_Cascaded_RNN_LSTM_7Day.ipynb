# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-19 21:44:12.236082: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-19 21:44:12.280402: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-19 21:44:12.549962: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-19 21:44:12.552451: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-19 21:44:42.517244: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('MTC.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  54.243725  57.50  57.50  56.50  56.75  5741400
# 2019-07-02 00:00:00+00:00  54.007885  57.25  58.00  56.50  57.50  6927300
# 2019-07-03 00:00:00+00:00  53.772049  57.00  57.75  56.75  57.00  3766300
# 2019-07-04 00:00:00+00:00  53.772049  57.00  58.00  56.50  57.25  4936900
# 2019-07-05 00:00:00+00:00  54.007885  57.25  57.50  56.50  56.50  2941100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('MTC Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.650953    0.610778   0.654545    0.625000      0.102442
# 16         0.645089    0.622754   0.654545    0.642857      0.123602
# 17         0.639224    0.616766   0.660606    0.630952      0.067201
# 18         0.639224    0.622754   0.654545    0.636905      0.088088
# 19         0.645089    0.610778   0.654545    0.619048      0.052477
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.645089    0.622754   0.654545    0.642857      0.123602  ...
# 16         0.639224    0.616766   0.660606    0.630952      0.067201  ...
# 17         0.639224    0.622754   0.654545    0.636905      0.088088  ...
# 18         0.645089    0.610778   0.654545    0.619048      0.052477  ...
# 19         0.627495    0.604790   0.636364    0.630952      0.072568  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.678788  0.654762   0.092292        0.668547        0.692004
# 16  0.678788  0.660714   0.046650        0.692004        0.692004
# 17  0.684848  0.666667   0.126459        0.692004        0.692004
# 18  0.703030  0.678571   0.098638        0.692004        0.721326
# 19  0.709091  0.684524   0.046207        0.721326        0.721326
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.692004        0.692004        0.721326        0.721326
# 16        0.692004        0.721326        0.721326        0.727191
# 17        0.721326        0.721326        0.727191        0.686140
# 18        0.721326        0.727191        0.686140        0.721326
# 19        0.727191        0.686140        0.721326        0.803429
#
#     Adj Close(t+7)
# 15        0.727191
# 16        0.686140
# 17        0.721326
# 18        0.803429
# 19        0.680275
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_rnn_model(rnn_units_1,LR,L2,beta_1):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2331898/3334002836.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-19 22:20:43.668089: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.677606: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.678671: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.703985: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.704152: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.713616: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.715910: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.725981: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.737106: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.737137: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.774550: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.775193: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.807585: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.817464: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.825840: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.837192: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.838090: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.875433: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.887320: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.887322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.887757: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.911259: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.912150: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.912154: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.935627: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.945121: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.946458: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.958017: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.976758: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.987928: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:43.988483: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:20:44.000180: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 22:54:27.558465: W tensorflow/core/data/root_dataset.cc:273] Optimization loop failed: CANCELLED: Operation was cancelled
# Execution time: 3865.329391479492 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 36, 'beta_1': 0.9, 'LR': 0.002, 'L2': 0.005}
# Best RMSE Score: 0.06834486165278063

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
rnn_model = create_rnn_model(rnn_units_1=36, LR=0.002, L2=0.005, beta_1=0.9)
rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 36)                4212
#
#  dropout_1 (Dropout)         (None, 36)                0
#
#  dense_1 (Dense)             (None, 7)                 259
#
# =================================================================
# Total params: 4,471
# Trainable params: 4,471
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 1s 21ms/step - loss: 0.4050 - root_mean_squared_error: 0.4028 - val_loss: 0.2741 - val_root_mean_squared_error: 0.1938
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2933 - root_mean_squared_error: 0.2521 - val_loss: 0.2330 - val_root_mean_squared_error: 0.1072
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2597 - root_mean_squared_error: 0.2131 - val_loss: 0.2198 - val_root_mean_squared_error: 0.1185
# Epoch 4/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2313 - root_mean_squared_error: 0.1814 - val_loss: 0.1983 - val_root_mean_squared_error: 0.0918
# Epoch 5/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2063 - root_mean_squared_error: 0.1529 - val_loss: 0.1813 - val_root_mean_squared_error: 0.0810
# Epoch 6/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1885 - root_mean_squared_error: 0.1430 - val_loss: 0.1656 - val_root_mean_squared_error: 0.0726
# Epoch 7/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1707 - root_mean_squared_error: 0.1295 - val_loss: 0.1516 - val_root_mean_squared_error: 0.0699
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1553 - root_mean_squared_error: 0.1201 - val_loss: 0.1382 - val_root_mean_squared_error: 0.0634
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1415 - root_mean_squared_error: 0.1130 - val_loss: 0.1261 - val_root_mean_squared_error: 0.0601
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1302 - root_mean_squared_error: 0.1127 - val_loss: 0.1151 - val_root_mean_squared_error: 0.0577
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1192 - root_mean_squared_error: 0.1100 - val_loss: 0.1051 - val_root_mean_squared_error: 0.0568
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1090 - root_mean_squared_error: 0.1066 - val_loss: 0.0960 - val_root_mean_squared_error: 0.0557
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1000 - root_mean_squared_error: 0.1049 - val_loss: 0.0875 - val_root_mean_squared_error: 0.0535
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0919 - root_mean_squared_error: 0.1038 - val_loss: 0.0798 - val_root_mean_squared_error: 0.0513
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0839 - root_mean_squared_error: 0.1000 - val_loss: 0.0732 - val_root_mean_squared_error: 0.0534
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0772 - root_mean_squared_error: 0.0990 - val_loss: 0.0667 - val_root_mean_squared_error: 0.0515
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0711 - root_mean_squared_error: 0.0983 - val_loss: 0.0610 - val_root_mean_squared_error: 0.0502
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0655 - root_mean_squared_error: 0.0973 - val_loss: 0.0559 - val_root_mean_squared_error: 0.0511
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0605 - root_mean_squared_error: 0.0970 - val_loss: 0.0511 - val_root_mean_squared_error: 0.0499
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0557 - root_mean_squared_error: 0.0951 - val_loss: 0.0468 - val_root_mean_squared_error: 0.0492
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0514 - root_mean_squared_error: 0.0940 - val_loss: 0.0431 - val_root_mean_squared_error: 0.0504
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0480 - root_mean_squared_error: 0.0952 - val_loss: 0.0396 - val_root_mean_squared_error: 0.0503
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0450 - root_mean_squared_error: 0.0970 - val_loss: 0.0362 - val_root_mean_squared_error: 0.0479
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0420 - root_mean_squared_error: 0.0975 - val_loss: 0.0333 - val_root_mean_squared_error: 0.0477
# Epoch 25/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0383 - root_mean_squared_error: 0.0923 - val_loss: 0.0306 - val_root_mean_squared_error: 0.0466
# Epoch 26/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0358 - root_mean_squared_error: 0.0920 - val_loss: 0.0284 - val_root_mean_squared_error: 0.0481
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0340 - root_mean_squared_error: 0.0948 - val_loss: 0.0263 - val_root_mean_squared_error: 0.0489
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0314 - root_mean_squared_error: 0.0917 - val_loss: 0.0242 - val_root_mean_squared_error: 0.0471
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0291 - root_mean_squared_error: 0.0895 - val_loss: 0.0223 - val_root_mean_squared_error: 0.0464
# Epoch 30/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0275 - root_mean_squared_error: 0.0900 - val_loss: 0.0207 - val_root_mean_squared_error: 0.0463
# Epoch 31/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0263 - root_mean_squared_error: 0.0917 - val_loss: 0.0193 - val_root_mean_squared_error: 0.0471
# Epoch 32/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0245 - root_mean_squared_error: 0.0899 - val_loss: 0.0182 - val_root_mean_squared_error: 0.0492
# Epoch 33/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0229 - root_mean_squared_error: 0.0883 - val_loss: 0.0166 - val_root_mean_squared_error: 0.0462
# Epoch 34/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0213 - root_mean_squared_error: 0.0857 - val_loss: 0.0156 - val_root_mean_squared_error: 0.0473
# Epoch 35/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0204 - root_mean_squared_error: 0.0869 - val_loss: 0.0144 - val_root_mean_squared_error: 0.0465
# Epoch 36/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0190 - root_mean_squared_error: 0.0847 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0469
# Epoch 37/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0182 - root_mean_squared_error: 0.0852 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0463
# Epoch 38/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0174 - root_mean_squared_error: 0.0859 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0476
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0165 - root_mean_squared_error: 0.0849 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0486
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0153 - root_mean_squared_error: 0.0825 - val_loss: 0.0106 - val_root_mean_squared_error: 0.0490
# Epoch 41/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0154 - root_mean_squared_error: 0.0866 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0462
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0144 - root_mean_squared_error: 0.0844 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0460
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0140 - root_mean_squared_error: 0.0855 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0484
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0136 - root_mean_squared_error: 0.0857 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0463
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0131 - root_mean_squared_error: 0.0854 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0460
# Epoch 46/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0121 - root_mean_squared_error: 0.0824 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0469
# Epoch 47/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0117 - root_mean_squared_error: 0.0825 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0497
# Epoch 48/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0121 - root_mean_squared_error: 0.0867 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0471
# Epoch 49/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0107 - root_mean_squared_error: 0.0803 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0467
# Epoch 50/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0106 - root_mean_squared_error: 0.0816 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0477
# Epoch 51/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0105 - root_mean_squared_error: 0.0828 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0461
# Epoch 52/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0101 - root_mean_squared_error: 0.0815 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0459
# Epoch 53/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0102 - root_mean_squared_error: 0.0837 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0462
# Epoch 54/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0092 - root_mean_squared_error: 0.0789 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0460
# Epoch 55/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0089 - root_mean_squared_error: 0.0780 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0462
# Epoch 56/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0095 - root_mean_squared_error: 0.0832 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0466
# Epoch 57/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0088 - root_mean_squared_error: 0.0798 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0471
# Epoch 58/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0093 - root_mean_squared_error: 0.0835 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0461
# Epoch 59/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0083 - root_mean_squared_error: 0.0780 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0468
# Epoch 60/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0088 - root_mean_squared_error: 0.0823 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0470
# Epoch 61/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0082 - root_mean_squared_error: 0.0787 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0457
# Epoch 62/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0080 - root_mean_squared_error: 0.0781 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0462
# Epoch 63/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0081 - root_mean_squared_error: 0.0795 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0461
# Epoch 64/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0084 - root_mean_squared_error: 0.0819 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0469
# Epoch 65/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0086 - root_mean_squared_error: 0.0839 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0527
# Epoch 66/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0077 - root_mean_squared_error: 0.0791 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0460
# Epoch 67/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0079 - root_mean_squared_error: 0.0806 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0459
# Epoch 68/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0080 - root_mean_squared_error: 0.0812 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0467
# Epoch 69/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0072 - root_mean_squared_error: 0.0768 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0481
# Epoch 70/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0072 - root_mean_squared_error: 0.0773 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0463
# Epoch 71/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0071 - root_mean_squared_error: 0.0767 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0460
# Epoch 72/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0076 - root_mean_squared_error: 0.0804 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0458
# Epoch 73/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0075 - root_mean_squared_error: 0.0797 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0464
# Epoch 74/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0072 - root_mean_squared_error: 0.0783 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0458
# Epoch 75/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0069 - root_mean_squared_error: 0.0766 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0463
# Epoch 76/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0071 - root_mean_squared_error: 0.0781 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0460
# Epoch 77/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0074 - root_mean_squared_error: 0.0798 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0474
# Epoch 78/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0080 - root_mean_squared_error: 0.0836 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0487
# Epoch 79/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0075 - root_mean_squared_error: 0.0810 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0462
# Epoch 80/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0070 - root_mean_squared_error: 0.0781 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0462
# Epoch 81/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0069 - root_mean_squared_error: 0.0774 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0472
# Epoch 82/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0070 - root_mean_squared_error: 0.0784 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0463
# Epoch 83/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0070 - root_mean_squared_error: 0.0783 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0515
# Epoch 84/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0071 - root_mean_squared_error: 0.0790 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0457
# Epoch 85/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0071 - root_mean_squared_error: 0.0790 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0460
# Epoch 86/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0070 - root_mean_squared_error: 0.0785 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0466
# Epoch 87/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0065 - root_mean_squared_error: 0.0752 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0495
# Epoch 88/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0072 - root_mean_squared_error: 0.0803 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0465
# Epoch 89/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0072 - root_mean_squared_error: 0.0803 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0543

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0025 - root_mean_squared_error: 0.0402
# Test Loss: 0.0024592119734734297
# Test RMSE: 0.04021777957677841

# %%
# คำนวณ predicted values
yhat_train = rnn_model.predict(train_X)
yhat_val = rnn_model.predict(val_X)
yhat_test = rnn_model.predict(test_X)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_lstm_model(lstm_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2331898/1670406022.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-19 23:20:04.178631: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.189252: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.189568: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.200517: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.201021: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.202018: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.246375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.246787: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.256573: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.256588: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.256867: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.283760: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.298474: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.298682: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.328172: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.329789: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.337879: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.338250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.338428: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.358361: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.358415: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.358942: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.358939: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.381433: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.382036: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.393753: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.429952: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.444764: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.451703: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.456028: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.465185: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:20:04.466284: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-19 23:54:19.188318: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:54:19.190709: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:54:19.192001: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 23:54:19.922455: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:54:19.924966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:54:19.926915: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 23:54:21.129420: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:54:21.131451: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:54:21.132984: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-19 23:54:23.048150: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-19 23:54:23.050399: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-19 23:54:23.052065: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 3066.7375168800354 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 8, 'beta_1': 0.8, 'LR': 0.09, 'L2': 0.01}
# Best RMSE Score: 0.06091166985129163

# %%
lstm_model = create_lstm_model(lstm_units_1=8 ,beta_1=0.8 , LR=0.09, L2=0.01)
lstm_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 8)                 2848
#
#  dropout_3 (Dropout)         (None, 8)                 0
#
#  dense_3 (Dense)             (None, 7)                 63
#
# =================================================================
# Total params: 2,911
# Trainable params: 2,911
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-20 00:24:51.431942: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:24:51.433699: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:24:51.435053: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = lstm_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-20 00:24:53.830177: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:24:53.832424: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:24:53.833943: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 00:24:54.457241: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:24:54.459567: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:24:54.461082: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 19s - loss: 0.4727 - root_mean_squared_error: 0.1064
# 2024-12-20 00:24:55.566696: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:24:55.568940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:24:55.570375: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 46ms/step - loss: 0.1179 - root_mean_squared_error: 0.1119 - val_loss: 0.0288 - val_root_mean_squared_error: 0.0597
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0132 - root_mean_squared_error: 0.0712 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0508
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0656 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0493
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0658 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0506
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - root_mean_squared_error: 0.0649 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0487
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - root_mean_squared_error: 0.0651 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0490
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0042 - root_mean_squared_error: 0.0648 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0486
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0658 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0495
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0651 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0484
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - root_mean_squared_error: 0.0652 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0475
# Epoch 11/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0042 - root_mean_squared_error: 0.0646 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0511
# Epoch 12/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0484
# Epoch 13/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - root_mean_squared_error: 0.0650 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0476
# Epoch 14/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - root_mean_squared_error: 0.0653 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0524
# Epoch 15/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0043 - root_mean_squared_error: 0.0651 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0476

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = lstm_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0017 - root_mean_squared_error: 0.0404
# Test Loss: 0.0016591204330325127
# Test RMSE: 0.040438394993543625

# %%
# คำนวณ predicted residuals
yhat_train_resid = lstm_model.predict(train_X_resid)
yhat_val_resid = lstm_model.predict(val_X_resid)
yhat_test_resid = lstm_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-20 00:25:02.758689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:25:02.760834: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:25:02.762439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 2024-12-20 00:25:03.213683: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 00:25:03.216042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 00:25:03.217327: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('MTC_Adj_close_prediction By cascaded')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.0661%
# RMSE: 1.6263
