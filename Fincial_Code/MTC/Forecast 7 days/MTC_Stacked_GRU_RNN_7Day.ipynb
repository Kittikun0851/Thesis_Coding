# %% [markdown]
# ## Library

# %%
# !pip install tensorflow==2.12.0

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# Out:
# 2024-12-18 20:35:45.828044: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-18 20:35:45.840193: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-18 20:35:45.893727: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-18 20:35:45.895141: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 20:36:35.475210: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('MTC.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  54.243725  57.50  57.50  56.50  56.75  5741400
# 2019-07-02 00:00:00+00:00  54.007885  57.25  58.00  56.50  57.50  6927300
# 2019-07-03 00:00:00+00:00  53.772045  57.00  57.75  56.75  57.00  3766300
# 2019-07-04 00:00:00+00:00  53.772045  57.00  58.00  56.50  57.25  4936900
# 2019-07-05 00:00:00+00:00  54.007885  57.25  57.50  56.50  56.50  2941100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('MTC Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.650953    0.610778   0.654545    0.625000      0.102442
# 16         0.645089    0.622754   0.654545    0.642857      0.123602
# 17         0.639224    0.616766   0.660606    0.630952      0.067201
# 18         0.639224    0.622754   0.654545    0.636905      0.088088
# 19         0.645089    0.610778   0.654545    0.619048      0.052477
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.645089    0.622754   0.654545    0.642857      0.123602  ...
# 16         0.639224    0.616766   0.660606    0.630952      0.067201  ...
# 17         0.639224    0.622754   0.654545    0.636905      0.088088  ...
# 18         0.645089    0.610778   0.654545    0.619048      0.052477  ...
# 19         0.627495    0.604790   0.636364    0.630952      0.072568  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.678788  0.654762   0.092292        0.668546        0.692004
# 16  0.678788  0.660714   0.046650        0.692004        0.692004
# 17  0.684848  0.666667   0.126459        0.692004        0.692004
# 18  0.703030  0.678571   0.098638        0.692004        0.721327
# 19  0.709091  0.684524   0.046207        0.721327        0.721327
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.692004        0.692004        0.721327        0.721327
# 16        0.692004        0.721327        0.721327        0.727191
# 17        0.721327        0.721327        0.727191        0.686140
# 18        0.721327        0.727191        0.686140        0.721327
# 19        0.727191        0.686140        0.721327        0.803429
#
#     Adj Close(t+7)
# 15        0.727191
# 16        0.686140
# 17        0.721327
# 18        0.803429
# 19        0.680275
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Create Model & Evaluate (ยังไม่ Hyperparameter tuning)

# %%
model = Sequential()

# GRU layer with ReLU activation
model.add(GRU(units=70,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.005)))
model.add(Dropout(0.1))
# SimpleRNN layer with ReLU activation
model.add(SimpleRNN(units=70,activation='relu'))
model.add(Dropout(0.1))
# Output layer for 1 targets
model.add(Dense(1,activation='sigmoid'))
# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Compile the model
# model.compile(optimizer='adam', loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])

# %%
# # ทำ prediction
# yhat = model.predict(test_X)
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# # rescale ข้อมูลกลับ

# # Standardized -> actual
# # inv_yhat = (yhat * std_dict['Adj Close']) + mean_dict['Adj Close']
# # inv_y = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# # # Min-Max Normalized -> actual
# inv_yhat = yhat*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']
# inv_y = test_y*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']

# %%
# ทำ prediction
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# Rescale ข้อมูลกลับ (สำหรับ Standardized)
# inv_yhat_train = (yhat_train * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_yhat_val = (yhat_val * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_yhat_test = (yhat_test * std_dict['Adj Close']) + mean_dict['Adj Close']

# inv_y_train = (train_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_y_val = (val_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_y_test = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='KBANK_predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='KBANK_predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='KBANK_predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('KBANK_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')

# %% [markdown]
# ## Hyperparameter Tuning

# %%
def create_model(gru_units,rnn_units,LR,L2,beta_1):
    model = Sequential()
    model.add(GRU(gru_units,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(SimpleRNN(rnn_units,activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune
param_dist = {
    'gru_units': list(range(1, 101)),
    'rnn_units': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)

import time

start_time = time.time()


# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
random_search_result = random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_12168/2760256981.py:22: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-18 22:05:09.339862: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.341415: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.355212: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.372003: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.380216: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.388047: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.390167: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.395899: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.396698: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.398494: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.405366: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.427306: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.429589: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.430048: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.435227: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.437216: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.482003: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.482765: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.486165: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.501697: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.501788: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.501930: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.511180: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.511256: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.530373: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.539144: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.547554: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.547851: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.578253: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.590726: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.592559: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:05:09.592566: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 22:38:52.202783: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:38:52.227278: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:38:52.235684: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 22:38:58.506194: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:38:58.519213: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:38:58.521152: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 22:39:26.919752: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:39:26.940583: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:39:26.942467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 22:39:35.724474: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:39:35.727127: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:39:35.731271: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 3402.892458677292 seconds

# %%
# Get the best parameters and the best score
best_params = random_search_result.best_params_
best_score = -random_search_result.best_score_

# %%
print("Best Parameters:", best_params)
print("Best RMSE Score:", best_score)
# Out:
# Best Parameters: {'rnn_units': 55, 'gru_units': 47, 'beta_1': 0.9, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.0778714404174807

# %% [markdown]
# ## After Hyperparametertuning

# %%
gru_rnn_model = create_model(gru_units=47,rnn_units=55, beta_1=0.9,LR=0.003,L2=0.001)
gru_rnn_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_2 (GRU)                 (None, 1, 47)             18189
#
#  dropout_4 (Dropout)         (None, 1, 47)             0
#
#  simple_rnn_2 (SimpleRNN)    (None, 55)                5665
#
#  dropout_5 (Dropout)         (None, 55)                0
#
#  dense_2 (Dense)             (None, 7)                 392
#
# =================================================================
# Total params: 24,246
# Trainable params: 24,246
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-18 22:48:54.985966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:48:54.987779: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:48:54.988996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
gru_rnn_history = gru_rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-18 22:48:55.358554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:48:55.360754: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:48:55.362289: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 22:48:56.218279: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:48:56.220592: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:48:56.222123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 26s - loss: 0.6760 - root_mean_squared_error: 0.7573
# 2024-12-18 22:48:57.665202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:48:57.667547: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:48:57.669253: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 50ms/step - loss: 0.2069 - root_mean_squared_error: 0.3396 - val_loss: 0.0847 - val_root_mean_squared_error: 0.0712
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1109 - root_mean_squared_error: 0.1968 - val_loss: 0.0721 - val_root_mean_squared_error: 0.0867
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0873 - root_mean_squared_error: 0.1671 - val_loss: 0.0583 - val_root_mean_squared_error: 0.0656
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0718 - root_mean_squared_error: 0.1462 - val_loss: 0.0504 - val_root_mean_squared_error: 0.0613
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0622 - root_mean_squared_error: 0.1356 - val_loss: 0.0442 - val_root_mean_squared_error: 0.0580
# Epoch 6/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0534 - root_mean_squared_error: 0.1219 - val_loss: 0.0393 - val_root_mean_squared_error: 0.0563
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0478 - root_mean_squared_error: 0.1165 - val_loss: 0.0350 - val_root_mean_squared_error: 0.0541
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0428 - root_mean_squared_error: 0.1110 - val_loss: 0.0320 - val_root_mean_squared_error: 0.0580
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0395 - root_mean_squared_error: 0.1110 - val_loss: 0.0286 - val_root_mean_squared_error: 0.0541
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0385 - root_mean_squared_error: 0.1187 - val_loss: 0.0262 - val_root_mean_squared_error: 0.0557
# Epoch 11/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0336 - root_mean_squared_error: 0.1073 - val_loss: 0.0236 - val_root_mean_squared_error: 0.0520
# Epoch 12/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0304 - root_mean_squared_error: 0.1021 - val_loss: 0.0214 - val_root_mean_squared_error: 0.0484
# Epoch 13/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0277 - root_mean_squared_error: 0.0974 - val_loss: 0.0199 - val_root_mean_squared_error: 0.0511
# Epoch 14/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0259 - root_mean_squared_error: 0.0964 - val_loss: 0.0179 - val_root_mean_squared_error: 0.0468
# Epoch 15/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0245 - root_mean_squared_error: 0.0972 - val_loss: 0.0171 - val_root_mean_squared_error: 0.0518
# Epoch 16/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0228 - root_mean_squared_error: 0.0946 - val_loss: 0.0156 - val_root_mean_squared_error: 0.0491
# Epoch 17/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0220 - root_mean_squared_error: 0.0962 - val_loss: 0.0144 - val_root_mean_squared_error: 0.0473
# Epoch 18/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0222 - root_mean_squared_error: 0.1023 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0474
# Epoch 19/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0196 - root_mean_squared_error: 0.0936 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0475
# Epoch 20/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.0929 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0482
# Epoch 21/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0169 - root_mean_squared_error: 0.0868 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0476
# Epoch 22/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0171 - root_mean_squared_error: 0.0913 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0464
# Epoch 23/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0166 - root_mean_squared_error: 0.0923 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0462
# Epoch 24/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0150 - root_mean_squared_error: 0.0863 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0466
# Epoch 25/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0145 - root_mean_squared_error: 0.0863 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0459
# Epoch 26/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0139 - root_mean_squared_error: 0.0853 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0462
# Epoch 27/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0138 - root_mean_squared_error: 0.0867 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0466
# Epoch 28/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.0831 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0473
# Epoch 29/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0127 - root_mean_squared_error: 0.0850 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0456
# Epoch 30/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.0870 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0472
# Epoch 31/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0122 - root_mean_squared_error: 0.0856 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0454
# Epoch 32/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0114 - root_mean_squared_error: 0.0826 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0456
# Epoch 33/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0113 - root_mean_squared_error: 0.0835 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0461
# Epoch 34/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0123 - root_mean_squared_error: 0.0902 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0515
# Epoch 35/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0119 - root_mean_squared_error: 0.0891 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0464
# Epoch 36/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0112 - root_mean_squared_error: 0.0863 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0475
# Epoch 37/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0102 - root_mean_squared_error: 0.0816 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0458
# Epoch 38/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0101 - root_mean_squared_error: 0.0822 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0459
# Epoch 39/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0094 - root_mean_squared_error: 0.0788 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0457
# Epoch 40/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0095 - root_mean_squared_error: 0.0803 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0491
# Epoch 41/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0139 - root_mean_squared_error: 0.1049 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0484
# Epoch 42/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0116 - root_mean_squared_error: 0.0937 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0499
# Epoch 43/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0109 - root_mean_squared_error: 0.0901 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0473
# Epoch 44/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - root_mean_squared_error: 0.0838 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0453
# Epoch 45/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0097 - root_mean_squared_error: 0.0847 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0514
# Epoch 46/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0107 - root_mean_squared_error: 0.0909 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0470
# Epoch 47/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0094 - root_mean_squared_error: 0.0839 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0458
# Epoch 48/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0082 - root_mean_squared_error: 0.0770 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0458
# Epoch 49/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0083 - root_mean_squared_error: 0.0785 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0491
# Epoch 50/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0779 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0457
# Epoch 51/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0782 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0488
# Epoch 52/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - root_mean_squared_error: 0.0762 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0460
# Epoch 53/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - root_mean_squared_error: 0.0758 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0457
# Epoch 54/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - root_mean_squared_error: 0.0763 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0463
# Epoch 55/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - root_mean_squared_error: 0.0740 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0458
# Epoch 56/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - root_mean_squared_error: 0.0775 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0469
# Epoch 57/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - root_mean_squared_error: 0.0752 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0475
# Epoch 58/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0075 - root_mean_squared_error: 0.0777 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0460
# Epoch 59/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0068 - root_mean_squared_error: 0.0731 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0462
# Epoch 60/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0075 - root_mean_squared_error: 0.0780 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0460
# Epoch 61/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0801 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0471
# Epoch 62/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - root_mean_squared_error: 0.0799 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0497
# Epoch 63/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0070 - root_mean_squared_error: 0.0755 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0457
# Epoch 64/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - root_mean_squared_error: 0.0799 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0450
# Epoch 65/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0067 - root_mean_squared_error: 0.0744 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0464
# Epoch 66/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - root_mean_squared_error: 0.0800 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0454
# Epoch 67/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0067 - root_mean_squared_error: 0.0750 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0470
# Epoch 68/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0063 - root_mean_squared_error: 0.0721 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0461
# Epoch 69/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - root_mean_squared_error: 0.0733 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0494
# Epoch 70/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0074 - root_mean_squared_error: 0.0801 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0500
# Epoch 71/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0068 - root_mean_squared_error: 0.0764 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0457
# Epoch 72/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0069 - root_mean_squared_error: 0.0766 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0456
# Epoch 73/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0069 - root_mean_squared_error: 0.0770 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0471
# Epoch 74/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0075 - root_mean_squared_error: 0.0808 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0512
# Epoch 75/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0071 - root_mean_squared_error: 0.0786 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0489
# Epoch 76/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - root_mean_squared_error: 0.0743 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0507
# Epoch 77/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0067 - root_mean_squared_error: 0.0760 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0458
# Epoch 78/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0069 - root_mean_squared_error: 0.0776 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0506
# Epoch 79/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - root_mean_squared_error: 0.0795 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0464
# Epoch 80/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - root_mean_squared_error: 0.0746 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0461
# Epoch 81/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - root_mean_squared_error: 0.0843 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0536
# Epoch 82/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0074 - root_mean_squared_error: 0.0812 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0462
# Epoch 83/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0075 - root_mean_squared_error: 0.0818 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0456
# Epoch 84/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - root_mean_squared_error: 0.0746 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0461
# Epoch 85/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0066 - root_mean_squared_error: 0.0761 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0477
# Epoch 86/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0067 - root_mean_squared_error: 0.0769 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0457
# Epoch 87/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0060 - root_mean_squared_error: 0.0722 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0473
# Epoch 88/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0059 - root_mean_squared_error: 0.0720 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0499
# Epoch 89/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0065 - root_mean_squared_error: 0.0761 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0455
# Epoch 90/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0067 - root_mean_squared_error: 0.0777 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0454
# Epoch 91/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0066 - root_mean_squared_error: 0.0766 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0458
# Epoch 92/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0071 - root_mean_squared_error: 0.0800 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0452
# Epoch 93/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0061 - root_mean_squared_error: 0.0736 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0458
# Epoch 94/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0061 - root_mean_squared_error: 0.0736 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0462
# Epoch 95/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0059 - root_mean_squared_error: 0.0722 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0461
# Epoch 96/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0058 - root_mean_squared_error: 0.0714 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0462
# Epoch 97/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0060 - root_mean_squared_error: 0.0729 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0457

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(gru_rnn_history.history['loss'], label='train_loss')
plt.plot(gru_rnn_history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = gru_rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0030 - root_mean_squared_error: 0.0482
# Test Loss: 0.003020880278199911
# Test RMSE: 0.04819720610976219

# %%
# ทำ prediction
yhat_train = gru_rnn_model.predict(train_X)
yhat_val = gru_rnn_model.predict(val_X)
yhat_test = gru_rnn_model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
# Out:
# 2024-12-18 22:50:02.044995: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:50:02.046940: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:50:02.048418: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 1ms/step
# 2024-12-18 22:50:02.707216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 22:50:02.709082: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 22:50:02.710538: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 1s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('MTC_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.8330%
# RMSE: 1.9383
