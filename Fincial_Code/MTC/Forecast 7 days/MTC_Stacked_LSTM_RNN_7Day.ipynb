# %% [markdown]
# ## Library

# %%
# !pip install tensorflow==2.12.0

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, SimpleRNN, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# Out:
# 2024-12-18 20:35:35.737410: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-18 20:35:35.747332: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-18 20:35:35.801921: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-18 20:35:35.802997: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 20:36:24.530292: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('MTC.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  54.243729  57.50  57.50  56.50  56.75  5741400
# 2019-07-02 00:00:00+00:00  54.007885  57.25  58.00  56.50  57.50  6927300
# 2019-07-03 00:00:00+00:00  53.772041  57.00  57.75  56.75  57.00  3766300
# 2019-07-04 00:00:00+00:00  53.772041  57.00  58.00  56.50  57.25  4936900
# 2019-07-05 00:00:00+00:00  54.007885  57.25  57.50  56.50  56.50  2941100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('MTC Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.650953    0.610778   0.654545    0.625000      0.102442
# 16         0.645089    0.622754   0.654545    0.642857      0.123602
# 17         0.639224    0.616766   0.660606    0.630952      0.067201
# 18         0.639224    0.622754   0.654545    0.636905      0.088088
# 19         0.645089    0.610778   0.654545    0.619048      0.052477
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.645089    0.622754   0.654545    0.642857      0.123602  ...
# 16         0.639224    0.616766   0.660606    0.630952      0.067201  ...
# 17         0.639224    0.622754   0.654545    0.636905      0.088088  ...
# 18         0.645089    0.610778   0.654545    0.619048      0.052477  ...
# 19         0.627495    0.604790   0.636364    0.630952      0.072568  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.678788  0.654762   0.092292        0.668546        0.692004
# 16  0.678788  0.660714   0.046650        0.692004        0.692004
# 17  0.684848  0.666667   0.126459        0.692004        0.692004
# 18  0.703030  0.678571   0.098638        0.692004        0.721326
# 19  0.709091  0.684524   0.046207        0.721326        0.721326
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.692004        0.692004        0.721326        0.721326
# 16        0.692004        0.721326        0.721326        0.727191
# 17        0.721326        0.721326        0.727191        0.686140
# 18        0.721326        0.727191        0.686140        0.721326
# 19        0.727191        0.686140        0.721326        0.803429
#
#     Adj Close(t+7)
# 15        0.727191
# 16        0.686140
# 17        0.721326
# 18        0.803429
# 19        0.680275
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Create Model & Evaluate (ยังไม่ Hyperparameter tuning)

# %%
model = Sequential()

# GRU layer with ReLU activation
model.add(GRU(units=70,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.005)))
model.add(Dropout(0.1))
# SimpleRNN layer with ReLU activation
model.add(SimpleRNN(units=70,activation='relu'))
model.add(Dropout(0.1))
# Output layer for 1 targets
model.add(Dense(1,activation='sigmoid'))
# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Compile the model
# model.compile(optimizer='adam', loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 1, 70)             31920
#
#  dropout_2 (Dropout)         (None, 1, 70)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 70)                9870
#
#  dropout_3 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 1)                 71
#
# =================================================================
# Total params: 41,861
# Trainable params: 41,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 2024-12-14 09:08:58.941779: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-12-14 09:08:58.988072: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:134] tfg_optimizer{any(tfg-consolidate-attrs,tfg-toposort,tfg-shape-inference{graph-version=0},tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-12-14 09:08:59.043276: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:134] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-12-14 09:08:59.045384: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:134] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-12-14 09:08:59.048897: W tensorflow/core/common_runtime/optimize_function_graph_utils.cc:475] Ignoring multi-device function optimization failure: INVALID_ARGUMENT: Node 'sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu' does not specify an operation
# 13/13 [==============================] - 3s 57ms/step - loss: 0.5661 - root_mean_squared_error: 0.2110 - val_loss: 0.5896 - val_root_mean_squared_error: 0.3724
# Epoch 2/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4309 - root_mean_squared_error: 0.1842 - val_loss: 0.4467 - val_root_mean_squared_error: 0.3288
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3241 - root_mean_squared_error: 0.1667 - val_loss: 0.3364 - val_root_mean_squared_error: 0.2922
# Epoch 4/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.2391 - root_mean_squared_error: 0.1430 - val_loss: 0.2524 - val_root_mean_squared_error: 0.2612
# Epoch 5/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1725 - root_mean_squared_error: 0.1121 - val_loss: 0.1768 - val_root_mean_squared_error: 0.2066
# Epoch 6/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1223 - root_mean_squared_error: 0.0798 - val_loss: 0.1236 - val_root_mean_squared_error: 0.1637
# Epoch 7/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0865 - root_mean_squared_error: 0.0559 - val_loss: 0.0865 - val_root_mean_squared_error: 0.1316
# Epoch 8/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0614 - root_mean_squared_error: 0.0462 - val_loss: 0.0656 - val_root_mean_squared_error: 0.1290
# Epoch 9/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0442 - root_mean_squared_error: 0.0486 - val_loss: 0.0509 - val_root_mean_squared_error: 0.1285
# Epoch 10/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0317 - root_mean_squared_error: 0.0482 - val_loss: 0.0414 - val_root_mean_squared_error: 0.1314
# Epoch 11/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0226 - root_mean_squared_error: 0.0449 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1310
# Epoch 12/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0161 - root_mean_squared_error: 0.0421 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1304
# Epoch 13/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0119 - root_mean_squared_error: 0.0437 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1269
# Epoch 14/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0087 - root_mean_squared_error: 0.0416 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1316
# Epoch 15/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0067 - root_mean_squared_error: 0.0435 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1280
# Epoch 16/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0053 - root_mean_squared_error: 0.0433 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1259
# Epoch 17/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0043 - root_mean_squared_error: 0.0421 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1248
# Epoch 18/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0036 - root_mean_squared_error: 0.0414 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1234
# Epoch 19/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0031 - root_mean_squared_error: 0.0406 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1226
# Epoch 20/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0029 - root_mean_squared_error: 0.0425 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1215
# Epoch 21/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0030 - root_mean_squared_error: 0.0454 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1191
# Epoch 22/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0027 - root_mean_squared_error: 0.0439 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1167
# Epoch 23/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0025 - root_mean_squared_error: 0.0417 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1186
# Epoch 24/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0023 - root_mean_squared_error: 0.0405 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1200
# Epoch 25/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0023 - root_mean_squared_error: 0.0405 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1238
# Epoch 26/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0024 - root_mean_squared_error: 0.0422 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1235
# Epoch 27/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0022 - root_mean_squared_error: 0.0406 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1204

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])

# %%
# # ทำ prediction
# yhat = model.predict(test_X)
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# # rescale ข้อมูลกลับ

# # Standardized -> actual
# # inv_yhat = (yhat * std_dict['Adj Close']) + mean_dict['Adj Close']
# # inv_y = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# # # Min-Max Normalized -> actual
# inv_yhat = yhat*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']
# inv_y = test_y*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']

# %%
# ทำ prediction
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# Rescale ข้อมูลกลับ (สำหรับ Standardized)
# inv_yhat_train = (yhat_train * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_yhat_val = (yhat_val * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_yhat_test = (yhat_test * std_dict['Adj Close']) + mean_dict['Adj Close']

# inv_y_train = (train_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_y_val = (val_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_y_test = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('XPG_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')

# %% [markdown]
# ## Hyperparameter Tuning

# %%
def create_model(rnn_units,lstm_units,LR,L2,beta_1):
    model = Sequential()
    model.add(LSTM(lstm_units,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(SimpleRNN(rnn_units,activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune
param_dist = {
    'rnn_units': list(range(1, 101)),
    'lstm_units': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)

import time

start_time = time.time()


# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
random_search_result = random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_12164/371335417.py:22: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-18 21:00:50.420227: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.477578: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.595118: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.645564: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.653696: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.670229: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.763234: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.783504: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.921656: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.932993: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:50.948013: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.013462: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.044651: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.096887: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.121926: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.130942: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.212223: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.236168: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.246237: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.287004: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.287590: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.354322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.455019: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.478779: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.529191: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.587069: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.594542: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.618865: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.729259: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:51.815211: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:52.582675: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:00:52.642176: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:27:40.950167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:27:40.952377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:27:40.953718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 21:27:43.484361: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:27:43.486737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:27:43.488526: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 21:27:44.639134: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:27:44.641261: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:27:44.642702: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 21:27:47.322661: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:27:47.325097: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:27:47.326937: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 2848.6758387088776 seconds

# %%
# Get the best parameters and the best score
best_params = random_search_result.best_params_
best_score = -random_search_result.best_score_

# %%
print("Best Parameters:", best_params)
print("Best RMSE Score:", best_score)
# Out:
# Best Parameters: {'rnn_units': 55, 'lstm_units': 47, 'beta_1': 0.9, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.08255225806110941

# %% [markdown]
# ## After Hyperparametertuning

# %%
lstm_rnn_model = create_model(lstm_units=47,rnn_units=55,beta_1= 0.9,LR=0.003,L2=0.001)
lstm_rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 1, 47)             24064
#
#  dropout_2 (Dropout)         (None, 1, 47)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 55)                5665
#
#  dropout_3 (Dropout)         (None, 55)                0
#
#  dense_1 (Dense)             (None, 7)                 392
#
# =================================================================
# Total params: 30,121
# Trainable params: 30,121
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-18 21:37:29.927291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:37:29.929114: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:37:29.930258: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
lstm_rnn_history = lstm_rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-18 21:37:32.579537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:37:32.581620: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:37:32.583007: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 21:37:33.384269: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:37:33.386389: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:37:33.387825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 25s - loss: 0.5213 - root_mean_squared_error: 0.6404
# 2024-12-18 21:37:34.788112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:37:34.790090: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:37:34.791447: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 50ms/step - loss: 0.1983 - root_mean_squared_error: 0.3159 - val_loss: 0.0882 - val_root_mean_squared_error: 0.0660
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1051 - root_mean_squared_error: 0.1766 - val_loss: 0.0708 - val_root_mean_squared_error: 0.0864
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0770 - root_mean_squared_error: 0.1449 - val_loss: 0.0523 - val_root_mean_squared_error: 0.0608
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0610 - root_mean_squared_error: 0.1323 - val_loss: 0.0417 - val_root_mean_squared_error: 0.0579
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0489 - root_mean_squared_error: 0.1188 - val_loss: 0.0337 - val_root_mean_squared_error: 0.0519
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0407 - root_mean_squared_error: 0.1114 - val_loss: 0.0285 - val_root_mean_squared_error: 0.0548
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0345 - root_mean_squared_error: 0.1050 - val_loss: 0.0240 - val_root_mean_squared_error: 0.0525
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0297 - root_mean_squared_error: 0.1004 - val_loss: 0.0208 - val_root_mean_squared_error: 0.0543
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0268 - root_mean_squared_error: 0.1012 - val_loss: 0.0182 - val_root_mean_squared_error: 0.0554
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0243 - root_mean_squared_error: 0.1010 - val_loss: 0.0164 - val_root_mean_squared_error: 0.0591
# Epoch 11/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0205 - root_mean_squared_error: 0.0919 - val_loss: 0.0140 - val_root_mean_squared_error: 0.0536
# Epoch 12/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0185 - root_mean_squared_error: 0.0897 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0483
# Epoch 13/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0174 - root_mean_squared_error: 0.0914 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0540
# Epoch 14/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0160 - root_mean_squared_error: 0.0905 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0527
# Epoch 15/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0158 - root_mean_squared_error: 0.0946 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0566
# Epoch 16/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0155 - root_mean_squared_error: 0.0972 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0485
# Epoch 17/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0145 - root_mean_squared_error: 0.0952 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0503
# Epoch 18/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0127 - root_mean_squared_error: 0.0885 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0542
# Epoch 19/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0122 - root_mean_squared_error: 0.0887 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0497
# Epoch 20/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0121 - root_mean_squared_error: 0.0900 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0536
# Epoch 21/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.0859 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0475
# Epoch 22/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0110 - root_mean_squared_error: 0.0877 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0479
# Epoch 23/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0100 - root_mean_squared_error: 0.0838 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0459
# Epoch 24/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0114 - root_mean_squared_error: 0.0930 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0573
# Epoch 25/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0100 - root_mean_squared_error: 0.0866 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0471
# Epoch 26/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0094 - root_mean_squared_error: 0.0843 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0458
# Epoch 27/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0092 - root_mean_squared_error: 0.0839 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0475
# Epoch 28/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0798 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0468
# Epoch 29/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0091 - root_mean_squared_error: 0.0851 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0452
# Epoch 30/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0104 - root_mean_squared_error: 0.0928 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0532
# Epoch 31/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0090 - root_mean_squared_error: 0.0858 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0510
# Epoch 32/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0086 - root_mean_squared_error: 0.0834 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0449
# Epoch 33/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - root_mean_squared_error: 0.0788 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0449
# Epoch 34/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0799 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0451
# Epoch 35/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0087 - root_mean_squared_error: 0.0856 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0453
# Epoch 36/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0088 - root_mean_squared_error: 0.0863 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0488
# Epoch 37/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0083 - root_mean_squared_error: 0.0837 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0449
# Epoch 38/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0087 - root_mean_squared_error: 0.0862 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0472
# Epoch 39/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - root_mean_squared_error: 0.0778 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0460
# Epoch 40/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - root_mean_squared_error: 0.0827 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0489
# Epoch 41/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0839 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0478
# Epoch 42/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0090 - root_mean_squared_error: 0.0891 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0690

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(lstm_rnn_history.history['loss'], label='train_loss')
plt.plot(lstm_rnn_history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = lstm_rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0033 - root_mean_squared_error: 0.0457
# Test Loss: 0.003338752780109644
# Test RMSE: 0.04572734981775284

# %%
# ทำ prediction
yhat_train = lstm_rnn_model.predict(train_X)
yhat_val = lstm_rnn_model.predict(val_X)
yhat_test = lstm_rnn_model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
# Out:
# 2024-12-18 21:37:46.495116: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:37:46.497117: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:37:46.498499: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 1ms/step
# 2024-12-18 21:37:47.043233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:37:47.045050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:37:47.046304: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('MTC_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.5634%
# RMSE: 1.8390
