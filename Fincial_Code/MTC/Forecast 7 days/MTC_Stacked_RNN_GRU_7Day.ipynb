# %% [markdown]
# ## Library

# %%
# !pip install tensorflow==2.12.0

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# Out:
# 2024-12-18 20:35:40.938674: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-18 20:35:40.949942: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-18 20:35:41.006111: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-18 20:35:41.007087: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-18 20:36:30.228002: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('MTC.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  54.243732  57.50  57.50  56.50  56.75  5741400
# 2019-07-02 00:00:00+00:00  54.007885  57.25  58.00  56.50  57.50  6927300
# 2019-07-03 00:00:00+00:00  53.772045  57.00  57.75  56.75  57.00  3766300
# 2019-07-04 00:00:00+00:00  53.772045  57.00  58.00  56.50  57.25  4936900
# 2019-07-05 00:00:00+00:00  54.007885  57.25  57.50  56.50  56.50  2941100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('MTC Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.650953    0.610778   0.654545    0.625000      0.102442
# 16         0.645089    0.622754   0.654545    0.642857      0.123602
# 17         0.639224    0.616766   0.660606    0.630952      0.067201
# 18         0.639224    0.622754   0.654545    0.636905      0.088088
# 19         0.645089    0.610778   0.654545    0.619048      0.052477
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.645089    0.622754   0.654545    0.642857      0.123602  ...
# 16         0.639224    0.616766   0.660606    0.630952      0.067201  ...
# 17         0.639224    0.622754   0.654545    0.636905      0.088088  ...
# 18         0.645089    0.610778   0.654545    0.619048      0.052477  ...
# 19         0.627495    0.604790   0.636364    0.630952      0.072568  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.678788  0.654762   0.092292        0.668547        0.692004
# 16  0.678788  0.660714   0.046650        0.692004        0.692004
# 17  0.684848  0.666667   0.126459        0.692004        0.692004
# 18  0.703030  0.678571   0.098638        0.692004        0.721327
# 19  0.709091  0.684524   0.046207        0.721327        0.721327
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.692004        0.692004        0.721327        0.721327
# 16        0.692004        0.721327        0.721327        0.727191
# 17        0.721327        0.721327        0.727191        0.686140
# 18        0.721327        0.727191        0.686140        0.721327
# 19        0.727191        0.686140        0.721327        0.803429
#
#     Adj Close(t+7)
# 15        0.727191
# 16        0.686140
# 17        0.721327
# 18        0.803429
# 19        0.680275
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Create Model & Evaluate (ยังไม่ Hyperparameter tuning)

# %%
model = Sequential()

# SimpleRNN layer with ReLU activation
model.add(SimpleRNN(units=94,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.005)))
model.add(Dropout(0.1))
# GRU layer with ReLU activation
model.add(GRU(units=73,activation='relu'))
model.add(Dropout(0.1))
# Output layer for 1 targets
model.add(Dense(1,activation='sigmoid'))
# model.add(Dense(1))
# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Compile the model
# model.compile(optimizer='adam', loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])

# %%
# # ทำ prediction
# yhat = model.predict(test_X)
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# # rescale ข้อมูลกลับ

# # Standardized -> actual
# # inv_yhat = (yhat * std_dict['Adj Close']) + mean_dict['Adj Close']
# # inv_y = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# # # Min-Max Normalized -> actual
# inv_yhat = yhat*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']
# inv_y = test_y*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']

# %%
# ทำ prediction
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('XPG_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')

# %% [markdown]
# ## Hyperparameter Tuning

# %%
def create_model(rnn_units,gru_units,LR,L2,beta_1):
    model = Sequential()
    model.add(SimpleRNN(rnn_units,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(GRU(gru_units,activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune
param_dist = {
    'gru_units': list(range(1, 101)),
    'rnn_units': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)

import time

start_time = time.time()


# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
random_search_result = random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_12166/4200879527.py:22: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-18 21:05:50.425092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.463616: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.489464: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.513160: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.519711: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.602470: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.621149: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.657516: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.657681: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.658472: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.660106: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.665968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.666203: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.713152: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.713219: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.716381: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.731060: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.753734: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.753845: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.776629: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.776630: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.776721: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.784947: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.785258: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.801349: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.826927: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.827397: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.838427: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.838772: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.838782: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.843853: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:05:50.852925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-18 21:31:42.643475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:31:42.645572: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:31:42.646797: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 21:31:43.525301: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:31:43.527835: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:31:43.529765: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 21:31:44.371296: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:31:44.373557: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:31:44.375214: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 21:31:46.017166: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:31:46.019575: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:31:46.021280: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 2928.978236436844 seconds

# %%
# Get the best parameters and the best score
best_params = random_search_result.best_params_
best_score = -random_search_result.best_score_

# %%
print("Best Parameters:", best_params)
print("Best RMSE Score:", best_score)
# Out:
# Best Parameters: {'rnn_units': 55, 'gru_units': 47, 'beta_1': 0.9, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.07517328434143195

# %% [markdown]
# ## After Hyperparameter Tuning

# %%
rnn_gru_model = create_model(rnn_units=55, gru_units=47,beta_1=0.9,LR=0.003,L2=0.001)
rnn_gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 1, 55)             7480
#
#  dropout_2 (Dropout)         (None, 1, 55)             0
#
#  gru_1 (GRU)                 (None, 47)                14664
#
#  dropout_3 (Dropout)         (None, 47)                0
#
#  dense_1 (Dense)             (None, 7)                 336
#
# =================================================================
# Total params: 22,480
# Trainable params: 22,480
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-18 21:39:05.197539: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:39:05.199181: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:39:05.200453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
rnn_gru_history = rnn_gru_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-18 21:39:07.793554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:39:07.795591: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:39:07.797030: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-18 21:39:08.566737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:39:08.568685: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:39:08.570102: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 24s - loss: 0.5068 - root_mean_squared_error: 0.6630
# 2024-12-18 21:39:09.952882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:39:09.955069: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:39:09.956623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 50ms/step - loss: 0.1632 - root_mean_squared_error: 0.3110 - val_loss: 0.0852 - val_root_mean_squared_error: 0.1430
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0985 - root_mean_squared_error: 0.1891 - val_loss: 0.0677 - val_root_mean_squared_error: 0.0872
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0799 - root_mean_squared_error: 0.1490 - val_loss: 0.0598 - val_root_mean_squared_error: 0.0695
# Epoch 4/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0699 - root_mean_squared_error: 0.1321 - val_loss: 0.0539 - val_root_mean_squared_error: 0.0653
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0626 - root_mean_squared_error: 0.1234 - val_loss: 0.0477 - val_root_mean_squared_error: 0.0543
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0558 - root_mean_squared_error: 0.1147 - val_loss: 0.0432 - val_root_mean_squared_error: 0.0536
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0513 - root_mean_squared_error: 0.1136 - val_loss: 0.0390 - val_root_mean_squared_error: 0.0519
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0462 - root_mean_squared_error: 0.1075 - val_loss: 0.0354 - val_root_mean_squared_error: 0.0513
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0427 - root_mean_squared_error: 0.1069 - val_loss: 0.0321 - val_root_mean_squared_error: 0.0509
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0387 - root_mean_squared_error: 0.1024 - val_loss: 0.0292 - val_root_mean_squared_error: 0.0503
# Epoch 11/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0353 - root_mean_squared_error: 0.0992 - val_loss: 0.0266 - val_root_mean_squared_error: 0.0492
# Epoch 12/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0330 - root_mean_squared_error: 0.0996 - val_loss: 0.0244 - val_root_mean_squared_error: 0.0510
# Epoch 13/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0310 - root_mean_squared_error: 0.1005 - val_loss: 0.0226 - val_root_mean_squared_error: 0.0518
# Epoch 14/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0286 - root_mean_squared_error: 0.0978 - val_loss: 0.0205 - val_root_mean_squared_error: 0.0484
# Epoch 15/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0261 - root_mean_squared_error: 0.0930 - val_loss: 0.0190 - val_root_mean_squared_error: 0.0483
# Epoch 16/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0241 - root_mean_squared_error: 0.0902 - val_loss: 0.0179 - val_root_mean_squared_error: 0.0524
# Epoch 17/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0239 - root_mean_squared_error: 0.0966 - val_loss: 0.0163 - val_root_mean_squared_error: 0.0485
# Epoch 18/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.0958 - val_loss: 0.0158 - val_root_mean_squared_error: 0.0549
# Epoch 19/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0223 - root_mean_squared_error: 0.1001 - val_loss: 0.0143 - val_root_mean_squared_error: 0.0497
# Epoch 20/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0198 - root_mean_squared_error: 0.0918 - val_loss: 0.0134 - val_root_mean_squared_error: 0.0498
# Epoch 21/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0189 - root_mean_squared_error: 0.0917 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0504
# Epoch 22/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0187 - root_mean_squared_error: 0.0949 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0474
# Epoch 23/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0160 - root_mean_squared_error: 0.0838 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0489
# Epoch 24/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0159 - root_mean_squared_error: 0.0871 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0492
# Epoch 25/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0167 - root_mean_squared_error: 0.0949 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0512
# Epoch 26/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0169 - root_mean_squared_error: 0.0987 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0504
# Epoch 27/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0151 - root_mean_squared_error: 0.0916 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0495
# Epoch 28/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - root_mean_squared_error: 0.0865 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0489
# Epoch 29/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.0832 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0468
# Epoch 30/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0123 - root_mean_squared_error: 0.0827 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0470
# Epoch 31/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0122 - root_mean_squared_error: 0.0844 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0468
# Epoch 32/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0116 - root_mean_squared_error: 0.0827 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0483
# Epoch 33/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0109 - root_mean_squared_error: 0.0804 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0470
# Epoch 34/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0110 - root_mean_squared_error: 0.0827 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0519
# Epoch 35/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0109 - root_mean_squared_error: 0.0841 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0468
# Epoch 36/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0099 - root_mean_squared_error: 0.0793 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0478
# Epoch 37/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0103 - root_mean_squared_error: 0.0834 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0465
# Epoch 38/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0106 - root_mean_squared_error: 0.0863 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0504
# Epoch 39/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0096 - root_mean_squared_error: 0.0815 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0468
# Epoch 40/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0096 - root_mean_squared_error: 0.0820 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0468
# Epoch 41/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0095 - root_mean_squared_error: 0.0825 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0482
# Epoch 42/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0086 - root_mean_squared_error: 0.0780 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0486
# Epoch 43/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - root_mean_squared_error: 0.0806 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0487
# Epoch 44/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0083 - root_mean_squared_error: 0.0779 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0534
# Epoch 45/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0083 - root_mean_squared_error: 0.0782 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0522
# Epoch 46/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0781 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0470
# Epoch 47/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0079 - root_mean_squared_error: 0.0777 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0471
# Epoch 48/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0094 - root_mean_squared_error: 0.0873 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0526
# Epoch 49/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0085 - root_mean_squared_error: 0.0822 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0481
# Epoch 50/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0078 - root_mean_squared_error: 0.0782 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0469
# Epoch 51/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0081 - root_mean_squared_error: 0.0807 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0493
# Epoch 52/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0084 - root_mean_squared_error: 0.0831 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0470
# Epoch 53/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0073 - root_mean_squared_error: 0.0763 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0476
# Epoch 54/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - root_mean_squared_error: 0.0790 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0471
# Epoch 55/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - root_mean_squared_error: 0.0800 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0476
# Epoch 56/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0077 - root_mean_squared_error: 0.0804 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0496
# Epoch 57/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0096 - root_mean_squared_error: 0.0913 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0512
# Epoch 58/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0080 - root_mean_squared_error: 0.0823 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0489
# Epoch 59/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0076 - root_mean_squared_error: 0.0802 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0560
# Epoch 60/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0074 - root_mean_squared_error: 0.0789 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0473
# Epoch 61/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0069 - root_mean_squared_error: 0.0762 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0525
# Epoch 62/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0070 - root_mean_squared_error: 0.0770 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0528
# Epoch 63/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - root_mean_squared_error: 0.0782 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0491
# Epoch 64/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0066 - root_mean_squared_error: 0.0749 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0516
# Epoch 65/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0071 - root_mean_squared_error: 0.0781 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0489
# Epoch 66/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0065 - root_mean_squared_error: 0.0746 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0479
# Epoch 67/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - root_mean_squared_error: 0.0737 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0477
# Epoch 68/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0068 - root_mean_squared_error: 0.0771 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0491
# Epoch 69/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - root_mean_squared_error: 0.0745 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0521
# Epoch 70/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0065 - root_mean_squared_error: 0.0749 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0477
# Epoch 71/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0073 - root_mean_squared_error: 0.0804 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0481
# Epoch 72/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0060 - root_mean_squared_error: 0.0724 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0504
# Epoch 73/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0061 - root_mean_squared_error: 0.0727 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0494
# Epoch 74/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0070 - root_mean_squared_error: 0.0787 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0555
# Epoch 75/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0069 - root_mean_squared_error: 0.0783 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0495

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(rnn_gru_history.history['loss'], label='train_loss')
plt.plot(rnn_gru_history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_gru_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0027 - root_mean_squared_error: 0.0436
# Test Loss: 0.0027358776424080133
# Test RMSE: 0.0436224527657032

# %%
# ทำ prediction
yhat_train = rnn_gru_model.predict(train_X)
yhat_val = rnn_gru_model.predict(val_X)
yhat_test = rnn_gru_model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
# Out:
# 2024-12-18 21:39:20.487825: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:39:20.490298: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:39:20.492220: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 1ms/step
# 1/6 [====>.........................] - ETA: 2s
# 2024-12-18 21:39:21.060339: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-18 21:39:21.062626: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-18 21:39:21.063988: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('MTC_Adj_close_prediction By stacked LSTM-GRU')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.3463%
# RMSE: 1.7543
