# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-20 11:49:33.064112: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-20 11:49:33.076144: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-20 11:49:33.134557: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-20 11:49:33.135629: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-20 11:50:22.906264: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('XPG.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close     Close      High       Low      Open  \
# Date
# 2019-07-01 00:00:00+00:00   0.345485  0.345485  0.345485  0.341730  0.345485
# 2019-07-02 00:00:00+00:00   0.341730  0.341730  0.345485  0.337974  0.341730
# 2019-07-03 00:00:00+00:00   0.341730  0.341730  0.341730  0.337974  0.341730
# 2019-07-04 00:00:00+00:00   0.341730  0.341730  0.352995  0.337974  0.337974
# 2019-07-05 00:00:00+00:00   0.341730  0.341730  0.345485  0.337974  0.341730
#
# Price                       Volume
# Date
# 2019-07-01 00:00:00+00:00  1475258
# 2019-07-02 00:00:00+00:00  2414470
# 2019-07-03 00:00:00+00:00  1151180
# 2019-07-04 00:00:00+00:00  9879436
# 2019-07-05 00:00:00+00:00  1341313

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('XPG Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.042807    0.036534   0.043138    0.040565      0.001496
# 16         0.041934    0.036534   0.042239    0.039702      0.002448
# 17         0.041934    0.035757   0.042239    0.039702      0.001167
# 18         0.041934    0.038089   0.042239    0.038839      0.010017
# 19         0.041934    0.036534   0.042239    0.039702      0.001360
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.041934    0.036534   0.042239    0.039702      0.002448  ...
# 16         0.041934    0.035757   0.042239    0.039702      0.001167  ...
# 17         0.041934    0.038089   0.042239    0.038839      0.010017  ...
# 18         0.041934    0.036534   0.042239    0.039702      0.001360  ...
# 19         0.041934    0.035757   0.041341    0.039702      0.006624  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.042239  0.039702   0.000567        0.041934        0.041060
# 16  0.042239  0.039702   0.000123        0.041060        0.041934
# 17  0.042239  0.038839   0.000781        0.041934        0.041934
# 18  0.042239  0.038839   0.002395        0.041934        0.041934
# 19  0.042239  0.039702   0.001677        0.041934        0.041934
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.041934        0.041934        0.041934        0.041934
# 16        0.041934        0.041934        0.041934        0.041060
# 17        0.041934        0.041934        0.041060        0.041060
# 18        0.041934        0.041060        0.041060        0.041060
# 19        0.041060        0.041060        0.041060        0.039313
#
#     Adj Close(t+7)
# 15        0.041060
# 16        0.041060
# 17        0.041060
# 18        0.039313
# 19        0.039313
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_gru_model(gru_units_1, beta_1 ,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_4008380/2081204696.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-20 12:19:16.555914: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:16.910987: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:16.920397: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:16.941019: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:16.961115: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:16.980341: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.000875: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.006594: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.007469: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.025265: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.160852: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.272215: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.418815: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.470766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.506673: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.528974: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.529323: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.575200: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.637639: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.639162: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.681897: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.706110: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.740796: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.761377: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.784708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.812092: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:17.864864: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:18.028899: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:18.029598: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:18.046678: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:18.151306: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:19:18.184531: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 12:49:40.016945: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 12:49:40.019168: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 12:49:40.020492: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 12:49:42.651233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 12:49:42.653972: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 12:49:42.655850: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 12:49:43.602865: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 12:49:43.605654: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 12:49:43.607407: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 12:49:45.933943: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 12:49:45.936363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 12:49:45.938204: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 3357.6893305778503 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 17, 'beta_1': 0.8, 'LR': 0.004, 'L2': 0.001}
# Best RMSE Score: 0.0480603003243349

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
gru_model = create_gru_model(gru_units_1=17 ,beta_1=0.8, LR=0.004, L2=0.001)
gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 17)                5049
#
#  dropout_1 (Dropout)         (None, 17)                0
#
#  dense_1 (Dense)             (None, 7)                 126
#
# =================================================================
# Total params: 5,175
# Trainable params: 5,175
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-20 13:09:36.779260: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 13:09:36.780809: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 13:09:36.782202: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = gru_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-20 13:09:37.285091: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 13:09:37.287465: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 13:09:37.289000: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-20 13:09:38.180058: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 13:09:38.182227: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 13:09:38.183974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 56ms/step - loss: 0.1587 - root_mean_squared_error: 0.3199 - val_loss: 0.0548 - val_root_mean_squared_error: 0.0802
# Epoch 2/150
#  1/13 [=>............................] - ETA: 0s - loss: 0.0734 - root_mean_squared_error: 0.1583
# 2024-12-20 13:09:39.680966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 13:09:39.683174: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 13:09:39.684843: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0597 - root_mean_squared_error: 0.1296 - val_loss: 0.0412 - val_root_mean_squared_error: 0.0620
# Epoch 3/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0464 - root_mean_squared_error: 0.1122 - val_loss: 0.0324 - val_root_mean_squared_error: 0.0463
# Epoch 4/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0375 - root_mean_squared_error: 0.0985 - val_loss: 0.0264 - val_root_mean_squared_error: 0.0335
# Epoch 5/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0325 - root_mean_squared_error: 0.0943 - val_loss: 0.0228 - val_root_mean_squared_error: 0.0312
# Epoch 6/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0283 - root_mean_squared_error: 0.0888 - val_loss: 0.0195 - val_root_mean_squared_error: 0.0235
# Epoch 7/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0250 - root_mean_squared_error: 0.0844 - val_loss: 0.0171 - val_root_mean_squared_error: 0.0214
# Epoch 8/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0222 - root_mean_squared_error: 0.0804 - val_loss: 0.0154 - val_root_mean_squared_error: 0.0267
# Epoch 9/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0204 - root_mean_squared_error: 0.0805 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0209
# Epoch 10/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0184 - root_mean_squared_error: 0.0777 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0319
# Epoch 11/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0173 - root_mean_squared_error: 0.0791 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0217
# Epoch 12/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0152 - root_mean_squared_error: 0.0735 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0216
# Epoch 13/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.0737 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0211
# Epoch 14/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0128 - root_mean_squared_error: 0.0698 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0311
# Epoch 15/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0127 - root_mean_squared_error: 0.0743 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0271
# Epoch 16/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0115 - root_mean_squared_error: 0.0712 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0226
# Epoch 17/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0107 - root_mean_squared_error: 0.0698 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0346
# Epoch 18/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0105 - root_mean_squared_error: 0.0722 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0207
# Epoch 19/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0105 - root_mean_squared_error: 0.0749 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0250
# Epoch 20/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0100 - root_mean_squared_error: 0.0745 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0199
# Epoch 21/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0094 - root_mean_squared_error: 0.0732 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0189
# Epoch 22/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0086 - root_mean_squared_error: 0.0695 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0470
# Epoch 23/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0084 - root_mean_squared_error: 0.0703 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0255
# Epoch 24/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0076 - root_mean_squared_error: 0.0663 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0295
# Epoch 25/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0073 - root_mean_squared_error: 0.0663 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0239
# Epoch 26/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0069 - root_mean_squared_error: 0.0650 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0187
# Epoch 27/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0070 - root_mean_squared_error: 0.0673 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0194
# Epoch 28/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0067 - root_mean_squared_error: 0.0665 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0192
# Epoch 29/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0074 - root_mean_squared_error: 0.0725 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0288
# Epoch 30/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0063 - root_mean_squared_error: 0.0655 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0200
# Epoch 31/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0057 - root_mean_squared_error: 0.0616 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0202
# Epoch 32/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0059 - root_mean_squared_error: 0.0643 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0218
# Epoch 33/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0054 - root_mean_squared_error: 0.0616 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0185
# Epoch 34/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0056 - root_mean_squared_error: 0.0641 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0340
# Epoch 35/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0051 - root_mean_squared_error: 0.0606 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0244
# Epoch 36/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0054 - root_mean_squared_error: 0.0635 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0187
# Epoch 37/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0051 - root_mean_squared_error: 0.0621 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0190
# Epoch 38/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0050 - root_mean_squared_error: 0.0621 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0318
# Epoch 39/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0051 - root_mean_squared_error: 0.0629 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0265
# Epoch 40/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0053 - root_mean_squared_error: 0.0652 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0195
# Epoch 41/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0052 - root_mean_squared_error: 0.0646 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0301
# Epoch 42/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0049 - root_mean_squared_error: 0.0628 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0310
# Epoch 43/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0601 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0215
# Epoch 44/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0047 - root_mean_squared_error: 0.0623 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0204
# Epoch 45/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0047 - root_mean_squared_error: 0.0623 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0276
# Epoch 46/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0048 - root_mean_squared_error: 0.0635 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0261
# Epoch 47/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0042 - root_mean_squared_error: 0.0591 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0363
# Epoch 48/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0055 - root_mean_squared_error: 0.0693 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0219
# Epoch 49/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0043 - root_mean_squared_error: 0.0598 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0262
# Epoch 50/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0044 - root_mean_squared_error: 0.0612 - val_loss: 9.7394e-04 - val_root_mean_squared_error: 0.0182
# Epoch 51/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0047 - root_mean_squared_error: 0.0636 - val_loss: 0.0010 - val_root_mean_squared_error: 0.0198
# Epoch 52/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0055 - root_mean_squared_error: 0.0698 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0442
# Epoch 53/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0043 - root_mean_squared_error: 0.0604 - val_loss: 9.5360e-04 - val_root_mean_squared_error: 0.0189
# Epoch 54/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0041 - root_mean_squared_error: 0.0593 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0362
# Epoch 55/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0040 - root_mean_squared_error: 0.0590 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0251
# Epoch 56/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0047 - root_mean_squared_error: 0.0643 - val_loss: 9.7363e-04 - val_root_mean_squared_error: 0.0211
# Epoch 57/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0048 - root_mean_squared_error: 0.0654 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0348
# Epoch 58/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0040 - root_mean_squared_error: 0.0593 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0287

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0011 - root_mean_squared_error: 0.0223
# Test Loss: 0.0010932141449302435
# Test RMSE: 0.022313138470053673

# %%
# คำนวณ predicted values
yhat_train = gru_model.predict(train_X)
yhat_val = gru_model.predict(val_X)
yhat_test = gru_model.predict(test_X)
# Out:
#  1/26 [>.............................] - ETA: 23s
# 2024-12-20 13:09:46.642663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 13:09:46.644849: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 13:09:46.646384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 1ms/step
# 6/6 [==============================] - 0s 2ms/step
# 2024-12-20 13:09:47.420075: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-20 13:09:47.422123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-20 13:09:47.423574: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_rnn_model(rnn_units_1,beta_1,LR,L2):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_4008380/849910436.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-20 13:34:31.201208: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.201394: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.230920: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.247664: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.259739: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.280722: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.280746: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.280786: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.307834: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.307858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.312536: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.341562: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.349811: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.351409: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.363395: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.381791: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.381801: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.390455: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.390960: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.391115: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.398346: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.398798: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.399303: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.439360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.439682: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.466689: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.467251: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.467284: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.467451: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.470947: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.498250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-20 13:34:31.498389: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 3111.3484449386597 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 69, 'beta_1': 0.8, 'LR': 0.009000000000000001, 'L2': 0.001}
# Best RMSE Score: 0.039064489107985996

# %%
rnn_model = create_rnn_model(rnn_units_1=69, beta_1=0.8 , LR=0.009, L2=0.001)
rnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 69)                10350
#
#  dropout_3 (Dropout)         (None, 69)                0
#
#  dense_3 (Dense)             (None, 7)                 490
#
# =================================================================
# Total params: 10,840
# Trainable params: 10,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_resid = rnn_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 1s 23ms/step - loss: 0.1491 - root_mean_squared_error: 0.2806 - val_loss: 0.0688 - val_root_mean_squared_error: 0.0607
# Epoch 2/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0783 - root_mean_squared_error: 0.1337 - val_loss: 0.0573 - val_root_mean_squared_error: 0.0462
# Epoch 3/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0618 - root_mean_squared_error: 0.1022 - val_loss: 0.0493 - val_root_mean_squared_error: 0.0472
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0509 - root_mean_squared_error: 0.0830 - val_loss: 0.0427 - val_root_mean_squared_error: 0.0447
# Epoch 5/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0417 - root_mean_squared_error: 0.0599 - val_loss: 0.0358 - val_root_mean_squared_error: 0.0245
# Epoch 6/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0381 - root_mean_squared_error: 0.0721 - val_loss: 0.0313 - val_root_mean_squared_error: 0.0295
# Epoch 7/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0324 - root_mean_squared_error: 0.0620 - val_loss: 0.0272 - val_root_mean_squared_error: 0.0299
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0283 - root_mean_squared_error: 0.0606 - val_loss: 0.0237 - val_root_mean_squared_error: 0.0313
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0246 - root_mean_squared_error: 0.0587 - val_loss: 0.0204 - val_root_mean_squared_error: 0.0303
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0220 - root_mean_squared_error: 0.0617 - val_loss: 0.0174 - val_root_mean_squared_error: 0.0265
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0188 - root_mean_squared_error: 0.0566 - val_loss: 0.0149 - val_root_mean_squared_error: 0.0251
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0166 - root_mean_squared_error: 0.0578 - val_loss: 0.0149 - val_root_mean_squared_error: 0.0524
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0160 - root_mean_squared_error: 0.0685 - val_loss: 0.0153 - val_root_mean_squared_error: 0.0701
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0151 - root_mean_squared_error: 0.0741 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0380
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0117 - root_mean_squared_error: 0.0593 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0282
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0131 - root_mean_squared_error: 0.0780 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0265
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0090 - root_mean_squared_error: 0.0556 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0307
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0075 - root_mean_squared_error: 0.0499 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0259
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0069 - root_mean_squared_error: 0.0519 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0253
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0061 - root_mean_squared_error: 0.0499 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0221
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0491 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0261
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0048 - root_mean_squared_error: 0.0479 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0252
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0501 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0286
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0542 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0244
# Epoch 25/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0042 - root_mean_squared_error: 0.0521 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0298
# Epoch 26/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0043 - root_mean_squared_error: 0.0556 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0224
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0037 - root_mean_squared_error: 0.0519 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0216
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0035 - root_mean_squared_error: 0.0517 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0205
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0034 - root_mean_squared_error: 0.0516 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0272
# Epoch 30/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0032 - root_mean_squared_error: 0.0508 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0230
# Epoch 31/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0029 - root_mean_squared_error: 0.0491 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0270
# Epoch 32/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0029 - root_mean_squared_error: 0.0499 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0344
# Epoch 33/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0030 - root_mean_squared_error: 0.0518 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0460
# Epoch 34/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0038 - root_mean_squared_error: 0.0590 - val_loss: 9.2159e-04 - val_root_mean_squared_error: 0.0253
# Epoch 35/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0033 - root_mean_squared_error: 0.0551 - val_loss: 0.0012 - val_root_mean_squared_error: 0.0314
# Epoch 36/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027 - root_mean_squared_error: 0.0496 - val_loss: 9.1840e-04 - val_root_mean_squared_error: 0.0267
# Epoch 37/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0031 - root_mean_squared_error: 0.0536 - val_loss: 6.3998e-04 - val_root_mean_squared_error: 0.0214
# Epoch 38/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0028 - root_mean_squared_error: 0.0514 - val_loss: 6.4462e-04 - val_root_mean_squared_error: 0.0221
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027 - root_mean_squared_error: 0.0508 - val_loss: 0.0011 - val_root_mean_squared_error: 0.0306
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026 - root_mean_squared_error: 0.0501 - val_loss: 0.0013 - val_root_mean_squared_error: 0.0348
# Epoch 41/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027 - root_mean_squared_error: 0.0508 - val_loss: 5.6403e-04 - val_root_mean_squared_error: 0.0213
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0026 - root_mean_squared_error: 0.0495 - val_loss: 6.8482e-04 - val_root_mean_squared_error: 0.0243
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0030 - root_mean_squared_error: 0.0539 - val_loss: 0.0014 - val_root_mean_squared_error: 0.0355
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0033 - root_mean_squared_error: 0.0566 - val_loss: 0.0015 - val_root_mean_squared_error: 0.0378
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0027 - root_mean_squared_error: 0.0515 - val_loss: 6.7944e-04 - val_root_mean_squared_error: 0.0245
# Epoch 46/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0028 - root_mean_squared_error: 0.0525 - val_loss: 6.5165e-04 - val_root_mean_squared_error: 0.0240

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0535 - root_mean_squared_error: 0.2300
# Test Loss: 0.053489744663238525
# Test RMSE: 0.22998782992362976

# %%
# คำนวณ predicted residuals
yhat_train_resid = rnn_model.predict(train_X_resid)
yhat_val_resid = rnn_model.predict(val_X_resid)
yhat_test_resid = rnn_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('XPG_Adj_close_prediction By cascaded')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 7.1033%
# RMSE: 0.1102
