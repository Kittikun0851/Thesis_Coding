# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-22 11:56:10.813223: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-22 11:56:10.824564: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 11:56:10.882553: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 11:56:10.883640: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-22 11:57:00.313238: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('BCP.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  24.270227  31.00  31.25  30.75  30.75  4900700
# 2019-07-02 00:00:00+00:00  24.270227  31.00  31.25  30.50  31.00  4547000
# 2019-07-03 00:00:00+00:00  24.270227  31.00  31.00  30.50  30.75  2499300
# 2019-07-04 00:00:00+00:00  24.074501  30.75  31.00  30.25  31.00  2577300
# 2019-07-05 00:00:00+00:00  24.270227  31.00  31.00  30.50  30.75  1952100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('BCP Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.380723    0.513473   0.520240    0.512938      0.068406
# 16         0.380723    0.513473   0.512744    0.520548      0.063469
# 17         0.380723    0.505988   0.512744    0.512938      0.034886
# 18         0.375144    0.505988   0.505247    0.520548      0.035975
# 19         0.380723    0.505988   0.512744    0.512938      0.027248
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.380723    0.513473   0.512744    0.520548      0.063469  ...
# 16         0.380723    0.505988   0.512744    0.512938      0.034886  ...
# 17         0.375144    0.505988   0.505247    0.520548      0.035975  ...
# 18         0.380723    0.505988   0.512744    0.512938      0.027248  ...
# 19         0.369565    0.505988   0.512744    0.512938      0.035794  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.512744  0.520548   0.024909        0.391880        0.391880
# 16  0.520240  0.520548   0.035428        0.391880        0.386301
# 17  0.527736  0.535769   0.064707        0.386301        0.369565
# 18  0.527736  0.535769   0.040301        0.369565        0.363986
# 19  0.512744  0.528158   0.032925        0.363986        0.358407
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.386301        0.369565        0.363986        0.358407
# 16        0.369565        0.363986        0.358407        0.341671
# 17        0.363986        0.358407        0.341671        0.330513
# 18        0.358407        0.341671        0.330513        0.336092
# 19        0.341671        0.330513        0.336092        0.336092
#
#     Adj Close(t+7)
# 15        0.341671
# 16        0.330513
# 17        0.336092
# 18        0.336092
# 19        0.319355
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_gru_model(gru_units_1, beta_1 ,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_596717/2081204696.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-22 12:26:39.105487: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.105578: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.107326: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.143222: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.163362: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.181758: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.181890: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.182049: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.191434: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.191651: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.200154: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.209677: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.221271: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.222837: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.222865: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.224206: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.232884: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.278725: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.287785: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.300588: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.309581: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.309911: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.310439: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.319089: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.350046: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.350489: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.358979: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.359414: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.359508: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.368704: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.378752: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:26:39.386429: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 12:56:01.305513: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 12:56:01.307503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 12:56:01.308648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 12:56:03.762203: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 12:56:03.764610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 12:56:03.766412: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 12:56:04.680187: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 12:56:04.682738: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 12:56:04.684350: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 12:56:06.980631: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 12:56:06.983692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 12:56:06.986523: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 3128.2743067741394 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 70, 'beta_1': 0.8, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.04594986327620437

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
gru_model = create_gru_model(gru_units_1=70 ,beta_1=0.8, LR=0.003, L2=0.001)
gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 70)                31920
#
#  dropout_1 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 7)                 497
#
# =================================================================
# Total params: 32,417
# Trainable params: 32,417
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-22 13:29:15.745667: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 13:29:15.747677: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 13:29:15.748812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = gru_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-22 13:29:16.231302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 13:29:16.233320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 13:29:16.234837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 13:29:17.062687: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 13:29:17.064649: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 13:29:17.066103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 25s - loss: 0.2605 - root_mean_squared_error: 0.3792
# 2024-12-22 13:29:18.485767: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 13:29:18.487937: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 13:29:18.489563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 56ms/step - loss: 0.1220 - root_mean_squared_error: 0.1619 - val_loss: 0.1221 - val_root_mean_squared_error: 0.2202
# Epoch 2/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0664 - root_mean_squared_error: 0.0798 - val_loss: 0.0686 - val_root_mean_squared_error: 0.1473
# Epoch 3/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0443 - root_mean_squared_error: 0.0695 - val_loss: 0.0436 - val_root_mean_squared_error: 0.1060
# Epoch 4/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0323 - root_mean_squared_error: 0.0640 - val_loss: 0.0338 - val_root_mean_squared_error: 0.0987
# Epoch 5/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0251 - root_mean_squared_error: 0.0599 - val_loss: 0.0269 - val_root_mean_squared_error: 0.0896
# Epoch 6/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0204 - root_mean_squared_error: 0.0582 - val_loss: 0.0224 - val_root_mean_squared_error: 0.0851
# Epoch 7/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0169 - root_mean_squared_error: 0.0550 - val_loss: 0.0169 - val_root_mean_squared_error: 0.0662
# Epoch 8/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0145 - root_mean_squared_error: 0.0545 - val_loss: 0.0152 - val_root_mean_squared_error: 0.0690
# Epoch 9/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0124 - root_mean_squared_error: 0.0527 - val_loss: 0.0165 - val_root_mean_squared_error: 0.0879
# Epoch 10/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0106 - root_mean_squared_error: 0.0497 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0661
# Epoch 11/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0094 - root_mean_squared_error: 0.0497 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0809
# Epoch 12/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0084 - root_mean_squared_error: 0.0493 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0642
# Epoch 13/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0077 - root_mean_squared_error: 0.0511 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0726
# Epoch 14/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0067 - root_mean_squared_error: 0.0470 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0871
# Epoch 15/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0060 - root_mean_squared_error: 0.0454 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0649
# Epoch 16/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0055 - root_mean_squared_error: 0.0461 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0939
# Epoch 17/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0054 - root_mean_squared_error: 0.0485 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0684
# Epoch 18/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0048 - root_mean_squared_error: 0.0456 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0578
# Epoch 19/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0044 - root_mean_squared_error: 0.0451 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0709
# Epoch 20/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0040 - root_mean_squared_error: 0.0433 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0493
# Epoch 21/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0038 - root_mean_squared_error: 0.0438 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0814
# Epoch 22/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0039 - root_mean_squared_error: 0.0463 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0503
# Epoch 23/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0036 - root_mean_squared_error: 0.0446 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0419
# Epoch 24/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0039 - root_mean_squared_error: 0.0496 - val_loss: 0.0142 - val_root_mean_squared_error: 0.1135
# Epoch 25/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0032 - root_mean_squared_error: 0.0439 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0665
# Epoch 26/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0029 - root_mean_squared_error: 0.0406 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0588
# Epoch 27/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0028 - root_mean_squared_error: 0.0416 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0415
# Epoch 28/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0028 - root_mean_squared_error: 0.0420 - val_loss: 0.0117 - val_root_mean_squared_error: 0.1035
# Epoch 29/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0036 - root_mean_squared_error: 0.0519 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0433
# Epoch 30/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0028 - root_mean_squared_error: 0.0440 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0778
# Epoch 31/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0024 - root_mean_squared_error: 0.0397 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0470
# Epoch 32/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0025 - root_mean_squared_error: 0.0414 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0782

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0028 - root_mean_squared_error: 0.0416
# Test Loss: 0.0028045650105923414
# Test RMSE: 0.04159332066774368

# %%
# คำนวณ predicted values
yhat_train = gru_model.predict(train_X)
yhat_val = gru_model.predict(val_X)
yhat_test = gru_model.predict(test_X)
# Out:
#  1/26 [>.............................] - ETA: 22s
# 2024-12-22 13:29:31.074341: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 13:29:31.076468: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 13:29:31.077882: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 1ms/step
# 6/6 [==============================] - 1s 2ms/step
# 2024-12-22 13:29:32.000692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 13:29:32.003384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 13:29:32.005329: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_rnn_model(rnn_units_1,beta_1,LR,L2):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_596717/849910436.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-22 13:56:09.385292: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.385393: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.386162: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.394413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.412973: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.413154: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.417003: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.425763: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.425968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.436790: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.452597: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.452622: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.461836: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.472416: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.485108: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.492914: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.493335: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.493426: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.528484: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.532611: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.532800: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.551025: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.559752: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.560201: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.569731: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.595616: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.595804: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.599322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.607972: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.613142: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.615907: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 13:56:09.616357: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 3293.398059606552 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 70, 'beta_1': 0.8, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.032221741416975445

# %%
rnn_model = create_rnn_model(rnn_units_1=70, beta_1=0.8 , LR=0.003, L2=0.001)
rnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 70)                10570
#
#  dropout_3 (Dropout)         (None, 70)                0
#
#  dense_3 (Dense)             (None, 7)                 497
#
# =================================================================
# Total params: 11,067
# Trainable params: 11,067
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_resid = rnn_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 2s 39ms/step - loss: 0.1062 - root_mean_squared_error: 0.1841 - val_loss: 0.0859 - val_root_mean_squared_error: 0.1270
# Epoch 2/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0778 - root_mean_squared_error: 0.1022 - val_loss: 0.0694 - val_root_mean_squared_error: 0.0705
# Epoch 3/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0663 - root_mean_squared_error: 0.0661 - val_loss: 0.0639 - val_root_mean_squared_error: 0.0701
# Epoch 4/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0589 - root_mean_squared_error: 0.0486 - val_loss: 0.0568 - val_root_mean_squared_error: 0.0565
# Epoch 5/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0531 - root_mean_squared_error: 0.0435 - val_loss: 0.0516 - val_root_mean_squared_error: 0.0559
# Epoch 6/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0479 - root_mean_squared_error: 0.0403 - val_loss: 0.0469 - val_root_mean_squared_error: 0.0563
# Epoch 7/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0433 - root_mean_squared_error: 0.0391 - val_loss: 0.0421 - val_root_mean_squared_error: 0.0520
# Epoch 8/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0390 - root_mean_squared_error: 0.0378 - val_loss: 0.0378 - val_root_mean_squared_error: 0.0484
# Epoch 9/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0351 - root_mean_squared_error: 0.0372 - val_loss: 0.0345 - val_root_mean_squared_error: 0.0519
# Epoch 10/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0316 - root_mean_squared_error: 0.0366 - val_loss: 0.0308 - val_root_mean_squared_error: 0.0478
# Epoch 11/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0284 - root_mean_squared_error: 0.0350 - val_loss: 0.0280 - val_root_mean_squared_error: 0.0490
# Epoch 12/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0256 - root_mean_squared_error: 0.0363 - val_loss: 0.0251 - val_root_mean_squared_error: 0.0477
# Epoch 13/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0230 - root_mean_squared_error: 0.0359 - val_loss: 0.0239 - val_root_mean_squared_error: 0.0586
# Epoch 14/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0207 - root_mean_squared_error: 0.0359 - val_loss: 0.0206 - val_root_mean_squared_error: 0.0489
# Epoch 15/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0188 - root_mean_squared_error: 0.0380 - val_loss: 0.0182 - val_root_mean_squared_error: 0.0440
# Epoch 16/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0167 - root_mean_squared_error: 0.0350 - val_loss: 0.0162 - val_root_mean_squared_error: 0.0406
# Epoch 17/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0149 - root_mean_squared_error: 0.0337 - val_loss: 0.0163 - val_root_mean_squared_error: 0.0575
# Epoch 18/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0136 - root_mean_squared_error: 0.0366 - val_loss: 0.0134 - val_root_mean_squared_error: 0.0428
# Epoch 19/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0121 - root_mean_squared_error: 0.0336 - val_loss: 0.0123 - val_root_mean_squared_error: 0.0452
# Epoch 20/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0108 - root_mean_squared_error: 0.0330 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0461
# Epoch 21/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0098 - root_mean_squared_error: 0.0337 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0704
# Epoch 22/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0091 - root_mean_squared_error: 0.0374 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0431
# Epoch 23/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0081 - root_mean_squared_error: 0.0350 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0472
# Epoch 24/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0073 - root_mean_squared_error: 0.0355 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0477
# Epoch 25/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0066 - root_mean_squared_error: 0.0350 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0577
# Epoch 26/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0060 - root_mean_squared_error: 0.0352 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0497
# Epoch 27/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0053 - root_mean_squared_error: 0.0331 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0418
# Epoch 28/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0050 - root_mean_squared_error: 0.0359 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0476
# Epoch 29/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0045 - root_mean_squared_error: 0.0336 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0513
# Epoch 30/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0041 - root_mean_squared_error: 0.0342 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0537
# Epoch 31/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0038 - root_mean_squared_error: 0.0339 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0408
# Epoch 32/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0035 - root_mean_squared_error: 0.0345 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0482
# Epoch 33/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0033 - root_mean_squared_error: 0.0347 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0671
# Epoch 34/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0033 - root_mean_squared_error: 0.0381 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0602
# Epoch 35/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0027 - root_mean_squared_error: 0.0336 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0530
# Epoch 36/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0025 - root_mean_squared_error: 0.0334 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0448
# Epoch 37/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0023 - root_mean_squared_error: 0.0326 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0549
# Epoch 38/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0022 - root_mean_squared_error: 0.0329 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0395
# Epoch 39/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0021 - root_mean_squared_error: 0.0326 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0539
# Epoch 40/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0336 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0408
# Epoch 41/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0331 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0456
# Epoch 42/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0018 - root_mean_squared_error: 0.0326 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0462
# Epoch 43/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0020 - root_mean_squared_error: 0.0367 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0517
# Epoch 44/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0017 - root_mean_squared_error: 0.0331 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0494
# Epoch 45/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0018 - root_mean_squared_error: 0.0356 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0594

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.7241 - root_mean_squared_error: 0.8503
# Test Loss: 0.7240668535232544
# Test RMSE: 0.8502895832061768

# %%
# คำนวณ predicted residuals
yhat_train_resid = rnn_model.predict(train_X_resid)
yhat_val_resid = rnn_model.predict(val_X_resid)
yhat_test_resid = rnn_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.0499%
# RMSE: 1.5697
