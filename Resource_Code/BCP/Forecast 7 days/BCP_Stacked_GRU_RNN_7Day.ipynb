# %% [markdown]
# ## Library

# %%
# !pip install tensorflow==2.12.0

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('BCP.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High    Low   Open   Volume
# Date
# 2019-07-01 00:00:00+00:00  24.270226  31.00  31.25  30.75  30.75  4900700
# 2019-07-02 00:00:00+00:00  24.270226  31.00  31.25  30.50  31.00  4547000
# 2019-07-03 00:00:00+00:00  24.270226  31.00  31.00  30.50  30.75  2499300
# 2019-07-04 00:00:00+00:00  24.074501  30.75  31.00  30.25  31.00  2577300
# 2019-07-05 00:00:00+00:00  24.270226  31.00  31.00  30.50  30.75  1952100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('BCP Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.380722    0.513473   0.520240    0.512938      0.068406
# 16         0.380722    0.513473   0.512744    0.520548      0.063469
# 17         0.380722    0.505988   0.512744    0.512938      0.034886
# 18         0.375144    0.505988   0.505247    0.520548      0.035975
# 19         0.380722    0.505988   0.512744    0.512938      0.027248
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.380722    0.513473   0.512744    0.520548      0.063469  ...
# 16         0.380722    0.505988   0.512744    0.512938      0.034886  ...
# 17         0.375144    0.505988   0.505247    0.520548      0.035975  ...
# 18         0.380722    0.505988   0.512744    0.512938      0.027248  ...
# 19         0.369565    0.505988   0.512744    0.512938      0.035794  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.512744  0.520548   0.024909        0.391880        0.391880
# 16  0.520240  0.520548   0.035428        0.391880        0.386301
# 17  0.527736  0.535769   0.064707        0.386301        0.369565
# 18  0.527736  0.535769   0.040301        0.369565        0.363986
# 19  0.512744  0.528158   0.032925        0.363986        0.358407
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.386301        0.369565        0.363986        0.358407
# 16        0.369565        0.363986        0.358407        0.341671
# 17        0.363986        0.358407        0.341671        0.330513
# 18        0.358407        0.341671        0.330513        0.336092
# 19        0.341671        0.330513        0.336092        0.336092
#
#     Adj Close(t+7)
# 15        0.341671
# 16        0.330513
# 17        0.336092
# 18        0.336092
# 19        0.319355
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Create Model & Evaluate (ยังไม่ Hyperparameter tuning)

# %%
model = Sequential()

# GRU layer with ReLU activation
model.add(GRU(units=70,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.005)))
model.add(Dropout(0.1))
# SimpleRNN layer with ReLU activation
model.add(SimpleRNN(units=70,activation='relu'))
model.add(Dropout(0.1))
# Output layer for 1 targets
model.add(Dense(1,activation='sigmoid'))
# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Compile the model
# model.compile(optimizer='adam', loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])

# %%
# # ทำ prediction
# yhat = model.predict(test_X)
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# # rescale ข้อมูลกลับ

# # Standardized -> actual
# # inv_yhat = (yhat * std_dict['Adj Close']) + mean_dict['Adj Close']
# # inv_y = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# # # Min-Max Normalized -> actual
# inv_yhat = yhat*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']
# inv_y = test_y*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']

# %%
# ทำ prediction
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# Rescale ข้อมูลกลับ (สำหรับ Standardized)
# inv_yhat_train = (yhat_train * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_yhat_val = (yhat_val * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_yhat_test = (yhat_test * std_dict['Adj Close']) + mean_dict['Adj Close']

# inv_y_train = (train_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_y_val = (val_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_y_test = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='KBANK_predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='KBANK_predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='KBANK_predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('KBANK_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')

# %% [markdown]
# ## Hyperparameter Tuning

# %%
def create_model(gru_units,rnn_units,LR,L2,beta_1):
    model = Sequential()
    model.add(GRU(gru_units,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(SimpleRNN(rnn_units,activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune
param_dist = {
    'gru_units': list(range(1, 101)),
    'rnn_units': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)

import time

start_time = time.time()


# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
random_search_result = random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_3032870/2760256981.py:22: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-14 15:15:57.796662: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.808770: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.808977: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.811932: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.814000: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.814714: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.819232: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.828637: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.828639: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.832975: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.863738: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.869644: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.871822: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.876563: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.877999: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.896112: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.897059: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.897364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.897477: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.909550: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.910210: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.916350: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.923389: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.928240: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.935965: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.986776: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.987753: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.993528: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:57.995560: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:58.007301: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:58.008865: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:15:58.009793: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 15:39:20.450328: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:39:20.457706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:39:20.459209: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 15:39:21.475444: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:39:21.477727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:39:21.481540: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 15:39:23.693755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:39:23.707106: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:39:23.713786: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 15:39:26.457770: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:39:26.460507: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:39:26.462808: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 2554.0212304592133 seconds

# %%
# Get the best parameters and the best score
best_params = random_search_result.best_params_
best_score = -random_search_result.best_score_

# %%
print("Best Parameters:", best_params)
print("Best RMSE Score:", best_score)
# Out:
# Best Parameters: {'rnn_units': 55, 'gru_units': 47, 'beta_1': 0.9, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.04004287345554804

# %% [markdown]
# ## After Hyperparametertuning

# %%
gru_rnn_model = create_model(gru_units=47,rnn_units=55, beta_1=0.9,LR=0.003,L2=0.001)
gru_rnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_3 (GRU)                 (None, 1, 47)             18189
#
#  dropout_6 (Dropout)         (None, 1, 47)             0
#
#  simple_rnn_3 (SimpleRNN)    (None, 55)                5665
#
#  dropout_7 (Dropout)         (None, 55)                0
#
#  dense_3 (Dense)             (None, 7)                 392
#
# =================================================================
# Total params: 24,246
# Trainable params: 24,246
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-14 15:47:58.444411: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:47:58.446123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:47:58.447267: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
gru_rnn_history = gru_rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-14 15:48:03.195330: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:48:03.197529: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:48:03.199079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 15:48:04.089797: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:48:04.091842: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:48:04.093289: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 32s - loss: 0.2322 - root_mean_squared_error: 0.3614
# 2024-12-14 15:48:05.586884: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:48:05.589405: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:48:05.591076: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 54ms/step - loss: 0.1200 - root_mean_squared_error: 0.1821 - val_loss: 0.1334 - val_root_mean_squared_error: 0.2506
# Epoch 2/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0699 - root_mean_squared_error: 0.1011 - val_loss: 0.0854 - val_root_mean_squared_error: 0.1918
# Epoch 3/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0488 - root_mean_squared_error: 0.0842 - val_loss: 0.0483 - val_root_mean_squared_error: 0.1161
# Epoch 4/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0357 - root_mean_squared_error: 0.0718 - val_loss: 0.0362 - val_root_mean_squared_error: 0.0995
# Epoch 5/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0280 - root_mean_squared_error: 0.0656 - val_loss: 0.0280 - val_root_mean_squared_error: 0.0840
# Epoch 6/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0229 - root_mean_squared_error: 0.0621 - val_loss: 0.0203 - val_root_mean_squared_error: 0.0564
# Epoch 7/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0192 - root_mean_squared_error: 0.0595 - val_loss: 0.0176 - val_root_mean_squared_error: 0.0578
# Epoch 8/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0162 - root_mean_squared_error: 0.0553 - val_loss: 0.0167 - val_root_mean_squared_error: 0.0689
# Epoch 9/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0140 - root_mean_squared_error: 0.0535 - val_loss: 0.0137 - val_root_mean_squared_error: 0.0601
# Epoch 10/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0120 - root_mean_squared_error: 0.0513 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0565
# Epoch 11/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0105 - root_mean_squared_error: 0.0503 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0427
# Epoch 12/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0095 - root_mean_squared_error: 0.0518 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0817
# Epoch 13/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0087 - root_mean_squared_error: 0.0532 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0403
# Epoch 14/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0073 - root_mean_squared_error: 0.0481 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0493
# Epoch 15/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0065 - root_mean_squared_error: 0.0459 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0563
# Epoch 16/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0062 - root_mean_squared_error: 0.0486 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0626
# Epoch 17/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0060 - root_mean_squared_error: 0.0515 - val_loss: 0.0123 - val_root_mean_squared_error: 0.0961
# Epoch 18/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0068 - root_mean_squared_error: 0.0618 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0411
# Epoch 19/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0055 - root_mean_squared_error: 0.0536 - val_loss: 0.0106 - val_root_mean_squared_error: 0.0897
# Epoch 20/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0050 - root_mean_squared_error: 0.0510 - val_loss: 0.0121 - val_root_mean_squared_error: 0.0990
# Epoch 21/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0043 - root_mean_squared_error: 0.0463 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0620
# Epoch 22/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0040 - root_mean_squared_error: 0.0453 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0593
# Epoch 23/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0037 - root_mean_squared_error: 0.0441 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0431
# Epoch 24/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0034 - root_mean_squared_error: 0.0420 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0750
# Epoch 25/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0036 - root_mean_squared_error: 0.0459 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0846
# Epoch 26/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0036 - root_mean_squared_error: 0.0478 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0391
# Epoch 27/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0033 - root_mean_squared_error: 0.0452 - val_loss: 0.0120 - val_root_mean_squared_error: 0.1041
# Epoch 28/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0033 - root_mean_squared_error: 0.0468 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0412
# Epoch 29/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0027 - root_mean_squared_error: 0.0403 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0399
# Epoch 30/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0025 - root_mean_squared_error: 0.0396 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0452
# Epoch 31/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0024 - root_mean_squared_error: 0.0387 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0406
# Epoch 32/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0025 - root_mean_squared_error: 0.0415 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0446
# Epoch 33/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0024 - root_mean_squared_error: 0.0405 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0426
# Epoch 34/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0024 - root_mean_squared_error: 0.0409 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0384
# Epoch 35/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0022 - root_mean_squared_error: 0.0387 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0441
# Epoch 36/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0021 - root_mean_squared_error: 0.0383 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0587
# Epoch 37/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0020 - root_mean_squared_error: 0.0378 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0487
# Epoch 38/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0020 - root_mean_squared_error: 0.0381 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0826
# Epoch 39/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0021 - root_mean_squared_error: 0.0393 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0393
# Epoch 40/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0019 - root_mean_squared_error: 0.0379 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0522
# Epoch 41/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0027 - root_mean_squared_error: 0.0479 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0541
# Epoch 42/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0020 - root_mean_squared_error: 0.0397 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0410
# Epoch 43/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0019 - root_mean_squared_error: 0.0379 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0381
# Epoch 44/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0019 - root_mean_squared_error: 0.0391 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0465
# Epoch 45/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0019 - root_mean_squared_error: 0.0387 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0415
# Epoch 46/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0016 - root_mean_squared_error: 0.0353 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0387
# Epoch 47/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0020 - root_mean_squared_error: 0.0404 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0541
# Epoch 48/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0035 - root_mean_squared_error: 0.0563 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0391
# Epoch 49/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0025 - root_mean_squared_error: 0.0455 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0419
# Epoch 50/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0020 - root_mean_squared_error: 0.0400 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0433
# Epoch 51/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0019 - root_mean_squared_error: 0.0391 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0545

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(gru_rnn_history.history['loss'], label='train_loss')
plt.plot(gru_rnn_history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = gru_rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0019 - root_mean_squared_error: 0.0394
# Test Loss: 0.0019164104014635086
# Test RMSE: 0.039388176053762436

# %%
# ทำ prediction
yhat_train = gru_rnn_model.predict(train_X)
yhat_val = gru_rnn_model.predict(val_X)
yhat_test = gru_rnn_model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
# Out:
# 2024-12-14 15:48:15.464780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:48:15.466848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:48:15.468311: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 1ms/step
# 2024-12-14 15:48:16.037285: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 15:48:16.039132: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 15:48:16.040555: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('BCP_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 2.6715%
# RMSE: 1.3819
