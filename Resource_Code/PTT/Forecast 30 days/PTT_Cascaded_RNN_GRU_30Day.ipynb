# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-22 23:33:07.104648: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-22 23:33:07.138409: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 23:33:07.255966: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 23:33:07.257637: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-22 23:33:50.818926: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('PTT.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High   Low   Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  38.007931  49.50  49.50  49.0  49.50  52067800
# 2019-07-02 00:00:00+00:00  37.240097  48.50  49.50  48.5  49.25  51490800
# 2019-07-03 00:00:00+00:00  37.048141  48.25  48.50  48.0  48.50  44524800
# 2019-07-04 00:00:00+00:00  37.048141  48.25  48.75  48.0  48.50  49509400
# 2019-07-05 00:00:00+00:00  37.048141  48.25  48.50  48.0  48.25  20907100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('PTT Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 31,feat_name=df.columns)
# แก้ไขจากการ drop คอลัมน์ตั้งแต่ t ถึง t-6 เป็น t ถึง t-29
reframed.drop(['High(t+1)', 'High(t+2)', 'High(t+3)', 'High(t+4)', 'High(t+5)', 'High(t+6)', 'High(t+7)', \
               'High(t+8)', 'High(t+9)', 'High(t+10)', 'High(t+11)', 'High(t+12)', 'High(t+13)', 'High(t+14)', \
               'High(t+15)', 'High(t+16)', 'High(t+17)', 'High(t+18)', 'High(t+19)', 'High(t+20)', 'High(t+21)', \
               'High(t+22)', 'High(t+23)', 'High(t+24)', 'High(t+25)', 'High(t+26)', 'High(t+27)', 'High(t+28)', 'High(t+29)','High(t+30)',\
               'Low(t+1)', 'Low(t+2)', 'Low(t+3)', 'Low(t+4)', 'Low(t+5)', 'Low(t+6)', 'Low(t+7)', \
               'Low(t+8)', 'Low(t+9)', 'Low(t+10)', 'Low(t+11)', 'Low(t+12)', 'Low(t+13)', 'Low(t+14)', \
               'Low(t+15)', 'Low(t+16)', 'Low(t+17)', 'Low(t+18)', 'Low(t+19)', 'Low(t+20)', 'Low(t+21)', \
               'Low(t+22)', 'Low(t+23)', 'Low(t+24)', 'Low(t+25)', 'Low(t+26)', 'Low(t+27)', 'Low(t+28)', 'Low(t+29)','Low(t+30)',\
               'Open(t+1)', 'Open(t+2)', 'Open(t+3)', 'Open(t+4)', 'Open(t+5)', 'Open(t+6)', 'Open(t+7)', 
               'Open(t+8)', 'Open(t+9)', 'Open(t+10)', 'Open(t+11)', 'Open(t+12)', 'Open(t+13)', 'Open(t+14)', \
               'Open(t+15)', 'Open(t+16)', 'Open(t+17)', 'Open(t+18)', 'Open(t+19)', 'Open(t+20)', 'Open(t+21)', \
               'Open(t+22)', 'Open(t+23)', 'Open(t+24)', 'Open(t+25)', 'Open(t+26)', 'Open(t+27)', 'Open(t+28)', 'Open(t+29)','Open(t+30)',\
               'Volume(t+1)', 'Volume(t+2)', 'Volume(t+3)', 'Volume(t+4)', 'Volume(t+5)', 'Volume(t+6)', 'Volume(t+7)', \
               'Volume(t+8)', 'Volume(t+9)', 'Volume(t+10)', 'Volume(t+11)', 'Volume(t+12)', 'Volume(t+13)', 'Volume(t+14)', \
               'Volume(t+15)', 'Volume(t+16)', 'Volume(t+17)', 'Volume(t+18)', 'Volume(t+19)', 'Volume(t+20)', 'Volume(t+21)', \
               'Volume(t+22)', 'Volume(t+23)', 'Volume(t+24)', 'Volume(t+25)', 'Volume(t+26)', 'Volume(t+27)', 'Volume(t+28)', 'Volume(t+29)','Volume(t+30)'], axis=1, inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         1.000000    1.000000   1.000000    1.000000      0.080878
# 16         0.955565    1.000000   0.980315    0.990119      0.079982
# 17         0.944456    0.957447   0.960630    0.960474      0.069161
# 18         0.944456    0.968085   0.960630    0.960474      0.076904
# 19         0.944456    0.957447   0.960630    0.950593      0.032475
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.955565    1.000000   0.980315    0.990119      0.079982  ...
# 16         0.944456    0.957447   0.960630    0.960474      0.069161  ...
# 17         0.944456    0.968085   0.960630    0.960474      0.076904  ...
# 18         0.944456    0.957447   0.960630    0.950593      0.032475  ...
# 19         0.944456    0.946809   0.960630    0.940711      0.019224  ...
#
#     Adj Close(t+21)  Adj Close(t+22)  Adj Close(t+23)  Adj Close(t+24)  \
# 15         0.688952         0.622299         0.611190         0.622299
# 16         0.622299         0.611190         0.622299         0.722279
# 17         0.611190         0.622299         0.722279         0.766714
# 18         0.622299         0.722279         0.766714         0.733388
# 19         0.722279         0.766714         0.733388         0.700061
#
#     Adj Close(t+25)  Adj Close(t+26)  Adj Close(t+27)  Adj Close(t+28)  \
# 15         0.722279         0.766714         0.733388         0.700061
# 16         0.766714         0.733388         0.700061         0.733388
# 17         0.733388         0.700061         0.733388         0.766714
# 18         0.700061         0.733388         0.766714         0.777823
# 19         0.733388         0.766714         0.777823         0.800041
#
#     Adj Close(t+29)  Adj Close(t+30)
# 15         0.733388         0.766714
# 16         0.766714         0.777823
# 17         0.777823         0.800041
# 18         0.800041         0.822259
# 19         0.822259         0.833367
#
# [5 rows x 110 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-30], train[:, -30:]
val_X, val_y = val[:, :-30], val[:, -30:]
test_X, test_y = test[:, :-30], test[:, -30:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (816, 1, 80)
# (816, 30)
# (175, 1, 80)
# (175, 30)
# (175, 1, 80)
# (175, 30)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_rnn_model(rnn_units_1, beta_1 ,LR,L2):
    model = Sequential()
    model.add(LSTM(rnn_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_2056652/484836469.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-22 23:48:28.666019: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.710485: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.714114: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.717919: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.751739: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.754568: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.761322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.763978: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.764506: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.792774: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.796065: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.799273: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.803838: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.809078: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.810794: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.816532: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.816995: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.837941: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.838169: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.843606: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.843629: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.849221: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.856437: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.856888: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.859289: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.859372: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.862938: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.865928: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.870738: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.875791: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.875926: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:48:28.881190: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:54:09.966961: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:54:09.969070: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:54:09.970431: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:54:10.758655: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:54:10.761244: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:54:10.763131: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:54:11.516371: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:54:11.518520: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:54:11.520020: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:54:12.964760: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:54:12.967228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:54:12.968974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 862.0354599952698 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 17, 'beta_1': 0.8, 'LR': 0.004, 'L2': 0.001}
# Best RMSE Score: 0.11698504630449742

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
rnn_model = create_rnn_model(rnn_units_1=17,beta_1=0.8 , LR=0.004, L2=0.001)
rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 17)                6664
#
#  dropout_1 (Dropout)         (None, 17)                0
#
#  dense_1 (Dense)             (None, 30)                540
#
# =================================================================
# Total params: 7,204
# Trainable params: 7,204
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-22 23:57:43.731868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:57:43.733629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:57:43.734834: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-22 23:57:46.378719: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:57:46.381076: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:57:46.382663: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:57:47.129125: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:57:47.131449: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:57:47.133002: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 23s - loss: 0.4987 - root_mean_squared_error: 0.6529
# 2024-12-22 23:57:48.447974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:57:48.450170: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:57:48.451573: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 45ms/step - loss: 0.3259 - root_mean_squared_error: 0.5141 - val_loss: 0.1070 - val_root_mean_squared_error: 0.2340
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1025 - root_mean_squared_error: 0.2410 - val_loss: 0.0480 - val_root_mean_squared_error: 0.1108
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0642 - root_mean_squared_error: 0.1839 - val_loss: 0.0362 - val_root_mean_squared_error: 0.1082
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0511 - root_mean_squared_error: 0.1733 - val_loss: 0.0274 - val_root_mean_squared_error: 0.0979
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0441 - root_mean_squared_error: 0.1685 - val_loss: 0.0223 - val_root_mean_squared_error: 0.0936
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0387 - root_mean_squared_error: 0.1634 - val_loss: 0.0184 - val_root_mean_squared_error: 0.0877
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0348 - root_mean_squared_error: 0.1587 - val_loss: 0.0159 - val_root_mean_squared_error: 0.0847
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0322 - root_mean_squared_error: 0.1561 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0795
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0302 - root_mean_squared_error: 0.1536 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0764
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0273 - root_mean_squared_error: 0.1476 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0746
# Epoch 11/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0264 - root_mean_squared_error: 0.1472 - val_loss: 0.0121 - val_root_mean_squared_error: 0.0884
# Epoch 12/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0252 - root_mean_squared_error: 0.1452 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0943
# Epoch 13/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0247 - root_mean_squared_error: 0.1453 - val_loss: 0.0093 - val_root_mean_squared_error: 0.0772
# Epoch 14/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0232 - root_mean_squared_error: 0.1413 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0756
# Epoch 15/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0231 - root_mean_squared_error: 0.1421 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0715
# Epoch 16/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0219 - root_mean_squared_error: 0.1391 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0799
# Epoch 17/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0210 - root_mean_squared_error: 0.1367 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0752
# Epoch 18/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0207 - root_mean_squared_error: 0.1362 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0713
# Epoch 19/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0216 - root_mean_squared_error: 0.1402 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0707
# Epoch 20/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0209 - root_mean_squared_error: 0.1383 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0701
# Epoch 21/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0211 - root_mean_squared_error: 0.1396 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0698
# Epoch 22/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0210 - root_mean_squared_error: 0.1395 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0706
# Epoch 23/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0193 - root_mean_squared_error: 0.1339 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0724
# Epoch 24/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1378 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0719
# Epoch 25/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0206 - root_mean_squared_error: 0.1394 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0774
# Epoch 26/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0203 - root_mean_squared_error: 0.1380 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0701
# Epoch 27/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0192 - root_mean_squared_error: 0.1344 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0731
# Epoch 28/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0195 - root_mean_squared_error: 0.1356 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0704
# Epoch 29/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0182 - root_mean_squared_error: 0.1308 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0693
# Epoch 30/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0188 - root_mean_squared_error: 0.1334 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0786
# Epoch 31/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0207 - root_mean_squared_error: 0.1404 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0704
# Epoch 32/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0200 - root_mean_squared_error: 0.1380 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0707
# Epoch 33/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0182 - root_mean_squared_error: 0.1312 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0693
# Epoch 34/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0186 - root_mean_squared_error: 0.1328 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0697
# Epoch 35/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1307 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0705
# Epoch 36/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0183 - root_mean_squared_error: 0.1318 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0694
# Epoch 37/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0174 - root_mean_squared_error: 0.1284 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0702
# Epoch 38/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0176 - root_mean_squared_error: 0.1292 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0700
# Epoch 39/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0189 - root_mean_squared_error: 0.1341 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0811
# Epoch 40/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0191 - root_mean_squared_error: 0.1351 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0705
# Epoch 41/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0180 - root_mean_squared_error: 0.1310 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0759

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0101 - root_mean_squared_error: 0.0958
# Test Loss: 0.010099782608449459
# Test RMSE: 0.09575046598911285

# %%
# คำนวณ predicted values
yhat_train = rnn_model.predict(train_X)
yhat_val = rnn_model.predict(val_X)
yhat_test = rnn_model.predict(test_X)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-22 23:57:54.136507: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:57:54.138563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:57:54.140112: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (816, 1, 80)
# (816, 30)
# (175, 1, 80)
# (175, 30)
# (175, 1, 80)
# (175, 30)

# %%
def create_gru_model(gru_units_1,beta_1,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_2056652/816457179.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-22 23:59:14.309039: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:59:14.311216: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:59:14.312505: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:59:14.734462: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:59:14.737121: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:59:14.739060: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:59:15.686291: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:59:15.688634: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:59:15.690613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:59:17.258935: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:59:17.261552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:59:17.263475: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 81.31604409217834 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 36, 'beta_1': 0.9, 'LR': 0.002, 'L2': 0.005}
# Best RMSE Score: 0.11197975706229187

# %%
gru_model = create_gru_model(gru_units_1=36 ,beta_1=0.9 , LR=0.002, L2=0.005)
gru_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 36)                12744
#
#  dropout_3 (Dropout)         (None, 36)                0
#
#  dense_3 (Dense)             (None, 30)                1110
#
# =================================================================
# Total params: 13,854
# Trainable params: 13,854
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-23 00:00:32.544721: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-23 00:00:32.546550: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-23 00:00:32.547731: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = gru_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-23 00:00:33.967604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-23 00:00:33.970039: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-23 00:00:33.971776: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-23 00:00:34.845385: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-23 00:00:34.848170: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-23 00:00:34.849658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 27s - loss: 0.5281 - root_mean_squared_error: 0.2534
# 2024-12-23 00:00:36.783772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-23 00:00:36.786102: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-23 00:00:36.787848: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 80ms/step - loss: 0.4242 - root_mean_squared_error: 0.1625 - val_loss: 0.3263 - val_root_mean_squared_error: 0.0815
# Epoch 2/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.2812 - root_mean_squared_error: 0.1275 - val_loss: 0.2111 - val_root_mean_squared_error: 0.0726
# Epoch 3/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.1825 - root_mean_squared_error: 0.1220 - val_loss: 0.1326 - val_root_mean_squared_error: 0.0730
# Epoch 4/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1168 - root_mean_squared_error: 0.1202 - val_loss: 0.0814 - val_root_mean_squared_error: 0.0713
# Epoch 5/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0750 - root_mean_squared_error: 0.1197 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0700
# Epoch 6/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0495 - root_mean_squared_error: 0.1193 - val_loss: 0.0307 - val_root_mean_squared_error: 0.0704
# Epoch 7/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0344 - root_mean_squared_error: 0.1191 - val_loss: 0.0196 - val_root_mean_squared_error: 0.0702
# Epoch 8/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0256 - root_mean_squared_error: 0.1189 - val_loss: 0.0132 - val_root_mean_squared_error: 0.0702
# Epoch 9/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0206 - root_mean_squared_error: 0.1188 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0704
# Epoch 10/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0179 - root_mean_squared_error: 0.1190 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0701
# Epoch 11/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0163 - root_mean_squared_error: 0.1189 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0698
# Epoch 12/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0155 - root_mean_squared_error: 0.1190 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0700
# Epoch 13/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0150 - root_mean_squared_error: 0.1191 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0701
# Epoch 14/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0147 - root_mean_squared_error: 0.1190 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0698
# Epoch 15/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0145 - root_mean_squared_error: 0.1189 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0709
# Epoch 16/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0144 - root_mean_squared_error: 0.1189 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0700
# Epoch 17/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1189 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0702
# Epoch 18/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1188 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0700
# Epoch 19/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1188 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0704
# Epoch 20/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1192 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0707
# Epoch 21/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1189 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0701
# Epoch 22/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1187 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0701
# Epoch 23/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1188 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0715
# Epoch 24/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0712
# Epoch 25/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1194 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0709
# Epoch 26/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0699
# Epoch 27/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0142 - root_mean_squared_error: 0.1190 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0716
# Epoch 28/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0143 - root_mean_squared_error: 0.1191 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0700
# Epoch 29/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0142 - root_mean_squared_error: 0.1187 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0710
# Epoch 30/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0142 - root_mean_squared_error: 0.1187 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0714
# Epoch 31/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0143 - root_mean_squared_error: 0.1191 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0706

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0073 - root_mean_squared_error: 0.0850
# Test Loss: 0.007291235029697418
# Test RMSE: 0.08496522903442383

# %%
# คำนวณ predicted residuals
yhat_train_resid = gru_model.predict(train_X_resid)
yhat_val_resid = gru_model.predict(val_X_resid)
yhat_test_resid = gru_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-23 00:00:50.493773: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-23 00:00:50.496027: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-23 00:00:50.497467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 3.8424%
# RMSE: 1.4682
