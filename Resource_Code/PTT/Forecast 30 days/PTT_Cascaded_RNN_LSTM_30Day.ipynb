# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-22 21:59:20.118024: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-22 21:59:20.242472: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 21:59:20.419352: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 21:59:20.420802: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-22 22:11:08.554596: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('PTT.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High   Low   Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  38.007946  49.50  49.50  49.0  49.50  52067800
# 2019-07-02 00:00:00+00:00  37.240097  48.50  49.50  48.5  49.25  51490800
# 2019-07-03 00:00:00+00:00  37.048141  48.25  48.50  48.0  48.50  44524800
# 2019-07-04 00:00:00+00:00  37.048141  48.25  48.75  48.0  48.50  49509400
# 2019-07-05 00:00:00+00:00  37.048141  48.25  48.50  48.0  48.25  20907100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('PTT Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 31,feat_name=df.columns)
# แก้ไขจากการ drop คอลัมน์ตั้งแต่ t ถึง t-6 เป็น t ถึง t-29
reframed.drop(['High(t+1)', 'High(t+2)', 'High(t+3)', 'High(t+4)', 'High(t+5)', 'High(t+6)', 'High(t+7)', \
               'High(t+8)', 'High(t+9)', 'High(t+10)', 'High(t+11)', 'High(t+12)', 'High(t+13)', 'High(t+14)', \
               'High(t+15)', 'High(t+16)', 'High(t+17)', 'High(t+18)', 'High(t+19)', 'High(t+20)', 'High(t+21)', \
               'High(t+22)', 'High(t+23)', 'High(t+24)', 'High(t+25)', 'High(t+26)', 'High(t+27)', 'High(t+28)', 'High(t+29)','High(t+30)',\
               'Low(t+1)', 'Low(t+2)', 'Low(t+3)', 'Low(t+4)', 'Low(t+5)', 'Low(t+6)', 'Low(t+7)', \
               'Low(t+8)', 'Low(t+9)', 'Low(t+10)', 'Low(t+11)', 'Low(t+12)', 'Low(t+13)', 'Low(t+14)', \
               'Low(t+15)', 'Low(t+16)', 'Low(t+17)', 'Low(t+18)', 'Low(t+19)', 'Low(t+20)', 'Low(t+21)', \
               'Low(t+22)', 'Low(t+23)', 'Low(t+24)', 'Low(t+25)', 'Low(t+26)', 'Low(t+27)', 'Low(t+28)', 'Low(t+29)','Low(t+30)',\
               'Open(t+1)', 'Open(t+2)', 'Open(t+3)', 'Open(t+4)', 'Open(t+5)', 'Open(t+6)', 'Open(t+7)', 
               'Open(t+8)', 'Open(t+9)', 'Open(t+10)', 'Open(t+11)', 'Open(t+12)', 'Open(t+13)', 'Open(t+14)', \
               'Open(t+15)', 'Open(t+16)', 'Open(t+17)', 'Open(t+18)', 'Open(t+19)', 'Open(t+20)', 'Open(t+21)', \
               'Open(t+22)', 'Open(t+23)', 'Open(t+24)', 'Open(t+25)', 'Open(t+26)', 'Open(t+27)', 'Open(t+28)', 'Open(t+29)','Open(t+30)',\
               'Volume(t+1)', 'Volume(t+2)', 'Volume(t+3)', 'Volume(t+4)', 'Volume(t+5)', 'Volume(t+6)', 'Volume(t+7)', \
               'Volume(t+8)', 'Volume(t+9)', 'Volume(t+10)', 'Volume(t+11)', 'Volume(t+12)', 'Volume(t+13)', 'Volume(t+14)', \
               'Volume(t+15)', 'Volume(t+16)', 'Volume(t+17)', 'Volume(t+18)', 'Volume(t+19)', 'Volume(t+20)', 'Volume(t+21)', \
               'Volume(t+22)', 'Volume(t+23)', 'Volume(t+24)', 'Volume(t+25)', 'Volume(t+26)', 'Volume(t+27)', 'Volume(t+28)', 'Volume(t+29)','Volume(t+30)'], axis=1, inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         1.000000    1.000000   1.000000    1.000000      0.080878
# 16         0.955564    1.000000   0.980315    0.990119      0.079982
# 17         0.944455    0.957447   0.960630    0.960474      0.069161
# 18         0.944455    0.968085   0.960630    0.960474      0.076904
# 19         0.944455    0.957447   0.960630    0.950593      0.032475
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.955564    1.000000   0.980315    0.990119      0.079982  ...
# 16         0.944455    0.957447   0.960630    0.960474      0.069161  ...
# 17         0.944455    0.968085   0.960630    0.960474      0.076904  ...
# 18         0.944455    0.957447   0.960630    0.950593      0.032475  ...
# 19         0.944455    0.946809   0.960630    0.940711      0.019224  ...
#
#     Adj Close(t+21)  Adj Close(t+22)  Adj Close(t+23)  Adj Close(t+24)  \
# 15         0.688952         0.622298         0.611190         0.622298
# 16         0.622298         0.611190         0.622298         0.722278
# 17         0.611190         0.622298         0.722278         0.766714
# 18         0.622298         0.722278         0.766714         0.733387
# 19         0.722278         0.766714         0.733387         0.700061
#
#     Adj Close(t+25)  Adj Close(t+26)  Adj Close(t+27)  Adj Close(t+28)  \
# 15         0.722278         0.766714         0.733387         0.700061
# 16         0.766714         0.733387         0.700061         0.733387
# 17         0.733387         0.700061         0.733387         0.766714
# 18         0.700061         0.733387         0.766714         0.777822
# 19         0.733387         0.766714         0.777822         0.800040
#
#     Adj Close(t+29)  Adj Close(t+30)
# 15         0.733387         0.766714
# 16         0.766714         0.777822
# 17         0.777822         0.800040
# 18         0.800040         0.822258
# 19         0.822258         0.833366
#
# [5 rows x 110 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-30], train[:, -30:]
val_X, val_y = val[:, :-30], val[:, -30:]
test_X, test_y = test[:, :-30], test[:, -30:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (816, 1, 80)
# (816, 30)
# (175, 1, 80)
# (175, 30)
# (175, 1, 80)
# (175, 30)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_rnn_model(rnn_units_1,LR,L2,beta_1):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2202827/1606349923.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-22 23:10:54.028069: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.029267: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.040895: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.052575: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.053341: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.059839: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.063407: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.068591: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.068891: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.073912: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.081930: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.086331: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.086554: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.086645: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.103197: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.104049: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.122355: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.122506: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.127957: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.130282: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.132893: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.142813: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.143587: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.147213: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.148703: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.158095: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.159912: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.168540: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.169548: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.170247: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.175225: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:10:54.175659: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 1810.4822709560394 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 17, 'beta_1': 0.8, 'LR': 0.004, 'L2': 0.001}
# Best RMSE Score: 0.11626758560200733

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
rnn_model = create_rnn_model(rnn_units_1=17,beta_1=0.8 , LR=0.004, L2=0.001)
rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 17)                1666
#
#  dropout_1 (Dropout)         (None, 17)                0
#
#  dense_1 (Dense)             (None, 30)                540
#
# =================================================================
# Total params: 2,206
# Trainable params: 2,206
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 1s 22ms/step - loss: 0.2950 - root_mean_squared_error: 0.5168 - val_loss: 0.0776 - val_root_mean_squared_error: 0.2240
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0983 - root_mean_squared_error: 0.2678 - val_loss: 0.0369 - val_root_mean_squared_error: 0.1069
# Epoch 3/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0676 - root_mean_squared_error: 0.2077 - val_loss: 0.0364 - val_root_mean_squared_error: 0.1146
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0612 - root_mean_squared_error: 0.1969 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1108
# Epoch 5/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0528 - root_mean_squared_error: 0.1792 - val_loss: 0.0355 - val_root_mean_squared_error: 0.1253
# Epoch 6/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0500 - root_mean_squared_error: 0.1754 - val_loss: 0.0338 - val_root_mean_squared_error: 0.1242
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0468 - root_mean_squared_error: 0.1703 - val_loss: 0.0241 - val_root_mean_squared_error: 0.0830
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0444 - root_mean_squared_error: 0.1667 - val_loss: 0.0271 - val_root_mean_squared_error: 0.1053
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0421 - root_mean_squared_error: 0.1628 - val_loss: 0.0213 - val_root_mean_squared_error: 0.0785
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0392 - root_mean_squared_error: 0.1565 - val_loss: 0.0214 - val_root_mean_squared_error: 0.0851
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0384 - root_mean_squared_error: 0.1570 - val_loss: 0.0218 - val_root_mean_squared_error: 0.0921
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0373 - root_mean_squared_error: 0.1561 - val_loss: 0.0191 - val_root_mean_squared_error: 0.0806
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0356 - root_mean_squared_error: 0.1527 - val_loss: 0.0171 - val_root_mean_squared_error: 0.0720
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0348 - root_mean_squared_error: 0.1524 - val_loss: 0.0169 - val_root_mean_squared_error: 0.0750
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0322 - root_mean_squared_error: 0.1458 - val_loss: 0.0158 - val_root_mean_squared_error: 0.0720
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0318 - root_mean_squared_error: 0.1463 - val_loss: 0.0152 - val_root_mean_squared_error: 0.0718
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0305 - root_mean_squared_error: 0.1439 - val_loss: 0.0154 - val_root_mean_squared_error: 0.0765
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0303 - root_mean_squared_error: 0.1449 - val_loss: 0.0138 - val_root_mean_squared_error: 0.0693
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0285 - root_mean_squared_error: 0.1403 - val_loss: 0.0133 - val_root_mean_squared_error: 0.0690
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0300 - root_mean_squared_error: 0.1470 - val_loss: 0.0134 - val_root_mean_squared_error: 0.0728
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0289 - root_mean_squared_error: 0.1448 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0702
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0271 - root_mean_squared_error: 0.1400 - val_loss: 0.0130 - val_root_mean_squared_error: 0.0752
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0268 - root_mean_squared_error: 0.1399 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0757
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0270 - root_mean_squared_error: 0.1421 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0714
# Epoch 25/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0259 - root_mean_squared_error: 0.1393 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0716
# Epoch 26/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0260 - root_mean_squared_error: 0.1407 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0725
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0257 - root_mean_squared_error: 0.1405 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0723
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0240 - root_mean_squared_error: 0.1353 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0724
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0234 - root_mean_squared_error: 0.1341 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0675
# Epoch 30/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0233 - root_mean_squared_error: 0.1346 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0685
# Epoch 31/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0223 - root_mean_squared_error: 0.1319 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0737
# Epoch 32/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0243 - root_mean_squared_error: 0.1397 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0677
# Epoch 33/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.1330 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0728
# Epoch 34/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0235 - root_mean_squared_error: 0.1383 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0759
# Epoch 35/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0216 - root_mean_squared_error: 0.1322 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0757
# Epoch 36/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0223 - root_mean_squared_error: 0.1352 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0680
# Epoch 37/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0212 - root_mean_squared_error: 0.1316 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0721
# Epoch 38/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0213 - root_mean_squared_error: 0.1326 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0799
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0239 - root_mean_squared_error: 0.1426 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0675
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0229 - root_mean_squared_error: 0.1396 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0678
# Epoch 41/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0205 - root_mean_squared_error: 0.1312 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0679
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0194 - root_mean_squared_error: 0.1277 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0721
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0208 - root_mean_squared_error: 0.1334 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0681
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0206 - root_mean_squared_error: 0.1332 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0681
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0196 - root_mean_squared_error: 0.1296 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0678
# Epoch 46/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0191 - root_mean_squared_error: 0.1280 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0780
# Epoch 47/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0194 - root_mean_squared_error: 0.1295 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0684
# Epoch 48/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0188 - root_mean_squared_error: 0.1274 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0687
# Epoch 49/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0186 - root_mean_squared_error: 0.1274 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0824
# Epoch 50/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0187 - root_mean_squared_error: 0.1281 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0680
# Epoch 51/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0193 - root_mean_squared_error: 0.1306 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0686
# Epoch 52/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0188 - root_mean_squared_error: 0.1291 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0695
# Epoch 53/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1263 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0709
# Epoch 54/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0189 - root_mean_squared_error: 0.1298 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0757
# Epoch 55/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0189 - root_mean_squared_error: 0.1302 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0686
# Epoch 56/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0179 - root_mean_squared_error: 0.1266 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0682
# Epoch 57/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.1258 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0710
# Epoch 58/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.1260 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0678
# Epoch 59/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0185 - root_mean_squared_error: 0.1298 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0753
# Epoch 60/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0196 - root_mean_squared_error: 0.1341 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0802
# Epoch 61/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0196 - root_mean_squared_error: 0.1341 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0690
# Epoch 62/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0193 - root_mean_squared_error: 0.1333 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0680
# Epoch 63/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0168 - root_mean_squared_error: 0.1239 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0691
# Epoch 64/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0180 - root_mean_squared_error: 0.1288 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0740
# Epoch 65/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0172 - root_mean_squared_error: 0.1258 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0700
# Epoch 66/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0170 - root_mean_squared_error: 0.1253 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0691
# Epoch 67/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0174 - root_mean_squared_error: 0.1268 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0737
# Epoch 68/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0178 - root_mean_squared_error: 0.1284 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0699
# Epoch 69/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0167 - root_mean_squared_error: 0.1244 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0805
# Epoch 70/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0166 - root_mean_squared_error: 0.1243 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0702
# Epoch 71/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0177 - root_mean_squared_error: 0.1284 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0749
# Epoch 72/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0170 - root_mean_squared_error: 0.1258 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0684
# Epoch 73/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0168 - root_mean_squared_error: 0.1252 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0815
# Epoch 74/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0165 - root_mean_squared_error: 0.1240 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0747
# Epoch 75/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0164 - root_mean_squared_error: 0.1240 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0722
# Epoch 76/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0173 - root_mean_squared_error: 0.1274 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0688
# Epoch 77/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0161 - root_mean_squared_error: 0.1228 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0682
# Epoch 78/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0161 - root_mean_squared_error: 0.1229 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0740
# Epoch 79/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0160 - root_mean_squared_error: 0.1225 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0724
# Epoch 80/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.1293 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0713
# Epoch 81/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0164 - root_mean_squared_error: 0.1243 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0751
# Epoch 82/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0166 - root_mean_squared_error: 0.1253 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0719

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0084 - root_mean_squared_error: 0.0862
# Test Loss: 0.008418652229011059
# Test RMSE: 0.08618330210447311

# %%
# คำนวณ predicted values
yhat_train = rnn_model.predict(train_X)
yhat_val = rnn_model.predict(val_X)
yhat_test = rnn_model.predict(test_X)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (816, 1, 80)
# (816, 30)
# (175, 1, 80)
# (175, 30)
# (175, 1, 80)
# (175, 30)

# %%
def create_lstm_model(lstm_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2202827/1996924287.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-22 23:39:41.508088: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.508287: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.509539: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.510804: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.513957: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.516114: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.517517: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.517541: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.518191: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.519222: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.522963: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.523032: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.524823: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.527391: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.528628: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.528685: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.530470: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.532730: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.535546: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.535750: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.537281: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.537276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.538768: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.541521: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.541560: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.542111: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.544108: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.544126: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.546045: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.547828: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.733351: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:39:41.785239: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 23:49:41.833113: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:49:41.835268: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:49:41.836662: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:49:42.290745: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:49:42.293243: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:49:42.295101: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:49:43.208218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:49:43.211178: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:49:43.212896: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:49:44.783077: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:49:44.785996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:49:44.788160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 925.3573961257935 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 11, 'beta_1': 0.8, 'LR': 0.069, 'L2': 0.05}
# Best RMSE Score: 0.10850643698574736

# %%
lstm_model = create_lstm_model(lstm_units_1=11 ,beta_1=0.8 , LR=0.069, L2=0.05)
lstm_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 11)                4048
#
#  dropout_3 (Dropout)         (None, 11)                0
#
#  dense_3 (Dense)             (None, 30)                360
#
# =================================================================
# Total params: 4,408
# Trainable params: 4,408
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-22 23:55:27.940586: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:55:27.942909: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:55:27.944099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = lstm_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-22 23:55:30.160154: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:55:30.162651: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:55:30.164153: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 23:55:30.923744: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:55:30.926221: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:55:30.928086: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 24s - loss: 2.8880 - root_mean_squared_error: 0.1704
# 2024-12-22 23:55:32.278249: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:55:32.280323: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:55:32.281729: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 45ms/step - loss: 0.5062 - root_mean_squared_error: 0.1282 - val_loss: 0.0781 - val_root_mean_squared_error: 0.0715
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0376 - root_mean_squared_error: 0.1182 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0704
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0154 - root_mean_squared_error: 0.1176 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0703
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0139 - root_mean_squared_error: 0.1172 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0759
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0139 - root_mean_squared_error: 0.1171 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0714
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0141 - root_mean_squared_error: 0.1177 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0676
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - root_mean_squared_error: 0.1168 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0767
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0140 - root_mean_squared_error: 0.1181 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0760
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0140 - root_mean_squared_error: 0.1178 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0699
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0141 - root_mean_squared_error: 0.1176 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0673
# Epoch 11/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0139 - root_mean_squared_error: 0.1174 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0758

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = lstm_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0087 - root_mean_squared_error: 0.0925
# Test Loss: 0.00866494420915842
# Test RMSE: 0.09248089790344238

# %%
# คำนวณ predicted residuals
yhat_train_resid = lstm_model.predict(train_X_resid)
yhat_val_resid = lstm_model.predict(val_X_resid)
yhat_test_resid = lstm_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-22 23:55:37.854199: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 23:55:37.860694: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 23:55:37.862194: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 4.0894%
# RMSE: 1.5981
