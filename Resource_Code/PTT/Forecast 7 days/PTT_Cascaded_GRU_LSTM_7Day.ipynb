# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('PTT.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High   Low   Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  38.007935  49.50  49.50  49.0  49.50  52067800
# 2019-07-02 00:00:00+00:00  37.240097  48.50  49.50  48.5  49.25  51490800
# 2019-07-03 00:00:00+00:00  37.048141  48.25  48.50  48.0  48.50  44524800
# 2019-07-04 00:00:00+00:00  37.048141  48.25  48.75  48.0  48.50  49509400
# 2019-07-05 00:00:00+00:00  37.048141  48.25  48.50  48.0  48.25  20907100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('BCP Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         1.000000    1.000000   1.000000    1.000000      0.080878
# 16         0.955565    1.000000   0.980315    0.990119      0.079982
# 17         0.944456    0.957447   0.960630    0.960474      0.069161
# 18         0.944456    0.968085   0.960630    0.960474      0.076904
# 19         0.944456    0.957447   0.960630    0.950593      0.032475
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.955565    1.000000   0.980315    0.990119      0.079982  ...
# 16         0.944456    0.957447   0.960630    0.960474      0.069161  ...
# 17         0.944456    0.968085   0.960630    0.960474      0.076904  ...
# 18         0.944456    0.957447   0.960630    0.950593      0.032475  ...
# 19         0.944456    0.946809   0.960630    0.940711      0.019224  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.940945  0.940711   0.032713        0.922238        0.922238
# 16  0.931102  0.930830   0.053481        0.922238        0.900020
# 17  0.940945  0.930830   0.031202        0.900020        0.900020
# 18  0.921260  0.920949   0.064817        0.900020        0.900020
# 19  0.921260  0.911067   0.036953        0.900020        0.900020
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.900020        0.900020        0.900020        0.900020
# 16        0.900020        0.900020        0.900020        0.844476
# 17        0.900020        0.900020        0.844476        0.833367
# 18        0.900020        0.844476        0.833367        0.822258
# 19        0.844476        0.833367        0.822258        0.800040
#
#     Adj Close(t+7)
# 15        0.844476
# 16        0.833367
# 17        0.822258
# 18        0.800040
# 19        0.766714
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_gru_model(gru_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}


# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_267428/25571886.py:20: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-22 22:10:17.498708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.499069: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.500002: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.506561: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.521898: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.529715: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.534032: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.542853: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.547494: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.557065: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.572290: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.589143: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.590619: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.597127: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.597281: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.599768: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.614539: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.614759: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.615837: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.621897: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.660203: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.660219: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.679173: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.679276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.679309: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.679322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.679694: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.679913: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.712485: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.712607: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.720545: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:10:17.720702: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:35:58.341450: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:35:58.343483: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:35:58.344755: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:35:59.227923: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:35:59.230435: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:35:59.232336: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:35:59.887180: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:35:59.889934: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:35:59.891656: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:36:01.126889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:36:01.129336: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:36:01.131189: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 2987.159912586212 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 17, 'beta_1': 0.8, 'LR': 0.004, 'L2': 0.001}
# Best RMSE Score: 0.07215382559078964

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
gru_model = create_gru_model(gru_units_1=17 ,beta_1=0.8, LR=0.004, L2=0.001)
gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 17)                5049
#
#  dropout_1 (Dropout)         (None, 17)                0
#
#  dense_1 (Dense)             (None, 7)                 126
#
# =================================================================
# Total params: 5,175
# Trainable params: 5,175
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-22 22:39:31.590837: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:39:31.592727: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:39:31.594041: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = gru_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-22 22:39:39.900305: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:39:39.905898: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:39:39.920394: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:39:41.501621: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:39:41.504938: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:39:41.512010: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  7/13 [===============>..............] - ETA: 0s - loss: 0.3322 - root_mean_squared_error: 0.5225
# 2024-12-22 22:39:44.491466: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:39:44.496788: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:39:44.499042: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 6s 121ms/step - loss: 0.2231 - root_mean_squared_error: 0.4083 - val_loss: 0.0583 - val_root_mean_squared_error: 0.0909
# Epoch 2/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0781 - root_mean_squared_error: 0.1806 - val_loss: 0.0480 - val_root_mean_squared_error: 0.0840
# Epoch 3/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0663 - root_mean_squared_error: 0.1680 - val_loss: 0.0396 - val_root_mean_squared_error: 0.0676
# Epoch 4/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0592 - root_mean_squared_error: 0.1619 - val_loss: 0.0381 - val_root_mean_squared_error: 0.0853
# Epoch 5/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0512 - root_mean_squared_error: 0.1475 - val_loss: 0.0338 - val_root_mean_squared_error: 0.0771
# Epoch 6/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0459 - root_mean_squared_error: 0.1388 - val_loss: 0.0323 - val_root_mean_squared_error: 0.0836
# Epoch 7/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0427 - root_mean_squared_error: 0.1356 - val_loss: 0.0295 - val_root_mean_squared_error: 0.0794
# Epoch 8/150
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0394 - root_mean_squared_error: 0.1307 - val_loss: 0.0260 - val_root_mean_squared_error: 0.0685
# Epoch 9/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0359 - root_mean_squared_error: 0.1237 - val_loss: 0.0244 - val_root_mean_squared_error: 0.0683
# Epoch 10/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0340 - root_mean_squared_error: 0.1224 - val_loss: 0.0228 - val_root_mean_squared_error: 0.0675
# Epoch 11/150
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0318 - root_mean_squared_error: 0.1194 - val_loss: 0.0212 - val_root_mean_squared_error: 0.0659
# Epoch 12/150
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0290 - root_mean_squared_error: 0.1129 - val_loss: 0.0198 - val_root_mean_squared_error: 0.0646
# Epoch 13/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0275 - root_mean_squared_error: 0.1116 - val_loss: 0.0181 - val_root_mean_squared_error: 0.0602
# Epoch 14/150
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0255 - root_mean_squared_error: 0.1073 - val_loss: 0.0166 - val_root_mean_squared_error: 0.0560
# Epoch 15/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0244 - root_mean_squared_error: 0.1068 - val_loss: 0.0154 - val_root_mean_squared_error: 0.0534
# Epoch 16/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0236 - root_mean_squared_error: 0.1072 - val_loss: 0.0155 - val_root_mean_squared_error: 0.0615
# Epoch 17/150
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0221 - root_mean_squared_error: 0.1035 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0506
# Epoch 18/150
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0216 - root_mean_squared_error: 0.1047 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0534
# Epoch 19/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0200 - root_mean_squared_error: 0.1003 - val_loss: 0.0125 - val_root_mean_squared_error: 0.0536
# Epoch 20/150
# 13/13 [==============================] - 0s 28ms/step - loss: 0.0196 - root_mean_squared_error: 0.1012 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0494
# Epoch 21/150
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0197 - root_mean_squared_error: 0.1041 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0499
# Epoch 22/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0185 - root_mean_squared_error: 0.1006 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0493
# Epoch 23/150
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0183 - root_mean_squared_error: 0.1021 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0488
# Epoch 24/150
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0165 - root_mean_squared_error: 0.0950 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0571
# Epoch 25/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0160 - root_mean_squared_error: 0.0945 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0481
# Epoch 26/150
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0159 - root_mean_squared_error: 0.0955 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0467
# Epoch 27/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0153 - root_mean_squared_error: 0.0945 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0446
# Epoch 28/150
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0149 - root_mean_squared_error: 0.0938 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0483
# Epoch 29/150
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0138 - root_mean_squared_error: 0.0898 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0437
# Epoch 30/150
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0139 - root_mean_squared_error: 0.0913 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0436
# Epoch 31/150
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0137 - root_mean_squared_error: 0.0917 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0489
# Epoch 32/150
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0149 - root_mean_squared_error: 0.0992 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0528
# Epoch 33/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0127 - root_mean_squared_error: 0.0885 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0467
# Epoch 34/150
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0131 - root_mean_squared_error: 0.0920 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0471
# Epoch 35/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0120 - root_mean_squared_error: 0.0873 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0484
# Epoch 36/150
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0124 - root_mean_squared_error: 0.0903 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0442
# Epoch 37/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0121 - root_mean_squared_error: 0.0895 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0497
# Epoch 38/150
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0122 - root_mean_squared_error: 0.0909 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0491
# Epoch 39/150
# 13/13 [==============================] - 0s 23ms/step - loss: 0.0118 - root_mean_squared_error: 0.0897 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0431
# Epoch 40/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0107 - root_mean_squared_error: 0.0841 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0430
# Epoch 41/150
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0111 - root_mean_squared_error: 0.0870 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0517
# Epoch 42/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0110 - root_mean_squared_error: 0.0872 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0434
# Epoch 43/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0103 - root_mean_squared_error: 0.0841 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0429
# Epoch 44/150
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0109 - root_mean_squared_error: 0.0881 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0436
# Epoch 45/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0106 - root_mean_squared_error: 0.0870 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0443
# Epoch 46/150
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0095 - root_mean_squared_error: 0.0815 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0418
# Epoch 47/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0100 - root_mean_squared_error: 0.0849 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0447
# Epoch 48/150
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0106 - root_mean_squared_error: 0.0886 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0461
# Epoch 49/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0093 - root_mean_squared_error: 0.0818 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0426
# Epoch 50/150
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0096 - root_mean_squared_error: 0.0844 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0508
# Epoch 51/150
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0091 - root_mean_squared_error: 0.0814 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0412
# Epoch 52/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0094 - root_mean_squared_error: 0.0842 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0570
# Epoch 53/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0107 - root_mean_squared_error: 0.0919 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0443
# Epoch 54/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0099 - root_mean_squared_error: 0.0877 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0509
# Epoch 55/150
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0095 - root_mean_squared_error: 0.0857 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0484
# Epoch 56/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0092 - root_mean_squared_error: 0.0841 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0426
# Epoch 57/150
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0086 - root_mean_squared_error: 0.0809 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0422
# Epoch 58/150
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0087 - root_mean_squared_error: 0.0820 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0419
# Epoch 59/150
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0088 - root_mean_squared_error: 0.0828 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0429
# Epoch 60/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0084 - root_mean_squared_error: 0.0810 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0411
# Epoch 61/150
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0091 - root_mean_squared_error: 0.0856 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0410
# Epoch 62/150
# 13/13 [==============================] - 0s 19ms/step - loss: 0.0090 - root_mean_squared_error: 0.0853 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0438
# Epoch 63/150
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0084 - root_mean_squared_error: 0.0820 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0412
# Epoch 64/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0084 - root_mean_squared_error: 0.0822 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0610
# Epoch 65/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0086 - root_mean_squared_error: 0.0836 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0444
# Epoch 66/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0081 - root_mean_squared_error: 0.0808 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0413
# Epoch 67/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0087 - root_mean_squared_error: 0.0848 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0457
# Epoch 68/150
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0079 - root_mean_squared_error: 0.0797 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0417
# Epoch 69/150
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0077 - root_mean_squared_error: 0.0787 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0421
# Epoch 70/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0085 - root_mean_squared_error: 0.0838 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0416
# Epoch 71/150
# 13/13 [==============================] - 0s 21ms/step - loss: 0.0079 - root_mean_squared_error: 0.0806 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0422
# Epoch 72/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0078 - root_mean_squared_error: 0.0803 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0412
# Epoch 73/150
# 13/13 [==============================] - 0s 22ms/step - loss: 0.0080 - root_mean_squared_error: 0.0817 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0409
# Epoch 74/150
# 13/13 [==============================] - 0s 18ms/step - loss: 0.0090 - root_mean_squared_error: 0.0875 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0414
# Epoch 75/150
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0080 - root_mean_squared_error: 0.0817 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0436
# Epoch 76/150
# 13/13 [==============================] - 0s 20ms/step - loss: 0.0075 - root_mean_squared_error: 0.0791 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0468
# Epoch 77/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0082 - root_mean_squared_error: 0.0832 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0432
# Epoch 78/150
# 13/13 [==============================] - 0s 17ms/step - loss: 0.0074 - root_mean_squared_error: 0.0787 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0477

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0040 - root_mean_squared_error: 0.0519
# Test Loss: 0.004030365496873856
# Test RMSE: 0.051851123571395874

# %%
# คำนวณ predicted values
yhat_train = gru_model.predict(train_X)
yhat_val = gru_model.predict(val_X)
yhat_test = gru_model.predict(test_X)
# Out:
# 2024-12-22 22:40:25.416313: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:40:25.419093: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:40:25.420587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 2ms/step
# 2024-12-22 22:40:26.683902: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:40:26.685985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:40:26.687718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 1s 2ms/step
# 6/6 [==============================] - 0s 3ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_lstm_model(lstm_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_267428/1752824025.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /nfs/workbench/home/g6680025026/venvs/myenv1/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# 2024-12-22 22:48:42.292267: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:53:00.593509: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:53:00.595604: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:53:00.596971: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:53:00.960397: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:53:00.963233: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:53:00.965254: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:53:01.636611: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:53:01.639147: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:53:01.640996: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:53:02.787597: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:53:02.790494: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:53:02.792245: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 750.231939792633 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 45, 'beta_1': 0.9, 'LR': 0.027000000000000003, 'L2': 0.005}
# Best RMSE Score: 0.06372390339516482

# %%
lstm_model = create_lstm_model(lstm_units_1=45 ,beta_1=0.9 , LR=0.027, L2=0.005)
lstm_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 45)                22680
#
#  dropout_3 (Dropout)         (None, 45)                0
#
#  dense_3 (Dense)             (None, 7)                 322
#
# =================================================================
# Total params: 23,002
# Trainable params: 23,002
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-22 22:57:23.351754: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:57:23.353581: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:57:23.354805: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = lstm_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-22 22:57:26.365657: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:57:26.368050: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:57:26.369622: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:57:27.021019: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:57:27.023556: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:57:27.025067: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 43ms/step - loss: 0.2176 - root_mean_squared_error: 0.1629 - val_loss: 0.0839 - val_root_mean_squared_error: 0.0541
# Epoch 2/150
#  1/13 [=>............................] - ETA: 0s - loss: 0.0865 - root_mean_squared_error: 0.0750
# 2024-12-22 22:57:28.100294: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:57:28.102415: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:57:28.103833: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0469 - root_mean_squared_error: 0.0840 - val_loss: 0.0234 - val_root_mean_squared_error: 0.0668
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0169 - root_mean_squared_error: 0.0803 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0507
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0082 - root_mean_squared_error: 0.0720 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0448
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0058 - root_mean_squared_error: 0.0704 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0430
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0052 - root_mean_squared_error: 0.0698 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0441
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0052 - root_mean_squared_error: 0.0707 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0445
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0052 - root_mean_squared_error: 0.0712 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0457
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0050 - root_mean_squared_error: 0.0698 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0429
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0686 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0415
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0694 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0422
# Epoch 12/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0049 - root_mean_squared_error: 0.0694 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0450
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0048 - root_mean_squared_error: 0.0687 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0429
# Epoch 14/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0691 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0417
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0420
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0694 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0424
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0048 - root_mean_squared_error: 0.0690 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0435
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0697 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0422
# Epoch 19/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0049 - root_mean_squared_error: 0.0694 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0422

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3723 - root_mean_squared_error: 0.6090
# Test Loss: 0.3722636103630066
# Test RMSE: 0.609033465385437

# %%
# คำนวณ predicted residuals
yhat_train_resid = lstm_model.predict(train_X_resid)
yhat_val_resid = lstm_model.predict(val_X_resid)
yhat_test_resid = lstm_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-22 22:57:34.352423: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:57:34.354511: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:57:34.355966: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step
# 2024-12-22 22:57:34.784499: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:57:34.786331: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:57:34.787639: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))


plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 2.0145%
# RMSE: 0.7989
