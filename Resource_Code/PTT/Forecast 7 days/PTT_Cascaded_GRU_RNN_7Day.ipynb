# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('PTT.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High   Low   Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  38.007938  49.50  49.50  49.0  49.50  52067800
# 2019-07-02 00:00:00+00:00  37.240101  48.50  49.50  48.5  49.25  51490800
# 2019-07-03 00:00:00+00:00  37.048138  48.25  48.50  48.0  48.50  44524800
# 2019-07-04 00:00:00+00:00  37.048138  48.25  48.75  48.0  48.50  49509400
# 2019-07-05 00:00:00+00:00  37.048138  48.25  48.50  48.0  48.25  20907100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('PTT Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         1.000000    1.000000   1.000000    1.000000      0.080878
# 16         0.955565    1.000000   0.980315    0.990119      0.079982
# 17         0.944455    0.957447   0.960630    0.960474      0.069161
# 18         0.944455    0.968085   0.960630    0.960474      0.076904
# 19         0.944455    0.957447   0.960630    0.950593      0.032475
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.955565    1.000000   0.980315    0.990119      0.079982  ...
# 16         0.944455    0.957447   0.960630    0.960474      0.069161  ...
# 17         0.944455    0.968085   0.960630    0.960474      0.076904  ...
# 18         0.944455    0.957447   0.960630    0.950593      0.032475  ...
# 19         0.944455    0.946809   0.960630    0.940711      0.019224  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.940945  0.940711   0.032713        0.922238        0.922238
# 16  0.931102  0.930830   0.053481        0.922238        0.900020
# 17  0.940945  0.930830   0.031202        0.900020        0.900020
# 18  0.921260  0.920949   0.064817        0.900020        0.900020
# 19  0.921260  0.911067   0.036953        0.900020        0.900020
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.900020        0.900020        0.900020        0.900020
# 16        0.900020        0.900020        0.900020        0.844475
# 17        0.900020        0.900020        0.844475        0.833367
# 18        0.900020        0.844475        0.833367        0.822258
# 19        0.844475        0.833367        0.822258        0.800041
#
#     Adj Close(t+7)
# 15        0.844475
# 16        0.833367
# 17        0.822258
# 18        0.800041
# 19        0.766714
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_gru_model(gru_units_1, beta_1 ,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_2202824/2081204696.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-22 22:07:24.208383: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.208917: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.329448: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.385575: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.451146: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.471412: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.553219: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.571660: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.581502: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.594757: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.670236: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.718747: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.766712: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.841276: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.888121: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.931328: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.949697: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.966218: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:24.982968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.067185: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.074965: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.173888: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.191360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.240045: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.276824: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.326066: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.331216: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.331968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.334406: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.360367: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.436375: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:25.566250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:35:35.341334: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:35:35.344377: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:35:35.346239: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:35:36.420126: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:35:36.424160: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:35:36.428525: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:35:37.236649: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:35:37.239040: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:35:37.240691: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:35:38.864610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:35:38.868044: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:35:38.870038: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 3098.11070394516 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 70, 'beta_1': 0.8, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.07263556748158934

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
gru_model = create_gru_model(gru_units_1=70 ,beta_1=0.8, LR=0.003, L2=0.001)
gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 70)                31920
#
#  dropout_1 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 7)                 497
#
# =================================================================
# Total params: 32,417
# Trainable params: 32,417
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-22 22:37:51.698971: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:37:51.700802: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:37:51.702148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = gru_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-22 22:37:54.752503: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:37:54.755119: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:37:54.757058: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:37:55.577864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:37:55.580796: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:37:55.582384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 25s - loss: 0.5266 - root_mean_squared_error: 0.6402
# 2024-12-22 22:37:57.076772: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:37:57.078917: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:37:57.080606: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 3s 60ms/step - loss: 0.1805 - root_mean_squared_error: 0.2807 - val_loss: 0.1084 - val_root_mean_squared_error: 0.1504
# Epoch 2/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0970 - root_mean_squared_error: 0.1463 - val_loss: 0.0739 - val_root_mean_squared_error: 0.0912
# Epoch 3/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0761 - root_mean_squared_error: 0.1295 - val_loss: 0.0609 - val_root_mean_squared_error: 0.0885
# Epoch 4/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0636 - root_mean_squared_error: 0.1210 - val_loss: 0.0532 - val_root_mean_squared_error: 0.0924
# Epoch 5/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0555 - root_mean_squared_error: 0.1171 - val_loss: 0.0439 - val_root_mean_squared_error: 0.0723
# Epoch 6/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0489 - root_mean_squared_error: 0.1121 - val_loss: 0.0406 - val_root_mean_squared_error: 0.0820
# Epoch 7/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0437 - root_mean_squared_error: 0.1083 - val_loss: 0.0349 - val_root_mean_squared_error: 0.0707
# Epoch 8/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0385 - root_mean_squared_error: 0.1009 - val_loss: 0.0316 - val_root_mean_squared_error: 0.0705
# Epoch 9/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0355 - root_mean_squared_error: 0.1012 - val_loss: 0.0287 - val_root_mean_squared_error: 0.0702
# Epoch 10/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0327 - root_mean_squared_error: 0.1000 - val_loss: 0.0253 - val_root_mean_squared_error: 0.0620
# Epoch 11/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0298 - root_mean_squared_error: 0.0968 - val_loss: 0.0246 - val_root_mean_squared_error: 0.0728
# Epoch 12/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0282 - root_mean_squared_error: 0.0982 - val_loss: 0.0203 - val_root_mean_squared_error: 0.0519
# Epoch 13/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0252 - root_mean_squared_error: 0.0912 - val_loss: 0.0182 - val_root_mean_squared_error: 0.0466
# Epoch 14/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0235 - root_mean_squared_error: 0.0904 - val_loss: 0.0168 - val_root_mean_squared_error: 0.0469
# Epoch 15/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0222 - root_mean_squared_error: 0.0903 - val_loss: 0.0154 - val_root_mean_squared_error: 0.0451
# Epoch 16/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0203 - root_mean_squared_error: 0.0866 - val_loss: 0.0144 - val_root_mean_squared_error: 0.0464
# Epoch 17/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0194 - root_mean_squared_error: 0.0870 - val_loss: 0.0134 - val_root_mean_squared_error: 0.0466
# Epoch 18/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0184 - root_mean_squared_error: 0.0870 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0425
# Epoch 19/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0182 - root_mean_squared_error: 0.0909 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0451
# Epoch 20/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0169 - root_mean_squared_error: 0.0875 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0484
# Epoch 21/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0159 - root_mean_squared_error: 0.0858 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0424
# Epoch 22/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0149 - root_mean_squared_error: 0.0836 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0428
# Epoch 23/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0147 - root_mean_squared_error: 0.0857 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0497
# Epoch 24/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0139 - root_mean_squared_error: 0.0842 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0620
# Epoch 25/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0140 - root_mean_squared_error: 0.0876 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0418
# Epoch 26/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0145 - root_mean_squared_error: 0.0923 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0434
# Epoch 27/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0143 - root_mean_squared_error: 0.0935 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0462
# Epoch 28/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0130 - root_mean_squared_error: 0.0882 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0464
# Epoch 29/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0117 - root_mean_squared_error: 0.0826 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0479
# Epoch 30/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0119 - root_mean_squared_error: 0.0851 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0423
# Epoch 31/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0113 - root_mean_squared_error: 0.0833 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0593
# Epoch 32/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0118 - root_mean_squared_error: 0.0877 - val_loss: 0.0071 - val_root_mean_squared_error: 0.0559
# Epoch 33/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0125 - root_mean_squared_error: 0.0931 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0412
# Epoch 34/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0105 - root_mean_squared_error: 0.0825 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0420
# Epoch 35/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0099 - root_mean_squared_error: 0.0801 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0404
# Epoch 36/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0093 - root_mean_squared_error: 0.0776 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0407
# Epoch 37/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0100 - root_mean_squared_error: 0.0827 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0470
# Epoch 38/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0114 - root_mean_squared_error: 0.0918 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0458
# Epoch 39/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0120 - root_mean_squared_error: 0.0957 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0725
# Epoch 40/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0132 - root_mean_squared_error: 0.1020 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0738
# Epoch 41/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0106 - root_mean_squared_error: 0.0889 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0452
# Epoch 42/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0096 - root_mean_squared_error: 0.0842 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0464
# Epoch 43/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0096 - root_mean_squared_error: 0.0849 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0455
# Epoch 44/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0099 - root_mean_squared_error: 0.0871 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0413
# Epoch 45/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0089 - root_mean_squared_error: 0.0820 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0410
# Epoch 46/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0092 - root_mean_squared_error: 0.0842 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0419
# Epoch 47/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0103 - root_mean_squared_error: 0.0909 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0521
# Epoch 48/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0089 - root_mean_squared_error: 0.0833 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0445
# Epoch 49/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0095 - root_mean_squared_error: 0.0870 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0527
# Epoch 50/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0085 - root_mean_squared_error: 0.0817 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0405
# Epoch 51/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0081 - root_mean_squared_error: 0.0791 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0402
# Epoch 52/150
# 13/13 [==============================] - 0s 15ms/step - loss: 0.0078 - root_mean_squared_error: 0.0778 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0411
# Epoch 53/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0080 - root_mean_squared_error: 0.0794 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0441
# Epoch 54/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0078 - root_mean_squared_error: 0.0784 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0402
# Epoch 55/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0085 - root_mean_squared_error: 0.0832 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0471
# Epoch 56/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0085 - root_mean_squared_error: 0.0835 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0419
# Epoch 57/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0078 - root_mean_squared_error: 0.0798 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0406
# Epoch 58/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0079 - root_mean_squared_error: 0.0807 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0402
# Epoch 59/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0077 - root_mean_squared_error: 0.0794 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0472
# Epoch 60/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0101 - root_mean_squared_error: 0.0936 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0411
# Epoch 61/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0078 - root_mean_squared_error: 0.0801 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0410
# Epoch 62/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0074 - root_mean_squared_error: 0.0782 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0466
# Epoch 63/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0078 - root_mean_squared_error: 0.0803 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0403
# Epoch 64/150
# 13/13 [==============================] - 0s 16ms/step - loss: 0.0074 - root_mean_squared_error: 0.0782 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0490
# Epoch 65/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0085 - root_mean_squared_error: 0.0853 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0412
# Epoch 66/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0097 - root_mean_squared_error: 0.0924 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0696
# Epoch 67/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0087 - root_mean_squared_error: 0.0865 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0437
# Epoch 68/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0072 - root_mean_squared_error: 0.0774 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0448
# Epoch 69/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0070 - root_mean_squared_error: 0.0761 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0409
# Epoch 70/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0072 - root_mean_squared_error: 0.0778 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0465
# Epoch 71/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0076 - root_mean_squared_error: 0.0807 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0427
# Epoch 72/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0077 - root_mean_squared_error: 0.0811 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0451
# Epoch 73/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0075 - root_mean_squared_error: 0.0803 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0593
# Epoch 74/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0077 - root_mean_squared_error: 0.0817 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0412
# Epoch 75/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0067 - root_mean_squared_error: 0.0750 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0410
# Epoch 76/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0076 - root_mean_squared_error: 0.0810 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0484
# Epoch 77/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0084 - root_mean_squared_error: 0.0862 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0415
# Epoch 78/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0070 - root_mean_squared_error: 0.0776 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0433
# Epoch 79/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0088 - root_mean_squared_error: 0.0883 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0482
# Epoch 80/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0079 - root_mean_squared_error: 0.0829 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0662

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0040 - root_mean_squared_error: 0.0543
# Test Loss: 0.003984752111136913
# Test RMSE: 0.054305415600538254

# %%
# คำนวณ predicted values
yhat_train = gru_model.predict(train_X)
yhat_val = gru_model.predict(val_X)
yhat_test = gru_model.predict(test_X)
# Out:
# 2024-12-22 22:38:13.018182: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:38:13.020569: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:38:13.022176: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 2ms/step
# 2024-12-22 22:38:13.859384: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:38:13.861266: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:38:13.862814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 1s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_rnn_model(rnn_units_1,beta_1,LR,L2):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_2202824/849910436.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-22 22:38:57.798337: W tensorflow/core/data/root_dataset.cc:273] Optimization loop failed: CANCELLED: Operation was cancelled
# 2024-12-22 22:39:36.098712: W tensorflow/core/data/root_dataset.cc:273] Optimization loop failed: CANCELLED: Operation was cancelled
# Execution time: 129.4936122894287 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 52, 'beta_1': 0.8, 'LR': 0.001, 'L2': 0.1}
# Best RMSE Score: 0.06327958601642074

# %%
rnn_model = create_rnn_model(rnn_units_1=52, beta_1=0.8 , LR=0.001, L2=0.1)
rnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 52)                6916
#
#  dropout_3 (Dropout)         (None, 52)                0
#
#  dense_3 (Dense)             (None, 7)                 371
#
# =================================================================
# Total params: 7,287
# Trainable params: 7,287
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_resid = rnn_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 1s 20ms/step - loss: 6.2187 - root_mean_squared_error: 0.3508 - val_loss: 5.6136 - val_root_mean_squared_error: 0.0715
# Epoch 2/150
# 13/13 [==============================] - 0s 4ms/step - loss: 5.2241 - root_mean_squared_error: 0.1929 - val_loss: 4.7205 - val_root_mean_squared_error: 0.0652
# Epoch 3/150
# 13/13 [==============================] - 0s 4ms/step - loss: 4.3815 - root_mean_squared_error: 0.1789 - val_loss: 3.9444 - val_root_mean_squared_error: 0.0622
# Epoch 4/150
# 13/13 [==============================] - 0s 4ms/step - loss: 3.6499 - root_mean_squared_error: 0.1632 - val_loss: 3.2762 - val_root_mean_squared_error: 0.0621
# Epoch 5/150
# 13/13 [==============================] - 0s 4ms/step - loss: 3.0238 - root_mean_squared_error: 0.1461 - val_loss: 2.7091 - val_root_mean_squared_error: 0.0689
# Epoch 6/150
# 13/13 [==============================] - 0s 4ms/step - loss: 2.4952 - root_mean_squared_error: 0.1386 - val_loss: 2.2286 - val_root_mean_squared_error: 0.0668
# Epoch 7/150
# 13/13 [==============================] - 0s 4ms/step - loss: 2.0479 - root_mean_squared_error: 0.1250 - val_loss: 1.8252 - val_root_mean_squared_error: 0.0643
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 1.6740 - root_mean_squared_error: 0.1163 - val_loss: 1.4889 - val_root_mean_squared_error: 0.0672
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 1.3630 - root_mean_squared_error: 0.1100 - val_loss: 1.2081 - val_root_mean_squared_error: 0.0601
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 1.1045 - root_mean_squared_error: 0.1015 - val_loss: 0.9772 - val_root_mean_squared_error: 0.0621
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.8915 - root_mean_squared_error: 0.0949 - val_loss: 0.7871 - val_root_mean_squared_error: 0.0632
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.7166 - root_mean_squared_error: 0.0900 - val_loss: 0.6315 - val_root_mean_squared_error: 0.0654
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5737 - root_mean_squared_error: 0.0855 - val_loss: 0.5039 - val_root_mean_squared_error: 0.0610
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.4577 - root_mean_squared_error: 0.0836 - val_loss: 0.4007 - val_root_mean_squared_error: 0.0601
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.3636 - root_mean_squared_error: 0.0803 - val_loss: 0.3174 - val_root_mean_squared_error: 0.0595
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2879 - root_mean_squared_error: 0.0783 - val_loss: 0.2501 - val_root_mean_squared_error: 0.0564
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2271 - root_mean_squared_error: 0.0764 - val_loss: 0.1966 - val_root_mean_squared_error: 0.0565
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1785 - root_mean_squared_error: 0.0746 - val_loss: 0.1542 - val_root_mean_squared_error: 0.0581
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1400 - root_mean_squared_error: 0.0734 - val_loss: 0.1202 - val_root_mean_squared_error: 0.0559
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1096 - root_mean_squared_error: 0.0727 - val_loss: 0.0934 - val_root_mean_squared_error: 0.0533
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0857 - root_mean_squared_error: 0.0720 - val_loss: 0.0727 - val_root_mean_squared_error: 0.0551
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0669 - root_mean_squared_error: 0.0715 - val_loss: 0.0562 - val_root_mean_squared_error: 0.0527
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0523 - root_mean_squared_error: 0.0707 - val_loss: 0.0435 - val_root_mean_squared_error: 0.0524
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0410 - root_mean_squared_error: 0.0707 - val_loss: 0.0336 - val_root_mean_squared_error: 0.0519
# Epoch 25/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0323 - root_mean_squared_error: 0.0707 - val_loss: 0.0260 - val_root_mean_squared_error: 0.0510
# Epoch 26/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0256 - root_mean_squared_error: 0.0701 - val_loss: 0.0201 - val_root_mean_squared_error: 0.0493
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0204 - root_mean_squared_error: 0.0694 - val_loss: 0.0156 - val_root_mean_squared_error: 0.0487
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0164 - root_mean_squared_error: 0.0692 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0454
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0135 - root_mean_squared_error: 0.0695 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0464
# Epoch 30/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0113 - root_mean_squared_error: 0.0693 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0460
# Epoch 31/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0097 - root_mean_squared_error: 0.0697 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0461
# Epoch 32/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0084 - root_mean_squared_error: 0.0692 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0450
# Epoch 33/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0074 - root_mean_squared_error: 0.0688 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0444
# Epoch 34/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0066 - root_mean_squared_error: 0.0683 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0442
# Epoch 35/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0061 - root_mean_squared_error: 0.0685 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0433
# Epoch 36/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0058 - root_mean_squared_error: 0.0686 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0418
# Epoch 37/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0055 - root_mean_squared_error: 0.0683 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0428
# Epoch 38/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0053 - root_mean_squared_error: 0.0687 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0425
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0051 - root_mean_squared_error: 0.0683 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0423
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0051 - root_mean_squared_error: 0.0690 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0419
# Epoch 41/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0682 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0412
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0685 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0412
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0676 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0410
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0677 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0406
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0048 - root_mean_squared_error: 0.0684 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0412
# Epoch 46/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 47/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0680 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0414
# Epoch 48/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0681 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 49/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0678 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 50/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0678 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0403
# Epoch 51/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0676 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0403
# Epoch 52/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0678 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408
# Epoch 53/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0680 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 54/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0680 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0403
# Epoch 55/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0679 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0400
# Epoch 56/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0678 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0411
# Epoch 57/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 58/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0676 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0400
# Epoch 59/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0673 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0403
# Epoch 60/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0405
# Epoch 61/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0046 - root_mean_squared_error: 0.0677 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0406
# Epoch 62/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0415
# Epoch 63/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0680 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0405

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.3655 - root_mean_squared_error: 0.6037
# Test Loss: 0.365499883890152
# Test RMSE: 0.6037087440490723

# %%
# คำนวณ predicted residuals
yhat_train_resid = rnn_model.predict(train_X_resid)
yhat_val_resid = rnn_model.predict(val_X_resid)
yhat_test_resid = rnn_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 1.9561%
# RMSE: 0.7840
