# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('PTT.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High   Low   Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  38.007935  49.50  49.50  49.0  49.50  52067800
# 2019-07-02 00:00:00+00:00  37.240101  48.50  49.50  48.5  49.25  51490800
# 2019-07-03 00:00:00+00:00  37.048138  48.25  48.50  48.0  48.50  44524800
# 2019-07-04 00:00:00+00:00  37.048138  48.25  48.75  48.0  48.50  49509400
# 2019-07-05 00:00:00+00:00  37.048138  48.25  48.50  48.0  48.25  20907100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('PTT Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df =df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         1.000000    1.000000   1.000000    1.000000      0.080878
# 16         0.955565    1.000000   0.980315    0.990119      0.079982
# 17         0.944456    0.957447   0.960630    0.960474      0.069161
# 18         0.944456    0.968085   0.960630    0.960474      0.076904
# 19         0.944456    0.957447   0.960630    0.950593      0.032475
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.955565    1.000000   0.980315    0.990119      0.079982  ...
# 16         0.944456    0.957447   0.960630    0.960474      0.069161  ...
# 17         0.944456    0.968085   0.960630    0.960474      0.076904  ...
# 18         0.944456    0.957447   0.960630    0.950593      0.032475  ...
# 19         0.944456    0.946809   0.960630    0.940711      0.019224  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.940945  0.940711   0.032713        0.922238        0.922238
# 16  0.931102  0.930830   0.053481        0.922238        0.900020
# 17  0.940945  0.930830   0.031202        0.900020        0.900020
# 18  0.921260  0.920949   0.064817        0.900020        0.900020
# 19  0.921260  0.911067   0.036953        0.900020        0.900020
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.900020        0.900020        0.900020        0.900020
# 16        0.900020        0.900020        0.900020        0.844476
# 17        0.900020        0.900020        0.844476        0.833367
# 18        0.900020        0.844476        0.833367        0.822258
# 19        0.844476        0.833367        0.822258        0.800041
#
#     Adj Close(t+7)
# 15        0.844476
# 16        0.833367
# 17        0.822258
# 18        0.800041
# 19        0.766714
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_rnn_model(rnn_units_1, beta_1 ,LR,L2):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_2202819/610512278.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-22 22:07:09.142922: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.252388: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.253297: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.411710: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.412228: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.419670: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.444367: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.444497: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.451475: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.493756: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.573410: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.621178: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.777062: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.793308: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.793417: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.828360: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:09.952558: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.004016: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.026619: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.060134: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.060309: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.077214: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.176924: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.187498: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.235209: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.292193: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.308262: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.500445: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.552109: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.710830: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.875072: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:07:10.875481: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 3074.3552668094635 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 70, 'beta_1': 0.8, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.07020546756645542

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
rnn_model = create_rnn_model(rnn_units_1=70 ,beta_1=0.8, LR=0.003, L2=0.001)
rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 70)                10570
#
#  dropout_1 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 7)                 497
#
# =================================================================
# Total params: 11,067
# Trainable params: 11,067
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 2s 32ms/step - loss: 0.1754 - root_mean_squared_error: 0.3179 - val_loss: 0.0792 - val_root_mean_squared_error: 0.0832
# Epoch 2/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.1077 - root_mean_squared_error: 0.1934 - val_loss: 0.0749 - val_root_mean_squared_error: 0.0829
# Epoch 3/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0889 - root_mean_squared_error: 0.1506 - val_loss: 0.0770 - val_root_mean_squared_error: 0.1133
# Epoch 4/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0808 - root_mean_squared_error: 0.1356 - val_loss: 0.0696 - val_root_mean_squared_error: 0.0951
# Epoch 5/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0743 - root_mean_squared_error: 0.1236 - val_loss: 0.0648 - val_root_mean_squared_error: 0.0864
# Epoch 6/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0673 - root_mean_squared_error: 0.1070 - val_loss: 0.0584 - val_root_mean_squared_error: 0.0644
# Epoch 7/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0635 - root_mean_squared_error: 0.1029 - val_loss: 0.0553 - val_root_mean_squared_error: 0.0633
# Epoch 8/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0611 - root_mean_squared_error: 0.1053 - val_loss: 0.0513 - val_root_mean_squared_error: 0.0514
# Epoch 9/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0575 - root_mean_squared_error: 0.1004 - val_loss: 0.0488 - val_root_mean_squared_error: 0.0521
# Epoch 10/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0545 - root_mean_squared_error: 0.0978 - val_loss: 0.0458 - val_root_mean_squared_error: 0.0464
# Epoch 11/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0516 - root_mean_squared_error: 0.0947 - val_loss: 0.0440 - val_root_mean_squared_error: 0.0503
# Epoch 12/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0501 - root_mean_squared_error: 0.0983 - val_loss: 0.0433 - val_root_mean_squared_error: 0.0633
# Epoch 13/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0489 - root_mean_squared_error: 0.1024 - val_loss: 0.0395 - val_root_mean_squared_error: 0.0463
# Epoch 14/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0457 - root_mean_squared_error: 0.0959 - val_loss: 0.0378 - val_root_mean_squared_error: 0.0477
# Epoch 15/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0442 - root_mean_squared_error: 0.0970 - val_loss: 0.0359 - val_root_mean_squared_error: 0.0449
# Epoch 16/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0449 - root_mean_squared_error: 0.1088 - val_loss: 0.0362 - val_root_mean_squared_error: 0.0629
# Epoch 17/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0417 - root_mean_squared_error: 0.1006 - val_loss: 0.0328 - val_root_mean_squared_error: 0.0439
# Epoch 18/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0392 - root_mean_squared_error: 0.0951 - val_loss: 0.0324 - val_root_mean_squared_error: 0.0542
# Epoch 19/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0379 - root_mean_squared_error: 0.0950 - val_loss: 0.0300 - val_root_mean_squared_error: 0.0430
# Epoch 20/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0359 - root_mean_squared_error: 0.0913 - val_loss: 0.0288 - val_root_mean_squared_error: 0.0438
# Epoch 21/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0351 - root_mean_squared_error: 0.0936 - val_loss: 0.0277 - val_root_mean_squared_error: 0.0449
# Epoch 22/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0343 - root_mean_squared_error: 0.0953 - val_loss: 0.0266 - val_root_mean_squared_error: 0.0453
# Epoch 23/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0321 - root_mean_squared_error: 0.0893 - val_loss: 0.0255 - val_root_mean_squared_error: 0.0443
# Epoch 24/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0308 - root_mean_squared_error: 0.0878 - val_loss: 0.0242 - val_root_mean_squared_error: 0.0415
# Epoch 25/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0297 - root_mean_squared_error: 0.0873 - val_loss: 0.0232 - val_root_mean_squared_error: 0.0410
# Epoch 26/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0297 - root_mean_squared_error: 0.0928 - val_loss: 0.0222 - val_root_mean_squared_error: 0.0403
# Epoch 27/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0285 - root_mean_squared_error: 0.0916 - val_loss: 0.0219 - val_root_mean_squared_error: 0.0470
# Epoch 28/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0265 - root_mean_squared_error: 0.0852 - val_loss: 0.0208 - val_root_mean_squared_error: 0.0440
# Epoch 29/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0259 - root_mean_squared_error: 0.0861 - val_loss: 0.0208 - val_root_mean_squared_error: 0.0530
# Epoch 30/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0255 - root_mean_squared_error: 0.0886 - val_loss: 0.0190 - val_root_mean_squared_error: 0.0425
# Epoch 31/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0257 - root_mean_squared_error: 0.0940 - val_loss: 0.0206 - val_root_mean_squared_error: 0.0644
# Epoch 32/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0237 - root_mean_squared_error: 0.0869 - val_loss: 0.0174 - val_root_mean_squared_error: 0.0406
# Epoch 33/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0242 - root_mean_squared_error: 0.0938 - val_loss: 0.0169 - val_root_mean_squared_error: 0.0425
# Epoch 34/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0235 - root_mean_squared_error: 0.0935 - val_loss: 0.0167 - val_root_mean_squared_error: 0.0474
# Epoch 35/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0213 - root_mean_squared_error: 0.0848 - val_loss: 0.0155 - val_root_mean_squared_error: 0.0407
# Epoch 36/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0213 - root_mean_squared_error: 0.0877 - val_loss: 0.0150 - val_root_mean_squared_error: 0.0420
# Epoch 37/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0204 - root_mean_squared_error: 0.0859 - val_loss: 0.0145 - val_root_mean_squared_error: 0.0429
# Epoch 38/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0192 - root_mean_squared_error: 0.0821 - val_loss: 0.0139 - val_root_mean_squared_error: 0.0414
# Epoch 39/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0204 - root_mean_squared_error: 0.0923 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0427
# Epoch 40/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0182 - root_mean_squared_error: 0.0823 - val_loss: 0.0129 - val_root_mean_squared_error: 0.0413
# Epoch 41/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0183 - root_mean_squared_error: 0.0854 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0447
# Epoch 42/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0178 - root_mean_squared_error: 0.0853 - val_loss: 0.0130 - val_root_mean_squared_error: 0.0523
# Epoch 43/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0179 - root_mean_squared_error: 0.0888 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0572
# Epoch 44/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0165 - root_mean_squared_error: 0.0828 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0509
# Epoch 45/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0164 - root_mean_squared_error: 0.0848 - val_loss: 0.0106 - val_root_mean_squared_error: 0.0399
# Epoch 46/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0157 - root_mean_squared_error: 0.0826 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0542
# Epoch 47/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0170 - root_mean_squared_error: 0.0921 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0510
# Epoch 48/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0171 - root_mean_squared_error: 0.0945 - val_loss: 0.0099 - val_root_mean_squared_error: 0.0435
# Epoch 49/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0156 - root_mean_squared_error: 0.0882 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0445
# Epoch 50/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0170 - root_mean_squared_error: 0.0970 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0442
# Epoch 51/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0150 - root_mean_squared_error: 0.0882 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0405
# Epoch 52/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0154 - root_mean_squared_error: 0.0915 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0419
# Epoch 53/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0137 - root_mean_squared_error: 0.0833 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0402
# Epoch 54/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0132 - root_mean_squared_error: 0.0818 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0417
# Epoch 55/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0134 - root_mean_squared_error: 0.0846 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0399
# Epoch 56/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0125 - root_mean_squared_error: 0.0808 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0548
# Epoch 57/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0124 - root_mean_squared_error: 0.0816 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0420
# Epoch 58/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0143 - root_mean_squared_error: 0.0936 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0529
# Epoch 59/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0144 - root_mean_squared_error: 0.0953 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0649
# Epoch 60/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0123 - root_mean_squared_error: 0.0842 - val_loss: 0.0068 - val_root_mean_squared_error: 0.0421
# Epoch 61/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0115 - root_mean_squared_error: 0.0805 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0400
# Epoch 62/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0110 - root_mean_squared_error: 0.0788 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0430
# Epoch 63/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0120 - root_mean_squared_error: 0.0858 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0437
# Epoch 64/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0116 - root_mean_squared_error: 0.0846 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0468
# Epoch 65/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0112 - root_mean_squared_error: 0.0833 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0404
# Epoch 66/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0104 - root_mean_squared_error: 0.0788 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0456
# Epoch 67/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0103 - root_mean_squared_error: 0.0792 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0443
# Epoch 68/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0125 - root_mean_squared_error: 0.0929 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0405
# Epoch 69/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0099 - root_mean_squared_error: 0.0784 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0460
# Epoch 70/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0100 - root_mean_squared_error: 0.0800 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0418
# Epoch 71/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0100 - root_mean_squared_error: 0.0809 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0466
# Epoch 72/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0105 - root_mean_squared_error: 0.0844 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0416
# Epoch 73/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0098 - root_mean_squared_error: 0.0808 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0459
# Epoch 74/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0106 - root_mean_squared_error: 0.0861 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0554
# Epoch 75/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0101 - root_mean_squared_error: 0.0842 - val_loss: 0.0049 - val_root_mean_squared_error: 0.0438
# Epoch 76/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0095 - root_mean_squared_error: 0.0808 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0427
# Epoch 77/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0088 - root_mean_squared_error: 0.0773 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0443
# Epoch 78/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0089 - root_mean_squared_error: 0.0784 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0477
# Epoch 79/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0096 - root_mean_squared_error: 0.0834 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0419
# Epoch 80/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0089 - root_mean_squared_error: 0.0796 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0462
# Epoch 81/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0086 - root_mean_squared_error: 0.0778 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0403
# Epoch 82/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0086 - root_mean_squared_error: 0.0783 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0452
# Epoch 83/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0096 - root_mean_squared_error: 0.0851 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0394
# Epoch 84/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0086 - root_mean_squared_error: 0.0793 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0494
# Epoch 85/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0093 - root_mean_squared_error: 0.0841 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0396
# Epoch 86/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0088 - root_mean_squared_error: 0.0814 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0424
# Epoch 87/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0083 - root_mean_squared_error: 0.0784 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0410
# Epoch 88/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0080 - root_mean_squared_error: 0.0769 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0460
# Epoch 89/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0082 - root_mean_squared_error: 0.0790 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0402
# Epoch 90/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0076 - root_mean_squared_error: 0.0750 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0589
# Epoch 91/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0098 - root_mean_squared_error: 0.0887 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0418
# Epoch 92/150
# 13/13 [==============================] - 0s 13ms/step - loss: 0.0077 - root_mean_squared_error: 0.0769 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0398
# Epoch 93/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0077 - root_mean_squared_error: 0.0771 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0410
# Epoch 94/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0075 - root_mean_squared_error: 0.0756 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0458
# Epoch 95/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0076 - root_mean_squared_error: 0.0767 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0504
# Epoch 96/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0078 - root_mean_squared_error: 0.0784 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0422
# Epoch 97/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0083 - root_mean_squared_error: 0.0818 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0588

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 3ms/step - loss: 0.0036 - root_mean_squared_error: 0.0418
# Test Loss: 0.003561823396012187
# Test RMSE: 0.04184092581272125

# %%
# คำนวณ predicted values
yhat_train = rnn_model.predict(train_X)
yhat_val = rnn_model.predict(val_X)
yhat_test = rnn_model.predict(test_X)
# Out:
# 26/26 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 3ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_gru_model(gru_units_1,beta_1,LR,L2):
    model = Sequential()
    model.add(GRU(gru_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_gru = {
    'gru_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

gru_random_search = RandomizedSearchCV(estimator=gru_model, param_distributions=param_dist_gru,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
gru_random_search_result = gru_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_2202819/1327760477.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   gru_model = KerasRegressor(build_fn=create_gru_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /nfs/workbench/home/g6680025026/venvs/myenv1/lib/python3.11/site-packages/joblib/externals/loky/process_executor.py:752: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# 2024-12-22 22:46:48.006937: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:46:48.008946: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:46:50.040985: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:46:51.427098: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:46:53.647049: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:01.247521: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:02.604846: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:03.425868: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:04.697271: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:05.201780: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:06.828099: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:08.698391: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:09.439899: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:10.289466: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:11.652352: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:12.823206: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:13.111175: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:14.292024: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:14.895387: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:16.053709: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:16.976348: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:18.022677: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:19.533089: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:47:20.057444: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:52:50.718490: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:52:50.720535: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:52:50.721689: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:52:51.051099: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:52:51.053543: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:52:51.055452: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:52:51.674036: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:52:51.676194: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:52:51.677792: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:52:52.736716: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:52:52.739347: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:52:52.741103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 915.0994102954865 seconds

# %%
# Get the best parameters and the best score
gru_best_params = gru_random_search_result.best_params_
gru_best_score = -gru_random_search_result.best_score_

# %%
print("Best Parameters:", gru_best_params)
print("Best RMSE Score:", gru_best_score)
# Out:
# Best Parameters: {'gru_units_1': 52, 'beta_1': 0.8, 'LR': 0.001, 'L2': 0.1}
# Best RMSE Score: 0.061943789647866704

# %%
gru_model = create_gru_model(gru_units_1=52 ,beta_1=0.8, LR=0.001, L2=0.1)
gru_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru_1 (GRU)                 (None, 52)                20904
#
#  dropout_3 (Dropout)         (None, 52)                0
#
#  dense_3 (Dense)             (None, 7)                 371
#
# =================================================================
# Total params: 21,275
# Trainable params: 21,275
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-22 22:55:10.353521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:55:10.355521: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:55:10.356984: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = gru_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-22 22:55:13.360052: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:55:13.362613: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:55:13.364349: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:55:14.004990: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:55:14.007309: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:55:14.008812: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 45ms/step - loss: 9.5253 - root_mean_squared_error: 0.2112 - val_loss: 8.2582 - val_root_mean_squared_error: 0.0601
# Epoch 2/150
#  1/13 [=>............................] - ETA: 0s - loss: 8.2731 - root_mean_squared_error: 0.1360
# 2024-12-22 22:55:15.125875: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:55:15.128587: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:55:15.130489: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 0s 5ms/step - loss: 7.3559 - root_mean_squared_error: 0.1195 - val_loss: 6.3591 - val_root_mean_squared_error: 0.0456
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 5.6510 - root_mean_squared_error: 0.1050 - val_loss: 4.8710 - val_root_mean_squared_error: 0.0430
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 4.3187 - root_mean_squared_error: 0.0975 - val_loss: 3.7097 - val_root_mean_squared_error: 0.0442
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 3.2801 - root_mean_squared_error: 0.0899 - val_loss: 2.8071 - val_root_mean_squared_error: 0.0473
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 2.4746 - root_mean_squared_error: 0.0842 - val_loss: 2.1089 - val_root_mean_squared_error: 0.0494
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 1.8534 - root_mean_squared_error: 0.0798 - val_loss: 1.5726 - val_root_mean_squared_error: 0.0513
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 1.3779 - root_mean_squared_error: 0.0777 - val_loss: 1.1635 - val_root_mean_squared_error: 0.0523
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 1.0164 - root_mean_squared_error: 0.0754 - val_loss: 0.8539 - val_root_mean_squared_error: 0.0523
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.7436 - root_mean_squared_error: 0.0726 - val_loss: 0.6217 - val_root_mean_squared_error: 0.0529
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.5400 - root_mean_squared_error: 0.0719 - val_loss: 0.4489 - val_root_mean_squared_error: 0.0526
# Epoch 12/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.3890 - root_mean_squared_error: 0.0704 - val_loss: 0.3214 - val_root_mean_squared_error: 0.0516
# Epoch 13/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2782 - root_mean_squared_error: 0.0695 - val_loss: 0.2284 - val_root_mean_squared_error: 0.0509
# Epoch 14/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1977 - root_mean_squared_error: 0.0692 - val_loss: 0.1610 - val_root_mean_squared_error: 0.0505
# Epoch 15/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1396 - root_mean_squared_error: 0.0684 - val_loss: 0.1127 - val_root_mean_squared_error: 0.0490
# Epoch 16/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0981 - root_mean_squared_error: 0.0681 - val_loss: 0.0784 - val_root_mean_squared_error: 0.0487
# Epoch 17/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0689 - root_mean_squared_error: 0.0678 - val_loss: 0.0543 - val_root_mean_squared_error: 0.0475
# Epoch 18/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0483 - root_mean_squared_error: 0.0675 - val_loss: 0.0374 - val_root_mean_squared_error: 0.0464
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0341 - root_mean_squared_error: 0.0674 - val_loss: 0.0258 - val_root_mean_squared_error: 0.0458
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0243 - root_mean_squared_error: 0.0673 - val_loss: 0.0178 - val_root_mean_squared_error: 0.0443
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0176 - root_mean_squared_error: 0.0669 - val_loss: 0.0124 - val_root_mean_squared_error: 0.0438
# Epoch 22/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0131 - root_mean_squared_error: 0.0666 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0432
# Epoch 23/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0101 - root_mean_squared_error: 0.0668 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0417
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0082 - root_mean_squared_error: 0.0669 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0414
# Epoch 25/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0068 - root_mean_squared_error: 0.0667 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0406
# Epoch 26/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0060 - root_mean_squared_error: 0.0664 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0413
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0055 - root_mean_squared_error: 0.0670 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0419
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0051 - root_mean_squared_error: 0.0670 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0404
# Epoch 29/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0049 - root_mean_squared_error: 0.0667 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0401
# Epoch 30/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0047 - root_mean_squared_error: 0.0663 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0402
# Epoch 31/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0046 - root_mean_squared_error: 0.0666 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0398
# Epoch 32/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0045 - root_mean_squared_error: 0.0665 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0404
# Epoch 33/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0046 - root_mean_squared_error: 0.0668 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0398
# Epoch 34/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0045 - root_mean_squared_error: 0.0665 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0396
# Epoch 35/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0045 - root_mean_squared_error: 0.0666 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0400
# Epoch 36/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0045 - root_mean_squared_error: 0.0665 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0396
# Epoch 37/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0395
# Epoch 38/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0398
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0045 - root_mean_squared_error: 0.0666 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0399
# Epoch 41/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0401
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0396
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0398
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0045 - root_mean_squared_error: 0.0666 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0664 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0396
# Epoch 46/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0401
# Epoch 47/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394
# Epoch 48/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394
# Epoch 49/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0660 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394
# Epoch 50/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0395
# Epoch 51/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394
# Epoch 52/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0661 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0395
# Epoch 53/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0663 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0396
# Epoch 54/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0044 - root_mean_squared_error: 0.0662 - val_loss: 0.0016 - val_root_mean_squared_error: 0.0394

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = gru_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0020 - root_mean_squared_error: 0.0448
# Test Loss: 0.002016669139266014
# Test RMSE: 0.04479679465293884

# %%
# คำนวณ predicted residuals
yhat_train_resid = gru_model.predict(train_X_resid)
yhat_val_resid = gru_model.predict(val_X_resid)
yhat_test_resid = gru_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-22 22:55:25.974977: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:55:25.977073: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:55:25.978679: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 6/6 [==============================] - 0s 1ms/step
# 2024-12-22 22:55:26.416312: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:55:26.418356: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:55:26.419784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 1.9135%
# RMSE: 0.7741
