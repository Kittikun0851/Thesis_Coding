# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-22 21:38:44.389262: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-22 21:38:44.397348: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 21:38:44.458864: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-22 21:38:44.460546: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-22 21:39:11.365771: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('PTT.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High   Low   Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  38.007938  49.50  49.50  49.0  49.50  52067800
# 2019-07-02 00:00:00+00:00  37.240101  48.50  49.50  48.5  49.25  51490800
# 2019-07-03 00:00:00+00:00  37.048141  48.25  48.50  48.0  48.50  44524800
# 2019-07-04 00:00:00+00:00  37.048141  48.25  48.75  48.0  48.50  49509400
# 2019-07-05 00:00:00+00:00  37.048141  48.25  48.50  48.0  48.25  20907100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('PTT Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         1.000000    1.000000   1.000000    1.000000      0.080878
# 16         0.955565    1.000000   0.980315    0.990119      0.079982
# 17         0.944456    0.957447   0.960630    0.960474      0.069161
# 18         0.944456    0.968085   0.960630    0.960474      0.076904
# 19         0.944456    0.957447   0.960630    0.950593      0.032475
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.955565    1.000000   0.980315    0.990119      0.079982  ...
# 16         0.944456    0.957447   0.960630    0.960474      0.069161  ...
# 17         0.944456    0.968085   0.960630    0.960474      0.076904  ...
# 18         0.944456    0.957447   0.960630    0.950593      0.032475  ...
# 19         0.944456    0.946809   0.960630    0.940711      0.019224  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.940945  0.940711   0.032713        0.922238        0.922238
# 16  0.931102  0.930830   0.053481        0.922238        0.900020
# 17  0.940945  0.930830   0.031202        0.900020        0.900020
# 18  0.921260  0.920949   0.064817        0.900020        0.900020
# 19  0.921260  0.911067   0.036953        0.900020        0.900020
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.900020        0.900020        0.900020        0.900020
# 16        0.900020        0.900020        0.900020        0.844476
# 17        0.900020        0.900020        0.844476        0.833367
# 18        0.900020        0.844476        0.833367        0.822258
# 19        0.844476        0.833367        0.822258        0.800040
#
#     Adj Close(t+7)
# 15        0.844476
# 16        0.833367
# 17        0.822258
# 18        0.800040
# 19        0.766714
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_rnn_model(rnn_units_1,LR,L2,beta_1):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2228102/3334002836.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-22 22:01:52.778607: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.779199: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.796355: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.815714: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.827430: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.832422: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.833716: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.850569: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.853379: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.860701: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.860877: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.861007: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.861439: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.904122: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.904266: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.933578: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.934548: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.935671: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.943227: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.951084: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.951277: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.951363: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.951577: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.969585: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.987462: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:52.995753: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:53.004790: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:53.004865: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:53.012571: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:53.012566: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:53.024157: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:01:53.024250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 2723.2895753383636 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 69, 'beta_1': 0.8, 'LR': 0.009000000000000001, 'L2': 0.001}
# Best RMSE Score: 0.07088846981895934

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
rnn_model = create_rnn_model(rnn_units_1=69, LR=0.009, L2=0.001, beta_1=0.8)
rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 69)                10350
#
#  dropout_1 (Dropout)         (None, 69)                0
#
#  dense_1 (Dense)             (None, 7)                 490
#
# =================================================================
# Total params: 10,840
# Trainable params: 10,840
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 2s 40ms/step - loss: 0.3382 - root_mean_squared_error: 0.5159 - val_loss: 0.0827 - val_root_mean_squared_error: 0.1106
# Epoch 2/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.1274 - root_mean_squared_error: 0.2426 - val_loss: 0.0779 - val_root_mean_squared_error: 0.1087
# Epoch 3/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0980 - root_mean_squared_error: 0.1840 - val_loss: 0.0697 - val_root_mean_squared_error: 0.0890
# Epoch 4/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0829 - root_mean_squared_error: 0.1518 - val_loss: 0.0647 - val_root_mean_squared_error: 0.0836
# Epoch 5/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0736 - root_mean_squared_error: 0.1330 - val_loss: 0.0589 - val_root_mean_squared_error: 0.0706
# Epoch 6/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0690 - root_mean_squared_error: 0.1292 - val_loss: 0.0566 - val_root_mean_squared_error: 0.0783
# Epoch 7/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0628 - root_mean_squared_error: 0.1175 - val_loss: 0.0499 - val_root_mean_squared_error: 0.0517
# Epoch 8/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0591 - root_mean_squared_error: 0.1148 - val_loss: 0.0470 - val_root_mean_squared_error: 0.0524
# Epoch 9/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0543 - root_mean_squared_error: 0.1066 - val_loss: 0.0447 - val_root_mean_squared_error: 0.0572
# Epoch 10/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0527 - root_mean_squared_error: 0.1116 - val_loss: 0.0424 - val_root_mean_squared_error: 0.0599
# Epoch 11/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0519 - root_mean_squared_error: 0.1191 - val_loss: 0.0411 - val_root_mean_squared_error: 0.0683
# Epoch 12/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0478 - root_mean_squared_error: 0.1114 - val_loss: 0.0365 - val_root_mean_squared_error: 0.0476
# Epoch 13/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0445 - root_mean_squared_error: 0.1065 - val_loss: 0.0347 - val_root_mean_squared_error: 0.0521
# Epoch 14/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0439 - root_mean_squared_error: 0.1133 - val_loss: 0.0348 - val_root_mean_squared_error: 0.0689
# Epoch 15/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0403 - root_mean_squared_error: 0.1057 - val_loss: 0.0322 - val_root_mean_squared_error: 0.0635
# Epoch 16/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0421 - root_mean_squared_error: 0.1215 - val_loss: 0.0312 - val_root_mean_squared_error: 0.0697
# Epoch 17/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0383 - root_mean_squared_error: 0.1126 - val_loss: 0.0272 - val_root_mean_squared_error: 0.0494
# Epoch 18/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0346 - root_mean_squared_error: 0.1026 - val_loss: 0.0258 - val_root_mean_squared_error: 0.0508
# Epoch 19/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0321 - root_mean_squared_error: 0.0981 - val_loss: 0.0235 - val_root_mean_squared_error: 0.0423
# Epoch 20/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0320 - root_mean_squared_error: 0.1044 - val_loss: 0.0241 - val_root_mean_squared_error: 0.0608
# Epoch 21/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0296 - root_mean_squared_error: 0.0990 - val_loss: 0.0213 - val_root_mean_squared_error: 0.0473
# Epoch 22/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0293 - root_mean_squared_error: 0.1040 - val_loss: 0.0232 - val_root_mean_squared_error: 0.0737
# Epoch 23/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0292 - root_mean_squared_error: 0.1093 - val_loss: 0.0188 - val_root_mean_squared_error: 0.0464
# Epoch 24/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0265 - root_mean_squared_error: 0.1020 - val_loss: 0.0189 - val_root_mean_squared_error: 0.0582
# Epoch 25/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0251 - root_mean_squared_error: 0.1000 - val_loss: 0.0171 - val_root_mean_squared_error: 0.0509
# Epoch 26/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0230 - root_mean_squared_error: 0.0943 - val_loss: 0.0158 - val_root_mean_squared_error: 0.0469
# Epoch 27/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0217 - root_mean_squared_error: 0.0927 - val_loss: 0.0171 - val_root_mean_squared_error: 0.0665
# Epoch 28/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0238 - root_mean_squared_error: 0.1075 - val_loss: 0.0135 - val_root_mean_squared_error: 0.0409
# Epoch 29/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0192 - root_mean_squared_error: 0.0878 - val_loss: 0.0133 - val_root_mean_squared_error: 0.0478
# Epoch 30/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0189 - root_mean_squared_error: 0.0905 - val_loss: 0.0124 - val_root_mean_squared_error: 0.0455
# Epoch 31/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0187 - root_mean_squared_error: 0.0935 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0450
# Epoch 32/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0227 - root_mean_squared_error: 0.1156 - val_loss: 0.0138 - val_root_mean_squared_error: 0.0691
# Epoch 33/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0207 - root_mean_squared_error: 0.1096 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0493
# Epoch 34/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0190 - root_mean_squared_error: 0.1040 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0430
# Epoch 35/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0148 - root_mean_squared_error: 0.0845 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0429
# Epoch 36/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0154 - root_mean_squared_error: 0.0906 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0465
# Epoch 37/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0146 - root_mean_squared_error: 0.0890 - val_loss: 0.0114 - val_root_mean_squared_error: 0.0706
# Epoch 38/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0163 - root_mean_squared_error: 0.1006 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0529
# Epoch 39/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0161 - root_mean_squared_error: 0.1015 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0599
# Epoch 40/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0132 - root_mean_squared_error: 0.0880 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0465
# Epoch 41/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0119 - root_mean_squared_error: 0.0823 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0428
# Epoch 42/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0119 - root_mean_squared_error: 0.0844 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0672
# Epoch 43/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0181 - root_mean_squared_error: 0.1170 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0622
# Epoch 44/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0134 - root_mean_squared_error: 0.0963 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0562
# Epoch 45/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0112 - root_mean_squared_error: 0.0853 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0556
# Epoch 46/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0113 - root_mean_squared_error: 0.0869 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0474
# Epoch 47/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0107 - root_mean_squared_error: 0.0849 - val_loss: 0.0064 - val_root_mean_squared_error: 0.0555
# Epoch 48/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0117 - root_mean_squared_error: 0.0916 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0478
# Epoch 49/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0109 - root_mean_squared_error: 0.0886 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0423
# Epoch 50/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0106 - root_mean_squared_error: 0.0876 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0420
# Epoch 51/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0094 - root_mean_squared_error: 0.0815 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0657
# Epoch 52/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0124 - root_mean_squared_error: 0.0991 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0610
# Epoch 53/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0098 - root_mean_squared_error: 0.0860 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0417
# Epoch 54/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0091 - root_mean_squared_error: 0.0824 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0429
# Epoch 55/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0087 - root_mean_squared_error: 0.0809 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0442
# Epoch 56/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0106 - root_mean_squared_error: 0.0923 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0430
# Epoch 57/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0099 - root_mean_squared_error: 0.0890 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0418
# Epoch 58/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0105 - root_mean_squared_error: 0.0926 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0498
# Epoch 59/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0122 - root_mean_squared_error: 0.1022 - val_loss: 0.0053 - val_root_mean_squared_error: 0.0589
# Epoch 60/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0092 - root_mean_squared_error: 0.0862 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0485
# Epoch 61/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0095 - root_mean_squared_error: 0.0878 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0491
# Epoch 62/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0085 - root_mean_squared_error: 0.0828 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0437
# Epoch 63/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0078 - root_mean_squared_error: 0.0786 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0430
# Epoch 64/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0081 - root_mean_squared_error: 0.0809 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0526
# Epoch 65/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0091 - root_mean_squared_error: 0.0876 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0700
# Epoch 66/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0088 - root_mean_squared_error: 0.0860 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0446
# Epoch 67/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0092 - root_mean_squared_error: 0.0883 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0481
# Epoch 68/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0092 - root_mean_squared_error: 0.0885 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0475
# Epoch 69/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0085 - root_mean_squared_error: 0.0849 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0443
# Epoch 70/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0089 - root_mean_squared_error: 0.0875 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0476
# Epoch 71/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0074 - root_mean_squared_error: 0.0784 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0496
# Epoch 72/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0082 - root_mean_squared_error: 0.0837 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0426
# Epoch 73/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0080 - root_mean_squared_error: 0.0830 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0498
# Epoch 74/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0081 - root_mean_squared_error: 0.0833 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0474
# Epoch 75/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0071 - root_mean_squared_error: 0.0775 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0419
# Epoch 76/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0092 - root_mean_squared_error: 0.0898 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0502
# Epoch 77/150
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0087 - root_mean_squared_error: 0.0870 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0590
# Epoch 78/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0075 - root_mean_squared_error: 0.0803 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0424
# Epoch 79/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0071 - root_mean_squared_error: 0.0778 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0606
# Epoch 80/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0083 - root_mean_squared_error: 0.0852 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0467
# Epoch 81/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0076 - root_mean_squared_error: 0.0809 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0464
# Epoch 82/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0081 - root_mean_squared_error: 0.0841 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0461
# Epoch 83/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0115 - root_mean_squared_error: 0.1024 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0455

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0042 - root_mean_squared_error: 0.0563
# Test Loss: 0.004228291101753712
# Test RMSE: 0.056321293115615845

# %%
# คำนวณ predicted values
yhat_train = rnn_model.predict(train_X)
yhat_val = rnn_model.predict(val_X)
yhat_test = rnn_model.predict(test_X)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_lstm_model(lstm_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_2228102/1670406022.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-22 22:43:28.385322: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.387709: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.391033: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.396281: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.401743: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.404731: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.405026: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.405050: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.405382: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.408245: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.413011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.414468: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.416413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.419197: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.419398: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.419548: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.422264: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.427736: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.429965: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.435718: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.436326: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.438525: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.441767: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.442145: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.442392: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.444982: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.445009: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.454170: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.454527: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.454581: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.454596: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:43:28.460474: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-22 22:52:02.572820: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:52:02.575025: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:52:02.576236: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:52:02.984072: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:52:02.986784: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:52:02.988838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:52:03.762672: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:52:03.765088: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:52:03.766660: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:52:04.973922: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:52:04.976672: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:52:04.978747: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 961.9939198493958 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 17, 'beta_1': 0.8, 'LR': 0.004, 'L2': 0.001}
# Best RMSE Score: 0.06434311681980402

# %%
lstm_model = create_lstm_model(lstm_units_1=17 ,beta_1=0.8 , LR=0.004, L2=0.001)
lstm_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 17)                6664
#
#  dropout_3 (Dropout)         (None, 17)                0
#
#  dense_3 (Dense)             (None, 7)                 126
#
# =================================================================
# Total params: 6,790
# Trainable params: 6,790
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-22 22:53:53.931879: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:53:53.933697: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:53:53.934958: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = lstm_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-22 22:53:57.093444: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:53:57.095659: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:53:57.097130: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-22 22:53:57.707123: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:53:57.709200: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:53:57.710814: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 19s - loss: 0.0892 - root_mean_squared_error: 0.1233
# 2024-12-22 22:53:58.797718: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:53:58.800273: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:53:58.801701: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 46ms/step - loss: 0.0666 - root_mean_squared_error: 0.0880 - val_loss: 0.0445 - val_root_mean_squared_error: 0.0423
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0377 - root_mean_squared_error: 0.0715 - val_loss: 0.0248 - val_root_mean_squared_error: 0.0439
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0223 - root_mean_squared_error: 0.0697 - val_loss: 0.0140 - val_root_mean_squared_error: 0.0409
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0145 - root_mean_squared_error: 0.0698 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0420
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0105 - root_mean_squared_error: 0.0694 - val_loss: 0.0060 - val_root_mean_squared_error: 0.0410
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0085 - root_mean_squared_error: 0.0704 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0415
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0072 - root_mean_squared_error: 0.0695 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0408
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0064 - root_mean_squared_error: 0.0688 - val_loss: 0.0031 - val_root_mean_squared_error: 0.0415
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0059 - root_mean_squared_error: 0.0692 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0404
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0056 - root_mean_squared_error: 0.0689 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0419
# Epoch 11/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0054 - root_mean_squared_error: 0.0691 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0407
# Epoch 12/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0052 - root_mean_squared_error: 0.0690 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0407
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0051 - root_mean_squared_error: 0.0687 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0404
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0689 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0402
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0684 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0408
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0689 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0402
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0048 - root_mean_squared_error: 0.0684 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0434
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0697 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0407
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0689 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0420
# Epoch 20/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0685 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0403
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0682 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0407
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0047 - root_mean_squared_error: 0.0685 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0410
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0051 - root_mean_squared_error: 0.0706 - val_loss: 0.0018 - val_root_mean_squared_error: 0.0413
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0048 - root_mean_squared_error: 0.0686 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0409
# Epoch 25/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0048 - root_mean_squared_error: 0.0687 - val_loss: 0.0017 - val_root_mean_squared_error: 0.0408

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = lstm_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0022 - root_mean_squared_error: 0.0464
# Test Loss: 0.0022252879571169615
# Test RMSE: 0.046380892395973206

# %%
# คำนวณ predicted residuals
yhat_train_resid = lstm_model.predict(train_X_resid)
yhat_val_resid = lstm_model.predict(val_X_resid)
yhat_test_resid = lstm_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-22 22:54:05.309997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:54:05.312035: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:54:05.313434: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step
# 1/6 [====>.........................] - ETA: 0s
# 2024-12-22 22:54:05.760658: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-22 22:54:05.762681: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-22 22:54:05.763975: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 1.9916%
# RMSE: 0.8015
