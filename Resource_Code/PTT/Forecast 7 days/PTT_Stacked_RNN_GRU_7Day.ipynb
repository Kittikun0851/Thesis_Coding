# %% [markdown]
# ## Library

# %%
# !pip install tensorflow==2.12.0

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# Out:
# 2024-12-14 16:31:31.066815: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-14 16:31:31.074317: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-14 16:31:31.124840: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-14 16:31:31.125830: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-14 16:31:59.422066: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('PTT.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close  Close   High   Low   Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  38.007935  49.50  49.50  49.0  49.50  52067800
# 2019-07-02 00:00:00+00:00  37.240093  48.50  49.50  48.5  49.25  51490800
# 2019-07-03 00:00:00+00:00  37.048138  48.25  48.50  48.0  48.50  44524800
# 2019-07-04 00:00:00+00:00  37.048138  48.25  48.75  48.0  48.50  49509400
# 2019-07-05 00:00:00+00:00  37.048138  48.25  48.50  48.0  48.25  20907100

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('PTT Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         1.000000    1.000000   1.000000    1.000000      0.080878
# 16         0.955564    1.000000   0.980315    0.990119      0.079982
# 17         0.944456    0.957447   0.960630    0.960474      0.069161
# 18         0.944456    0.968085   0.960630    0.960474      0.076904
# 19         0.944456    0.957447   0.960630    0.950593      0.032475
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.955564    1.000000   0.980315    0.990119      0.079982  ...
# 16         0.944456    0.957447   0.960630    0.960474      0.069161  ...
# 17         0.944456    0.968085   0.960630    0.960474      0.076904  ...
# 18         0.944456    0.957447   0.960630    0.950593      0.032475  ...
# 19         0.944456    0.946809   0.960630    0.940711      0.019224  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.940945  0.940711   0.032713        0.922238        0.922238
# 16  0.931102  0.930830   0.053481        0.922238        0.900020
# 17  0.940945  0.930830   0.031202        0.900020        0.900020
# 18  0.921260  0.920949   0.064817        0.900020        0.900020
# 19  0.921260  0.911067   0.036953        0.900020        0.900020
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.900020        0.900020        0.900020        0.900020
# 16        0.900020        0.900020        0.900020        0.844476
# 17        0.900020        0.900020        0.844476        0.833367
# 18        0.900020        0.844476        0.833367        0.822259
# 19        0.844476        0.833367        0.822259        0.800041
#
#     Adj Close(t+7)
# 15        0.844476
# 16        0.833367
# 17        0.822259
# 18        0.800041
# 19        0.766714
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Create Model & Evaluate (ยังไม่ Hyperparameter tuning)

# %%
model = Sequential()

# SimpleRNN layer with ReLU activation
model.add(SimpleRNN(units=94,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.005)))
model.add(Dropout(0.1))
# GRU layer with ReLU activation
model.add(GRU(units=73,activation='relu'))
model.add(Dropout(0.1))
# Output layer for 1 targets
model.add(Dense(1,activation='sigmoid'))
# model.add(Dense(1))
# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Compile the model
# model.compile(optimizer='adam', loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])

# %%
# # ทำ prediction
# yhat = model.predict(test_X)
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# # rescale ข้อมูลกลับ

# # Standardized -> actual
# # inv_yhat = (yhat * std_dict['Adj Close']) + mean_dict['Adj Close']
# # inv_y = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# # # Min-Max Normalized -> actual
# inv_yhat = yhat*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']
# inv_y = test_y*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']

# %%
# ทำ prediction
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('XPG_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')

# %% [markdown]
# ## Hyperparameter Tuning

# %%
def create_model(rnn_units,gru_units,LR,L2,beta_1):
    model = Sequential()
    model.add(SimpleRNN(rnn_units,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(GRU(gru_units,activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune
param_dist = {
    'gru_units': list(range(1, 101)),
    'rnn_units': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)

import time

start_time = time.time()


# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
random_search_result = random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_1888664/4200879527.py:22: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-14 17:10:25.064439: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.065021: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.070493: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.072812: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.073316: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.073590: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.073988: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.082378: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.111825: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.138800: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.138852: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.139021: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.139563: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.157395: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.157975: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.175437: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.187682: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.188043: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.196640: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.197948: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.232650: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.236221: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.245299: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.254561: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.264201: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.274816: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.275189: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.279766: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.279905: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.292562: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.292595: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:10:25.303356: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 17:29:54.024222: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 17:29:54.026317: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 17:29:54.027553: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 17:29:55.412177: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 17:29:55.414536: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 17:29:55.416447: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 17:29:56.390082: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 17:29:56.392527: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 17:29:56.394439: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 17:29:58.377610: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 17:29:58.379903: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 17:29:58.381629: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 2678.6567857265472 seconds

# %%
# Get the best parameters and the best score
best_params = random_search_result.best_params_
best_score = -random_search_result.best_score_

# %%
print("Best Parameters:", best_params)
print("Best RMSE Score:", best_score)
# Out:
# Best Parameters: {'rnn_units': 55, 'gru_units': 47, 'beta_1': 0.9, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.06917785048656717

# %% [markdown]
# ## After Hyperparameter Tuning

# %%
rnn_gru_model = create_model(rnn_units=55, gru_units=47,beta_1=0.9,LR=0.003,L2=0.001)
rnn_gru_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 1, 55)             7480
#
#  dropout_6 (Dropout)         (None, 1, 55)             0
#
#  gru_3 (GRU)                 (None, 47)                14664
#
#  dropout_7 (Dropout)         (None, 47)                0
#
#  dense_3 (Dense)             (None, 7)                 336
#
# =================================================================
# Total params: 22,480
# Trainable params: 22,480
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-14 18:38:46.191156: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 18:38:46.192846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 18:38:46.193985: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
rnn_gru_history = rnn_gru_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-14 18:38:50.252359: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 18:38:50.254348: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 18:38:50.255849: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 18:38:51.432554: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 18:38:51.434688: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 18:38:51.436218: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 35s - loss: 0.5566 - root_mean_squared_error: 0.7013
# 2024-12-14 18:38:53.410563: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 18:38:53.412944: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 18:38:53.414737: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 4s 74ms/step - loss: 0.1605 - root_mean_squared_error: 0.3104 - val_loss: 0.0723 - val_root_mean_squared_error: 0.0990
# Epoch 2/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0919 - root_mean_squared_error: 0.1775 - val_loss: 0.0640 - val_root_mean_squared_error: 0.0790
# Epoch 3/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0783 - root_mean_squared_error: 0.1512 - val_loss: 0.0566 - val_root_mean_squared_error: 0.0622
# Epoch 4/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0697 - root_mean_squared_error: 0.1389 - val_loss: 0.0516 - val_root_mean_squared_error: 0.0618
# Epoch 5/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0611 - root_mean_squared_error: 0.1242 - val_loss: 0.0496 - val_root_mean_squared_error: 0.0796
# Epoch 6/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0559 - root_mean_squared_error: 0.1205 - val_loss: 0.0425 - val_root_mean_squared_error: 0.0566
# Epoch 7/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0520 - root_mean_squared_error: 0.1196 - val_loss: 0.0421 - val_root_mean_squared_error: 0.0797
# Epoch 8/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0470 - root_mean_squared_error: 0.1125 - val_loss: 0.0360 - val_root_mean_squared_error: 0.0581
# Epoch 9/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0432 - root_mean_squared_error: 0.1089 - val_loss: 0.0349 - val_root_mean_squared_error: 0.0717
# Epoch 10/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0402 - root_mean_squared_error: 0.1075 - val_loss: 0.0307 - val_root_mean_squared_error: 0.0589
# Epoch 11/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0373 - root_mean_squared_error: 0.1057 - val_loss: 0.0276 - val_root_mean_squared_error: 0.0522
# Epoch 12/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0345 - root_mean_squared_error: 0.1027 - val_loss: 0.0269 - val_root_mean_squared_error: 0.0642
# Epoch 13/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0322 - root_mean_squared_error: 0.1014 - val_loss: 0.0236 - val_root_mean_squared_error: 0.0515
# Epoch 14/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0300 - root_mean_squared_error: 0.0992 - val_loss: 0.0211 - val_root_mean_squared_error: 0.0434
# Epoch 15/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0274 - root_mean_squared_error: 0.0942 - val_loss: 0.0196 - val_root_mean_squared_error: 0.0445
# Epoch 16/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0255 - root_mean_squared_error: 0.0921 - val_loss: 0.0188 - val_root_mean_squared_error: 0.0508
# Epoch 17/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0239 - root_mean_squared_error: 0.0910 - val_loss: 0.0169 - val_root_mean_squared_error: 0.0454
# Epoch 18/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0242 - root_mean_squared_error: 0.0995 - val_loss: 0.0155 - val_root_mean_squared_error: 0.0421
# Epoch 19/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0226 - root_mean_squared_error: 0.0970 - val_loss: 0.0154 - val_root_mean_squared_error: 0.0529
# Epoch 20/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0215 - root_mean_squared_error: 0.0966 - val_loss: 0.0134 - val_root_mean_squared_error: 0.0418
# Epoch 21/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0196 - root_mean_squared_error: 0.0913 - val_loss: 0.0126 - val_root_mean_squared_error: 0.0425
# Epoch 22/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0183 - root_mean_squared_error: 0.0888 - val_loss: 0.0123 - val_root_mean_squared_error: 0.0471
# Epoch 23/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0181 - root_mean_squared_error: 0.0917 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0417
# Epoch 24/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0172 - root_mean_squared_error: 0.0903 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0404
# Epoch 25/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0163 - root_mean_squared_error: 0.0892 - val_loss: 0.0118 - val_root_mean_squared_error: 0.0614
# Epoch 26/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0164 - root_mean_squared_error: 0.0928 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0438
# Epoch 27/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0151 - root_mean_squared_error: 0.0888 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0417
# Epoch 28/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0158 - root_mean_squared_error: 0.0951 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0569
# Epoch 29/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0163 - root_mean_squared_error: 0.0997 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0554
# Epoch 30/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0155 - root_mean_squared_error: 0.0977 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0501
# Epoch 31/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0154 - root_mean_squared_error: 0.0989 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0634
# Epoch 32/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0135 - root_mean_squared_error: 0.0903 - val_loss: 0.0076 - val_root_mean_squared_error: 0.0499
# Epoch 33/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0128 - root_mean_squared_error: 0.0882 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0496
# Epoch 34/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0130 - root_mean_squared_error: 0.0909 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0415
# Epoch 35/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0123 - root_mean_squared_error: 0.0887 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0425
# Epoch 36/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0117 - root_mean_squared_error: 0.0868 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0473
# Epoch 37/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0131 - root_mean_squared_error: 0.0953 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0483
# Epoch 38/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0122 - root_mean_squared_error: 0.0916 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0411
# Epoch 39/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0111 - root_mean_squared_error: 0.0868 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0436
# Epoch 40/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0101 - root_mean_squared_error: 0.0821 - val_loss: 0.0052 - val_root_mean_squared_error: 0.0440
# Epoch 41/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0102 - root_mean_squared_error: 0.0836 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0408
# Epoch 42/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0102 - root_mean_squared_error: 0.0845 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0453
# Epoch 43/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0105 - root_mean_squared_error: 0.0873 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0403
# Epoch 44/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0096 - root_mean_squared_error: 0.0827 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0403
# Epoch 45/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0105 - root_mean_squared_error: 0.0890 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0668
# Epoch 46/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0108 - root_mean_squared_error: 0.0911 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0492
# Epoch 47/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0118 - root_mean_squared_error: 0.0974 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0560
# Epoch 48/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0094 - root_mean_squared_error: 0.0844 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0415
# Epoch 49/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0095 - root_mean_squared_error: 0.0856 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0407
# Epoch 50/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0087 - root_mean_squared_error: 0.0816 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0410
# Epoch 51/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0089 - root_mean_squared_error: 0.0828 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0496
# Epoch 52/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0088 - root_mean_squared_error: 0.0831 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0404
# Epoch 53/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0102 - root_mean_squared_error: 0.0917 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0522
# Epoch 54/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0141 - root_mean_squared_error: 0.1112 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0445
# Epoch 55/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0108 - root_mean_squared_error: 0.0951 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0537
# Epoch 56/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0096 - root_mean_squared_error: 0.0886 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0422
# Epoch 57/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0088 - root_mean_squared_error: 0.0845 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0416
# Epoch 58/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0084 - root_mean_squared_error: 0.0825 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0413
# Epoch 59/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0084 - root_mean_squared_error: 0.0828 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0417
# Epoch 60/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0082 - root_mean_squared_error: 0.0821 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0400
# Epoch 61/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0074 - root_mean_squared_error: 0.0776 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0406
# Epoch 62/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0076 - root_mean_squared_error: 0.0790 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0546
# Epoch 63/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0075 - root_mean_squared_error: 0.0786 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0414
# Epoch 64/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0085 - root_mean_squared_error: 0.0848 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0411
# Epoch 65/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0072 - root_mean_squared_error: 0.0773 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0397
# Epoch 66/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0080 - root_mean_squared_error: 0.0828 - val_loss: 0.0040 - val_root_mean_squared_error: 0.0532
# Epoch 67/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0087 - root_mean_squared_error: 0.0869 - val_loss: 0.0046 - val_root_mean_squared_error: 0.0586
# Epoch 68/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0082 - root_mean_squared_error: 0.0840 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0487
# Epoch 69/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0078 - root_mean_squared_error: 0.0819 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0401
# Epoch 70/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0073 - root_mean_squared_error: 0.0792 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0477
# Epoch 71/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0078 - root_mean_squared_error: 0.0825 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0405
# Epoch 72/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0072 - root_mean_squared_error: 0.0784 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0399
# Epoch 73/150
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0072 - root_mean_squared_error: 0.0790 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0473
# Epoch 74/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0075 - root_mean_squared_error: 0.0808 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0479
# Epoch 75/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0073 - root_mean_squared_error: 0.0800 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0413
# Epoch 76/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0070 - root_mean_squared_error: 0.0780 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0397
# Epoch 77/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0066 - root_mean_squared_error: 0.0759 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0402
# Epoch 78/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0071 - root_mean_squared_error: 0.0790 - val_loss: 0.0025 - val_root_mean_squared_error: 0.0410
# Epoch 79/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0071 - root_mean_squared_error: 0.0788 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0396
# Epoch 80/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0069 - root_mean_squared_error: 0.0777 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0443
# Epoch 81/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0073 - root_mean_squared_error: 0.0808 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0465
# Epoch 82/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0068 - root_mean_squared_error: 0.0773 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0499
# Epoch 83/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0064 - root_mean_squared_error: 0.0752 - val_loss: 0.0026 - val_root_mean_squared_error: 0.0433
# Epoch 84/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0070 - root_mean_squared_error: 0.0790 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0409

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(rnn_gru_history.history['loss'], label='train_loss')
plt.plot(rnn_gru_history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_gru_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0025 - root_mean_squared_error: 0.0403
# Test Loss: 0.00245747365988791
# Test RMSE: 0.04034016653895378

# %%
# ทำ prediction
yhat_train = rnn_gru_model.predict(train_X)
yhat_val = rnn_gru_model.predict(val_X)
yhat_test = rnn_gru_model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
# Out:
# 2024-12-14 18:39:20.420724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 18:39:20.422692: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 18:39:20.424276: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 1ms/step
# 1/6 [====>.........................] - ETA: 3s
# 2024-12-14 18:39:21.501889: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 18:39:21.503786: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 18:39:21.505135: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 1s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('PTT_Adj_close_prediction By stacked LSTM-GRU')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 1.7172%
# RMSE: 0.6971
