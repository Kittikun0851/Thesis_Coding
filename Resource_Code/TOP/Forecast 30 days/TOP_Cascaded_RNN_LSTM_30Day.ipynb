# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-24 12:03:02.996621: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-24 12:03:03.008466: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-24 12:03:03.065763: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-24 12:03:03.068134: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-24 12:03:54.153996: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('TOP.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Date
# 2019-07-01 00:00:00+00:00  53.684330  68.170570  68.668167  67.175385
# 2019-07-02 00:00:00+00:00  53.292477  67.672981  68.419373  67.175385
# 2019-07-03 00:00:00+00:00  51.920975  65.931396  67.175385  65.682594
# 2019-07-04 00:00:00+00:00  51.137257  64.936203  67.175385  64.687408
# 2019-07-05 00:00:00+00:00  52.116901  66.180191  66.677788  65.184998
#
# Price                           Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  67.175385  19107189
# 2019-07-02 00:00:00+00:00  68.170570  13898439
# 2019-07-03 00:00:00+00:00  67.175385  18479168
# 2019-07-04 00:00:00+00:00  66.180191  13314028
# 2019-07-05 00:00:00+00:00  65.433800   9670506

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('TOP Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 31,feat_name=df.columns)
# แก้ไขจากการ drop คอลัมน์ตั้งแต่ t ถึง t-6 เป็น t ถึง t-29
reframed.drop(['High(t+1)', 'High(t+2)', 'High(t+3)', 'High(t+4)', 'High(t+5)', 'High(t+6)', 'High(t+7)', \
               'High(t+8)', 'High(t+9)', 'High(t+10)', 'High(t+11)', 'High(t+12)', 'High(t+13)', 'High(t+14)', \
               'High(t+15)', 'High(t+16)', 'High(t+17)', 'High(t+18)', 'High(t+19)', 'High(t+20)', 'High(t+21)', \
               'High(t+22)', 'High(t+23)', 'High(t+24)', 'High(t+25)', 'High(t+26)', 'High(t+27)', 'High(t+28)', 'High(t+29)','High(t+30)',\
               'Low(t+1)', 'Low(t+2)', 'Low(t+3)', 'Low(t+4)', 'Low(t+5)', 'Low(t+6)', 'Low(t+7)', \
               'Low(t+8)', 'Low(t+9)', 'Low(t+10)', 'Low(t+11)', 'Low(t+12)', 'Low(t+13)', 'Low(t+14)', \
               'Low(t+15)', 'Low(t+16)', 'Low(t+17)', 'Low(t+18)', 'Low(t+19)', 'Low(t+20)', 'Low(t+21)', \
               'Low(t+22)', 'Low(t+23)', 'Low(t+24)', 'Low(t+25)', 'Low(t+26)', 'Low(t+27)', 'Low(t+28)', 'Low(t+29)','Low(t+30)',\
               'Open(t+1)', 'Open(t+2)', 'Open(t+3)', 'Open(t+4)', 'Open(t+5)', 'Open(t+6)', 'Open(t+7)', 
               'Open(t+8)', 'Open(t+9)', 'Open(t+10)', 'Open(t+11)', 'Open(t+12)', 'Open(t+13)', 'Open(t+14)', \
               'Open(t+15)', 'Open(t+16)', 'Open(t+17)', 'Open(t+18)', 'Open(t+19)', 'Open(t+20)', 'Open(t+21)', \
               'Open(t+22)', 'Open(t+23)', 'Open(t+24)', 'Open(t+25)', 'Open(t+26)', 'Open(t+27)', 'Open(t+28)', 'Open(t+29)','Open(t+30)',\
               'Volume(t+1)', 'Volume(t+2)', 'Volume(t+3)', 'Volume(t+4)', 'Volume(t+5)', 'Volume(t+6)', 'Volume(t+7)', \
               'Volume(t+8)', 'Volume(t+9)', 'Volume(t+10)', 'Volume(t+11)', 'Volume(t+12)', 'Volume(t+13)', 'Volume(t+14)', \
               'Volume(t+15)', 'Volume(t+16)', 'Volume(t+17)', 'Volume(t+18)', 'Volume(t+19)', 'Volume(t+20)', 'Volume(t+21)', \
               'Volume(t+22)', 'Volume(t+23)', 'Volume(t+24)', 'Volume(t+25)', 'Volume(t+26)', 'Volume(t+27)', 'Volume(t+28)', 'Volume(t+29)','Volume(t+30)'], axis=1, inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.877558    0.901099   0.913514    0.881081      0.225678
# 16         0.866806    0.895604   0.913514    0.902703      0.164157
# 17         0.829171    0.868132   0.881081    0.881081      0.218260
# 18         0.807666    0.868132   0.859460    0.859459      0.157254
# 19         0.834548    0.857143   0.870270    0.843243      0.114220
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.866806    0.895604   0.913514    0.902703      0.164157  ...
# 16         0.829171    0.868132   0.881081    0.881081      0.218260  ...
# 17         0.807666    0.868132   0.859460    0.859459      0.157254  ...
# 18         0.834548    0.857143   0.870270    0.843243      0.114220  ...
# 19         0.829171    0.846154   0.870270    0.854054      0.112278  ...
#
#     Adj Close(t+21)  Adj Close(t+22)  Adj Close(t+23)  Adj Close(t+24)  \
# 15         0.813042         0.748526         0.716268         0.743150
# 16         0.748526         0.716268         0.743150         0.866806
# 17         0.716268         0.743150         0.866806         0.861429
# 18         0.743150         0.866806         0.861429         0.839924
# 19         0.866806         0.861429         0.839924         0.834548
#
#     Adj Close(t+25)  Adj Close(t+26)  Adj Close(t+27)  Adj Close(t+28)  \
# 15         0.866806         0.861429         0.839924         0.834548
# 16         0.861429         0.839924         0.834548         0.872182
# 17         0.839924         0.834548         0.872182         0.904440
# 18         0.834548         0.872182         0.904440         0.888311
# 19         0.872182         0.904440         0.888311         0.882935
#
#     Adj Close(t+29)  Adj Close(t+30)
# 15         0.872182         0.904440
# 16         0.904440         0.888311
# 17         0.888311         0.882935
# 18         0.882935         0.904440
# 19         0.904440         0.931322
#
# [5 rows x 110 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-30], train[:, -30:]
val_X, val_y = val[:, :-30], val[:, -30:]
test_X, test_y = test[:, :-30], test[:, -30:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (816, 1, 80)
# (816, 30)
# (175, 1, 80)
# (175, 30)
# (175, 1, 80)
# (175, 30)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_rnn_model(rnn_units_1,LR,L2,beta_1):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_325331/1606349923.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-24 12:39:48.408141: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.469502: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.511662: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.522508: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.531285: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.701149: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.701236: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.730076: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.776607: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.805825: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.838112: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.871627: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.959638: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:48.988533: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.096059: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.128350: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.166209: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.166241: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.207215: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.371708: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.426850: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.436332: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.523257: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.579128: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.582131: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.591893: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.592287: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.706880: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.788308: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.914437: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:49.927211: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:39:50.103498: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 3570.4278733730316 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 17, 'beta_1': 0.8, 'LR': 0.004, 'L2': 0.001}
# Best RMSE Score: 0.11886752708428239

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
rnn_model = create_rnn_model(rnn_units_1=17,beta_1=0.8 , LR=0.004, L2=0.001)
rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 17)                1666
#
#  dropout_1 (Dropout)         (None, 17)                0
#
#  dense_1 (Dense)             (None, 30)                540
#
# =================================================================
# Total params: 2,206
# Trainable params: 2,206
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 2s 46ms/step - loss: 0.2966 - root_mean_squared_error: 0.5183 - val_loss: 0.1142 - val_root_mean_squared_error: 0.2945
# Epoch 2/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0964 - root_mean_squared_error: 0.2635 - val_loss: 0.0536 - val_root_mean_squared_error: 0.1655
# Epoch 3/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0672 - root_mean_squared_error: 0.2040 - val_loss: 0.0440 - val_root_mean_squared_error: 0.1385
# Epoch 4/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0613 - root_mean_squared_error: 0.1928 - val_loss: 0.0417 - val_root_mean_squared_error: 0.1354
# Epoch 5/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0549 - root_mean_squared_error: 0.1791 - val_loss: 0.0377 - val_root_mean_squared_error: 0.1248
# Epoch 6/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0517 - root_mean_squared_error: 0.1738 - val_loss: 0.0390 - val_root_mean_squared_error: 0.1349
# Epoch 7/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0495 - root_mean_squared_error: 0.1706 - val_loss: 0.0337 - val_root_mean_squared_error: 0.1183
# Epoch 8/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0458 - root_mean_squared_error: 0.1628 - val_loss: 0.0320 - val_root_mean_squared_error: 0.1155
# Epoch 9/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0430 - root_mean_squared_error: 0.1574 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1060
# Epoch 10/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0401 - root_mean_squared_error: 0.1510 - val_loss: 0.0336 - val_root_mean_squared_error: 0.1297
# Epoch 11/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0398 - root_mean_squared_error: 0.1531 - val_loss: 0.0299 - val_root_mean_squared_error: 0.1183
# Epoch 12/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0381 - root_mean_squared_error: 0.1503 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1044
# Epoch 13/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0360 - root_mean_squared_error: 0.1461 - val_loss: 0.0291 - val_root_mean_squared_error: 0.1218
# Epoch 14/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0358 - root_mean_squared_error: 0.1480 - val_loss: 0.0213 - val_root_mean_squared_error: 0.0880
# Epoch 15/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0336 - root_mean_squared_error: 0.1428 - val_loss: 0.0198 - val_root_mean_squared_error: 0.0833
# Epoch 16/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0337 - root_mean_squared_error: 0.1451 - val_loss: 0.0260 - val_root_mean_squared_error: 0.1173
# Epoch 17/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0318 - root_mean_squared_error: 0.1408 - val_loss: 0.0208 - val_root_mean_squared_error: 0.0956
# Epoch 18/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0311 - root_mean_squared_error: 0.1401 - val_loss: 0.0174 - val_root_mean_squared_error: 0.0789
# Epoch 19/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0315 - root_mean_squared_error: 0.1434 - val_loss: 0.0170 - val_root_mean_squared_error: 0.0797
# Epoch 20/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0291 - root_mean_squared_error: 0.1365 - val_loss: 0.0187 - val_root_mean_squared_error: 0.0920
# Epoch 21/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0290 - root_mean_squared_error: 0.1379 - val_loss: 0.0222 - val_root_mean_squared_error: 0.1116
# Epoch 22/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0276 - root_mean_squared_error: 0.1344 - val_loss: 0.0152 - val_root_mean_squared_error: 0.0767
# Epoch 23/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0270 - root_mean_squared_error: 0.1334 - val_loss: 0.0178 - val_root_mean_squared_error: 0.0939
# Epoch 24/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0273 - root_mean_squared_error: 0.1362 - val_loss: 0.0145 - val_root_mean_squared_error: 0.0770
# Epoch 25/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0264 - root_mean_squared_error: 0.1341 - val_loss: 0.0139 - val_root_mean_squared_error: 0.0757
# Epoch 26/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0253 - root_mean_squared_error: 0.1314 - val_loss: 0.0137 - val_root_mean_squared_error: 0.0763
# Epoch 27/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0249 - root_mean_squared_error: 0.1311 - val_loss: 0.0133 - val_root_mean_squared_error: 0.0762
# Epoch 28/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0246 - root_mean_squared_error: 0.1313 - val_loss: 0.0136 - val_root_mean_squared_error: 0.0800
# Epoch 29/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0243 - root_mean_squared_error: 0.1312 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0788
# Epoch 30/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0232 - root_mean_squared_error: 0.1281 - val_loss: 0.0122 - val_root_mean_squared_error: 0.0746
# Epoch 31/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0251 - root_mean_squared_error: 0.1363 - val_loss: 0.0144 - val_root_mean_squared_error: 0.0895
# Epoch 32/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0240 - root_mean_squared_error: 0.1330 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0739
# Epoch 33/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0235 - root_mean_squared_error: 0.1323 - val_loss: 0.0116 - val_root_mean_squared_error: 0.0752
# Epoch 34/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0226 - root_mean_squared_error: 0.1296 - val_loss: 0.0113 - val_root_mean_squared_error: 0.0752
# Epoch 35/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0216 - root_mean_squared_error: 0.1265 - val_loss: 0.0133 - val_root_mean_squared_error: 0.0883
# Epoch 36/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0214 - root_mean_squared_error: 0.1265 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0758
# Epoch 37/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0211 - root_mean_squared_error: 0.1263 - val_loss: 0.0142 - val_root_mean_squared_error: 0.0954
# Epoch 38/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0219 - root_mean_squared_error: 0.1300 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0748
# Epoch 39/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0209 - root_mean_squared_error: 0.1270 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0798
# Epoch 40/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0207 - root_mean_squared_error: 0.1267 - val_loss: 0.0115 - val_root_mean_squared_error: 0.0837
# Epoch 41/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0218 - root_mean_squared_error: 0.1317 - val_loss: 0.0242 - val_root_mean_squared_error: 0.1408
# Epoch 42/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0217 - root_mean_squared_error: 0.1321 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0741
# Epoch 43/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0230 - root_mean_squared_error: 0.1375 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0878
# Epoch 44/150
# 13/13 [==============================] - 0s 11ms/step - loss: 0.0232 - root_mean_squared_error: 0.1386 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0738
# Epoch 45/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0203 - root_mean_squared_error: 0.1283 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0820
# Epoch 46/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0210 - root_mean_squared_error: 0.1312 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0804
# Epoch 47/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0191 - root_mean_squared_error: 0.1244 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0777
# Epoch 48/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0186 - root_mean_squared_error: 0.1228 - val_loss: 0.0103 - val_root_mean_squared_error: 0.0824
# Epoch 49/150
# 13/13 [==============================] - 0s 10ms/step - loss: 0.0183 - root_mean_squared_error: 0.1219 - val_loss: 0.0104 - val_root_mean_squared_error: 0.0840

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0109 - root_mean_squared_error: 0.0836
# Test Loss: 0.010917550884187222
# Test RMSE: 0.08359488844871521

# %%
# คำนวณ predicted values
yhat_train = rnn_model.predict(train_X)
yhat_val = rnn_model.predict(val_X)
yhat_test = rnn_model.predict(test_X)
# Out:
# 26/26 [==============================] - 1s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (816, 1, 80)
# (816, 30)
# (175, 1, 80)
# (175, 30)
# (175, 1, 80)
# (175, 30)

# %%
def create_lstm_model(lstm_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_325331/1996924287.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-24 14:26:30.467120: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.467503: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.497868: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.536363: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.536538: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.578796: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.607974: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.607968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.616534: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.634602: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.634859: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.644588: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.661575: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.661621: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.674741: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.684611: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.703975: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.764625: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.764943: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.784364: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.796250: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.836232: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.836982: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.860944: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.878371: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.910183: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.916624: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.939624: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:30.939742: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:31.010885: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:31.204620: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:26:31.320698: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:49:27.350833: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 14:49:27.353059: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 14:49:27.354373: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 14:49:27.720780: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 14:49:27.723292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 14:49:27.725118: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 14:49:28.482316: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 14:49:28.484339: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 14:49:28.485853: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 14:49:29.812887: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 14:49:29.816314: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 14:49:29.818028: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 3006.0627884864807 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 28, 'beta_1': 0.9, 'LR': 0.076, 'L2': 0.05}
# Best RMSE Score: 0.10519025417466003

# %%
lstm_model = create_lstm_model(lstm_units_1=28 ,beta_1=0.9 , LR=0.076, L2=0.05)
lstm_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_2 (LSTM)               (None, 28)                12208
#
#  dropout_4 (Dropout)         (None, 28)                0
#
#  dense_4 (Dense)             (None, 30)                870
#
# =================================================================
# Total params: 13,078
# Trainable params: 13,078
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-24 15:01:52.701628: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:01:52.703427: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:01:52.704706: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = lstm_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-24 15:01:54.649537: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:01:54.651538: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:01:54.653015: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 15:01:55.373766: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:01:55.375774: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:01:55.377321: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 41ms/step - loss: 1.1147 - root_mean_squared_error: 0.1377 - val_loss: 0.4761 - val_root_mean_squared_error: 0.0775
# Epoch 2/150
#  1/13 [=>............................] - ETA: 0s - loss: 0.4876 - root_mean_squared_error: 0.1322
# 2024-12-24 15:01:56.655857: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:01:56.657767: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:01:56.659206: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 0s 5ms/step - loss: 0.2273 - root_mean_squared_error: 0.1161 - val_loss: 0.0830 - val_root_mean_squared_error: 0.0745
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0690 - root_mean_squared_error: 0.1150 - val_loss: 0.0343 - val_root_mean_squared_error: 0.0780
# Epoch 4/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0285 - root_mean_squared_error: 0.1143 - val_loss: 0.0133 - val_root_mean_squared_error: 0.0747
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0173 - root_mean_squared_error: 0.1134 - val_loss: 0.0078 - val_root_mean_squared_error: 0.0756
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0142 - root_mean_squared_error: 0.1133 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0759
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0137 - root_mean_squared_error: 0.1142 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0744
# Epoch 8/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0135 - root_mean_squared_error: 0.1142 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0760
# Epoch 9/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0132 - root_mean_squared_error: 0.1131 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0742
# Epoch 10/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0130 - root_mean_squared_error: 0.1132 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0739
# Epoch 11/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0128 - root_mean_squared_error: 0.1127 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0736
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0128 - root_mean_squared_error: 0.1128 - val_loss: 0.0055 - val_root_mean_squared_error: 0.0738
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0130 - root_mean_squared_error: 0.1134 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0762
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0133 - root_mean_squared_error: 0.1135 - val_loss: 0.0058 - val_root_mean_squared_error: 0.0744
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0129 - root_mean_squared_error: 0.1127 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0777
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0134 - root_mean_squared_error: 0.1148 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0739
# Epoch 17/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0132 - root_mean_squared_error: 0.1133 - val_loss: 0.0063 - val_root_mean_squared_error: 0.0777

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = lstm_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0074 - root_mean_squared_error: 0.0859
# Test Loss: 0.007434130180627108
# Test RMSE: 0.08593212068080902

# %%
# คำนวณ predicted residuals
yhat_train_resid = lstm_model.predict(train_X_resid)
yhat_val_resid = lstm_model.predict(val_X_resid)
yhat_test_resid = lstm_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-24 15:02:02.825741: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:02:02.828027: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:02:02.829453: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 4.7210%
# RMSE: 3.1316
