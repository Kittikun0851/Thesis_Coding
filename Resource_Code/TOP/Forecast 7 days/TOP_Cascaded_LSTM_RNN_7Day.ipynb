# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-24 12:02:51.794430: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-24 12:02:51.807229: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-24 12:02:51.872675: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-24 12:02:51.874448: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-24 12:03:42.612984: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('TOP.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Date
# 2019-07-01 00:00:00+00:00  53.684334  68.170570  68.668167  67.175385
# 2019-07-02 00:00:00+00:00  53.292473  67.672981  68.419373  67.175385
# 2019-07-03 00:00:00+00:00  51.920971  65.931396  67.175385  65.682594
# 2019-07-04 00:00:00+00:00  51.137257  64.936203  67.175385  64.687408
# 2019-07-05 00:00:00+00:00  52.116894  66.180191  66.677788  65.184998
#
# Price                           Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  67.175385  19107189
# 2019-07-02 00:00:00+00:00  68.170570  13898439
# 2019-07-03 00:00:00+00:00  67.175385  18479168
# 2019-07-04 00:00:00+00:00  66.180191  13314028
# 2019-07-05 00:00:00+00:00  65.433800   9670506

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('TOP Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.877558    0.901099   0.913514    0.881081      0.225678
# 16         0.866806    0.895604   0.913514    0.902703      0.164157
# 17         0.829171    0.868132   0.881081    0.881081      0.218260
# 18         0.807666    0.868132   0.859460    0.859459      0.157254
# 19         0.834547    0.857143   0.870270    0.843243      0.114220
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.866806    0.895604   0.913514    0.902703      0.164157  ...
# 16         0.829171    0.868132   0.881081    0.881081      0.218260  ...
# 17         0.807666    0.868132   0.859460    0.859459      0.157254  ...
# 18         0.834547    0.857143   0.870270    0.843243      0.114220  ...
# 19         0.829171    0.846154   0.870270    0.854054      0.112278  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.972973  0.962162   0.071283        0.931321        0.904440
# 16  0.972973  0.962162   0.092897        0.904440        0.899063
# 17  0.951351  0.945946   0.121590        0.899063        0.882935
# 18  0.945946  0.929730   0.043613        0.882935        0.888310
# 19  0.924324  0.913513   0.091801        0.888310        0.882935
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.899063        0.882935        0.888310        0.882935
# 16        0.882935        0.888310        0.882935        0.845300
# 17        0.888310        0.882935        0.845300        0.823795
# 18        0.882935        0.845300        0.823795        0.818419
# 19        0.845300        0.823795        0.818419        0.775408
#
#     Adj Close(t+7)
# 15        0.845300
# 16        0.823795
# 17        0.818419
# 18        0.775408
# 19        0.737774
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_lstm_model(lstm_units_1, beta_1 ,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_325326/3692575797.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-24 12:37:51.907559: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:51.937049: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.048953: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.076033: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.163851: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.165770: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.252159: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.297830: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.336925: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.374181: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.443500: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.686915: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.696053: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.704829: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.721854: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.825345: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.835448: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.885911: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:52.905764: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.139788: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.165812: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.232017: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.232206: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.268736: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.326831: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.512858: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.531556: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.610905: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.672007: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.788484: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:53.847631: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:54.018846: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 13:09:39.172356: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:09:39.212079: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:09:39.213467: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 13:09:46.246804: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:09:46.281771: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:09:46.292906: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 13:09:52.237358: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:09:52.239482: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:09:52.241187: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 13:10:00.611320: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:10:00.629426: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:10:00.636838: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 3529.2098400592804 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 70, 'beta_1': 0.8, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.07074568885243808

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
lstm_model = create_lstm_model(lstm_units_1=70 ,beta_1=0.8, LR=0.003, L2=0.001)
lstm_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 70)                42280
#
#  dropout_1 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 7)                 497
#
# =================================================================
# Total params: 42,777
# Trainable params: 42,777
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-24 13:50:15.169874: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:50:15.171705: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:50:15.172920: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history = lstm_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-24 13:50:19.575222: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:50:19.577247: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:50:19.578730: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 13:50:20.299179: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:50:20.301282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:50:20.302846: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 22s - loss: 0.4620 - root_mean_squared_error: 0.5820
# 2024-12-24 13:50:21.522017: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:50:21.524041: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:50:21.525508: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 50ms/step - loss: 0.1823 - root_mean_squared_error: 0.2758 - val_loss: 0.1016 - val_root_mean_squared_error: 0.1232
# Epoch 2/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0899 - root_mean_squared_error: 0.1306 - val_loss: 0.0674 - val_root_mean_squared_error: 0.0894
# Epoch 3/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0647 - root_mean_squared_error: 0.1173 - val_loss: 0.0531 - val_root_mean_squared_error: 0.1028
# Epoch 4/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0496 - root_mean_squared_error: 0.1108 - val_loss: 0.0446 - val_root_mean_squared_error: 0.1124
# Epoch 5/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0400 - root_mean_squared_error: 0.1069 - val_loss: 0.0340 - val_root_mean_squared_error: 0.0947
# Epoch 6/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0328 - root_mean_squared_error: 0.1015 - val_loss: 0.0267 - val_root_mean_squared_error: 0.0817
# Epoch 7/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0288 - root_mean_squared_error: 0.1031 - val_loss: 0.0268 - val_root_mean_squared_error: 0.1029
# Epoch 8/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0245 - root_mean_squared_error: 0.0976 - val_loss: 0.0212 - val_root_mean_squared_error: 0.0877
# Epoch 9/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0213 - root_mean_squared_error: 0.0941 - val_loss: 0.0179 - val_root_mean_squared_error: 0.0811
# Epoch 10/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0189 - root_mean_squared_error: 0.0919 - val_loss: 0.0174 - val_root_mean_squared_error: 0.0886
# Epoch 11/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0168 - root_mean_squared_error: 0.0893 - val_loss: 0.0127 - val_root_mean_squared_error: 0.0668
# Epoch 12/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0154 - root_mean_squared_error: 0.0885 - val_loss: 0.0112 - val_root_mean_squared_error: 0.0641
# Epoch 13/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0141 - root_mean_squared_error: 0.0867 - val_loss: 0.0110 - val_root_mean_squared_error: 0.0700
# Epoch 14/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0131 - root_mean_squared_error: 0.0860 - val_loss: 0.0106 - val_root_mean_squared_error: 0.0720
# Epoch 15/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0124 - root_mean_squared_error: 0.0856 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0785
# Epoch 16/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0119 - root_mean_squared_error: 0.0864 - val_loss: 0.0128 - val_root_mean_squared_error: 0.0930
# Epoch 17/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0108 - root_mean_squared_error: 0.0820 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0733
# Epoch 18/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0100 - root_mean_squared_error: 0.0799 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0784
# Epoch 19/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0099 - root_mean_squared_error: 0.0813 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0767
# Epoch 20/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0098 - root_mean_squared_error: 0.0825 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0713
# Epoch 21/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0096 - root_mean_squared_error: 0.0826 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0493
# Epoch 22/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0089 - root_mean_squared_error: 0.0796 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0712
# Epoch 23/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0081 - root_mean_squared_error: 0.0757 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0679
# Epoch 24/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0083 - root_mean_squared_error: 0.0781 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0483
# Epoch 25/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0090 - root_mean_squared_error: 0.0829 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0454
# Epoch 26/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0776 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0715
# Epoch 27/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0087 - root_mean_squared_error: 0.0823 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0454
# Epoch 28/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0093 - root_mean_squared_error: 0.0864 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0887
# Epoch 29/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0080 - root_mean_squared_error: 0.0790 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0461
# Epoch 30/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0072 - root_mean_squared_error: 0.0743 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0625
# Epoch 31/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0073 - root_mean_squared_error: 0.0752 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0519
# Epoch 32/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0090 - root_mean_squared_error: 0.0862 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0969
# Epoch 33/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0088 - root_mean_squared_error: 0.0849 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0599
# Epoch 34/150
# 13/13 [==============================] - 0s 6ms/step - loss: 0.0073 - root_mean_squared_error: 0.0760 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0569

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = lstm_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0062 - root_mean_squared_error: 0.0668
# Test Loss: 0.006189900916069746
# Test RMSE: 0.06676890701055527

# %%
# คำนวณ predicted values
yhat_train = lstm_model.predict(train_X)
yhat_val = lstm_model.predict(val_X)
yhat_test = lstm_model.predict(test_X)
# Out:
# 26/26 [==============================] - 1s 1ms/step
# 2024-12-24 13:50:27.514724: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:50:27.517360: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:50:27.518864: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 2024-12-24 13:50:28.101095: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 13:50:28.103073: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 13:50:28.104341: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
# เตรียมข้อมูล train สำหรับ residual GRU
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_rnn_model(rnn_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_325326/1532983884.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-24 14:10:07.400522: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.400749: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.419777: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.419956: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.427901: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.436257: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.437941: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.443148: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.478531: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.478748: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.478835: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.486618: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.489764: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.496007: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.498999: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.532636: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.549769: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.550582: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.559213: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.560283: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.566488: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.579641: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.587535: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.587587: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.587629: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.596058: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.616968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.625821: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.634029: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.640744: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.671013: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:10:07.692353: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 2969.2505424022675 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 91, 'beta_1': 0.9, 'LR': 0.013000000000000001, 'L2': 0.001}
# Best RMSE Score: 0.05921514925095456

# %%
rnn_model = create_rnn_model(rnn_units_1=91 ,beta_1=0.9 , LR=0.013, L2=0.001)
rnn_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 91)                15652
#
#  dropout_3 (Dropout)         (None, 91)                0
#
#  dense_3 (Dense)             (None, 7)                 644
#
# =================================================================
# Total params: 16,296
# Trainable params: 16,296
# Non-trainable params: 0
# _________________________________________________________________

# %%
history_resid = rnn_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 1s 21ms/step - loss: 0.6798 - root_mean_squared_error: 0.7713 - val_loss: 0.1971 - val_root_mean_squared_error: 0.3352
# Epoch 2/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.2164 - root_mean_squared_error: 0.3646 - val_loss: 0.1345 - val_root_mean_squared_error: 0.2306
# Epoch 3/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1581 - root_mean_squared_error: 0.2817 - val_loss: 0.0889 - val_root_mean_squared_error: 0.1149
# Epoch 4/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1223 - root_mean_squared_error: 0.2219 - val_loss: 0.0784 - val_root_mean_squared_error: 0.0922
# Epoch 5/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.1000 - root_mean_squared_error: 0.1808 - val_loss: 0.0684 - val_root_mean_squared_error: 0.0635
# Epoch 6/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0849 - root_mean_squared_error: 0.1517 - val_loss: 0.0625 - val_root_mean_squared_error: 0.0590
# Epoch 7/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0752 - root_mean_squared_error: 0.1359 - val_loss: 0.0577 - val_root_mean_squared_error: 0.0590
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0667 - root_mean_squared_error: 0.1210 - val_loss: 0.0534 - val_root_mean_squared_error: 0.0613
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0606 - root_mean_squared_error: 0.1135 - val_loss: 0.0486 - val_root_mean_squared_error: 0.0559
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0541 - root_mean_squared_error: 0.1022 - val_loss: 0.0447 - val_root_mean_squared_error: 0.0553
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0484 - root_mean_squared_error: 0.0918 - val_loss: 0.0416 - val_root_mean_squared_error: 0.0595
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0434 - root_mean_squared_error: 0.0824 - val_loss: 0.0376 - val_root_mean_squared_error: 0.0519
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0409 - root_mean_squared_error: 0.0859 - val_loss: 0.0347 - val_root_mean_squared_error: 0.0524
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0369 - root_mean_squared_error: 0.0787 - val_loss: 0.0317 - val_root_mean_squared_error: 0.0499
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0337 - root_mean_squared_error: 0.0748 - val_loss: 0.0294 - val_root_mean_squared_error: 0.0513
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0307 - root_mean_squared_error: 0.0707 - val_loss: 0.0273 - val_root_mean_squared_error: 0.0529
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0279 - root_mean_squared_error: 0.0665 - val_loss: 0.0247 - val_root_mean_squared_error: 0.0476
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0264 - root_mean_squared_error: 0.0700 - val_loss: 0.0232 - val_root_mean_squared_error: 0.0518
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0239 - root_mean_squared_error: 0.0653 - val_loss: 0.0213 - val_root_mean_squared_error: 0.0510
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.0652 - val_loss: 0.0193 - val_root_mean_squared_error: 0.0475
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0209 - root_mean_squared_error: 0.0675 - val_loss: 0.0183 - val_root_mean_squared_error: 0.0524
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0210 - root_mean_squared_error: 0.0775 - val_loss: 0.0248 - val_root_mean_squared_error: 0.1025
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0233 - root_mean_squared_error: 0.0980 - val_loss: 0.0318 - val_root_mean_squared_error: 0.1370
# Epoch 24/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0213 - root_mean_squared_error: 0.0940 - val_loss: 0.0148 - val_root_mean_squared_error: 0.0534
# Epoch 25/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0159 - root_mean_squared_error: 0.0671 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0473
# Epoch 26/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0141 - root_mean_squared_error: 0.0603 - val_loss: 0.0120 - val_root_mean_squared_error: 0.0451
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0132 - root_mean_squared_error: 0.0608 - val_loss: 0.0111 - val_root_mean_squared_error: 0.0455
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0126 - root_mean_squared_error: 0.0624 - val_loss: 0.0117 - val_root_mean_squared_error: 0.0584
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0121 - root_mean_squared_error: 0.0649 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0510
# Epoch 30/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0113 - root_mean_squared_error: 0.0636 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0602
# Epoch 31/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0120 - root_mean_squared_error: 0.0732 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0560
# Epoch 32/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0102 - root_mean_squared_error: 0.0649 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0666
# Epoch 33/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0103 - root_mean_squared_error: 0.0693 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0597
# Epoch 34/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0093 - root_mean_squared_error: 0.0653 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0468
# Epoch 35/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0088 - root_mean_squared_error: 0.0654 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0584
# Epoch 36/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0084 - root_mean_squared_error: 0.0649 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0476
# Epoch 37/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0078 - root_mean_squared_error: 0.0631 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0498
# Epoch 38/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0077 - root_mean_squared_error: 0.0655 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0530
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0074 - root_mean_squared_error: 0.0655 - val_loss: 0.0065 - val_root_mean_squared_error: 0.0592
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0070 - root_mean_squared_error: 0.0640 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0459
# Epoch 41/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0065 - root_mean_squared_error: 0.0622 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0425
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0061 - root_mean_squared_error: 0.0614 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0525
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0060 - root_mean_squared_error: 0.0622 - val_loss: 0.0043 - val_root_mean_squared_error: 0.0476
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0065 - root_mean_squared_error: 0.0673 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0565
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0058 - root_mean_squared_error: 0.0636 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0521
# Epoch 46/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0056 - root_mean_squared_error: 0.0626 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0465
# Epoch 47/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0626 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0456
# Epoch 48/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0620 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0448
# Epoch 49/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0627 - val_loss: 0.0036 - val_root_mean_squared_error: 0.0494
# Epoch 50/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0622 - val_loss: 0.0032 - val_root_mean_squared_error: 0.0454
# Epoch 51/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0052 - root_mean_squared_error: 0.0642 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0482
# Epoch 52/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0630 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0439
# Epoch 53/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0670 - val_loss: 0.0035 - val_root_mean_squared_error: 0.0511
# Epoch 54/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0643 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0549
# Epoch 55/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0050 - root_mean_squared_error: 0.0654 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0459
# Epoch 56/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0684 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0587
# Epoch 57/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0055 - root_mean_squared_error: 0.0700 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0484
# Epoch 58/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0049 - root_mean_squared_error: 0.0655 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0535
# Epoch 59/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0051 - root_mean_squared_error: 0.0673 - val_loss: 0.0029 - val_root_mean_squared_error: 0.0481
# Epoch 60/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0054 - root_mean_squared_error: 0.0701 - val_loss: 0.0028 - val_root_mean_squared_error: 0.0482

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0025 - root_mean_squared_error: 0.0426
# Test Loss: 0.0025354602839797735
# Test RMSE: 0.042615603655576706

# %%
# คำนวณ predicted residuals
yhat_train_resid = rnn_model.predict(train_X_resid)
yhat_val_resid = rnn_model.predict(val_X_resid)
yhat_test_resid = rnn_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 2.4676%
# RMSE: 1.5530
