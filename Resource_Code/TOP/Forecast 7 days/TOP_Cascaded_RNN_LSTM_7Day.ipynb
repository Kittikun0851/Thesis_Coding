# %% [markdown]
# ## Library

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import time
# Out:
# 2024-12-24 12:02:49.328877: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-24 12:02:49.343303: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-24 12:02:49.420857: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-24 12:02:49.423039: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-24 12:03:40.942502: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('TOP.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Date
# 2019-07-01 00:00:00+00:00  53.684330  68.170570  68.668167  67.175385
# 2019-07-02 00:00:00+00:00  53.292473  67.672981  68.419373  67.175385
# 2019-07-03 00:00:00+00:00  51.920967  65.931396  67.175385  65.682594
# 2019-07-04 00:00:00+00:00  51.137260  64.936203  67.175385  64.687408
# 2019-07-05 00:00:00+00:00  52.116898  66.180191  66.677788  65.184998
#
# Price                           Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  67.175385  19107189
# 2019-07-02 00:00:00+00:00  68.170570  13898439
# 2019-07-03 00:00:00+00:00  67.175385  18479168
# 2019-07-04 00:00:00+00:00  66.180191  13314028
# 2019-07-05 00:00:00+00:00  65.433800   9670506

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('TOP Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.877558    0.901099   0.913514    0.881081      0.225678
# 16         0.866806    0.895604   0.913514    0.902703      0.164157
# 17         0.829171    0.868132   0.881081    0.881081      0.218260
# 18         0.807666    0.868132   0.859460    0.859459      0.157254
# 19         0.834547    0.857143   0.870270    0.843243      0.114220
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.866806    0.895604   0.913514    0.902703      0.164157  ...
# 16         0.829171    0.868132   0.881081    0.881081      0.218260  ...
# 17         0.807666    0.868132   0.859460    0.859459      0.157254  ...
# 18         0.834547    0.857143   0.870270    0.843243      0.114220  ...
# 19         0.829171    0.846154   0.870270    0.854054      0.112278  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.972973  0.962162   0.071283        0.931321        0.904440
# 16  0.972973  0.962162   0.092897        0.904440        0.899063
# 17  0.951351  0.945946   0.121590        0.899063        0.882935
# 18  0.945946  0.929730   0.043613        0.882935        0.888311
# 19  0.924324  0.913513   0.091801        0.888311        0.882935
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.899063        0.882935        0.888311        0.882935
# 16        0.882935        0.888311        0.882935        0.845300
# 17        0.888311        0.882935        0.845300        0.823795
# 18        0.882935        0.845300        0.823795        0.818419
# 19        0.845300        0.823795        0.818419        0.775408
#
#     Adj Close(t+7)
# 15        0.845300
# 16        0.823795
# 17        0.818419
# 18        0.775408
# 19        0.737774
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Value)

# %%
def create_rnn_model(rnn_units_1,LR,L2,beta_1):
    model = Sequential()
    model.add(SimpleRNN(rnn_units_1,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune lstm
param_dist_rnn = {
    'rnn_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

# Define the RandomizedSearchCV object
rnn_random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist_rnn,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
rnn_random_search_result = rnn_random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_325315/3334002836.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   rnn_model = KerasRegressor(build_fn=create_rnn_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-24 12:37:18.626890: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.627002: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.627123: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.680763: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.690921: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.691511: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.699380: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.708606: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.719923: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.741532: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.741853: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.750419: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.750987: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.769847: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.779445: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.779610: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.780491: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.802073: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.802197: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.824579: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.824852: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.834038: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.834134: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.851762: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.861843: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.865821: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.885356: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.900824: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.902998: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.903342: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.903746: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 12:37:18.912901: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Execution time: 3473.3496775627136 seconds

# %%
# Get the best parameters and the best score
rnn_best_params = rnn_random_search_result.best_params_
rnn_best_score = -rnn_random_search_result.best_score_

# %%
print("Best Parameters:", rnn_best_params)
print("Best RMSE Score:", rnn_best_score)
# Out:
# Best Parameters: {'rnn_units_1': 70, 'beta_1': 0.8, 'LR': 0.003, 'L2': 0.001}
# Best RMSE Score: 0.06351140588171977

# %% [markdown]
# ## Hyperparameter Tuning (Predicted Residual)

# %%
rnn_model = create_rnn_model(rnn_units_1=70, LR=0.008, L2=0.001, beta_1=0.8)
rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_1 (SimpleRNN)    (None, 70)                10570
#
#  dropout_1 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 7)                 497
#
# =================================================================
# Total params: 11,067
# Trainable params: 11,067
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 13/13 [==============================] - 1s 20ms/step - loss: 0.3319 - root_mean_squared_error: 0.5088 - val_loss: 0.0950 - val_root_mean_squared_error: 0.1534
# Epoch 2/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.1275 - root_mean_squared_error: 0.2407 - val_loss: 0.0917 - val_root_mean_squared_error: 0.1558
# Epoch 3/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0938 - root_mean_squared_error: 0.1683 - val_loss: 0.0832 - val_root_mean_squared_error: 0.1411
# Epoch 4/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0810 - root_mean_squared_error: 0.1401 - val_loss: 0.0725 - val_root_mean_squared_error: 0.1154
# Epoch 5/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0706 - root_mean_squared_error: 0.1146 - val_loss: 0.0718 - val_root_mean_squared_error: 0.1280
# Epoch 6/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0656 - root_mean_squared_error: 0.1092 - val_loss: 0.0591 - val_root_mean_squared_error: 0.0858
# Epoch 7/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0626 - root_mean_squared_error: 0.1120 - val_loss: 0.0566 - val_root_mean_squared_error: 0.0913
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0582 - root_mean_squared_error: 0.1070 - val_loss: 0.0488 - val_root_mean_squared_error: 0.0620
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0635 - root_mean_squared_error: 0.1409 - val_loss: 0.0590 - val_root_mean_squared_error: 0.1302
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0542 - root_mean_squared_error: 0.1156 - val_loss: 0.0485 - val_root_mean_squared_error: 0.0958
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0498 - root_mean_squared_error: 0.1078 - val_loss: 0.0433 - val_root_mean_squared_error: 0.0806
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0469 - root_mean_squared_error: 0.1056 - val_loss: 0.0424 - val_root_mean_squared_error: 0.0894
# Epoch 13/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0452 - root_mean_squared_error: 0.1085 - val_loss: 0.0358 - val_root_mean_squared_error: 0.0598
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0409 - root_mean_squared_error: 0.0983 - val_loss: 0.0396 - val_root_mean_squared_error: 0.0972
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0396 - root_mean_squared_error: 0.1018 - val_loss: 0.0308 - val_root_mean_squared_error: 0.0513
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0433 - root_mean_squared_error: 0.1261 - val_loss: 0.0426 - val_root_mean_squared_error: 0.1272
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0384 - root_mean_squared_error: 0.1130 - val_loss: 0.0321 - val_root_mean_squared_error: 0.0859
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0346 - root_mean_squared_error: 0.1028 - val_loss: 0.0277 - val_root_mean_squared_error: 0.0674
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0317 - root_mean_squared_error: 0.0957 - val_loss: 0.0238 - val_root_mean_squared_error: 0.0457
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0295 - root_mean_squared_error: 0.0915 - val_loss: 0.0243 - val_root_mean_squared_error: 0.0629
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0282 - root_mean_squared_error: 0.0919 - val_loss: 0.0217 - val_root_mean_squared_error: 0.0516
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0265 - root_mean_squared_error: 0.0899 - val_loss: 0.0208 - val_root_mean_squared_error: 0.0551
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0280 - root_mean_squared_error: 0.1035 - val_loss: 0.0205 - val_root_mean_squared_error: 0.0616
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0240 - root_mean_squared_error: 0.0886 - val_loss: 0.0243 - val_root_mean_squared_error: 0.0932
# Epoch 25/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0233 - root_mean_squared_error: 0.0903 - val_loss: 0.0174 - val_root_mean_squared_error: 0.0529
# Epoch 26/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0222 - root_mean_squared_error: 0.0898 - val_loss: 0.0258 - val_root_mean_squared_error: 0.1102
# Epoch 27/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0243 - root_mean_squared_error: 0.1051 - val_loss: 0.0157 - val_root_mean_squared_error: 0.0544
# Epoch 28/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0214 - root_mean_squared_error: 0.0949 - val_loss: 0.0142 - val_root_mean_squared_error: 0.0473
# Epoch 29/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0190 - root_mean_squared_error: 0.0861 - val_loss: 0.0155 - val_root_mean_squared_error: 0.0655
# Epoch 30/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0183 - root_mean_squared_error: 0.0866 - val_loss: 0.0131 - val_root_mean_squared_error: 0.0515
# Epoch 31/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0185 - root_mean_squared_error: 0.0912 - val_loss: 0.0119 - val_root_mean_squared_error: 0.0457
# Epoch 32/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0181 - root_mean_squared_error: 0.0928 - val_loss: 0.0144 - val_root_mean_squared_error: 0.0725
# Epoch 33/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0165 - root_mean_squared_error: 0.0874 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0488
# Epoch 34/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0155 - root_mean_squared_error: 0.0847 - val_loss: 0.0102 - val_root_mean_squared_error: 0.0471
# Epoch 35/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0139 - root_mean_squared_error: 0.0786 - val_loss: 0.0109 - val_root_mean_squared_error: 0.0589
# Epoch 36/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0148 - root_mean_squared_error: 0.0868 - val_loss: 0.0217 - val_root_mean_squared_error: 0.1210
# Epoch 37/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0203 - root_mean_squared_error: 0.1164 - val_loss: 0.0087 - val_root_mean_squared_error: 0.0462
# Epoch 38/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0140 - root_mean_squared_error: 0.0874 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0592
# Epoch 39/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0137 - root_mean_squared_error: 0.0879 - val_loss: 0.0086 - val_root_mean_squared_error: 0.0530
# Epoch 40/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0126 - root_mean_squared_error: 0.0834 - val_loss: 0.0079 - val_root_mean_squared_error: 0.0494
# Epoch 41/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0113 - root_mean_squared_error: 0.0780 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0700
# Epoch 42/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0109 - root_mean_squared_error: 0.0773 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0578
# Epoch 43/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0115 - root_mean_squared_error: 0.0832 - val_loss: 0.0085 - val_root_mean_squared_error: 0.0638
# Epoch 44/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0106 - root_mean_squared_error: 0.0794 - val_loss: 0.0067 - val_root_mean_squared_error: 0.0500
# Epoch 45/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0097 - root_mean_squared_error: 0.0752 - val_loss: 0.0066 - val_root_mean_squared_error: 0.0522
# Epoch 46/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0115 - root_mean_squared_error: 0.0877 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0620
# Epoch 47/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0151 - root_mean_squared_error: 0.1072 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1233
# Epoch 48/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0153 - root_mean_squared_error: 0.1090 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0537
# Epoch 49/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0096 - root_mean_squared_error: 0.0800 - val_loss: 0.0062 - val_root_mean_squared_error: 0.0550
# Epoch 50/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0089 - root_mean_squared_error: 0.0764 - val_loss: 0.0056 - val_root_mean_squared_error: 0.0510
# Epoch 51/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0093 - root_mean_squared_error: 0.0798 - val_loss: 0.0051 - val_root_mean_squared_error: 0.0483
# Epoch 52/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0092 - root_mean_squared_error: 0.0808 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0430
# Epoch 53/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0097 - root_mean_squared_error: 0.0847 - val_loss: 0.0070 - val_root_mean_squared_error: 0.0673
# Epoch 54/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0083 - root_mean_squared_error: 0.0766 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0480
# Epoch 55/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0086 - root_mean_squared_error: 0.0794 - val_loss: 0.0047 - val_root_mean_squared_error: 0.0497
# Epoch 56/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0076 - root_mean_squared_error: 0.0736 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0601
# Epoch 57/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0104 - root_mean_squared_error: 0.0916 - val_loss: 0.0166 - val_root_mean_squared_error: 0.1208

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0049 - root_mean_squared_error: 0.0475
# Test Loss: 0.004887661896646023
# Test RMSE: 0.047506000846624374

# %%
# คำนวณ predicted values
yhat_train = rnn_model.predict(train_X)
yhat_val = rnn_model.predict(val_X)
yhat_test = rnn_model.predict(test_X)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step
# 6/6 [==============================] - 0s 1ms/step

# %%
# คำนวณ residuals
resid_train = train_y - yhat_train
resid_val = val_y - yhat_val
resid_test = test_y - yhat_test

# %%
train_X_resid = train_X.copy()
train_y_resid = resid_train.copy()
val_X_resid = val_X.copy()
val_y_resid = resid_val.copy()
test_X_resid = test_X.copy()
test_y_resid = resid_test.copy()

# %%
print(train_X_resid.shape)
print(train_y_resid.shape)
print(val_X_resid.shape)
print(val_y_resid.shape)
print(test_X_resid.shape)
print(test_y_resid.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %%
def create_lstm_model(lstm_units_1, beta_1,LR,L2):
    model = Sequential()
    model.add(LSTM(lstm_units_1,activation='tanh', input_shape=(train_X_resid.shape[1], train_X_resid.shape[2]), return_sequences=False, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune gru
param_dist_lstm = {
    'lstm_units_1': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)

start_time = time.time()

lstm_random_search = RandomizedSearchCV(estimator=lstm_model, param_distributions=param_dist_lstm,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
lstm_random_search_result = lstm_random_search.fit(train_X_resid, train_y_resid, validation_data=(val_X_resid, val_y_resid), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# /tmp/ipykernel_325315/1670406022.py:19: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   lstm_model = KerasRegressor(build_fn=create_lstm_model, epochs=100, batch_size=64, verbose=0)
# 2024-12-24 14:06:25.582654: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.591553: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.591592: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.599378: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.599892: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.601121: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.602094: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.632366: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.632544: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.632619: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.632923: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.642662: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.643608: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.694590: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.695134: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.704191: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.705108: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.713015: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.723258: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.734758: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.740129: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.753355: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.763872: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.786671: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.795780: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.808374: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.808610: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.809968: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.837654: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.837822: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.846011: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:06:25.855142: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-24 14:36:39.598148: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 14:36:39.600682: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 14:36:39.601990: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 14:36:40.271815: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 14:36:40.274185: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 14:36:40.276011: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 14:36:41.410067: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 14:36:41.412383: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 14:36:41.413974: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 14:36:43.259452: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 14:36:43.261702: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 14:36:43.263429: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 2805.826057434082 seconds

# %%
# Get the best parameters and the best score
lstm_best_params = lstm_random_search_result.best_params_
lstm_best_score = -lstm_random_search_result.best_score_

# %%
print("Best Parameters:", lstm_best_params)
print("Best RMSE Score:", lstm_best_score)
# Out:
# Best Parameters: {'lstm_units_1': 17, 'beta_1': 0.8, 'LR': 0.004, 'L2': 0.001}
# Best RMSE Score: 0.057073237404315746

# %%
lstm_model = create_lstm_model(lstm_units_1=17 ,beta_1=0.8 , LR=0.004, L2=0.001)
lstm_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 17)                6664
#
#  dropout_3 (Dropout)         (None, 17)                0
#
#  dense_3 (Dense)             (None, 7)                 126
#
# =================================================================
# Total params: 6,790
# Trainable params: 6,790
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-24 15:06:46.909316: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:06:46.911924: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:06:46.913299: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
history_resid = lstm_model.fit(train_X_resid, train_y_resid, epochs=150, batch_size=64, validation_data=(val_X_resid, val_y_resid),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-24 15:06:48.730103: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:06:48.732514: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:06:48.734045: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-24 15:06:49.350098: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:06:49.352171: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:06:49.353648: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 19s - loss: 0.0977 - root_mean_squared_error: 0.1576
# 2024-12-24 15:06:50.432398: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:06:50.434570: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:06:50.436105: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 2s 45ms/step - loss: 0.0665 - root_mean_squared_error: 0.0840 - val_loss: 0.0465 - val_root_mean_squared_error: 0.0474
# Epoch 2/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0380 - root_mean_squared_error: 0.0616 - val_loss: 0.0264 - val_root_mean_squared_error: 0.0441
# Epoch 3/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0225 - root_mean_squared_error: 0.0596 - val_loss: 0.0156 - val_root_mean_squared_error: 0.0439
# Epoch 4/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0143 - root_mean_squared_error: 0.0600 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0446
# Epoch 5/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0100 - root_mean_squared_error: 0.0600 - val_loss: 0.0069 - val_root_mean_squared_error: 0.0442
# Epoch 6/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0075 - root_mean_squared_error: 0.0588 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0427
# Epoch 7/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0061 - root_mean_squared_error: 0.0590 - val_loss: 0.0042 - val_root_mean_squared_error: 0.0453
# Epoch 8/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0053 - root_mean_squared_error: 0.0590 - val_loss: 0.0033 - val_root_mean_squared_error: 0.0429
# Epoch 9/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0048 - root_mean_squared_error: 0.0595 - val_loss: 0.0030 - val_root_mean_squared_error: 0.0443
# Epoch 10/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0045 - root_mean_squared_error: 0.0599 - val_loss: 0.0027 - val_root_mean_squared_error: 0.0447
# Epoch 11/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0041 - root_mean_squared_error: 0.0592 - val_loss: 0.0024 - val_root_mean_squared_error: 0.0432
# Epoch 12/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0039 - root_mean_squared_error: 0.0591 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0430
# Epoch 13/150
# 13/13 [==============================] - 0s 5ms/step - loss: 0.0038 - root_mean_squared_error: 0.0589 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0426
# Epoch 14/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0038 - root_mean_squared_error: 0.0596 - val_loss: 0.0023 - val_root_mean_squared_error: 0.0459
# Epoch 15/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0037 - root_mean_squared_error: 0.0591 - val_loss: 0.0022 - val_root_mean_squared_error: 0.0450
# Epoch 16/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0037 - root_mean_squared_error: 0.0593 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0434
# Epoch 17/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0035 - root_mean_squared_error: 0.0586 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0429
# Epoch 18/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0036 - root_mean_squared_error: 0.0590 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0427
# Epoch 19/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0035 - root_mean_squared_error: 0.0588 - val_loss: 0.0019 - val_root_mean_squared_error: 0.0427
# Epoch 20/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0036 - root_mean_squared_error: 0.0590 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0440
# Epoch 21/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0035 - root_mean_squared_error: 0.0589 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0443
# Epoch 22/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0035 - root_mean_squared_error: 0.0586 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0443
# Epoch 23/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0036 - root_mean_squared_error: 0.0595 - val_loss: 0.0021 - val_root_mean_squared_error: 0.0450
# Epoch 24/150
# 13/13 [==============================] - 0s 4ms/step - loss: 0.0035 - root_mean_squared_error: 0.0591 - val_loss: 0.0020 - val_root_mean_squared_error: 0.0438

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history_resid.history['loss'], label='train_loss')
plt.plot(history_resid.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('Training process')
plt.show()

# %%
results = lstm_model.evaluate(test_X_resid, test_y_resid)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0024 - root_mean_squared_error: 0.0484
# Test Loss: 0.002412372035905719
# Test RMSE: 0.04841308295726776

# %%
# คำนวณ predicted residuals
yhat_train_resid = lstm_model.predict(train_X_resid)
yhat_val_resid = lstm_model.predict(val_X_resid)
yhat_test_resid = lstm_model.predict(test_X_resid)
# Out:
# 26/26 [==============================] - 0s 1ms/step
# 2024-12-24 15:06:56.786035: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:06:56.787970: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:06:56.789370: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 2ms/step
# 2024-12-24 15:06:57.213292: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-24 15:06:57.215630: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-24 15:06:57.216997: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 0s 1ms/step

# %%
# Final predicted value = LSTM predicted value + GRU predicted residuals
final_yhat_train = yhat_train + yhat_train_resid
final_yhat_val = yhat_val + yhat_val_resid
final_yhat_test = yhat_test + yhat_test_resid

# %%
# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = final_yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = final_yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = final_yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 2.7433%
# RMSE: 1.7643
