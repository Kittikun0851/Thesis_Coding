# %% [markdown]
# ## Library

# %%
# !pip install tensorflow==2.12.0

# %%
# Data Preprocessing and Preparation
import numpy as np
import pandas as pd
import yfinance as yf
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error


# Model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, SimpleRNN, LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import RandomizedSearchCV
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
# Out:
# 2024-12-14 22:19:47.324280: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-12-14 22:19:47.332527: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-14 22:19:47.386082: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-12-14 22:19:47.387090: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-12-14 22:20:18.555393: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Data preparation

# %%
df = yf.download('TOP.BK', start="2019-07-01", end="2024-06-30")
df.index = pd.to_datetime(df.index)
df.columns = df.columns.droplevel(1)
df.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                      Adj Close      Close       High        Low  \
# Date
# 2019-07-01 00:00:00+00:00  53.684326  68.170570  68.668167  67.175385
# 2019-07-02 00:00:00+00:00  53.292473  67.672981  68.419373  67.175385
# 2019-07-03 00:00:00+00:00  51.920975  65.931396  67.175385  65.682594
# 2019-07-04 00:00:00+00:00  51.137257  64.936203  67.175385  64.687408
# 2019-07-05 00:00:00+00:00  52.116901  66.180191  66.677788  65.184998
#
# Price                           Open    Volume
# Date
# 2019-07-01 00:00:00+00:00  67.175385  19107189
# 2019-07-02 00:00:00+00:00  68.170570  13898439
# 2019-07-03 00:00:00+00:00  67.175385  18479168
# 2019-07-04 00:00:00+00:00  66.180191  13314028
# 2019-07-05 00:00:00+00:00  65.433800   9670506

# %%
import matplotlib.pyplot as plt

# สมมติว่าคุณมี DataFrame ที่ชื่อว่า dataset ที่มีคอลัมน์ 'Adj Close' และ index เป็น datetime
plt.figure(figsize=(10, 6))
plt.plot(df.index, df['Adj Close'], label='Adj Close', color='blue')

# ตั้งชื่อกราฟ
plt.title('TOP Adjusted Close Price')
plt.xlabel('Date')
plt.ylabel('Adjusted Close Price')

# แสดง legend และ plot
plt.legend()
plt.show()

# %%
# function สำหรับ preprocess ข้อมูล time series หลายตัวแปร
def series_to_supervised(data, n_in=1, n_out=1, dropnan=True,feat_name=None):

    n_vars = 1 if type(data) is list else data.shape[1]
    df = pd.DataFrame(data)
    cols, names = list(), list()

    # input sequence (t-n, ... t-1)
    for i in range(n_in, 0, -1):
        cols.append(df.shift(i))
        names += [f'{feat_name[j]}(t-{i})' for j in range(n_vars)]

    # forecast sequence (t, t+1, ... t+n)
    for i in range(0, n_out):
        cols.append(df.shift(-i))
        if i == 0:
            names += [f'{feat_name[j]}(t)' for j in range(n_vars)]
        else:
            names += [f'{feat_name[j]}(t+{i})' for j in range(n_vars)]

    # put it all together
    agg = pd.concat(cols, axis=1)
    agg.columns = names

    # drop rows with NaN values
    if dropnan:
        agg.dropna(inplace=True)
    return agg

# เลือกข้อมูลหุ้นจาก list ของ DataFrame และ drop column 'Close' เนื่องจากเราจะใช้ column 'Adj. Close' เท่านั้น
df = df.drop('Close',axis=1)
dataset = df
values = dataset.values
values = values.astype('float32')


# ทำ scaling ข้อมูลด้วยวิธี min-max normalized scaling เปลี่ยน scale ข้อมูลแต่ละ column และเก็บค่า mean และ sd แต่ละ column ไว้สำหรับทำ rescale ข้อมูลภายหลัง
min_dict = dict()
max_dict = dict()
for col in dataset.columns:
  min_dict[col] = dataset[col].min()
  max_dict[col] = dataset[col].max()
  dataset[col] = (dataset[col] - dataset[col].min())/(dataset[col].max()-dataset[col].min())


# ใช้ function สำหรับ preprocess ข้อมูลที่เขียนไว้ และ drop column ที่ไม่ได้ใช้
reframed = series_to_supervised(dataset.values, 15, 8,feat_name=df.columns)
reframed.drop(['High(t+1)','High(t+2)','High(t+3)','High(t+4)','High(t+5)','High(t+6)','High(t+7)','Low(t+1)','Low(t+2)','Low(t+3)','Low(t+4)','Low(t+5)','Low(t+6)','Low(t+7)',\
               'Open(t+1)','Open(t+2)','Open(t+3)','Open(t+4)','Open(t+5)','Open(t+6)','Open(t+7)','Volume(t+1)','Volume(t+2)','Volume(t+3)','Volume(t+4)','Volume(t+5)',\
               'Volume(t+6)','Volume(t+7)'],axis=1,inplace=True)

# %%
reframed.head()
# Out:
#     Adj Close(t-15)  High(t-15)  Low(t-15)  Open(t-15)  Volume(t-15)  \
# 15         0.877558    0.901099   0.913514    0.881081      0.225678
# 16         0.866806    0.895604   0.913514    0.902703      0.164157
# 17         0.829171    0.868132   0.881081    0.881081      0.218260
# 18         0.807666    0.868132   0.859460    0.859459      0.157254
# 19         0.834548    0.857143   0.870270    0.843243      0.114220
#
#     Adj Close(t-14)  High(t-14)  Low(t-14)  Open(t-14)  Volume(t-14)  ...  \
# 15         0.866806    0.895604   0.913514    0.902703      0.164157  ...
# 16         0.829171    0.868132   0.881081    0.881081      0.218260  ...
# 17         0.807666    0.868132   0.859460    0.859459      0.157254  ...
# 18         0.834548    0.857143   0.870270    0.843243      0.114220  ...
# 19         0.829171    0.846154   0.870270    0.854054      0.112278  ...
#
#       Low(t)   Open(t)  Volume(t)  Adj Close(t+1)  Adj Close(t+2)  \
# 15  0.972973  0.962162   0.071283        0.931322        0.904440
# 16  0.972973  0.962162   0.092897        0.904440        0.899064
# 17  0.951351  0.945946   0.121590        0.899064        0.882934
# 18  0.945946  0.929730   0.043613        0.882934        0.888311
# 19  0.924324  0.913513   0.091801        0.888311        0.882934
#
#     Adj Close(t+3)  Adj Close(t+4)  Adj Close(t+5)  Adj Close(t+6)  \
# 15        0.899064        0.882934        0.888311        0.882934
# 16        0.882934        0.888311        0.882934        0.845300
# 17        0.888311        0.882934        0.845300        0.823795
# 18        0.882934        0.845300        0.823795        0.818418
# 19        0.845300        0.823795        0.818418        0.775408
#
#     Adj Close(t+7)
# 15        0.845300
# 16        0.823795
# 17        0.818418
# 18        0.775408
# 19        0.737774
#
# [5 rows x 87 columns]

# %%
values = reframed.values

# Define the number of days for each set
# ทำ train, val, test split
values = reframed.values
n_train_percent = 0.7
n_val_percent = 0.15
train_split = int(values.shape[0] * n_train_percent)
val_split = int(values.shape[0] * (n_train_percent + n_val_percent))

train = values[:train_split, :]
val = values[train_split:val_split, :]
test = values[val_split:, :]

# เก็บค่า datetime ของ train, val, test
date_reframed = dataset.index[reframed.index]
date_train = date_reframed[:train_split]
date_val = date_reframed[train_split:val_split]
date_test = date_reframed[val_split:]

# split feature และ target
train_X, train_y = train[:, :-7], train[:, -7:]
val_X, val_y = val[:, :-7], val[:, -7:]
test_X, test_y = test[:, :-7], test[:, -7:]

# reshape input ให้เป็น 3D (samples, timesteps, features)
train_X = train_X.reshape((train_X.shape[0], 1, train_X.shape[1]))
val_X = val_X.reshape((val_X.shape[0], 1, val_X.shape[1]))
test_X = test_X.reshape((test_X.shape[0], 1, test_X.shape[1]))

# %%
# X (samples, timesteps, features)
# Y (samples , target)
print(train_X.shape)
print(train_y.shape)
print(val_X.shape)
print(val_y.shape)
print(test_X.shape)
print(test_y.shape)
# Out:
# (832, 1, 80)
# (832, 7)
# (178, 1, 80)
# (178, 7)
# (179, 1, 80)
# (179, 7)

# %% [markdown]
# ## Create Model & Evaluate (ยังไม่ Hyperparameter tuning)

# %%
model = Sequential()

# GRU layer with ReLU activation
model.add(GRU(units=70,activation='relu', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(0.005)))
model.add(Dropout(0.1))
# SimpleRNN layer with ReLU activation
model.add(SimpleRNN(units=70,activation='relu'))
model.add(Dropout(0.1))
# Output layer for 1 targets
model.add(Dense(1,activation='sigmoid'))
# Compile the model with  learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

# Compile the model
# model.compile(optimizer='adam', loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 1, 70)             31920
#
#  dropout_2 (Dropout)         (None, 1, 70)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 70)                9870
#
#  dropout_3 (Dropout)         (None, 70)                0
#
#  dense_1 (Dense)             (None, 1)                 71
#
# =================================================================
# Total params: 41,861
# Trainable params: 41,861
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_X, train_y, epochs=100, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/100
# 2024-12-14 09:08:58.941779: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-12-14 09:08:58.988072: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:134] tfg_optimizer{any(tfg-consolidate-attrs,tfg-toposort,tfg-shape-inference{graph-version=0},tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-12-14 09:08:59.043276: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:134] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-12-14 09:08:59.045384: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:134] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-12-14 09:08:59.048897: W tensorflow/core/common_runtime/optimize_function_graph_utils.cc:475] Ignoring multi-device function optimization failure: INVALID_ARGUMENT: Node 'sequential_1/simple_rnn_1/while/body/_94/sequential_1/simple_rnn_1/while/simple_rnn_cell_1/Relu' does not specify an operation
# 13/13 [==============================] - 3s 57ms/step - loss: 0.5661 - root_mean_squared_error: 0.2110 - val_loss: 0.5896 - val_root_mean_squared_error: 0.3724
# Epoch 2/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.4309 - root_mean_squared_error: 0.1842 - val_loss: 0.4467 - val_root_mean_squared_error: 0.3288
# Epoch 3/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.3241 - root_mean_squared_error: 0.1667 - val_loss: 0.3364 - val_root_mean_squared_error: 0.2922
# Epoch 4/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.2391 - root_mean_squared_error: 0.1430 - val_loss: 0.2524 - val_root_mean_squared_error: 0.2612
# Epoch 5/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1725 - root_mean_squared_error: 0.1121 - val_loss: 0.1768 - val_root_mean_squared_error: 0.2066
# Epoch 6/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.1223 - root_mean_squared_error: 0.0798 - val_loss: 0.1236 - val_root_mean_squared_error: 0.1637
# Epoch 7/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0865 - root_mean_squared_error: 0.0559 - val_loss: 0.0865 - val_root_mean_squared_error: 0.1316
# Epoch 8/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0614 - root_mean_squared_error: 0.0462 - val_loss: 0.0656 - val_root_mean_squared_error: 0.1290
# Epoch 9/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0442 - root_mean_squared_error: 0.0486 - val_loss: 0.0509 - val_root_mean_squared_error: 0.1285
# Epoch 10/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0317 - root_mean_squared_error: 0.0482 - val_loss: 0.0414 - val_root_mean_squared_error: 0.1314
# Epoch 11/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0226 - root_mean_squared_error: 0.0449 - val_loss: 0.0340 - val_root_mean_squared_error: 0.1310
# Epoch 12/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0161 - root_mean_squared_error: 0.0421 - val_loss: 0.0287 - val_root_mean_squared_error: 0.1304
# Epoch 13/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0119 - root_mean_squared_error: 0.0437 - val_loss: 0.0243 - val_root_mean_squared_error: 0.1269
# Epoch 14/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0087 - root_mean_squared_error: 0.0416 - val_loss: 0.0230 - val_root_mean_squared_error: 0.1316
# Epoch 15/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0067 - root_mean_squared_error: 0.0435 - val_loss: 0.0204 - val_root_mean_squared_error: 0.1280
# Epoch 16/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0053 - root_mean_squared_error: 0.0433 - val_loss: 0.0187 - val_root_mean_squared_error: 0.1259
# Epoch 17/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0043 - root_mean_squared_error: 0.0421 - val_loss: 0.0177 - val_root_mean_squared_error: 0.1248
# Epoch 18/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0036 - root_mean_squared_error: 0.0414 - val_loss: 0.0168 - val_root_mean_squared_error: 0.1234
# Epoch 19/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0031 - root_mean_squared_error: 0.0406 - val_loss: 0.0163 - val_root_mean_squared_error: 0.1226
# Epoch 20/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0029 - root_mean_squared_error: 0.0425 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1215
# Epoch 21/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0030 - root_mean_squared_error: 0.0454 - val_loss: 0.0151 - val_root_mean_squared_error: 0.1191
# Epoch 22/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0027 - root_mean_squared_error: 0.0439 - val_loss: 0.0144 - val_root_mean_squared_error: 0.1167
# Epoch 23/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0025 - root_mean_squared_error: 0.0417 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1186
# Epoch 24/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0023 - root_mean_squared_error: 0.0405 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1200
# Epoch 25/100
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0023 - root_mean_squared_error: 0.0405 - val_loss: 0.0159 - val_root_mean_squared_error: 0.1238
# Epoch 26/100
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0024 - root_mean_squared_error: 0.0422 - val_loss: 0.0158 - val_root_mean_squared_error: 0.1235
# Epoch 27/100
# 13/13 [==============================] - 0s 12ms/step - loss: 0.0022 - root_mean_squared_error: 0.0406 - val_loss: 0.0150 - val_root_mean_squared_error: 0.1204

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])

# %%
# # ทำ prediction
# yhat = model.predict(test_X)
# test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# # rescale ข้อมูลกลับ

# # Standardized -> actual
# # inv_yhat = (yhat * std_dict['Adj Close']) + mean_dict['Adj Close']
# # inv_y = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# # # Min-Max Normalized -> actual
# inv_yhat = yhat*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']
# inv_y = test_y*(max_dict['Adj Close']-min_dict['Adj Close'])+min_dict['Adj Close']

# %%
# ทำ prediction
yhat_train = model.predict(train_X)
yhat_val = model.predict(val_X)
yhat_test = model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

# Rescale ข้อมูลกลับ (สำหรับ Standardized)
# inv_yhat_train = (yhat_train * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_yhat_val = (yhat_val * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_yhat_test = (yhat_test * std_dict['Adj Close']) + mean_dict['Adj Close']

# inv_y_train = (train_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_y_val = (val_y * std_dict['Adj Close']) + mean_dict['Adj Close']
# inv_y_test = (test_y * std_dict['Adj Close']) + mean_dict['Adj Close']

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('XPG_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')

# %% [markdown]
# ## Hyperparameter Tuning

# %%
def create_model(rnn_units,lstm_units,LR,L2,beta_1):
    model = Sequential()
    model.add(LSTM(lstm_units,activation='tanh', input_shape=(train_X.shape[1], train_X.shape[2]), return_sequences=True, kernel_regularizer=l2(L2)))
    model.add(Dropout(0.1))
    model.add(SimpleRNN(rnn_units,activation='tanh'))
    model.add(Dropout(0.1))
    model.add(Dense(7))
    optimizer = Adam(learning_rate=LR, beta_1=beta_1, beta_2=0.999)
    model.compile(optimizer=optimizer, loss='mse',metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

# Define the hyperparameters to tune
param_dist = {
    'rnn_units': list(range(1, 101)),
    'lstm_units': list(range(1, 101)),
    'LR': np.linspace(0.001, 0.1, 100).tolist(),
    'L2':[0.001,0.005,0.01,0.05,0.1],
    'beta_1':[0.7,0.8,0.9]
}

# Wrap the model into a KerasRegressor
model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)

import time

start_time = time.time()


# Define the RandomizedSearchCV object
random_search = RandomizedSearchCV(estimator=model, param_distributions=param_dist,
                                    n_iter=100, scoring='neg_root_mean_squared_error',
                                    cv=3, verbose=1, random_state=42, n_jobs=-1)

# Define early stopping callback
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Fit the model using RandomizedSearchCV
random_search_result = random_search.fit(train_X, train_y, validation_data=(val_X, val_y), callbacks=[early_stopping])

end_time = time.time()
execution_time = end_time - start_time
print(f"Execution time: {execution_time} seconds")
# Out:
# /tmp/ipykernel_1579510/371335417.py:22: DeprecationWarning: KerasRegressor is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasRegressor(build_fn=create_model, epochs=100, batch_size=64, verbose=0)
# Fitting 3 folds for each of 100 candidates, totalling 300 fits
# 2024-12-14 22:38:04.634039: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.645376: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.645672: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.658724: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.659000: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.659246: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.659597: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.671144: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.682528: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.683863: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.688413: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.689653: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.693907: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.694139: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.695054: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.695694: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.705807: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.715590: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.720244: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.720280: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.734200: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.743493: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.744299: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.760480: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.767514: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.767908: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.772366: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.772440: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.774107: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.779292: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.791058: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:38:04.793306: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-12-14 22:56:00.546893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:56:00.548883: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:56:00.550167: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 22:56:03.131868: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:56:03.134506: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:56:03.136471: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 22:56:04.296162: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:56:04.298293: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:56:04.299832: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 22:56:07.033228: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:56:07.035552: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:56:07.037532: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# Execution time: 1834.3454163074493 seconds

# %%
# Get the best parameters and the best score
best_params = random_search_result.best_params_
best_score = -random_search_result.best_score_

# %%
print("Best Parameters:", best_params)
print("Best RMSE Score:", best_score)
# Out:
# Best Parameters: {'rnn_units': 56, 'lstm_units': 34, 'beta_1': 0.8, 'LR': 0.004, 'L2': 0.001}
# Best RMSE Score: 0.06414049876983743

# %% [markdown]
# ## After Hyperparametertuning

# %%
lstm_rnn_model = create_model(lstm_units=34,rnn_units=56,beta_1= 0.8,LR=0.004,L2=0.001)
lstm_rnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_1 (LSTM)               (None, 1, 34)             15640
#
#  dropout_2 (Dropout)         (None, 1, 34)             0
#
#  simple_rnn_1 (SimpleRNN)    (None, 56)                5096
#
#  dropout_3 (Dropout)         (None, 56)                0
#
#  dense_1 (Dense)             (None, 7)                 399
#
# =================================================================
# Total params: 21,135
# Trainable params: 21,135
# Non-trainable params: 0
# _________________________________________________________________
# 2024-12-14 22:58:28.133677: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:58:28.135447: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:58:28.136725: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]

# %%
lstm_rnn_history = lstm_rnn_model.fit(train_X, train_y, epochs=150, batch_size=64, validation_data=(val_X, val_y),callbacks=[EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)])
# Out:
# Epoch 1/150
# 2024-12-14 22:58:34.224205: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:58:34.226332: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:58:34.227852: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 2024-12-14 22:58:35.283222: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:58:35.285823: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:58:35.287524: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
#  1/13 [=>............................] - ETA: 32s - loss: 0.5845 - root_mean_squared_error: 0.6959
# 2024-12-14 22:58:37.076302: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:58:37.078186: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:58:37.079565: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 13/13 [==============================] - 4s 66ms/step - loss: 0.1863 - root_mean_squared_error: 0.3157 - val_loss: 0.0941 - val_root_mean_squared_error: 0.1508
# Epoch 2/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0864 - root_mean_squared_error: 0.1586 - val_loss: 0.0635 - val_root_mean_squared_error: 0.1119
# Epoch 3/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0627 - root_mean_squared_error: 0.1346 - val_loss: 0.0459 - val_root_mean_squared_error: 0.0879
# Epoch 4/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0497 - root_mean_squared_error: 0.1254 - val_loss: 0.0392 - val_root_mean_squared_error: 0.0975
# Epoch 5/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0400 - root_mean_squared_error: 0.1151 - val_loss: 0.0370 - val_root_mean_squared_error: 0.1154
# Epoch 6/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0332 - root_mean_squared_error: 0.1080 - val_loss: 0.0287 - val_root_mean_squared_error: 0.0978
# Epoch 7/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0281 - root_mean_squared_error: 0.1027 - val_loss: 0.0194 - val_root_mean_squared_error: 0.0608
# Epoch 8/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0245 - root_mean_squared_error: 0.1003 - val_loss: 0.0226 - val_root_mean_squared_error: 0.0982
# Epoch 9/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0217 - root_mean_squared_error: 0.0983 - val_loss: 0.0132 - val_root_mean_squared_error: 0.0485
# Epoch 10/150
# 13/13 [==============================] - 0s 7ms/step - loss: 0.0215 - root_mean_squared_error: 0.1066 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1207
# Epoch 11/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0200 - root_mean_squared_error: 0.1064 - val_loss: 0.0148 - val_root_mean_squared_error: 0.0822
# Epoch 12/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0163 - root_mean_squared_error: 0.0935 - val_loss: 0.0108 - val_root_mean_squared_error: 0.0621
# Epoch 13/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0162 - root_mean_squared_error: 0.0981 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0458
# Epoch 14/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0141 - root_mean_squared_error: 0.0912 - val_loss: 0.0074 - val_root_mean_squared_error: 0.0452
# Epoch 15/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0128 - root_mean_squared_error: 0.0880 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0692
# Epoch 16/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0130 - root_mean_squared_error: 0.0921 - val_loss: 0.0148 - val_root_mean_squared_error: 0.1031
# Epoch 17/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0138 - root_mean_squared_error: 0.0985 - val_loss: 0.0061 - val_root_mean_squared_error: 0.0469
# Epoch 18/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0116 - root_mean_squared_error: 0.0889 - val_loss: 0.0059 - val_root_mean_squared_error: 0.0483
# Epoch 19/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0112 - root_mean_squared_error: 0.0884 - val_loss: 0.0073 - val_root_mean_squared_error: 0.0643
# Epoch 20/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0104 - root_mean_squared_error: 0.0858 - val_loss: 0.0050 - val_root_mean_squared_error: 0.0449
# Epoch 21/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0122 - root_mean_squared_error: 0.0971 - val_loss: 0.0105 - val_root_mean_squared_error: 0.0882
# Epoch 22/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0108 - root_mean_squared_error: 0.0902 - val_loss: 0.0048 - val_root_mean_squared_error: 0.0475
# Epoch 23/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0108 - root_mean_squared_error: 0.0913 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0446
# Epoch 24/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0090 - root_mean_squared_error: 0.0816 - val_loss: 0.0044 - val_root_mean_squared_error: 0.0467
# Epoch 25/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0088 - root_mean_squared_error: 0.0814 - val_loss: 0.0057 - val_root_mean_squared_error: 0.0603
# Epoch 26/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0087 - root_mean_squared_error: 0.0816 - val_loss: 0.0038 - val_root_mean_squared_error: 0.0434
# Epoch 27/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0093 - root_mean_squared_error: 0.0864 - val_loss: 0.0054 - val_root_mean_squared_error: 0.0604
# Epoch 28/150
# 13/13 [==============================] - 0s 9ms/step - loss: 0.0089 - root_mean_squared_error: 0.0842 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0439
# Epoch 29/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0081 - root_mean_squared_error: 0.0802 - val_loss: 0.0039 - val_root_mean_squared_error: 0.0473
# Epoch 30/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0076 - root_mean_squared_error: 0.0776 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0432
# Epoch 31/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0089 - root_mean_squared_error: 0.0856 - val_loss: 0.0041 - val_root_mean_squared_error: 0.0510
# Epoch 32/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0075 - root_mean_squared_error: 0.0779 - val_loss: 0.0034 - val_root_mean_squared_error: 0.0441
# Epoch 33/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0077 - root_mean_squared_error: 0.0797 - val_loss: 0.0045 - val_root_mean_squared_error: 0.0556
# Epoch 34/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0084 - root_mean_squared_error: 0.0840 - val_loss: 0.0289 - val_root_mean_squared_error: 0.1663
# Epoch 35/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0166 - root_mean_squared_error: 0.1230 - val_loss: 0.0101 - val_root_mean_squared_error: 0.0923
# Epoch 36/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0096 - root_mean_squared_error: 0.0903 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0831
# Epoch 37/150
# 13/13 [==============================] - 0s 8ms/step - loss: 0.0077 - root_mean_squared_error: 0.0797 - val_loss: 0.0037 - val_root_mean_squared_error: 0.0490

# %%
# พล็อตค่า train&test loss
plt.figure(figsize=(12, 4))
plt.plot(lstm_rnn_history.history['loss'], label='train_loss')
plt.plot(lstm_rnn_history.history['val_loss'], label='val_loss')
plt.legend(loc=1)
plt.xlabel('num_epoch')  # ตั้งชื่อแกน X เป็น num_epoch
plt.ylabel('MSE')        # ตั้งชื่อแกน Y เป็น MSE
plt.title('GRU-RNN Training process')
plt.show()

# %%
results = lstm_rnn_model.evaluate(test_X, test_y)
print("Test Loss:", results[0])
print("Test RMSE:", results[1])
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.0034 - root_mean_squared_error: 0.0439
# Test Loss: 0.0033622097689658403
# Test RMSE: 0.043904416263103485

# %%
# ทำ prediction
yhat_train = lstm_rnn_model.predict(train_X)
yhat_val = lstm_rnn_model.predict(val_X)
yhat_test = lstm_rnn_model.predict(test_X)

# Reshape ข้อมูล (ถ้าจำเป็น)
train_X = train_X.reshape((train_X.shape[0], train_X.shape[2]))
val_X = val_X.reshape((val_X.shape[0], val_X.shape[2]))
test_X = test_X.reshape((test_X.shape[0], test_X.shape[2]))

# Rescale ข้อมูลกลับ (ในกรณีใช้ Min-Max Normalization)
inv_yhat_train = yhat_train * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_val = yhat_val * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_yhat_test = yhat_test * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']

inv_y_train = train_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_val = val_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
inv_y_test = test_y * (max_dict['Adj Close'] - min_dict['Adj Close']) + min_dict['Adj Close']
# Out:
# 2024-12-14 22:58:50.553971: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:58:50.555881: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:58:50.557419: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 26/26 [==============================] - 1s 1ms/step
# 2024-12-14 22:58:51.438501: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_2_grad/concat/split_2/split_dim' with dtype int32
# 	 [[{{node gradients/split_2_grad/concat/split_2/split_dim}}]]
# 2024-12-14 22:58:51.440311: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_grad/concat/split/split_dim' with dtype int32
# 	 [[{{node gradients/split_grad/concat/split/split_dim}}]]
# 2024-12-14 22:58:51.441623: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'gradients/split_1_grad/concat/split_1/split_dim' with dtype int32
# 	 [[{{node gradients/split_1_grad/concat/split_1/split_dim}}]]
# 6/6 [==============================] - 1s 2ms/step
# 6/6 [==============================] - 0s 2ms/step

# %%
# Visualizing Results with Month and Year on X-axis
plt.figure(figsize=(16, 5))
plt.plot(date_test, inv_y_test[:, 0], color='black', label='Actual Stock Price')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='Predicted Stock Price')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 3 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=1))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%b-%Y'))

# ตั้งชื่อกราฟ
plt.title('Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Stock Price')
plt.legend()
plt.show()

# %%
# Visualizing Results
plt.figure(figsize=(16, 5))

# Actual prices
plt.plot(date_train, inv_y_train[:, 0], color='black', label='Actual_Adj_Close')
plt.plot(date_val, inv_y_val[:, 0], color='black')
plt.plot(date_test, inv_y_test[:, 0], color='black')

# Predicted prices
plt.plot(date_train, inv_yhat_train[:, 0], color='green', label='predicted_train_set')
plt.plot(date_val, inv_yhat_val[:, 0], color='orange', label='predicted_val_set')
plt.plot(date_test, inv_yhat_test[:, 0], color='red', label='predicted_test_set')

# ตั้งค่าช่วงเวลาบนแกน X ให้แสดงผลทุก 6 เดือน
plt.gca().xaxis.set_major_locator(mdates.MonthLocator(interval=6))
# ตั้งค่าการแสดงผลของแกน X เป็นรูปแบบ 'Jan 2023', 'Feb 2023' เป็นต้น
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))

# ตั้งชื่อกราฟ
plt.title('TOP_Adj_close_prediction')
plt.xlabel('Date (Year-Month)')
plt.ylabel('Adj Close (THB)')
plt.legend()
plt.grid(True)
plt.show()

# %%
# คำนวณ MAPE และ RMSE
mape = mean_absolute_percentage_error(inv_y_test, inv_yhat_test)*100
rmse = np.sqrt(mean_squared_error(inv_y_test, inv_yhat_test))

# แสดงผลลัพธ์
print(f'MAPE: {mape:.4f}%')
print(f'RMSE: {rmse:.4f}')
# Out:
# MAPE: 2.5212%
# RMSE: 1.6000
